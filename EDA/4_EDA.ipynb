# %% [markdown]
# 4 - EDA
# ---
#
# This notebook takes the tweet and user results gathered from the Twitter search.
#
#
# - [Setup](#Setup)
#     - [Import libraries](#Import-libraries)
#     - [import data](#import-data)
#     - [Address Null Values](#Address-null-values)
#         -[tweets ](#tweets)
#         -[users](#users)
# - [By Column]
#     - []()
#     - [geo and location](#geo-and-location)
#
# ---

# %% [markdown]
# # Setup

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
import os
import json
import ast
import datetime as dt
import re

from datetime import datetime
from dateutil import tz

#use this to find union of multiple lists
from functools import reduce

#plotting
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import seaborn as sns

#pandas options
pd.options.display.max_columns = 100

plt.style.use('default')

merged_data_path = '../merged_data/'

# %matplotlib inline

# %%
# install traces
import traces

# %% [markdown]
# ### import data

# %%
os.listdir(merged_data_path)
# Out:
# ['merged_tweets.csv',
#  'merged_users.csv',
#  'resampled_tudf_minute_basic.csv',
#  'wordle_games.csv',
#  'wordle_games.pkl']

# %%
#low_memory = False is to deal with mixed column types. check these
tweets = pd.read_csv(merged_data_path + 'merged_tweets.csv', low_memory = False)
users = pd.read_csv(merged_data_path + 'merged_users.csv', low_memory = False)

# %%
tweets.set_index('id', inplace = True)
tweets.head(3)
# Out:
#                          conversation_id reply_settings lang  \
# id
# 1521733018293084160  1521733018293084160       everyone   en
# 1521733015738662913  1521733015738662913       everyone   es
# 1521733011414257664  1521733011414257664       everyone   en
#
#                                                               entities  \
# id
# 1521733018293084160  {'urls': [{'start': 54, 'end': 77, 'url': 'htt...
# 1521733015738662913  {'urls': [{'start': 58, 'end': 81, 'url': 'htt...
# 1521733011414257664                                                NaN
#
#                      possibly_sensitive               source  \
# id
# 1521733018293084160               False      Twitter Web App
# 1521733015738662913               False  Twitter for Android
# 1521733011414257664               False  Twitter for Android
#
#                                                         public_metrics  \
# id
# 1521733018293084160  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521733015738662913  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521733011414257664  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
#                                                                   text  \
# id
# 1521733018293084160  Wordle (ES)  #118 5/6\r\n\r\n⬜⬜🟨🟩⬜\r\n⬜⬜🟨🟩⬜\r\...
# 1521733015738662913  Wordle Científico #52 5/6\r\n\r\n⬜⬜⬜⬜🟨\r\n🟨⬜⬜⬜...
# 1521733011414257664  Wordle 319 4/6\r\n\r\n🟨🟨⬜⬜⬜\r\n🟨⬜⬜🟩⬜\r\n🟩🟨⬜🟩🟨\...
#
#                                                    context_annotations  \
# id
# 1521733018293084160  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521733015738662913  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521733011414257664  [{'domain': {'id': '30', 'name': 'Entities [En...
#
#                                author_id                 created_at  \
# id
# 1521733018293084160  1006110502043471872  2022-05-04 06:06:38+00:00
# 1521733015738662913            360002014  2022-05-04 06:06:38+00:00
# 1521733011414257664   828818052892422148  2022-05-04 06:06:37+00:00
#
#                     referenced_tweets  in_reply_to_user_id attachments  geo  \
# id
# 1521733018293084160               NaN                  NaN         NaN  NaN
# 1521733015738662913               NaN                  NaN         NaN  NaN
# 1521733011414257664               NaN                  NaN         NaN  NaN
#
#                     withheld
# id
# 1521733018293084160      NaN
# 1521733015738662913      NaN
# 1521733011414257664      NaN

# %%
#set the user index to the unique user id.
users.set_index('id', inplace = True)
# when it comes to drop_duplicates, any NaNs are not considered duplicate values.
# any repeated rows with NaNs must be dealt with.
users.drop_duplicates(inplace=True)
users.head(3)
# Out:
#                                  name  \
# id
# 1006110502043471872      Jose Antonio
# 360002014                Ana V Garcia
# 828818052892422144   Braden Van't Hof
#
#                                                         public_metrics  \
# id
# 1006110502043471872  {'followers_count': 147, 'following_count': 43...
# 360002014            {'followers_count': 41, 'following_count': 136...
# 828818052892422144   {'followers_count': 8, 'following_count': 282,...
#
#                                          url  \
# id
# 1006110502043471872                      NaN
# 360002014            https://t.co/uMfikCmd0I
# 828818052892422144                       NaN
#
#                                                            description  \
# id
# 1006110502043471872  Antiguo usuario bloqueado por error, pero he v...
# 360002014                                                          NaN
# 828818052892422144   LoL Head Coach/Manager/Mid Laner/4x Positional...
#
#                                                      profile_image_url  \
# id
# 1006110502043471872  https://pbs.twimg.com/profile_images/144681186...
# 360002014            https://pbs.twimg.com/profile_images/122215871...
# 828818052892422144   https://pbs.twimg.com/profile_images/149527273...
#
#                                       location  protected      username  \
# id
# 1006110502043471872  Alcalá de Guadaíra, Spain      False    Joseamj_97
# 360002014                    Alcalá de Henares      False   AnaVGarciaG
# 828818052892422144            Grand Rapids, MI      False  CLVRockmelon
#
#                      verified  \
# id
# 1006110502043471872     False
# 360002014               False
# 828818052892422144      False
#
#                                                               entities  \
# id
# 1006110502043471872                                                NaN
# 360002014            {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 828818052892422144                                                 NaN
#
#                      pinned_tweet_id withheld
# id
# 1006110502043471872              NaN      NaN
# 360002014                        NaN      NaN
# 828818052892422144               NaN      NaN

# %%
#I want to left-merge onto tweets. Each tweet has user info tacked on. some users will be repeated.
len(tweets), len(users)
# Out:
# (335327, 147313)

# %% [markdown]
# ## Address null values

# %% [markdown]
# ### tweets

# %%
#pick out tweets columns with any null values
tweets.loc[:, tweets.isna().any()].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 335327 entries, 1521733018293084160 to 1521994876677672966
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   entities             107512 non-null  object
#  1   context_annotations  331475 non-null  object
#  2   referenced_tweets    35202 non-null   object
#  3   in_reply_to_user_id  32555 non-null   float64
#  4   attachments          4130 non-null    object
#  5   geo                  5333 non-null    object
#  6   withheld             4 non-null       object
# dtypes: float64(1), object(6)
# memory usage: 20.5+ MB

# %%
tweets.loc[:, tweets.isna().any()].head(4)
# Out:
#                                                               entities  \
# id
# 1521733018293084160  {'urls': [{'start': 54, 'end': 77, 'url': 'htt...
# 1521733015738662913  {'urls': [{'start': 58, 'end': 81, 'url': 'htt...
# 1521733011414257664                                                NaN
# 1521733010504445954                                                NaN
#
#                                                    context_annotations  \
# id
# 1521733018293084160  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521733015738662913  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521733011414257664  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521733010504445954  [{'domain': {'id': '30', 'name': 'Entities [En...
#
#                     referenced_tweets  in_reply_to_user_id attachments  geo  \
# id
# 1521733018293084160               NaN                  NaN         NaN  NaN
# 1521733015738662913               NaN                  NaN         NaN  NaN
# 1521733011414257664               NaN                  NaN         NaN  NaN
# 1521733010504445954               NaN                  NaN         NaN  NaN
#
#                     withheld
# id
# 1521733018293084160      NaN
# 1521733015738662913      NaN
# 1521733011414257664      NaN
# 1521733010504445954      NaN

# %%
#show some non-NaN `referenced_tweets`
tweets[[ not tweet for tweet in tweets['referenced_tweets'].isna()]].head(4)
# Out:
#                          conversation_id reply_settings lang  \
# id
# 1521733001981444096  1521731925559418880       everyone   en
# 1521732989977305088  1493048111366877185       everyone   en
# 1521732967764140032  1495295658353315840       everyone   th
# 1521732951439945728  1510513887988264964       everyone   en
#
#                                                               entities  \
# id
# 1521733001981444096  {'mentions': [{'start': 0, 'end': 12, 'usernam...
# 1521732989977305088  {'mentions': [{'start': 0, 'end': 16, 'usernam...
# 1521732967764140032  {'urls': [{'start': 43, 'end': 66, 'url': 'htt...
# 1521732951439945728                                                NaN
#
#                      possibly_sensitive               source  \
# id
# 1521733001981444096               False   Twitter for iPhone
# 1521732989977305088               False      Twitter Web App
# 1521732967764140032               False  Twitter for Android
# 1521732951439945728               False      Twitter Web App
#
#                                                         public_metrics  \
# id
# 1521733001981444096  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521732989977305088  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521732967764140032  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521732951439945728  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
#                                                                   text  \
# id
# 1521733001981444096  @RwellsWells Same. Are we both spotters? Haha ...
# 1521732989977305088  @misfortunateApe @SamuelAlpha77 @1kisfud @SumP...
# 1521732967764140032  เวิร์ดเดล 98 4/6\r\n\r\n🟩⬜🟨🟨⬜\r\n🟩🟨⬜🟩⬜\r\n🟩⬜⬜⬜...
# 1521732951439945728  Wordle 319 4/6\r\n\r\n⬜🟩⬜🟨⬜\r\n⬜🟩🟩🟩🟩\r\n⬜🟩🟩🟩🟩\...
#
#                                                    context_annotations  \
# id
# 1521733001981444096  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521732989977305088  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521732967764140032                                                NaN
# 1521732951439945728  [{'domain': {'id': '30', 'name': 'Entities [En...
#
#                               author_id                 created_at  \
# id
# 1521733001981444096            53116513  2022-05-04 06:06:34+00:00
# 1521732989977305088  866231099135070208  2022-05-04 06:06:31+00:00
# 1521732967764140032  946067305879842819  2022-05-04 06:06:26+00:00
# 1521732951439945728  904515648327442433  2022-05-04 06:06:22+00:00
#
#                                                      referenced_tweets  \
# id
# 1521733001981444096  [{'type': 'replied_to', 'id': '152173192555941...
# 1521732989977305088  [{'type': 'replied_to', 'id': '152168705041154...
# 1521732967764140032  [{'type': 'replied_to', 'id': '152081469439032...
# 1521732951439945728  [{'type': 'replied_to', 'id': '152139649722441...
#
#                      in_reply_to_user_id attachments  geo withheld
# id
# 1521733001981444096         3.316225e+08         NaN  NaN      NaN
# 1521732989977305088         1.275839e+18         NaN  NaN      NaN
# 1521732967764140032         9.460673e+17         NaN  NaN      NaN
# 1521732951439945728         9.045156e+17         NaN  NaN      NaN

# %%
#show some non-NaN `attachments`
tweets[[ not tweet for tweet in tweets['attachments'].isna()]].head(4)
# Out:
#                          conversation_id reply_settings lang  \
# id
# 1521732559331282951  1521732559331282951       everyone   en
# 1521732521775534081  1521731955376762880       everyone   es
# 1521731301337878528  1521731301337878528       everyone   en
# 1521730995371724800  1521730995371724800       everyone   en
#
#                                                               entities  \
# id
# 1521732559331282951  {'urls': [{'start': 28, 'end': 51, 'url': 'htt...
# 1521732521775534081  {'urls': [{'start': 54, 'end': 77, 'url': 'htt...
# 1521731301337878528  {'urls': [{'start': 34, 'end': 57, 'url': 'htt...
# 1521730995371724800  {'urls': [{'start': 41, 'end': 64, 'url': 'htt...
#
#                      possibly_sensitive               source  \
# id
# 1521732559331282951               False  Twitter for Android
# 1521732521775534081               False  Twitter for Android
# 1521731301337878528               False  Twitter for Android
# 1521730995371724800               False   Twitter for iPhone
#
#                                                         public_metrics  \
# id
# 1521732559331282951  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521732521775534081  {'retweet_count': 0, 'reply_count': 1, 'like_c...
# 1521731301337878528  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521730995371724800  {'retweet_count': 0, 'reply_count': 1, 'like_c...
#
#                                                                   text  \
# id
# 1521732559331282951  Wordle 319 2/6\r\n\r\n⬛🟩⬛🟨⬛\r\n🟩🟩🟩🟩🟩 https://t...
# 1521732521775534081  @itsbroWken Wordle (ES)  #118 3/6\r\n\r\n🟨⬜🟨🟨⬜...
# 1521731301337878528  Wordle 319 3/6\r\n\r\n🟨⬜⬜🟩⬜\r\n⬜🟨🟩🟩🟨\r\n🟩🟩🟩🟩🟩 ...
# 1521730995371724800  Wordle 318 4/6*\r\n\r\n⬛⬛🟩⬛⬛\r\n⬛⬛🟩⬛⬛\r\n⬛🟨🟩⬛⬛...
#
#                                                    context_annotations  \
# id
# 1521732559331282951  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521732521775534081  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521731301337878528  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521730995371724800  [{'domain': {'id': '30', 'name': 'Entities [En...
#
#                               author_id                 created_at  \
# id
# 1521732559331282951           371437967  2022-05-04 06:04:49+00:00
# 1521732521775534081  887430842980675588  2022-05-04 06:04:40+00:00
# 1521731301337878528           303183839  2022-05-04 05:59:49+00:00
# 1521730995371724800          2849167760  2022-05-04 05:58:36+00:00
#
#                                                      referenced_tweets  \
# id
# 1521732559331282951                                                NaN
# 1521732521775534081  [{'type': 'replied_to', 'id': '152173195537676...
# 1521731301337878528                                                NaN
# 1521730995371724800                                                NaN
#
#                      in_reply_to_user_id  \
# id
# 1521732559331282951                  NaN
# 1521732521775534081         1.291470e+18
# 1521731301337878528                  NaN
# 1521730995371724800                  NaN
#
#                                                     attachments  geo withheld
# id
# 1521732559331282951  {'media_keys': ['16_1521732551106310145']}  NaN      NaN
# 1521732521775534081  {'media_keys': ['16_1521732511805714432']}  NaN      NaN
# 1521731301337878528  {'media_keys': ['16_1521731293393960960']}  NaN      NaN
# 1521730995371724800   {'media_keys': ['3_1521730992079130624']}  NaN      NaN

# %%
#show some non-NaN `geo`
tweets[[ not tweet for tweet in tweets['geo'].isna()]].head(4)
# Out:
#                          conversation_id reply_settings lang  \
# id
# 1521732543334211586  1521732543334211586       everyone   en
# 1521732291222925312  1521732291222925312       everyone   en
# 1521731264428003332  1521731264428003332       everyone   en
# 1521731243641118722  1521731243641118722       everyone   tr
#
#                                                               entities  \
# id
# 1521732543334211586  {'urls': [{'start': 42, 'end': 65, 'url': 'htt...
# 1521732291222925312                                                NaN
# 1521731264428003332                                                NaN
# 1521731243641118722  {'urls': [{'start': 67, 'end': 90, 'url': 'htt...
#
#                      possibly_sensitive               source  \
# id
# 1521732543334211586               False   Twitter for iPhone
# 1521732291222925312               False  Twitter for Android
# 1521731264428003332               False  Twitter for Android
# 1521731243641118722               False  Twitter for Android
#
#                                                         public_metrics  \
# id
# 1521732543334211586  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521732291222925312  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521731264428003332  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521731243641118722  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
#                                                                   text  \
# id
# 1521732543334211586  Wordle (ES)  #118 3/6\r\n\r\n⬜⬜🟨🟩🟩\r\n⬜🟩⬜🟩🟩\r\...
# 1521732291222925312  Phew!  \r\n\r\nWordle 259 6/6\r\n\r\n⬜🟩⬜⬜🟩\r\n...
# 1521731264428003332               Wordle 319 2/6\r\n\r\n🟨⬛🟩⬛🟨\r\n🟩🟩🟩🟩🟩
# 1521731243641118722  Ehh bence 🙄\r\nWordle Türkçe 319 5/6*\r\n\r\n⬜...
#
#                                                    context_annotations  \
# id
# 1521732543334211586  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521732291222925312  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521731264428003332  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521731243641118722  [{'domain': {'id': '30', 'name': 'Entities [En...
#
#                      author_id                 created_at referenced_tweets  \
# id
# 1521732543334211586  304032557  2022-05-04 06:04:45+00:00               NaN
# 1521732291222925312   18830193  2022-05-04 06:03:45+00:00               NaN
# 1521731264428003332   55833883  2022-05-04 05:59:40+00:00               NaN
# 1521731243641118722   45346113  2022-05-04 05:59:35+00:00               NaN
#
#                      in_reply_to_user_id attachments  \
# id
# 1521732543334211586                  NaN         NaN
# 1521732291222925312                  NaN         NaN
# 1521731264428003332                  NaN         NaN
# 1521731243641118722                  NaN         NaN
#
#                                                   geo withheld
# id
# 1521732543334211586  {'place_id': '206c436ce43a43a3'}      NaN
# 1521732291222925312  {'place_id': '173c2bb9d42baaa5'}      NaN
# 1521731264428003332  {'place_id': '5c0761bdffa0cb64'}      NaN
# 1521731243641118722  {'place_id': '57d9f7248731be9a'}      NaN

# %%
#show some non-NaN `withheld`
tweets[[ not tweet for tweet in tweets['withheld'].isna()]].head(4)
# Out:
#                          conversation_id reply_settings lang  \
# id
# 1521425660459290624  1521425660459290624       everyone   en
# 1521097766205861889  1521097766205861889       everyone   en
# 1520760168279072774  1520760168279072774       everyone   en
# 1520348164930351104  1520348164930351104       everyone   en
#
#                                                               entities  \
# id
# 1521425660459290624  {'hashtags': [{'start': 47, 'end': 57, 'tag': ...
# 1521097766205861889  {'hashtags': [{'start': 47, 'end': 57, 'tag': ...
# 1520760168279072774  {'hashtags': [{'start': 41, 'end': 51, 'tag': ...
# 1520348164930351104  {'hashtags': [{'start': 35, 'end': 45, 'tag': ...
#
#                      possibly_sensitive               source  \
# id
# 1521425660459290624               False      Twitter Web App
# 1521097766205861889               False  Twitter for Android
# 1520760168279072774               False      Twitter Web App
# 1520348164930351104               False      Twitter Web App
#
#                                                         public_metrics  \
# id
# 1521425660459290624  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521097766205861889  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1520760168279072774  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1520348164930351104  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
#                                                                   text  \
# id
# 1521425660459290624  Wordle 318 5/6\r\n\r\n⬛🟩⬛⬛⬛\r\n⬛🟩🟨⬛⬛\r\n🟨🟩⬛🟨⬛\...
# 1521097766205861889  Wordle 317 5/6\n\n🟩⬛⬛⬛🟨\n🟩⬛🟩⬛🟨\n🟩🟩🟩⬛⬛\n🟩🟩🟩🟩⬛\n...
# 1520760168279072774  Wordle 316 4/6\n\n⬛⬛⬛⬛⬛\n⬛🟩⬛⬛⬛\n🟨🟩⬛⬛⬛\n🟩🟩🟩🟩🟩\n...
# 1520348164930351104  Wordle 315 3/6\n\n⬛🟩🟨⬛⬛\n⬛🟩⬛🟨🟨\n🟩🟩🟩🟩🟩\n\n#Word...
#
#                                                    context_annotations  \
# id
# 1521425660459290624  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521097766205861889  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1520760168279072774  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1520348164930351104  [{'domain': {'id': '30', 'name': 'Entities [En...
#
#                      author_id                 created_at referenced_tweets  \
# id
# 1521425660459290624    5663832  2022-05-03 09:45:18+00:00               NaN
# 1521097766205861889    5663832  2022-05-02 12:02:22+00:00               NaN
# 1520760168279072774    5663832  2022-05-01 13:40:53+00:00               NaN
# 1520348164930351104    5663832  2022-04-30 10:23:43+00:00               NaN
#
#                      in_reply_to_user_id attachments  geo  \
# id
# 1521425660459290624                  NaN         NaN  NaN
# 1521097766205861889                  NaN         NaN  NaN
# 1520760168279072774                  NaN         NaN  NaN
# 1520348164930351104                  NaN         NaN  NaN
#
#                                                           withheld
# id
# 1521425660459290624  {'copyright': False, 'country_codes': ['IN']}
# 1521097766205861889  {'copyright': False, 'country_codes': ['IN']}
# 1520760168279072774  {'copyright': False, 'country_codes': ['IN']}
# 1520348164930351104  {'copyright': False, 'country_codes': ['IN']}

# %% [markdown]
# Columns with nulls in tweets are:
#
# - `entities`
#     these are all fake-json. Formatted with single quotes instead of doubles. "json-like"
# - `context_annotations`
#     list of json-likes.
# - `referenced_tweets`
#     list of json-likes
# - `in_reply_to_user_id`
#     integers of user ids if the tweet is a reply. replace with 0.
# - `attachments`
#     json-like
# - `geo`
#     json-like
# - `withheld`
#     json-like.
#
#
# Nulls should be filled with the same type.
#
# Json-likes should be empty string JSONs: '{}'
#
# Lists of json-likes should be empty lists: '[]'
#
# the integer `in_reply...` replace with integer 0.

# %%
# do all these NaN replacements.
json_likes = ['entities', 'attachments', 'geo', 'withheld']
lists_of_json_likes = ['context_annotations','referenced_tweets']

tweets[json_likes] = tweets[json_likes].fillna('{}')
tweets[lists_of_json_likes] = tweets[lists_of_json_likes].fillna('[]')
tweets['in_reply_to_user_id'].fillna(0, inplace=True)
tweets.head(5)
# Out:
#                          conversation_id reply_settings lang  \
# id
# 1521733018293084160  1521733018293084160       everyone   en
# 1521733015738662913  1521733015738662913       everyone   es
# 1521733011414257664  1521733011414257664       everyone   en
# 1521733010504445954  1521733010504445954       everyone   en
# 1521733001981444096  1521731925559418880       everyone   en
#
#                                                               entities  \
# id
# 1521733018293084160  {'urls': [{'start': 54, 'end': 77, 'url': 'htt...
# 1521733015738662913  {'urls': [{'start': 58, 'end': 81, 'url': 'htt...
# 1521733011414257664                                                 {}
# 1521733010504445954                                                 {}
# 1521733001981444096  {'mentions': [{'start': 0, 'end': 12, 'usernam...
#
#                      possibly_sensitive               source  \
# id
# 1521733018293084160               False      Twitter Web App
# 1521733015738662913               False  Twitter for Android
# 1521733011414257664               False  Twitter for Android
# 1521733010504445954               False  Twitter for Android
# 1521733001981444096               False   Twitter for iPhone
#
#                                                         public_metrics  \
# id
# 1521733018293084160  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521733015738662913  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521733011414257664  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521733010504445954  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521733001981444096  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
#                                                                   text  \
# id
# 1521733018293084160  Wordle (ES)  #118 5/6\r\n\r\n⬜⬜🟨🟩⬜\r\n⬜⬜🟨🟩⬜\r\...
# 1521733015738662913  Wordle Científico #52 5/6\r\n\r\n⬜⬜⬜⬜🟨\r\n🟨⬜⬜⬜...
# 1521733011414257664  Wordle 319 4/6\r\n\r\n🟨🟨⬜⬜⬜\r\n🟨⬜⬜🟩⬜\r\n🟩🟨⬜🟩🟨\...
# 1521733010504445954  Back in the saddle.\r\n\r\nWordle 319 3/6\r\n\...
# 1521733001981444096  @RwellsWells Same. Are we both spotters? Haha ...
#
#                                                    context_annotations  \
# id
# 1521733018293084160  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521733015738662913  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521733011414257664  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521733010504445954  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521733001981444096  [{'domain': {'id': '30', 'name': 'Entities [En...
#
#                                author_id                 created_at  \
# id
# 1521733018293084160  1006110502043471872  2022-05-04 06:06:38+00:00
# 1521733015738662913            360002014  2022-05-04 06:06:38+00:00
# 1521733011414257664   828818052892422148  2022-05-04 06:06:37+00:00
# 1521733010504445954            862077942  2022-05-04 06:06:36+00:00
# 1521733001981444096             53116513  2022-05-04 06:06:34+00:00
#
#                                                      referenced_tweets  \
# id
# 1521733018293084160                                                 []
# 1521733015738662913                                                 []
# 1521733011414257664                                                 []
# 1521733010504445954                                                 []
# 1521733001981444096  [{'type': 'replied_to', 'id': '152173192555941...
#
#                      in_reply_to_user_id attachments geo withheld
# id
# 1521733018293084160                  0.0          {}  {}       {}
# 1521733015738662913                  0.0          {}  {}       {}
# 1521733011414257664                  0.0          {}  {}       {}
# 1521733010504445954                  0.0          {}  {}       {}
# 1521733001981444096          331622540.0          {}  {}       {}

# %%
#no remaining cells are null.
tweets.isna().sum().sum()
# Out:
# 0

# %%
#none of the tweets are duplicates.
tweets.duplicated().sum()
# Out:
# 0

# %%
tweets.head()
# Out:
#                          conversation_id reply_settings lang  \
# id
# 1521733018293084160  1521733018293084160       everyone   en
# 1521733015738662913  1521733015738662913       everyone   es
# 1521733011414257664  1521733011414257664       everyone   en
# 1521733010504445954  1521733010504445954       everyone   en
# 1521733001981444096  1521731925559418880       everyone   en
#
#                                                               entities  \
# id
# 1521733018293084160  {'urls': [{'start': 54, 'end': 77, 'url': 'htt...
# 1521733015738662913  {'urls': [{'start': 58, 'end': 81, 'url': 'htt...
# 1521733011414257664                                                 {}
# 1521733010504445954                                                 {}
# 1521733001981444096  {'mentions': [{'start': 0, 'end': 12, 'usernam...
#
#                      possibly_sensitive               source  \
# id
# 1521733018293084160               False      Twitter Web App
# 1521733015738662913               False  Twitter for Android
# 1521733011414257664               False  Twitter for Android
# 1521733010504445954               False  Twitter for Android
# 1521733001981444096               False   Twitter for iPhone
#
#                                                         public_metrics  \
# id
# 1521733018293084160  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521733015738662913  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521733011414257664  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521733010504445954  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521733001981444096  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
#                                                                   text  \
# id
# 1521733018293084160  Wordle (ES)  #118 5/6\r\n\r\n⬜⬜🟨🟩⬜\r\n⬜⬜🟨🟩⬜\r\...
# 1521733015738662913  Wordle Científico #52 5/6\r\n\r\n⬜⬜⬜⬜🟨\r\n🟨⬜⬜⬜...
# 1521733011414257664  Wordle 319 4/6\r\n\r\n🟨🟨⬜⬜⬜\r\n🟨⬜⬜🟩⬜\r\n🟩🟨⬜🟩🟨\...
# 1521733010504445954  Back in the saddle.\r\n\r\nWordle 319 3/6\r\n\...
# 1521733001981444096  @RwellsWells Same. Are we both spotters? Haha ...
#
#                                                    context_annotations  \
# id
# 1521733018293084160  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521733015738662913  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521733011414257664  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521733010504445954  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521733001981444096  [{'domain': {'id': '30', 'name': 'Entities [En...
#
#                                author_id                 created_at  \
# id
# 1521733018293084160  1006110502043471872  2022-05-04 06:06:38+00:00
# 1521733015738662913            360002014  2022-05-04 06:06:38+00:00
# 1521733011414257664   828818052892422148  2022-05-04 06:06:37+00:00
# 1521733010504445954            862077942  2022-05-04 06:06:36+00:00
# 1521733001981444096             53116513  2022-05-04 06:06:34+00:00
#
#                                                      referenced_tweets  \
# id
# 1521733018293084160                                                 []
# 1521733015738662913                                                 []
# 1521733011414257664                                                 []
# 1521733010504445954                                                 []
# 1521733001981444096  [{'type': 'replied_to', 'id': '152173192555941...
#
#                      in_reply_to_user_id attachments geo withheld
# id
# 1521733018293084160                  0.0          {}  {}       {}
# 1521733015738662913                  0.0          {}  {}       {}
# 1521733011414257664                  0.0          {}  {}       {}
# 1521733010504445954                  0.0          {}  {}       {}
# 1521733001981444096          331622540.0          {}  {}       {}

# %%
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 335327 entries, 1521733018293084160 to 1521994876677672966
# Data columns (total 16 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   conversation_id      335327 non-null  int64
#  1   reply_settings       335327 non-null  object
#  2   lang                 335327 non-null  object
#  3   entities             335327 non-null  object
#  4   possibly_sensitive   335327 non-null  bool
#  5   source               335327 non-null  object
#  6   public_metrics       335327 non-null  object
#  7   text                 335327 non-null  object
#  8   context_annotations  335327 non-null  object
#  9   author_id            335327 non-null  int64
#  10  created_at           335327 non-null  object
#  11  referenced_tweets    335327 non-null  object
#  12  in_reply_to_user_id  335327 non-null  float64
#  13  attachments          335327 non-null  object
#  14  geo                  335327 non-null  object
#  15  withheld             335327 non-null  object
# dtypes: bool(1), float64(1), int64(2), object(12)
# memory usage: 41.3+ MB

# %% [markdown]
# About 335000 tweets remain after dropping duplicates.

# %% [markdown]
# ### check nans in users

# %%
# look at columns with any nans in users
users.loc[:, users.isna().any()].head()
# Out:
#                                    name                      url  \
# id
# 1006110502043471872        Jose Antonio                      NaN
# 360002014                  Ana V Garcia  https://t.co/uMfikCmd0I
# 828818052892422144     Braden Van't Hof                      NaN
# 862077942                 John Milton ✊  https://t.co/iOfRLxEru5
# 53116513             christopher  jones                      NaN
#
#                                                            description  \
# id
# 1006110502043471872  Antiguo usuario bloqueado por error, pero he v...
# 360002014                                                          NaN
# 828818052892422144   LoL Head Coach/Manager/Mid Laner/4x Positional...
# 862077942            It's not criticism, it's just a different way ...
# 53116513                       I don't like cricket. oh no. i love it!
#
#                                       location  \
# id
# 1006110502043471872  Alcalá de Guadaíra, Spain
# 360002014                    Alcalá de Henares
# 828818052892422144            Grand Rapids, MI
# 862077942                                Spain
# 53116513                             sheffield
#
#                                                               entities  \
# id
# 1006110502043471872                                                NaN
# 360002014            {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 828818052892422144                                                 NaN
# 862077942            {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 53116513                                                           NaN
#
#                      pinned_tweet_id withheld
# id
# 1006110502043471872              NaN      NaN
# 360002014                        NaN      NaN
# 828818052892422144               NaN      NaN
# 862077942                        NaN      NaN
# 53116513                         NaN      NaN

# %%
# look at info for these columns
users.loc[:, users.isna().any()].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 147313 entries, 1006110502043471872 to 233970658
# Data columns (total 7 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   name             147306 non-null  object
#  1   url              44780 non-null   object
#  2   description      129085 non-null  object
#  3   location         105401 non-null  object
#  4   entities         62081 non-null   object
#  5   pinned_tweet_id  68630 non-null   float64
#  6   withheld         1 non-null       object
# dtypes: float64(1), object(6)
# memory usage: 9.0+ MB

# %%
#look at the single "withheld" user.
users[users['withheld'].notnull()]
# Out:
#           name                                     public_metrics  \
# id
# 5663832  Ali 🔥  {'followers_count': 246, 'following_count': 37...
#
#                              url  \
# id
# 5663832  https://t.co/ncsbcZfaw1
#
#                                                description  \
# id
# 5663832  • For the heart and soul of the country • RTs ...
#
#                                          profile_image_url  \
# id
# 5663832  https://pbs.twimg.com/profile_images/135222168...
#
#                        location  protected    username  verified  \
# id
# 5663832  neither here nor there      False  AliAsifPTI     False
#
#                                                   entities  pinned_tweet_id  \
# id
# 5663832  {'url': {'urls': [{'start': 0, 'end': 23, 'url...     7.893531e+17
#
#                           withheld
# id
# 5663832  {'country_codes': ['IN']}

# %% [markdown]
# Columns in users with NaNs:
# - `name`
#     a string. replace with empty string.
# - `url`
#     string
# - `description`
#     string
# - `location`
#     string
# - `entities`
#     json-like
# - `pinned_tweet_id`
#     integer. tweet id.
# - `withheld`
#     it appears a small number of users can be withheld by country, not just tweets.
#     json-like

# %%
#fill missing values in user columns.
json_likes = ['entities', 'withheld']
string_cols = ['name', 'url', 'description', 'location']

users[json_likes] = users[json_likes].fillna('{}')
users[string_cols] = users[string_cols].fillna('')
users['pinned_tweet_id'].fillna(0, inplace = True)
users.head()
# Out:
#                                    name  \
# id
# 1006110502043471872        Jose Antonio
# 360002014                  Ana V Garcia
# 828818052892422144     Braden Van't Hof
# 862077942                 John Milton ✊
# 53116513             christopher  jones
#
#                                                         public_metrics  \
# id
# 1006110502043471872  {'followers_count': 147, 'following_count': 43...
# 360002014            {'followers_count': 41, 'following_count': 136...
# 828818052892422144   {'followers_count': 8, 'following_count': 282,...
# 862077942            {'followers_count': 1465, 'following_count': 2...
# 53116513             {'followers_count': 189, 'following_count': 26...
#
#                                          url  \
# id
# 1006110502043471872
# 360002014            https://t.co/uMfikCmd0I
# 828818052892422144
# 862077942            https://t.co/iOfRLxEru5
# 53116513
#
#                                                            description  \
# id
# 1006110502043471872  Antiguo usuario bloqueado por error, pero he v...
# 360002014
# 828818052892422144   LoL Head Coach/Manager/Mid Laner/4x Positional...
# 862077942            It's not criticism, it's just a different way ...
# 53116513                       I don't like cricket. oh no. i love it!
#
#                                                      profile_image_url  \
# id
# 1006110502043471872  https://pbs.twimg.com/profile_images/144681186...
# 360002014            https://pbs.twimg.com/profile_images/122215871...
# 828818052892422144   https://pbs.twimg.com/profile_images/149527273...
# 862077942            https://pbs.twimg.com/profile_images/150123920...
# 53116513             https://pbs.twimg.com/profile_images/110881711...
#
#                                       location  protected       username  \
# id
# 1006110502043471872  Alcalá de Guadaíra, Spain      False     Joseamj_97
# 360002014                    Alcalá de Henares      False    AnaVGarciaG
# 828818052892422144            Grand Rapids, MI      False   CLVRockmelon
# 862077942                                Spain      False      Geordioca
# 53116513                             sheffield      False  chrisjones792
#
#                      verified  \
# id
# 1006110502043471872     False
# 360002014               False
# 828818052892422144      False
# 862077942               False
# 53116513                False
#
#                                                               entities  \
# id
# 1006110502043471872                                                 {}
# 360002014            {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 828818052892422144                                                  {}
# 862077942            {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 53116513                                                            {}
#
#                      pinned_tweet_id withheld
# id
# 1006110502043471872              0.0       {}
# 360002014                        0.0       {}
# 828818052892422144               0.0       {}
# 862077942                        0.0       {}
# 53116513                         0.0       {}

# %%
#no remaining cells are null.
users.isna().sum().sum()
# Out:
# 0

# %%
#no user rows are found with .duplicated()
users.duplicated().sum()
# Out:
# 0

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 147313 entries, 1006110502043471872 to 233970658
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   name               147313 non-null  object
#  1   public_metrics     147313 non-null  object
#  2   url                147313 non-null  object
#  3   description        147313 non-null  object
#  4   profile_image_url  147313 non-null  object
#  5   location           147313 non-null  object
#  6   protected          147313 non-null  bool
#  7   username           147313 non-null  object
#  8   verified           147313 non-null  bool
#  9   entities           147313 non-null  object
#  10  pinned_tweet_id    147313 non-null  float64
#  11  withheld           147313 non-null  object
# dtypes: bool(2), float64(1), object(9)
# memory usage: 12.6+ MB

# %%
pd.DataFrame(users.index)['id'].astype(str)
# Out:
# 0         1006110502043471872
# 1                   360002014
# 2          828818052892422144
# 3                   862077942
# 4                    53116513
#                  ...
# 147308               17114791
# 147309               48706026
# 147310             2921974090
# 147311              546752134
# 147312              233970658
# Name: id, Length: 147313, dtype: object

# %% [markdown]
# ### merge tweets and users on tweet id into a master dataframe

# %%
tweets['author_id'].astype(np.int64)
# Out:
# id
# 1521733018293084160    1006110502043471872
# 1521733015738662913              360002014
# 1521733011414257664     828818052892422148
# 1521733010504445954              862077942
# 1521733001981444096               53116513
#                               ...
# 1521994904523706368              939561834
# 1521994898974588929              626288465
# 1521994886941413376    1348171206910873600
# 1521994883032039424              592259279
# 1521994876677672966              125443746
# Name: author_id, Length: 335327, dtype: int64

# %%
#check if any user ids from the users dataframe aren't actually in the tweets author_id list
int64authid = tweets['author_id'].astype(np.int64)
pd.DataFrame(users.index)['id'].astype(np.int64).apply(lambda x: x in int64authid).sum()
# Out:
# 0

# %%
users.index[0].astype(np.int64) in tweets['author_id'].astype(np.int64)
# Out:
# False

# %%
users.loc[862077942]
# Out:
# name                                                     John Milton ✊
# public_metrics       {'followers_count': 1465, 'following_count': 2...
# url                                            https://t.co/iOfRLxEru5
# description          It's not criticism, it's just a different way ...
# profile_image_url    https://pbs.twimg.com/profile_images/150123920...
# location                                                         Spain
# protected                                                        False
# username                                                     Geordioca
# verified                                                         False
# entities             {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# pinned_tweet_id                                                    0.0
# withheld                                                            {}
# Name: 862077942, dtype: object

# %%
users.loc[360002014]
# Out:
# name                                                      Ana V Garcia
# public_metrics       {'followers_count': 41, 'following_count': 136...
# url                                            https://t.co/uMfikCmd0I
# description
# profile_image_url    https://pbs.twimg.com/profile_images/122215871...
# location                                             Alcalá de Henares
# protected                                                        False
# username                                                   AnaVGarciaG
# verified                                                         False
# entities             {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# pinned_tweet_id                                                    0.0
# withheld                                                            {}
# Name: 360002014, dtype: object

# %%
tweets['author_id']
# Out:
# id
# 1521733018293084160    1006110502043471872
# 1521733015738662913              360002014
# 1521733011414257664     828818052892422148
# 1521733010504445954              862077942
# 1521733001981444096               53116513
#                               ...
# 1521994904523706368              939561834
# 1521994898974588929              626288465
# 1521994886941413376    1348171206910873600
# 1521994883032039424              592259279
# 1521994876677672966              125443746
# Name: author_id, Length: 335327, dtype: int64

# %%
tweets[tweets['author_id'] > 999999999]['author_id'].hist()
# Out:
# <AxesSubplot:>

# %%
#the merged df should have as many records as tweets.

#copy tweet index
tweets['id_tweets_copy'] = tweets.index
#check that no
assert(tweets['id_tweets_copy'].isna().sum() == 0)
tudf = pd.merge(tweets, users, how = 'left', left_on = 'author_id', right_on = 'id', suffixes = ('_tweet', '_user') )
tudf.fillna(0, inplace = True)
tudf.drop_duplicates(subset = 'id_tweets_copy', inplace = True)
tudf.set_index('id_tweets_copy', inplace=True)
tudf.index.rename('tweet_id', inplace = True)
tudf.head()
# Out:
#                          conversation_id reply_settings lang  \
# tweet_id
# 1521733018293084160  1521733018293084160       everyone   en
# 1521733015738662913  1521733015738662913       everyone   es
# 1521733011414257664  1521733011414257664       everyone   en
# 1521733010504445954  1521733010504445954       everyone   en
# 1521733001981444096  1521731925559418880       everyone   en
#
#                                                         entities_tweet  \
# tweet_id
# 1521733018293084160  {'urls': [{'start': 54, 'end': 77, 'url': 'htt...
# 1521733015738662913  {'urls': [{'start': 58, 'end': 81, 'url': 'htt...
# 1521733011414257664                                                 {}
# 1521733010504445954                                                 {}
# 1521733001981444096  {'mentions': [{'start': 0, 'end': 12, 'usernam...
#
#                      possibly_sensitive               source  \
# tweet_id
# 1521733018293084160               False      Twitter Web App
# 1521733015738662913               False  Twitter for Android
# 1521733011414257664               False  Twitter for Android
# 1521733010504445954               False  Twitter for Android
# 1521733001981444096               False   Twitter for iPhone
#
#                                                   public_metrics_tweet  \
# tweet_id
# 1521733018293084160  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521733015738662913  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521733011414257664  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521733010504445954  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521733001981444096  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
#                                                                   text  \
# tweet_id
# 1521733018293084160  Wordle (ES)  #118 5/6\r\n\r\n⬜⬜🟨🟩⬜\r\n⬜⬜🟨🟩⬜\r\...
# 1521733015738662913  Wordle Científico #52 5/6\r\n\r\n⬜⬜⬜⬜🟨\r\n🟨⬜⬜⬜...
# 1521733011414257664  Wordle 319 4/6\r\n\r\n🟨🟨⬜⬜⬜\r\n🟨⬜⬜🟩⬜\r\n🟩🟨⬜🟩🟨\...
# 1521733010504445954  Back in the saddle.\r\n\r\nWordle 319 3/6\r\n\...
# 1521733001981444096  @RwellsWells Same. Are we both spotters? Haha ...
#
#                                                    context_annotations  \
# tweet_id
# 1521733018293084160  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521733015738662913  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521733011414257664  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521733010504445954  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521733001981444096  [{'domain': {'id': '30', 'name': 'Entities [En...
#
#                                author_id                 created_at  \
# tweet_id
# 1521733018293084160  1006110502043471872  2022-05-04 06:06:38+00:00
# 1521733015738662913            360002014  2022-05-04 06:06:38+00:00
# 1521733011414257664   828818052892422148  2022-05-04 06:06:37+00:00
# 1521733010504445954            862077942  2022-05-04 06:06:36+00:00
# 1521733001981444096             53116513  2022-05-04 06:06:34+00:00
#
#                                                      referenced_tweets  \
# tweet_id
# 1521733018293084160                                                 []
# 1521733015738662913                                                 []
# 1521733011414257664                                                 []
# 1521733010504445954                                                 []
# 1521733001981444096  [{'type': 'replied_to', 'id': '152173192555941...
#
#                      in_reply_to_user_id attachments geo withheld_tweet  \
# tweet_id
# 1521733018293084160                  0.0          {}  {}             {}
# 1521733015738662913                  0.0          {}  {}             {}
# 1521733011414257664                  0.0          {}  {}             {}
# 1521733010504445954                  0.0          {}  {}             {}
# 1521733001981444096          331622540.0          {}  {}             {}
#
#                                    name  \
# tweet_id
# 1521733018293084160        Jose Antonio
# 1521733015738662913        Ana V Garcia
# 1521733011414257664                   0
# 1521733010504445954       John Milton ✊
# 1521733001981444096  christopher  jones
#
#                                                    public_metrics_user  \
# tweet_id
# 1521733018293084160  {'followers_count': 147, 'following_count': 43...
# 1521733015738662913  {'followers_count': 41, 'following_count': 136...
# 1521733011414257664                                                  0
# 1521733010504445954  {'followers_count': 1465, 'following_count': 2...
# 1521733001981444096  {'followers_count': 189, 'following_count': 26...
#
#                                          url  \
# tweet_id
# 1521733018293084160
# 1521733015738662913  https://t.co/uMfikCmd0I
# 1521733011414257664                        0
# 1521733010504445954  https://t.co/iOfRLxEru5
# 1521733001981444096
#
#                                                            description  \
# tweet_id
# 1521733018293084160  Antiguo usuario bloqueado por error, pero he v...
# 1521733015738662913
# 1521733011414257664                                                  0
# 1521733010504445954  It's not criticism, it's just a different way ...
# 1521733001981444096            I don't like cricket. oh no. i love it!
#
#                                                      profile_image_url  \
# tweet_id
# 1521733018293084160  https://pbs.twimg.com/profile_images/144681186...
# 1521733015738662913  https://pbs.twimg.com/profile_images/122215871...
# 1521733011414257664                                                  0
# 1521733010504445954  https://pbs.twimg.com/profile_images/150123920...
# 1521733001981444096  https://pbs.twimg.com/profile_images/110881711...
#
#                                       location protected       username  \
# tweet_id
# 1521733018293084160  Alcalá de Guadaíra, Spain     False     Joseamj_97
# 1521733015738662913          Alcalá de Henares     False    AnaVGarciaG
# 1521733011414257664                          0         0              0
# 1521733010504445954                      Spain     False      Geordioca
# 1521733001981444096                  sheffield     False  chrisjones792
#
#                     verified  \
# tweet_id
# 1521733018293084160    False
# 1521733015738662913    False
# 1521733011414257664        0
# 1521733010504445954    False
# 1521733001981444096    False
#
#                                                          entities_user  \
# tweet_id
# 1521733018293084160                                                 {}
# 1521733015738662913  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1521733011414257664                                                  0
# 1521733010504445954  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1521733001981444096                                                 {}
#
#                      pinned_tweet_id withheld_user
# tweet_id
# 1521733018293084160              0.0            {}
# 1521733015738662913              0.0            {}
# 1521733011414257664              0.0             0
# 1521733010504445954              0.0            {}
# 1521733001981444096              0.0            {}

# %%
#no duplicate indices
tudf[tudf.index.duplicated()]
# Out:
# Empty DataFrame
# Columns: [conversation_id, reply_settings, lang, entities_tweet, possibly_sensitive, source, public_metrics_tweet, text, context_annotations, author_id, created_at, referenced_tweets, in_reply_to_user_id, attachments, geo, withheld_tweet, name, public_metrics_user, url, description, profile_image_url, location, protected, username, verified, entities_user, pinned_tweet_id, withheld_user]
# Index: []

# %%
#no duplicate data
tudf[tudf.duplicated()]
# Out:
# Empty DataFrame
# Columns: [conversation_id, reply_settings, lang, entities_tweet, possibly_sensitive, source, public_metrics_tweet, text, context_annotations, author_id, created_at, referenced_tweets, in_reply_to_user_id, attachments, geo, withheld_tweet, name, public_metrics_user, url, description, profile_image_url, location, protected, username, verified, entities_user, pinned_tweet_id, withheld_user]
# Index: []

# %%
#look at info for new merged dataframe.
tudf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 335327 entries, 1521733018293084160 to 1521994876677672966
# Data columns (total 28 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   conversation_id       335327 non-null  int64
#  1   reply_settings        335327 non-null  object
#  2   lang                  335327 non-null  object
#  3   entities_tweet        335327 non-null  object
#  4   possibly_sensitive    335327 non-null  bool
#  5   source                335327 non-null  object
#  6   public_metrics_tweet  335327 non-null  object
#  7   text                  335327 non-null  object
#  8   context_annotations   335327 non-null  object
#  9   author_id             335327 non-null  int64
#  10  created_at            335327 non-null  object
#  11  referenced_tweets     335327 non-null  object
#  12  in_reply_to_user_id   335327 non-null  float64
#  13  attachments           335327 non-null  object
#  14  geo                   335327 non-null  object
#  15  withheld_tweet        335327 non-null  object
#  16  name                  335327 non-null  object
#  17  public_metrics_user   335327 non-null  object
#  18  url                   335327 non-null  object
#  19  description           335327 non-null  object
#  20  profile_image_url     335327 non-null  object
#  21  location              335327 non-null  object
#  22  protected             335327 non-null  object
#  23  username              335327 non-null  object
#  24  verified              335327 non-null  object
#  25  entities_user         335327 non-null  object
#  26  pinned_tweet_id       335327 non-null  float64
#  27  withheld_user         335327 non-null  object
# dtypes: bool(1), float64(2), int64(2), object(23)
# memory usage: 80.0+ MB

# %%
# a large number of these do not have usernames. These seem to be those for very large author_ids.
tudf[tudf['username'] == 0]
# Out:
#                          conversation_id reply_settings lang  \
# tweet_id
# 1521733011414257664  1521733011414257664       everyone   en
# 1521732967764140032  1495295658353315840       everyone   th
# 1521732951439945728  1510513887988264964       everyone   en
# 1521732892392534016  1521732892392534016       everyone   ko
# 1521732887770456065  1521732885782347776       everyone   fr
# ...                                  ...            ...  ...
# 1521995141334114305  1521988433408929795       everyone   en
# 1521995093204475906  1521995093204475906       everyone   en
# 1521995088444162048  1521995088444162048       everyone   ja
# 1521994934793818112  1521886654075707395       everyone   en
# 1521994919094763520  1521994919094763520       everyone   en
#
#                                                         entities_tweet  \
# tweet_id
# 1521733011414257664                                                 {}
# 1521732967764140032  {'urls': [{'start': 43, 'end': 66, 'url': 'htt...
# 1521732951439945728                                                 {}
# 1521732892392534016  {'urls': [{'start': 11, 'end': 34, 'url': 'htt...
# 1521732887770456065  {'urls': [{'start': 54, 'end': 77, 'url': 'htt...
# ...                                                                ...
# 1521995141334114305  {'mentions': [{'start': 0, 'end': 10, 'usernam...
# 1521995093204475906                                                 {}
# 1521995088444162048  {'urls': [{'start': 55, 'end': 78, 'url': 'htt...
# 1521994934793818112  {'urls': [{'start': 46, 'end': 69, 'url': 'htt...
# 1521994919094763520                                                 {}
#
#                      possibly_sensitive               source  \
# tweet_id
# 1521733011414257664               False  Twitter for Android
# 1521732967764140032               False  Twitter for Android
# 1521732951439945728               False      Twitter Web App
# 1521732892392534016               False  Twitter for Android
# 1521732887770456065               False      Twitter Web App
# ...                                 ...                  ...
# 1521995141334114305               False   Twitter for iPhone
# 1521995093204475906               False   Twitter for iPhone
# 1521995088444162048               False   Twitter for iPhone
# 1521994934793818112               False   Twitter for iPhone
# 1521994919094763520               False      Twitter Web App
#
#                                                   public_metrics_tweet  \
# tweet_id
# 1521733011414257664  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521732967764140032  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521732951439945728  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521732892392534016  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521732887770456065  {'retweet_count': 0, 'reply_count': 1, 'like_c...
# ...                                                                ...
# 1521995141334114305  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521995093204475906  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521995088444162048  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521994934793818112  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521994919094763520  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
#                                                                   text  \
# tweet_id
# 1521733011414257664  Wordle 319 4/6\r\n\r\n🟨🟨⬜⬜⬜\r\n🟨⬜⬜🟩⬜\r\n🟩🟨⬜🟩🟨\...
# 1521732967764140032  เวิร์ดเดล 98 4/6\r\n\r\n🟩⬜🟨🟨⬜\r\n🟩🟨⬜🟩⬜\r\n🟩⬜⬜⬜...
# 1521732951439945728  Wordle 319 4/6\r\n\r\n⬜🟩⬜🟨⬜\r\n⬜🟩🟩🟩🟩\r\n⬜🟩🟩🟩🟩\...
# 1521732892392534016  워들 206 5/6\r\nhttps://t.co/9kAozJhfgA\r\n\r\n🟩...
# 1521732887770456065  Le Mot (@WordleFR) #115 4/6\r\n\r\n⬛⬛⬛⬛⬛\r\n⬛🟩...
# ...                                                                ...
# 1521995141334114305  @paulsinha Wordle 320 X/6\n\n⬛⬛⬛🟨🟩\n⬛🟩⬛🟩🟩\n⬛🟩⬛...
# 1521995093204475906       Wordle 320 4/6\n\n⬛🟨⬛⬛⬛\n⬛🟨⬛🟩⬛\n🟨🟩⬛🟩🟩\n🟩🟩🟩🟩🟩
# 1521995088444162048  ポケモンWordle 6/10\n\n⬛⬛⬛🟨⬛  🟩🟩🟩🟩🟩\n⬛🟨⬛⬛⬛\n🟩⬛⬛⬛⬛\...
# 1521994934793818112  @Diegarr0 Wordle (ES)  #118 2/6\n\n🟩⬜⬜🟩🟩\n🟩🟩🟩🟩...
# 1521994919094763520              Wordle 319 3/6\n\n🟩⬛🟩⬛⬛\n🟩🟩🟩⬛⬛\n🟩🟩🟩🟩🟩
#
#                                                    context_annotations  \
# tweet_id
# 1521733011414257664  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521732967764140032                                                 []
# 1521732951439945728  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521732892392534016                                                 []
# 1521732887770456065  [{'domain': {'id': '30', 'name': 'Entities [En...
# ...                                                                ...
# 1521995141334114305  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521995093204475906  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521995088444162048  [{'domain': {'id': '45', 'name': 'Brand Vertic...
# 1521994934793818112  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521994919094763520  [{'domain': {'id': '30', 'name': 'Entities [En...
#
#                                author_id                 created_at  \
# tweet_id
# 1521733011414257664   828818052892422148  2022-05-04 06:06:37+00:00
# 1521732967764140032   946067305879842819  2022-05-04 06:06:26+00:00
# 1521732951439945728   904515648327442433  2022-05-04 06:06:22+00:00
# 1521732892392534016  1505751287404498954  2022-05-04 06:06:08+00:00
# 1521732887770456065  1393902207960064001  2022-05-04 06:06:07+00:00
# ...                                  ...                        ...
# 1521995141334114305  1176436558142038017  2022-05-04 23:28:13+00:00
# 1521995093204475906  1050021399585263617  2022-05-04 23:28:02+00:00
# 1521995088444162048  1266878568325279749  2022-05-04 23:28:01+00:00
# 1521994934793818112   864579307984871434  2022-05-04 23:27:24+00:00
# 1521994919094763520  1499904008839962627  2022-05-04 23:27:20+00:00
#
#                                                      referenced_tweets  \
# tweet_id
# 1521733011414257664                                                 []
# 1521732967764140032  [{'type': 'replied_to', 'id': '152081469439032...
# 1521732951439945728  [{'type': 'replied_to', 'id': '152139649722441...
# 1521732892392534016                                                 []
# 1521732887770456065  [{'type': 'replied_to', 'id': '152173288578234...
# ...                                                                ...
# 1521995141334114305  [{'type': 'replied_to', 'id': '152198843340892...
# 1521995093204475906                                                 []
# 1521995088444162048                                                 []
# 1521994934793818112  [{'type': 'replied_to', 'id': '152188665407570...
# 1521994919094763520                                                 []
#
#                      in_reply_to_user_id attachments geo withheld_tweet name  \
# tweet_id
# 1521733011414257664         0.000000e+00          {}  {}             {}    0
# 1521732967764140032         9.460673e+17          {}  {}             {}    0
# 1521732951439945728         9.045156e+17          {}  {}             {}    0
# 1521732892392534016         0.000000e+00          {}  {}             {}    0
# 1521732887770456065         1.393902e+18          {}  {}             {}    0
# ...                                  ...         ...  ..            ...  ...
# 1521995141334114305         2.048170e+07          {}  {}             {}    0
# 1521995093204475906         0.000000e+00          {}  {}             {}    0
# 1521995088444162048         0.000000e+00          {}  {}             {}    0
# 1521994934793818112         8.282864e+17          {}  {}             {}    0
# 1521994919094763520         0.000000e+00          {}  {}             {}    0
#
#                     public_metrics_user url description profile_image_url  \
# tweet_id
# 1521733011414257664                   0   0           0                 0
# 1521732967764140032                   0   0           0                 0
# 1521732951439945728                   0   0           0                 0
# 1521732892392534016                   0   0           0                 0
# 1521732887770456065                   0   0           0                 0
# ...                                 ...  ..         ...               ...
# 1521995141334114305                   0   0           0                 0
# 1521995093204475906                   0   0           0                 0
# 1521995088444162048                   0   0           0                 0
# 1521994934793818112                   0   0           0                 0
# 1521994919094763520                   0   0           0                 0
#
#                     location protected username verified entities_user  \
# tweet_id
# 1521733011414257664        0         0        0        0             0
# 1521732967764140032        0         0        0        0             0
# 1521732951439945728        0         0        0        0             0
# 1521732892392534016        0         0        0        0             0
# 1521732887770456065        0         0        0        0             0
# ...                      ...       ...      ...      ...           ...
# 1521995141334114305        0         0        0        0             0
# 1521995093204475906        0         0        0        0             0
# 1521995088444162048        0         0        0        0             0
# 1521994934793818112        0         0        0        0             0
# 1521994919094763520        0         0        0        0             0
#
#                      pinned_tweet_id withheld_user
# tweet_id
# 1521733011414257664              0.0             0
# 1521732967764140032              0.0             0
# 1521732951439945728              0.0             0
# 1521732892392534016              0.0             0
# 1521732887770456065              0.0             0
# ...                              ...           ...
# 1521995141334114305              0.0             0
# 1521995093204475906              0.0             0
# 1521995088444162048              0.0             0
# 1521994934793818112              0.0             0
# 1521994919094763520              0.0             0
#
# [52181 rows x 28 columns]

# %% [markdown]
# users
#
#     json_likes = ['entities', 'withheld']
#
#
# tweets
#
#     json_likes = ['entities', 'attachments', 'geo', 'withheld']
#     lists_of_json_likes = ['context_annotations','referenced_tweets']

# %%
json_cols_in_tudf = ['entities_tweet',
            'withheld_tweet',
            'public_metrics_tweet',
            'public_metrics_user',
            'geo',
            'withheld_user',
            'entities_user']

json_list_cols_in_tudf = [
            'context_annotations',
            'referenced_tweets'
]

# %%
# show the json-like columns in tudf
tudf[json_cols_in_tudf].head()
# Out:
#                                                         entities_tweet  \
# tweet_id
# 1521733018293084160  {'urls': [{'start': 54, 'end': 77, 'url': 'htt...
# 1521733015738662913  {'urls': [{'start': 58, 'end': 81, 'url': 'htt...
# 1521733011414257664                                                 {}
# 1521733010504445954                                                 {}
# 1521733001981444096  {'mentions': [{'start': 0, 'end': 12, 'usernam...
#
#                     withheld_tweet  \
# tweet_id
# 1521733018293084160             {}
# 1521733015738662913             {}
# 1521733011414257664             {}
# 1521733010504445954             {}
# 1521733001981444096             {}
#
#                                                   public_metrics_tweet  \
# tweet_id
# 1521733018293084160  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521733015738662913  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521733011414257664  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521733010504445954  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521733001981444096  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
#                                                    public_metrics_user geo  \
# tweet_id
# 1521733018293084160  {'followers_count': 147, 'following_count': 43...  {}
# 1521733015738662913  {'followers_count': 41, 'following_count': 136...  {}
# 1521733011414257664                                                  0  {}
# 1521733010504445954  {'followers_count': 1465, 'following_count': 2...  {}
# 1521733001981444096  {'followers_count': 189, 'following_count': 26...  {}
#
#                     withheld_user  \
# tweet_id
# 1521733018293084160            {}
# 1521733015738662913            {}
# 1521733011414257664             0
# 1521733010504445954            {}
# 1521733001981444096            {}
#
#                                                          entities_user
# tweet_id
# 1521733018293084160                                                 {}
# 1521733015738662913  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1521733011414257664                                                  0
# 1521733010504445954  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1521733001981444096                                                 {}

# %%
#show the lists of jsons in tudf
tudf[json_list_cols_in_tudf]
# Out:
#                                                    context_annotations  \
# tweet_id
# 1521733018293084160  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521733015738662913  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521733011414257664  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521733010504445954  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521733001981444096  [{'domain': {'id': '30', 'name': 'Entities [En...
# ...                                                                ...
# 1521994904523706368  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521994898974588929  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521994886941413376  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521994883032039424  [{'domain': {'id': '29', 'name': 'Events [Enti...
# 1521994876677672966  [{'domain': {'id': '30', 'name': 'Entities [En...
#
#                                                      referenced_tweets
# tweet_id
# 1521733018293084160                                                 []
# 1521733015738662913                                                 []
# 1521733011414257664                                                 []
# 1521733010504445954                                                 []
# 1521733001981444096  [{'type': 'replied_to', 'id': '152173192555941...
# ...                                                                ...
# 1521994904523706368                                                 []
# 1521994898974588929                                                 []
# 1521994886941413376                                                 []
# 1521994883032039424                                                 []
# 1521994876677672966                                                 []
#
# [335327 rows x 2 columns]

# %%
tudf.head(3)
# Out:
#                          conversation_id reply_settings lang  \
# tweet_id
# 1521733018293084160  1521733018293084160       everyone   en
# 1521733015738662913  1521733015738662913       everyone   es
# 1521733011414257664  1521733011414257664       everyone   en
#
#                                                         entities_tweet  \
# tweet_id
# 1521733018293084160  {'urls': [{'start': 54, 'end': 77, 'url': 'htt...
# 1521733015738662913  {'urls': [{'start': 58, 'end': 81, 'url': 'htt...
# 1521733011414257664                                                 {}
#
#                      possibly_sensitive               source  \
# tweet_id
# 1521733018293084160               False      Twitter Web App
# 1521733015738662913               False  Twitter for Android
# 1521733011414257664               False  Twitter for Android
#
#                                                   public_metrics_tweet  \
# tweet_id
# 1521733018293084160  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521733015738662913  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521733011414257664  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
#                                                                   text  \
# tweet_id
# 1521733018293084160  Wordle (ES)  #118 5/6\r\n\r\n⬜⬜🟨🟩⬜\r\n⬜⬜🟨🟩⬜\r\...
# 1521733015738662913  Wordle Científico #52 5/6\r\n\r\n⬜⬜⬜⬜🟨\r\n🟨⬜⬜⬜...
# 1521733011414257664  Wordle 319 4/6\r\n\r\n🟨🟨⬜⬜⬜\r\n🟨⬜⬜🟩⬜\r\n🟩🟨⬜🟩🟨\...
#
#                                                    context_annotations  \
# tweet_id
# 1521733018293084160  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521733015738662913  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521733011414257664  [{'domain': {'id': '30', 'name': 'Entities [En...
#
#                                author_id                 created_at  \
# tweet_id
# 1521733018293084160  1006110502043471872  2022-05-04 06:06:38+00:00
# 1521733015738662913            360002014  2022-05-04 06:06:38+00:00
# 1521733011414257664   828818052892422148  2022-05-04 06:06:37+00:00
#
#                     referenced_tweets  in_reply_to_user_id attachments geo  \
# tweet_id
# 1521733018293084160                []                  0.0          {}  {}
# 1521733015738662913                []                  0.0          {}  {}
# 1521733011414257664                []                  0.0          {}  {}
#
#                     withheld_tweet          name  \
# tweet_id
# 1521733018293084160             {}  Jose Antonio
# 1521733015738662913             {}  Ana V Garcia
# 1521733011414257664             {}             0
#
#                                                    public_metrics_user  \
# tweet_id
# 1521733018293084160  {'followers_count': 147, 'following_count': 43...
# 1521733015738662913  {'followers_count': 41, 'following_count': 136...
# 1521733011414257664                                                  0
#
#                                          url  \
# tweet_id
# 1521733018293084160
# 1521733015738662913  https://t.co/uMfikCmd0I
# 1521733011414257664                        0
#
#                                                            description  \
# tweet_id
# 1521733018293084160  Antiguo usuario bloqueado por error, pero he v...
# 1521733015738662913
# 1521733011414257664                                                  0
#
#                                                      profile_image_url  \
# tweet_id
# 1521733018293084160  https://pbs.twimg.com/profile_images/144681186...
# 1521733015738662913  https://pbs.twimg.com/profile_images/122215871...
# 1521733011414257664                                                  0
#
#                                       location protected     username  \
# tweet_id
# 1521733018293084160  Alcalá de Guadaíra, Spain     False   Joseamj_97
# 1521733015738662913          Alcalá de Henares     False  AnaVGarciaG
# 1521733011414257664                          0         0            0
#
#                     verified  \
# tweet_id
# 1521733018293084160    False
# 1521733015738662913    False
# 1521733011414257664        0
#
#                                                          entities_user  \
# tweet_id
# 1521733018293084160                                                 {}
# 1521733015738662913  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1521733011414257664                                                  0
#
#                      pinned_tweet_id withheld_user
# tweet_id
# 1521733018293084160              0.0            {}
# 1521733015738662913              0.0            {}
# 1521733011414257664              0.0             0

# %% [markdown]
# ## format jsons with double quotes instead of single
#
# This isn't just a matter of changing all single quotes into doubles, because there is an example of a value enclosed by rare double quotes to start, and containing a single quote.
#
# luckily, ast.literal_eval magically solves this problem for us. It doesn't even require json.loads().

# %%
#example of literal_eval turning a json-like-but-with-single-quotes string into a python dict.
ast.literal_eval(
    tudf.iloc[0]['entities_tweet']
)
# Out:
# {'urls': [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/oJCukg4JnD',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}]}

# %%
###################################################
# No need for this function with ast.literal_eval()
# Made before I knew about the above function.
###################################################


# Turns all json-like strings with single quotes for keys and values will have those quotes changed into doubles quotes.
# Any single quote within double quotes (like in object 2846) will be turned 
def singleq_to_doubleq(some_string):
    new_string = some_string.replace("""'""",'''"''')
    return new_string

# %%
#test it out
singleq_to_doubleq('''aejkrha;ebglaerghlajerhar;tha'erghaqergha[serthnasrtgnasR"TNSrN"SrfnSRf'ns'rtn'srtna]''')
# Out:
# 'aejkrha;ebglaerghlajerhar;tha"erghaqergha[serthnasrtgnasR"TNSrN"SrfnSRf"ns"rtn"srtna]'

# %%
###################################################
# No need for this function with ast.literal_eval()
###################################################
# replace single quotes with double quotes in strings in a pandas series
def series_singleq_to_doubleq(pandas_series):
    new_series = pandas_series.apply(lambda some_string: singleq_to_doubleq(some_string) )
    return new_series

###########
# use this!
###########
#goes straight from json-looking-but-with-single-quotes strings to a list of dicts using ast.literal_eval()
def series_literal_eval(pandas_series):
    new_series = list(map(lambda some_string: ast.literal_eval(some_string), list(pandas_series)))
    return new_series

# %%
#try out series_literal_eval
entities_tweet_list = series_literal_eval(tudf['entities_tweet'])
entities_tweet_list
# Out:
# [{'urls': [{'start': 54,
#     'end': 77,
#     'url': 'https://t.co/oJCukg4JnD',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com',
#     'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#       'width': 1200,
#       'height': 630},
#      {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#       'width': 150,
#       'height': 150}],
#     'status': 200,
#     'title': 'Un juego de palabras diario',
#     'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#     'unwound_url': 'https://wordle.danielfrg.com/'}]},
#  {'urls': [{'start': 58,
#     'end': 81,
#     'url': 'https://t.co/ifnVQsE6bO',
#     'expanded_url': 'https://wordle.danielfrg.com/ciencia/index.html',
#     'display_url': 'wordle.danielfrg.com/ciencia/index.…',
#     'images': [{'url': 'https://pbs.twimg.com/news_img/1521711979752136704/Qr2DllcV?format=jpg&name=orig',
#       'width': 1200,
#       'height': 630},
#      {'url': 'https://pbs.twimg.com/news_img/1521711979752136704/Qr2DllcV?format=jpg&name=150x150',
#       'width': 150,
#       'height': 150}],
#     'status': 200,
#     'title': 'Un juego de palabras diario',
#     'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#     'unwound_url': 'https://wordle.danielfrg.com/ciencia/index.html'}]},
#  {},
#  {},
#  {'mentions': [{'start': 0,
#     'end': 12,
#     'username': 'RwellsWells',
#     'id': '331622540'}]},
#  {},
#  {'urls': [{'start': 58,
#     'end': 81,
#     'url': 'https://t.co/Pxb1ZKeNoD',
#     'expanded_url': 'https://wordle.danielfrg.com/ciencia/index.html',
#     'display_url': 'wordle.danielfrg.com/ciencia/index.…',
#     'images': [{'url': 'https://pbs.twimg.com/news_img/1521711979752136704/Qr2DllcV?format=jpg&name=orig',
#       'width': 1200,
#       'height': 630},
#      {'url': 'https://pbs.twimg.com/news_img/1521711979752136704/Qr2DllcV?format=jpg&name=150x150',
#       'width': 150,
#       'height': 150}],
#     'status': 200,
#     'title': 'Un juego de palabras diario',
#     'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#     'unwound_url': 'https://wordle.danielfrg.com/ciencia/index.html'}]},
#  {'urls': [{'start': 42,
#     'end': 65,
#     'url': 'https://t.co/IC6ZxPHDEF',
#     'expanded_url': 'https://wordle.mega-yadoran.jp/',
#     'display_url': 'wordle.mega-yadoran.jp',
#     'images': [{'url': 'https://pbs.twimg.com/news_img/1520627181159784450/oEzApr9k?format=png&name=orig',
#       'width': 200,
#       'height': 200},
#      {'url': 'https://pbs.twimg.com/news_img/1520627181159784450/oEzApr9k?format=png&name=150x150',
#       'width': 150,
#       'height': 150}],
#     'status': 200,
#     'title': 'ポケモンWordle',
#     'description': 'ポケモンWordle (ポケモンワードル)は単語当てゲーム「Wordle」のポケモン版。１０回のチャレンジでポケモンの名前を当てよう！',
#     'unwound_url': 'https://wordle.mega-yadoran.jp/'}],
#   'hashtags': [{'start': 67, 'end': 78, 'tag': 'ポケモンWordle'}]},
#  {'mentions': [{'start': 0,
#     'end': 16,
#     'username': 'misfortunateApe',
#     'id': '1275838631891152898'},
#    {'start': 17,
#     'end': 31,
#     'username': 'SamuelAlpha77',
#     'id': '1353120743199023106'},
#    {'start': 32,
#     'end': 40,
#     'username': '1kisfud',
#     'id': '1495802955580297216'},
#    {'start': 41,
#     'end': 53,
#     'username': 'SumPersonal',
#     'id': '1437848652085669894'},
#    {'start': 54,
#     'end': 69,
#     'username': 'ifyouknowyk4ir',
#     'id': '1105516614978596864'},
#    {'start': 70,
#     'end': 84,
#     'username': '42Chainlink42',
#     'id': '1350970179128356866'},
#    {'start': 85,
#     'end': 101,
#     'username': 'onlyshitpost777',
#     'id': '1150564524354764800'}]},
#  {},
#  {'urls': [{'start': 54,
#     'end': 77,
#     'url': 'https://t.co/LqTwoZRmma',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com',
#     'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#       'width': 1200,
#       'height': 630},
#      {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#       'width': 150,
#       'height': 150}],
#     'status': 200,
#     'title': 'Un juego de palabras diario',
#     'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#     'unwound_url': 'https://wordle.danielfrg.com/'}]},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/gVwzNU1bJE',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com',
#     'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#       'width': 1200,
#       'height': 630},
#      {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#       'width': 150,
#       'height': 150}],
#     'status': 200,
#     'title': 'Un juego de palabras diario',
#     'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#     'unwound_url': 'https://wordle.danielfrg.com/'}]},
#  {'urls': [{'start': 43,
#     'end': 66,
#     'url': 'https://t.co/lGJkZO2hl7',
#     'expanded_url': 'https://bit.ly/wordlethai',
#     'display_url': 'bit.ly/wordlethai',
#     'status': 200,
#     'title': 'เวิร์ดเดลไทย - Thai Wordle',
#     'description': 'Wordle ฉบับภาษาไทย',
#     'unwound_url': 'https://buddhistuniversity.net/wordle-thai/'}]},
#  {'urls': [{'start': 51,
#     'end': 74,
#     'url': 'https://t.co/BtXcWPrgJa',
#     'expanded_url': 'http://wordle.gelozp.com',
#     'display_url': 'wordle.gelozp.com',
#     'images': [{'url': 'https://pbs.twimg.com/news_img/1520479054184468480/yryaukBy?format=png&name=orig',
#       'width': 400,
#       'height': 400},
#      {'url': 'https://pbs.twimg.com/news_img/1520479054184468480/yryaukBy?format=png&name=150x150',
#       'width': 150,
#       'height': 150}],
#     'status': 200,
#     'title': 'WordleCAT - Un mot diari',
#     'description': 'Endevina el mot amagat en 6 intents. Cada dia hi ha un nou mot per endevinar.',
#     'unwound_url': 'https://wordle.gelozp.com/'}],
#   'hashtags': [{'start': 0, 'end': 10, 'tag': 'WordleCAT'}]},
#  {},
#  {'urls': [{'start': 62,
#     'end': 85,
#     'url': 'https://t.co/4wLdS1B3Eo',
#     'expanded_url': 'https://wordle.mega-yadoran.jp/',
#     'display_url': 'wordle.mega-yadoran.jp',
#     'images': [{'url': 'https://pbs.twimg.com/news_img/1520627181159784450/oEzApr9k?format=png&name=orig',
#       'width': 200,
#       'height': 200},
#      {'url': 'https://pbs.twimg.com/news_img/1520627181159784450/oEzApr9k?format=png&name=150x150',
#       'width': 150,
#       'height': 150}],
#     'status': 200,
#     'title': 'ポケモンWordle',
#     'description': 'ポケモンWordle (ポケモンワードル)は単語当てゲーム「Wordle」のポケモン版。１０回のチャレンジでポケモンの名前を当てよう！',
#     'unwound_url': 'https://wordle.mega-yadoran.jp/'}],
#   'hashtags': [{'start': 87, 'end': 98, 'tag': 'ポケモンWordle'}]},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/QKa1OEBtOf',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 60,
#     'end': 83,
#     'url': 'https://t.co/rao9P4BI4l',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {},
#  {'urls': [{'start': 42,
#     'end': 65,
#     'url': 'https://t.co/xvcZIZrn1C',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {'mentions': [{'start': 0,
#     'end': 9,
#     'username': 'albolt76',
#     'id': '1160130818678972416'},
#    {'start': 10,
#     'end': 24,
#     'username': 'aBitSquirrely',
#     'id': '1248231058614747137'},
#    {'start': 25, 'end': 34, 'username': 'dawardle', 'id': '1165789231'}]},
#  {},
#  {'urls': [{'start': 11,
#     'end': 34,
#     'url': 'https://t.co/9kAozJhfgA',
#     'expanded_url': 'https://jhlov.github.io/wordle',
#     'display_url': 'jhlov.github.io/wordle'}]},
#  {'urls': [{'start': 54,
#     'end': 77,
#     'url': 'https://t.co/IX2xW6CoFe',
#     'expanded_url': 'https://wordle.louan.me',
#     'display_url': 'wordle.louan.me'}],
#   'mentions': [{'start': 8,
#     'end': 17,
#     'username': 'WordleFR',
#     'id': '1480029602105995267'}]},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/3C0TIloNqG',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {'hashtags': [{'start': 0, 'end': 7, 'tag': 'Wordle'},
#    {'start': 24, 'end': 32, 'tag': 'Woordle'}]},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/GM0zE5k0Hl',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {'urls': [{'start': 60,
#     'end': 83,
#     'url': 'https://t.co/aqLBN2A9r4',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 60,
#     'end': 83,
#     'url': 'https://t.co/Ap6i9Yy0Ya',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'hashtags': [{'start': 0, 'end': 7, 'tag': 'Wordle'}]},
#  {'urls': [{'start': 85,
#     'end': 108,
#     'url': 'https://t.co/PTITgYe6Pb',
#     'expanded_url': 'https://wordle.louan.me',
#     'display_url': 'wordle.louan.me'}],
#   'mentions': [{'start': 0,
#     'end': 14,
#     'username': 'NarcissusCapM',
#     'id': '611788548'},
#    {'start': 15,
#     'end': 24,
#     'username': 'WordleFR',
#     'id': '1480029602105995267'},
#    {'start': 33,
#     'end': 42,
#     'username': 'WordleFR',
#     'id': '1480029602105995267'}]},
#  {},
#  {},
#  {},
#  {'urls': [{'start': 26,
#     'end': 49,
#     'url': 'https://t.co/8CnLzuBWOC',
#     'expanded_url': 'https://wordle-jp.netlify.app/',
#     'display_url': 'wordle-jp.netlify.app'}]},
#  {},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/BWjS9otbCA',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {'urls': [{'start': 39,
#     'end': 62,
#     'url': 'https://t.co/4ux5mq4PlD',
#     'expanded_url': 'http://wordle.gelozp.com',
#     'display_url': 'wordle.gelozp.com'}],
#   'hashtags': [{'start': 0, 'end': 10, 'tag': 'WordleCAT'}]},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/VqKBtNowH3',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {},
#  {'urls': [{'start': 57,
#     'end': 80,
#     'url': 'https://t.co/3jE1v0Kn5m',
#     'expanded_url': 'http://wordle.gelozp.com',
#     'display_url': 'wordle.gelozp.com'}],
#   'hashtags': [{'start': 0, 'end': 10, 'tag': 'WordleCAT'}]},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/lSyzFOO1Z3',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {},
#  {'urls': [{'start': 66,
#     'end': 89,
#     'url': 'https://t.co/ifLVf6959X',
#     'expanded_url': 'https://wordle.louan.me',
#     'display_url': 'wordle.louan.me'}],
#   'mentions': [{'start': 8,
#     'end': 17,
#     'username': 'WordleFR',
#     'id': '1480029602105995267'}]},
#  {'urls': [{'start': 42,
#     'end': 65,
#     'url': 'https://t.co/1XY95qobyB',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {},
#  {},
#  {'urls': [{'start': 34,
#     'end': 57,
#     'url': 'https://t.co/dABljpbPHx',
#     'expanded_url': 'https://twitter.com/deepfriedlard/status/1521369984223514624',
#     'display_url': 'twitter.com/deepfriedlard/…'}]},
#  {},
#  {'hashtags': [{'start': 9, 'end': 16, 'tag': 'wordle'}]},
#  {},
#  {},
#  {'urls': [{'start': 60,
#     'end': 83,
#     'url': 'https://t.co/UYfDx8iylz',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'mentions': [{'start': 71,
#     'end': 79,
#     'username': 'AboutEG',
#     'id': '957239371'}]},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/uxWTQsv3kx',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {},
#  {'mentions': [{'start': 0,
#     'end': 7,
#     'username': 'suwhar',
#     'id': '31870615'}]},
#  {},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/e6bPLMyyia',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 69,
#     'end': 92,
#     'url': 'https://t.co/NRzSippMRU',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 42,
#     'end': 65,
#     'url': 'https://t.co/LkzSKyQdHG',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'hashtags': [{'start': 0, 'end': 10, 'tag': 'Wordle319'},
#    {'start': 15, 'end': 22, 'tag': 'Wordle'}]},
#  {'mentions': [{'start': 66,
#     'end': 74,
#     'username': 'nytimes',
#     'id': '807095'}],
#   'hashtags': [{'start': 55, 'end': 65, 'tag': 'Wordle319'}]},
#  {'urls': [{'start': 58,
#     'end': 81,
#     'url': 'https://t.co/72uJ8rPlCp',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {},
#  {'urls': [{'start': 54,
#     'end': 77,
#     'url': 'https://t.co/VzdHJehuQL',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {},
#  {},
#  {'urls': [{'start': 82,
#     'end': 105,
#     'url': 'https://t.co/IaUEPseE62',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {},
#  {},
#  {},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/uAogSyv9zJ',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 55,
#     'end': 78,
#     'url': 'https://t.co/OMYc29k8GS',
#     'expanded_url': 'http://wordle.at',
#     'display_url': 'wordle.at'}]},
#  {'urls': [{'start': 58,
#     'end': 81,
#     'url': 'https://t.co/Baw2N1Ljt7',
#     'expanded_url': 'https://wordle.danielfrg.com/ciencia/index.html',
#     'display_url': 'wordle.danielfrg.com/ciencia/index.…'}]},
#  {},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/9w0MwM7FHj',
#     'expanded_url': 'https://wordle.louan.me',
#     'display_url': 'wordle.louan.me'}],
#   'mentions': [{'start': 8,
#     'end': 17,
#     'username': 'WordleFR',
#     'id': '1480029602105995267'}]},
#  {},
#  {'urls': [{'start': 28,
#     'end': 51,
#     'url': 'https://t.co/HUMP4KvGbv',
#     'expanded_url': 'https://twitter.com/priestwendy/status/1521732559331282951/photo/1',
#     'display_url': 'pic.twitter.com/HUMP4KvGbv',
#     'media_key': '16_1521732551106310145'}]},
#  {},
#  {},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/Ei9OwtR6k4',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com',
#     'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#       'width': 1200,
#       'height': 630},
#      {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#       'width': 150,
#       'height': 150}],
#     'status': 200,
#     'title': 'Un juego de palabras diario',
#     'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#     'unwound_url': 'https://wordle.danielfrg.com/'}]},
#  {},
#  {},
#  {'urls': [{'start': 42,
#     'end': 65,
#     'url': 'https://t.co/GOymFg1AR3',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 42,
#     'end': 65,
#     'url': 'https://t.co/a6FV3ZAwwa',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'mentions': [{'start': 0,
#     'end': 15,
#     'username': 'DaraghO_Writer',
#     'id': '1488947351620362242'}]},
#  {},
#  {},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/LOBFASgKbQ',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 54,
#     'end': 77,
#     'url': 'https://t.co/dzaLnHA7uo',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'},
#    {'start': 94,
#     'end': 117,
#     'url': 'https://t.co/2Ifo4gJe0Z',
#     'expanded_url': 'https://twitter.com/slytherinnds/status/1521732521775534081/photo/1',
#     'display_url': 'pic.twitter.com/2Ifo4gJe0Z',
#     'media_key': '16_1521732511805714432'}],
#   'mentions': [{'start': 0,
#     'end': 11,
#     'username': 'itsbroWken',
#     'id': '1291469818877620226'}]},
#  {},
#  {},
#  {'urls': [{'start': 58,
#     'end': 81,
#     'url': 'https://t.co/Yz8kw4lcE3',
#     'expanded_url': 'https://wordle.danielfrg.com/ciencia/index.html',
#     'display_url': 'wordle.danielfrg.com/ciencia/index.…',
#     'images': [{'url': 'https://pbs.twimg.com/news_img/1521711979752136704/Qr2DllcV?format=jpg&name=orig',
#       'width': 1200,
#       'height': 630},
#      {'url': 'https://pbs.twimg.com/news_img/1521711979752136704/Qr2DllcV?format=jpg&name=150x150',
#       'width': 150,
#       'height': 150}],
#     'status': 200,
#     'title': 'Un juego de palabras diario',
#     'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#     'unwound_url': 'https://wordle.danielfrg.com/ciencia/index.html'}]},
#  {'urls': [{'start': 54,
#     'end': 77,
#     'url': 'https://t.co/1w1Lfos0xN',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {},
#  {'urls': [{'start': 42,
#     'end': 65,
#     'url': 'https://t.co/aLmb1GAhgn',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {},
#  {'hashtags': [{'start': 16, 'end': 21, 'tag': 'Thai'}]},
#  {'urls': [{'start': 75,
#     'end': 98,
#     'url': 'https://t.co/2nsCxhOYSs',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 84,
#     'end': 107,
#     'url': 'https://t.co/usBmCsXdwu',
#     'expanded_url': 'https://wordle.danielfrg.com/#',
#     'display_url': 'wordle.danielfrg.com/#'}]},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/FaXJnKrXWZ',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {},
#  {},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/UHmoJHttft',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {},
#  {},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/xrcyUgyil1',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {'urls': [{'start': 60,
#     'end': 83,
#     'url': 'https://t.co/dsJ1LY4Tfn',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/ZhqNlPPHPz',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/FzJYr0nBJ0',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com',
#     'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#       'width': 1200,
#       'height': 630},
#      {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#       'width': 150,
#       'height': 150}],
#     'status': 200,
#     'title': 'Un juego de palabras diario',
#     'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#     'unwound_url': 'https://wordle.danielfrg.com/'}]},
#  {},
#  {},
#  {'urls': [{'start': 79,
#     'end': 102,
#     'url': 'https://t.co/ofC8iJnkkm',
#     'expanded_url': 'http://wordle.gelozp.com',
#     'display_url': 'wordle.gelozp.com'}],
#   'hashtags': [{'start': 0, 'end': 7, 'tag': 'BonDia'},
#    {'start': 8, 'end': 17, 'tag': 'Dimecres'},
#    {'start': 18, 'end': 39, 'tag': 'Tatatatatatatatatata'},
#    {'start': 40, 'end': 50, 'tag': 'WordleCAT'}]},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/0ta25rI33k',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {'urls': [{'start': 87,
#     'end': 110,
#     'url': 'https://t.co/OHLZo1kbEY',
#     'expanded_url': 'https://wordle.belousov.one',
#     'display_url': 'wordle.belousov.one'}],
#   'hashtags': [{'start': 57, 'end': 64, 'tag': 'вордли'}]},
#  {'urls': [{'start': 11,
#     'end': 34,
#     'url': 'https://t.co/m8GRzLztZb',
#     'expanded_url': 'https://jhlov.github.io/wordle',
#     'display_url': 'jhlov.github.io/wordle'}]},
#  {},
#  {},
#  {'urls': [{'start': 57,
#     'end': 80,
#     'url': 'https://t.co/GwBUPV9m8Q',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com',
#     'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#       'width': 1200,
#       'height': 630},
#      {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#       'width': 150,
#       'height': 150}],
#     'status': 200,
#     'title': 'Un juego de palabras diario',
#     'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#     'unwound_url': 'https://wordle.danielfrg.com/'}],
#   'mentions': [{'start': 0,
#     'end': 8,
#     'username': 'Pocotu4',
#     'id': '1259399014627377158'}]},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/IHcDFMR29n',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {'urls': [{'start': 42,
#     'end': 65,
#     'url': 'https://t.co/N8d9xYcwzs',
#     'expanded_url': 'https://wordle.mega-yadoran.jp/',
#     'display_url': 'wordle.mega-yadoran.jp'}],
#   'hashtags': [{'start': 67, 'end': 78, 'tag': 'ポケモンWordle'}]},
#  {},
#  {},
#  {},
#  {'urls': [{'start': 54,
#     'end': 77,
#     'url': 'https://t.co/ZuqiTgCbwX',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {'urls': [{'start': 42,
#     'end': 65,
#     'url': 'https://t.co/710R09nYc9',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com',
#     'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#       'width': 1200,
#       'height': 630},
#      {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#       'width': 150,
#       'height': 150}],
#     'status': 200,
#     'title': 'Un juego de palabras diario',
#     'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#     'unwound_url': 'https://wordle.danielfrg.com/'}]},
#  {},
#  {},
#  {},
#  {'urls': [{'start': 54,
#     'end': 77,
#     'url': 'https://t.co/b5JT8ZP9me',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com',
#     'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#       'width': 1200,
#       'height': 630},
#      {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#       'width': 150,
#       'height': 150}],
#     'status': 200,
#     'title': 'Un juego de palabras diario',
#     'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#     'unwound_url': 'https://wordle.danielfrg.com/'}]},
#  {},
#  {'urls': [{'start': 55,
#     'end': 78,
#     'url': 'https://t.co/9nlV6pL0V0',
#     'expanded_url': 'https://wordle.mega-yadoran.jp/',
#     'display_url': 'wordle.mega-yadoran.jp',
#     'images': [{'url': 'https://pbs.twimg.com/news_img/1520627181159784450/oEzApr9k?format=png&name=orig',
#       'width': 200,
#       'height': 200},
#      {'url': 'https://pbs.twimg.com/news_img/1520627181159784450/oEzApr9k?format=png&name=150x150',
#       'width': 150,
#       'height': 150}],
#     'status': 200,
#     'title': 'ポケモンWordle',
#     'description': 'ポケモンWordle (ポケモンワードル)は単語当てゲーム「Wordle」のポケモン版。１０回のチャレンジでポケモンの名前を当てよう！',
#     'unwound_url': 'https://wordle.mega-yadoran.jp/'}],
#   'hashtags': [{'start': 80, 'end': 91, 'tag': 'ポケモンWordle'}]},
#  {},
#  {},
#  {},
#  {},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/OKNoQ7rEIB',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {'mentions': [{'start': 0,
#     'end': 13,
#     'username': 'olliemasters',
#     'id': '86398584'}]},
#  {},
#  {'urls': [{'start': 89,
#     'end': 112,
#     'url': 'https://t.co/5h1AN61NVM',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}],
#   'hashtags': [{'start': 24, 'end': 39, 'tag': 'FelizMiércoles'}]},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/YdEOQja0si',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/TpKEuGxWCT',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 95,
#     'end': 118,
#     'url': 'https://t.co/gGZVEJAgMX',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}],
#   'mentions': [{'start': 0,
#     'end': 11,
#     'username': 'lauravy555',
#     'id': '4707430889'},
#    {'start': 12, 'end': 21, 'username': 'vinamher', 'id': '300952598'},
#    {'start': 22, 'end': 37, 'username': 'garcia_chema_8', 'id': '2423128126'},
#    {'start': 38, 'end': 52, 'username': 'palomavmartin', 'id': '1370356184'}]},
#  {},
#  {'urls': [{'start': 134,
#     'end': 157,
#     'url': 'https://t.co/gZc536YnSB',
#     'expanded_url': 'https://wordle.belousov.one',
#     'display_url': 'wordle.belousov.one'}],
#   'hashtags': [{'start': 104, 'end': 111, 'tag': 'вордли'}]},
#  {'urls': [{'start': 42,
#     'end': 65,
#     'url': 'https://t.co/8CTKalht3i',
#     'expanded_url': 'https://wordle.louan.me',
#     'display_url': 'wordle.louan.me'}],
#   'mentions': [{'start': 8,
#     'end': 17,
#     'username': 'WordleFR',
#     'id': '1480029602105995267'}]},
#  {},
#  {'urls': [{'start': 42,
#     'end': 65,
#     'url': 'https://t.co/KvvQte8kcG',
#     'expanded_url': 'https://wordle.mega-yadoran.jp/',
#     'display_url': 'wordle.mega-yadoran.jp',
#     'images': [{'url': 'https://pbs.twimg.com/news_img/1520627181159784450/oEzApr9k?format=png&name=orig',
#       'width': 200,
#       'height': 200},
#      {'url': 'https://pbs.twimg.com/news_img/1520627181159784450/oEzApr9k?format=png&name=150x150',
#       'width': 150,
#       'height': 150}],
#     'status': 200,
#     'title': 'ポケモンWordle',
#     'description': 'ポケモンWordle (ポケモンワードル)は単語当てゲーム「Wordle」のポケモン版。１０回のチャレンジでポケモンの名前を当てよう！',
#     'unwound_url': 'https://wordle.mega-yadoran.jp/'}],
#   'hashtags': [{'start': 67, 'end': 78, 'tag': 'ポケモンWordle'}]},
#  {},
#  {},
#  {'urls': [{'start': 39,
#     'end': 62,
#     'url': 'https://t.co/tLpC59BN9Y',
#     'expanded_url': 'http://wordle.gelozp.com',
#     'display_url': 'wordle.gelozp.com'}],
#   'hashtags': [{'start': 0, 'end': 10, 'tag': 'WordleCAT'}]},
#  {},
#  {},
#  {},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/zJA9agkM6p',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {'urls': [{'start': 88,
#     'end': 111,
#     'url': 'https://t.co/cLkxl43qD0',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 64,
#     'end': 87,
#     'url': 'https://t.co/KEAEO4YSBz',
#     'expanded_url': 'https://wordle.danielfrg.com/tildes/index.html',
#     'display_url': 'wordle.danielfrg.com/tildes/index.h…'}]},
#  {},
#  {'urls': [{'start': 0,
#     'end': 23,
#     'url': 'https://t.co/hQSpbCRtcz',
#     'expanded_url': 'http://6mal5.com',
#     'display_url': '6mal5.com'}],
#   'mentions': [{'start': 70,
#     'end': 79,
#     'username': 'dewordle',
#     'id': '1482411529152741376'}]},
#  {},
#  {'hashtags': [{'start': 61, 'end': 72, 'tag': 'ポケモンWordle'}],
#   'urls': [{'start': 36,
#     'end': 59,
#     'url': 'https://t.co/qAZvZhGk6m',
#     'expanded_url': 'https://wordle.mega-yadoran.jp/',
#     'display_url': 'wordle.mega-yadoran.jp'}]},
#  {},
#  {},
#  {},
#  {},
#  {'urls': [{'start': 54,
#     'end': 77,
#     'url': 'https://t.co/RlVM954Jxi',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com',
#     'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#       'width': 1200,
#       'height': 630},
#      {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#       'width': 150,
#       'height': 150}],
#     'status': 200,
#     'title': 'Un juego de palabras diario',
#     'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#     'unwound_url': 'https://wordle.danielfrg.com/'}]},
#  {},
#  {},
#  {'urls': [{'start': 54,
#     'end': 77,
#     'url': 'https://t.co/qfyszTCKaD',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 42,
#     'end': 65,
#     'url': 'https://t.co/oUqb22mREi',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com',
#     'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#       'width': 1200,
#       'height': 630},
#      {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#       'width': 150,
#       'height': 150}],
#     'status': 200,
#     'title': 'Un juego de palabras diario',
#     'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#     'unwound_url': 'https://wordle.danielfrg.com/'}]},
#  {'urls': [{'start': 42,
#     'end': 65,
#     'url': 'https://t.co/dvgP83ZaCf',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'hashtags': [{'start': 73, 'end': 84, 'tag': 'ポケモンWordle'}],
#   'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/4sDQPwE5cA',
#     'expanded_url': 'https://wordle.mega-yadoran.jp/',
#     'display_url': 'wordle.mega-yadoran.jp'}]},
#  {},
#  {},
#  {},
#  {'urls': [{'start': 54,
#     'end': 77,
#     'url': 'https://t.co/dOq9ku0O4i',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com',
#     'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#       'width': 1200,
#       'height': 630},
#      {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#       'width': 150,
#       'height': 150}],
#     'status': 200,
#     'title': 'Un juego de palabras diario',
#     'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#     'unwound_url': 'https://wordle.danielfrg.com/'}]},
#  {},
#  {},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/rR5XaXtZ0R',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 54,
#     'end': 77,
#     'url': 'https://t.co/9R6UZYMD3x',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {},
#  {'urls': [{'start': 42,
#     'end': 65,
#     'url': 'https://t.co/uJEdGvG8UX',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {},
#  {},
#  {},
#  {'hashtags': [{'start': 0, 'end': 10, 'tag': 'WordleCAT'}],
#   'urls': [{'start': 39,
#     'end': 62,
#     'url': 'https://t.co/ZakKiEKsUR',
#     'expanded_url': 'http://wordle.gelozp.com',
#     'display_url': 'wordle.gelozp.com'}]},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/sgTsPs0R12',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'hashtags': [{'start': 0, 'end': 10, 'tag': 'WordleCAT'}],
#   'urls': [{'start': 51,
#     'end': 74,
#     'url': 'https://t.co/yHI33ROJLe',
#     'expanded_url': 'http://wordle.gelozp.com',
#     'display_url': 'wordle.gelozp.com',
#     'images': [{'url': 'https://pbs.twimg.com/news_img/1520479054184468480/yryaukBy?format=png&name=orig',
#       'width': 400,
#       'height': 400},
#      {'url': 'https://pbs.twimg.com/news_img/1520479054184468480/yryaukBy?format=png&name=150x150',
#       'width': 150,
#       'height': 150}],
#     'status': 200,
#     'title': 'WordleCAT - Un mot diari',
#     'description': 'Endevina el mot amagat en 6 intents. Cada dia hi ha un nou mot per endevinar.',
#     'unwound_url': 'https://wordle.gelozp.com/'}]},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'urls': [{'start': 42,
#     'end': 65,
#     'url': 'https://t.co/KguzENiojv',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {},
#  {'urls': [{'start': 42,
#     'end': 65,
#     'url': 'https://t.co/Xdj83kfUVk',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/IFecYJuJJp',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {},
#  {'hashtags': [{'start': 0, 'end': 9, 'tag': 'Thwordle'}]},
#  {'hashtags': [{'start': 57, 'end': 64, 'tag': 'вордли'}],
#   'urls': [{'start': 87,
#     'end': 110,
#     'url': 'https://t.co/sVK6XzXwKR',
#     'expanded_url': 'https://wordle.belousov.one',
#     'display_url': 'wordle.belousov.one'}]},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'mentions': [{'start': 52,
#     'end': 61,
#     'username': 'hvamstad',
#     'id': '190352471'},
#    {'start': 62, 'end': 70, 'username': 'emufear', 'id': '13545062'},
#    {'start': 71, 'end': 85, 'username': 'rovinbhandari', 'id': '471186624'},
#    {'start': 86,
#     'end': 94,
#     'username': 'linkovm',
#     'id': '925805345233973248'}]},
#  {},
#  {},
#  {},
#  {'urls': [{'start': 54,
#     'end': 77,
#     'url': 'https://t.co/K86RSzhGPS',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/buTcZv0iDv',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 54,
#     'end': 77,
#     'url': 'https://t.co/9Upz0uiRag',
#     'expanded_url': 'https://www.bundle.app/wordle-tr/',
#     'display_url': 'bundle.app/wordle-tr/'}]},
#  {},
#  {},
#  {},
#  {'hashtags': [{'start': 65, 'end': 76, 'tag': 'ポケモンWordle'}],
#   'urls': [{'start': 40,
#     'end': 63,
#     'url': 'https://t.co/8rbj6vpAXX',
#     'expanded_url': 'https://wordle.mega-yadoran.jp/',
#     'display_url': 'wordle.mega-yadoran.jp'}]},
#  {},
#  {'urls': [{'start': 54,
#     'end': 77,
#     'url': 'https://t.co/GzP8bj5JAE',
#     'expanded_url': 'https://wordle.danielfrg.com/?s=08',
#     'display_url': 'wordle.danielfrg.com/?s=08'}]},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/6LrZPELAHI',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {},
#  {},
#  {'urls': [{'start': 54,
#     'end': 77,
#     'url': 'https://t.co/PzwYje5otj',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 54,
#     'end': 77,
#     'url': 'https://t.co/lpkVOlJjXb',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {},
#  {},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/vuRhUEeAqs',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 42,
#     'end': 65,
#     'url': 'https://t.co/lcDtyUHuY4',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com',
#     'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#       'width': 1200,
#       'height': 630},
#      {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#       'width': 150,
#       'height': 150}],
#     'status': 200,
#     'title': 'Un juego de palabras diario',
#     'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#     'unwound_url': 'https://wordle.danielfrg.com/'}]},
#  {},
#  {},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/MqLf2qji4T',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {'urls': [{'start': 54,
#     'end': 77,
#     'url': 'https://t.co/j8Hj5kq1F6',
#     'expanded_url': 'https://wordle.louan.me',
#     'display_url': 'wordle.louan.me'}],
#   'mentions': [{'start': 8,
#     'end': 17,
#     'username': 'WordleFR',
#     'id': '1480029602105995267'}]},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'urls': [{'start': 50,
#     'end': 73,
#     'url': 'https://t.co/jMutIMOYrk',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/WOQoMbTuMB',
#     'expanded_url': 'https://wordle.danielfrg.com/tildes/index.html',
#     'display_url': 'wordle.danielfrg.com/tildes/index.h…'}]},
#  {},
#  {'urls': [{'start': 64,
#     'end': 87,
#     'url': 'https://t.co/xqMuSEVHbx',
#     'expanded_url': 'https://wordle.danielfrg.com/tildes/index.html',
#     'display_url': 'wordle.danielfrg.com/tildes/index.h…'}]},
#  {},
#  {'urls': [{'start': 72,
#     'end': 95,
#     'url': 'https://t.co/hq8X4VGCWI',
#     'expanded_url': 'https://wordle.danielfrg.com/tildes/index.html',
#     'display_url': 'wordle.danielfrg.com/tildes/index.h…'}]},
#  {},
#  {'urls': [{'start': 46,
#     'end': 69,
#     'url': 'https://t.co/HFxX7CrLPD',
#     'expanded_url': 'https://wordle.danielfrg.com/ciencia/index.html',
#     'display_url': 'wordle.danielfrg.com/ciencia/index.…'}]},
#  {'urls': [{'start': 34,
#     'end': 57,
#     'url': 'https://t.co/CVS4FQtktG',
#     'expanded_url': 'https://twitter.com/StuartOrr1/status/1521731301337878528/photo/1',
#     'display_url': 'pic.twitter.com/CVS4FQtktG',
#     'media_key': '16_1521731293393960960'}]},
#  {},
#  {'urls': [{'start': 54,
#     'end': 77,
#     'url': 'https://t.co/ZUx5iSC42e',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'urls': [{'start': 67,
#     'end': 90,
#     'url': 'https://t.co/kllXvOfYBq',
#     'expanded_url': 'https://www.bundle.app/wordle-tr/',
#     'display_url': 'bundle.app/wordle-tr/'}]},
#  {'mentions': [{'start': 0,
#     'end': 10,
#     'username': 'augie_pup',
#     'id': '2959665705'}]},
#  {'urls': [{'start': 47,
#     'end': 70,
#     'url': 'https://t.co/9xLUtMbvc4',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/kW2ocGC7Ug',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 43,
#     'end': 66,
#     'url': 'https://t.co/Ph6uuGEcnY',
#     'expanded_url': 'http://wordle.at',
#     'display_url': 'wordle.at'}]},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'urls': [{'start': 42,
#     'end': 65,
#     'url': 'https://t.co/ZNEVRMopZ0',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {'urls': [{'start': 58,
#     'end': 81,
#     'url': 'https://t.co/dw3XO2k9lv',
#     'expanded_url': 'https://wordle.danielfrg.com/ciencia/index.html',
#     'display_url': 'wordle.danielfrg.com/ciencia/index.…'}]},
#  {'hashtags': [{'start': 63, 'end': 70, 'tag': 'вордли'}]},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'urls': [{'start': 42,
#     'end': 65,
#     'url': 'https://t.co/YyglqUhmFj',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {},
#  {'urls': [{'start': 42,
#     'end': 65,
#     'url': 'https://t.co/QGUBw12yWl',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {'urls': [{'start': 49,
#     'end': 72,
#     'url': 'https://t.co/6EV9N6mXYS',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {},
#  {'urls': [{'start': 42,
#     'end': 65,
#     'url': 'https://t.co/rKEvsWxozj',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {},
#  {},
#  {'hashtags': [{'start': 0, 'end': 7, 'tag': 'wordle'}]},
#  {},
#  {},
#  {'hashtags': [{'start': 61, 'end': 72, 'tag': 'ポケモンWordle'}],
#   'urls': [{'start': 36,
#     'end': 59,
#     'url': 'https://t.co/VjgVhCH1t6',
#     'expanded_url': 'https://wordle.mega-yadoran.jp/',
#     'display_url': 'wordle.mega-yadoran.jp'}]},
#  {'urls': [{'start': 54,
#     'end': 77,
#     'url': 'https://t.co/of3dNdBhCb',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'mentions': [{'start': 0,
#     'end': 12,
#     'username': 'ITankMuchOW',
#     'id': '1282276437429379075'}]},
#  {},
#  {'hashtags': [{'start': 49, 'end': 59, 'tag': 'WordleCAT'}],
#   'urls': [{'start': 88,
#     'end': 111,
#     'url': 'https://t.co/vMeaYlrMVQ',
#     'expanded_url': 'http://wordle.gelozp.com',
#     'display_url': 'wordle.gelozp.com',
#     'images': [{'url': 'https://pbs.twimg.com/news_img/1520479054184468480/yryaukBy?format=png&name=orig',
#       'width': 400,
#       'height': 400},
#      {'url': 'https://pbs.twimg.com/news_img/1520479054184468480/yryaukBy?format=png&name=150x150',
#       'width': 150,
#       'height': 150}],
#     'status': 200,
#     'title': 'WordleCAT - Un mot diari',
#     'description': 'Endevina el mot amagat en 6 intents. Cada dia hi ha un nou mot per endevinar.',
#     'unwound_url': 'https://wordle.gelozp.com/'}],
#   'mentions': [{'start': 0,
#     'end': 10,
#     'username': 'RondaAbad',
#     'id': '1343862882795188225'}]},
#  {'urls': [{'start': 42,
#     'end': 65,
#     'url': 'https://t.co/gW5ZbaxyGW',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 36,
#     'end': 59,
#     'url': 'https://t.co/zZkmsdiqlc',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/faF8qAG5XU',
#     'expanded_url': 'https://www.wordleturkce.com/',
#     'display_url': 'wordleturkce.com'}]},
#  {},
#  {},
#  {},
#  {'urls': [{'start': 41,
#     'end': 64,
#     'url': 'https://t.co/7PsaNn2WaD',
#     'expanded_url': 'https://twitter.com/sh3sg0ne/status/1521730995371724800/photo/1',
#     'display_url': 'pic.twitter.com/7PsaNn2WaD',
#     'media_key': '3_1521730992079130624'}]},
#  {},
#  {'hashtags': [{'start': 2, 'end': 12, 'tag': 'WordleCAT'}],
#   'urls': [{'start': 59,
#     'end': 82,
#     'url': 'https://t.co/B9Gg2eMzM3',
#     'expanded_url': 'http://wordle.gelozp.com',
#     'display_url': 'wordle.gelozp.com'}]},
#  {},
#  {},
#  {'mentions': [{'start': 0,
#     'end': 15,
#     'username': 'AdrianManifold',
#     'id': '804321630'}]},
#  {},
#  {'urls': [{'start': 77,
#     'end': 100,
#     'url': 'https://t.co/u6s78G5QcK',
#     'expanded_url': 'https://wordle.louan.me',
#     'display_url': 'wordle.louan.me',
#     'status': 200,
#     'title': 'Le Mot - Wordle en français',
#     'description': 'Wordle, mais en français. Devinez le mot du jour ! Totalement gratuit, en ligne, et sans pub.',
#     'unwound_url': 'https://wordle.louan.me'}],
#   'mentions': [{'start': 0,
#     'end': 12,
#     'username': 'TonyRenucci',
#     'id': '325517086'},
#    {'start': 13, 'end': 22, 'username': 'Henscher', 'id': '35743765'},
#    {'start': 31,
#     'end': 40,
#     'username': 'WordleFR',
#     'id': '1480029602105995267'}]},
#  {},
#  {},
#  {},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/TC40Ed5b1G',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'hashtags': [{'start': 17, 'end': 22, 'tag': 'Day6'}]},
#  {'mentions': [{'start': 0,
#     'end': 9,
#     'username': 'MoRupees',
#     'id': '1245246639838826497'},
#    {'start': 10, 'end': 24, 'username': 'TradingNerden', 'id': '3346402781'},
#    {'start': 25, 'end': 31, 'username': 'igge4', 'id': '468705257'},
#    {'start': 32,
#     'end': 47,
#     'username': 'A_Gustavsson83',
#     'id': '1276034256524005382'},
#    {'start': 48,
#     'end': 60,
#     'username': 'frejornberg',
#     'id': '1060132889453608960'},
#    {'start': 61, 'end': 70, 'username': 'missswee', 'id': '84899949'},
#    {'start': 71, 'end': 87, 'username': 'anders1337h4x0r', 'id': '3331600516'},
#    {'start': 88,
#     'end': 101,
#     'username': 'viccaninvest',
#     'id': '1213521062270423040'},
#    {'start': 102, 'end': 116, 'username': 'aniajohansson', 'id': '583823318'},
#    {'start': 117,
#     'end': 129,
#     'username': 'RikLangsamt',
#     'id': '1398347685971771396'},
#    {'start': 130,
#     'end': 143,
#     'username': 'alden_niklas',
#     'id': '876356830401892352'},
#    {'start': 144,
#     'end': 156,
#     'username': 'TomteTrader',
#     'id': '1370353387800252426'},
#    {'start': 157, 'end': 169, 'username': 'emil_bogren', 'id': '374650576'},
#    {'start': 170, 'end': 178, 'username': 'Grottot', 'id': '127069187'}]},
#  {},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/PlNMcyllH7',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {'urls': [{'start': 93,
#     'end': 116,
#     'url': 'https://t.co/DwTZS6NCC2',
#     'expanded_url': 'https://wordlegame.org?challenge=c3R1ZGlv',
#     'display_url': 'wordlegame.org/?challenge=c3R…'},
#    {'start': 117,
#     'end': 140,
#     'url': 'https://t.co/VVqXq2Gf7O',
#     'expanded_url': 'https://wordlegame.org/6-letter-words-wordle',
#     'display_url': 'wordlegame.org/6-letter-words…'}]},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/BC8YNQzcwb',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {},
#  {'hashtags': [{'start': 94, 'end': 105, 'tag': 'ポケモンWordle'}],
#   'urls': [{'start': 69,
#     'end': 92,
#     'url': 'https://t.co/kNntYdX2Z5',
#     'expanded_url': 'https://wordle.mega-yadoran.jp/',
#     'display_url': 'wordle.mega-yadoran.jp'}]},
#  {'mentions': [{'start': 26,
#     'end': 39,
#     'username': 'misterspoons',
#     'id': '70691724'}]},
#  {'urls': [{'start': 54,
#     'end': 77,
#     'url': 'https://t.co/KbsmQFEaqB',
#     'expanded_url': 'https://wordle.danielfrg.com/ciencia/index.html',
#     'display_url': 'wordle.danielfrg.com/ciencia/index.…'}]},
#  {'urls': [{'start': 42,
#     'end': 65,
#     'url': 'https://t.co/OyTm896KLk',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'urls': [{'start': 43,
#     'end': 66,
#     'url': 'https://t.co/jGE0efcn2V',
#     'expanded_url': 'http://wordle.at',
#     'display_url': 'wordle.at'}]},
#  {'hashtags': [{'start': 46, 'end': 56, 'tag': 'Wordle319'}]},
#  {'urls': [{'start': 85,
#     'end': 108,
#     'url': 'https://t.co/ckwwTx5ryH',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'mentions': [{'start': 48,
#     'end': 62,
#     'username': 'DebSreeSarkar',
#     'id': '932135675997982720'}]},
#  {},
#  {'urls': [{'start': 54,
#     'end': 77,
#     'url': 'https://t.co/jF7YbOnpor',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 42,
#     'end': 65,
#     'url': 'https://t.co/nSvzQnW1Xl',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {'urls': [{'start': 54,
#     'end': 77,
#     'url': 'https://t.co/QgwOCNCDt5',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'},
#    {'start': 78,
#     'end': 101,
#     'url': 'https://t.co/kZdrT9cMS3',
#     'expanded_url': 'https://twitter.com/CarlosTribuno/status/1521730761933660161/photo/1',
#     'display_url': 'pic.twitter.com/kZdrT9cMS3',
#     'media_key': '16_1521730754002182150'}]},
#  {},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/GqWXeHEiXg',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 211,
#     'end': 234,
#     'url': 'https://t.co/3Tx0RtSudv',
# ...
#     'id': '254698305'}]},
#  {},
#  {},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/CgyllQiTba',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/pRJeKavOR6',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 70,
#     'end': 93,
#     'url': 'https://t.co/IEUVCtSecT',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 54,
#     'end': 77,
#     'url': 'https://t.co/CbaaPQJ79j',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/Y9Q3BVumVV',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {},
#  {'hashtags': [{'start': 0, 'end': 15, 'tag': 'WordleJapanese'}],
#   'urls': [{'start': 72,
#     'end': 95,
#     'url': 'https://t.co/nSxDcZmHP6',
#     'expanded_url': 'https://wordle.mottox2.com/',
#     'display_url': 'wordle.mottox2.com'}]},
#  {'urls': [{'start': 54,
#     'end': 77,
#     'url': 'https://t.co/3zvGDZvfhK',
#     'expanded_url': 'https://www.bundle.app/wordle-tr/',
#     'display_url': 'bundle.app/wordle-tr/'}]},
#  {'urls': [{'start': 216,
#     'end': 239,
#     'url': 'https://t.co/91hWJ1rMDs',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}],
#   'mentions': [{'start': 0,
#     'end': 9,
#     'username': 'ppucedac',
#     'id': '263597822'},
#    {'start': 10,
#     'end': 24,
#     'username': 'Rusty76936632',
#     'id': '1164095506357936128'},
#    {'start': 25,
#     'end': 36,
#     'username': 'bertoconve',
#     'id': '741186522561556480'},
#    {'start': 37, 'end': 53, 'username': 'mercheiglesiasc', 'id': '260686206'},
#    {'start': 54, 'end': 69, 'username': 'Pancho_Badajoz', 'id': '163801624'},
#    {'start': 70, 'end': 81, 'username': 'PabloRaso1', 'id': '559072218'},
#    {'start': 82, 'end': 93, 'username': 'Santihumor', 'id': '132365110'},
#    {'start': 94, 'end': 110, 'username': 'cmartinizkierdo', 'id': '368185661'},
#    {'start': 111, 'end': 118, 'username': 'pukyjc', 'id': '387881156'},
#    {'start': 119, 'end': 131, 'username': 'williemjose', 'id': '1706947710'},
#    {'start': 132,
#     'end': 147,
#     'username': 'juanito_aragor',
#     'id': '253241290'}]},
#  {},
#  {'hashtags': [{'start': 8, 'end': 18, 'tag': 'WordleCAT'}],
#   'urls': [{'start': 221,
#     'end': 244,
#     'url': 'https://t.co/SN32H9lpWm',
#     'expanded_url': 'http://wordle.gelozp.com',
#     'display_url': 'wordle.gelozp.com'}]},
#  {},
#  {'urls': [{'start': 60,
#     'end': 83,
#     'url': 'https://t.co/l9F18pg2YV',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {'urls': [{'start': 54,
#     'end': 77,
#     'url': 'https://t.co/6R2AG5R0VK',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com',
#     'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#       'width': 1200,
#       'height': 630},
#      {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#       'width': 150,
#       'height': 150}],
#     'status': 200,
#     'title': 'Un juego de palabras diario',
#     'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#     'unwound_url': 'https://wordle.danielfrg.com/'}]},
#  {},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/T0dBHl1QwT',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {},
#  {},
#  {'urls': [{'start': 51,
#     'end': 74,
#     'url': 'https://t.co/oRP1mTEJ1H',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/TAbWsiC821',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 19,
#     'end': 42,
#     'url': 'https://t.co/OYluG6h7zs',
#     'expanded_url': 'https://ygo-wordle.vercel.app',
#     'display_url': 'ygo-wordle.vercel.app'}]},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/c5rXeG8i8q',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 54,
#     'end': 77,
#     'url': 'https://t.co/KMA5OHUIdn',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}],
#   'mentions': [{'start': 78,
#     'end': 89,
#     'username': 'marco_roji',
#     'id': '1278817659963035650'},
#    {'start': 90, 'end': 100, 'username': 'mroji1973', 'id': '632986242'},
#    {'start': 101, 'end': 112, 'username': 'jjromero70', 'id': '2442630999'}]},
#  {},
#  {},
#  {'urls': [{'start': 42,
#     'end': 65,
#     'url': 'https://t.co/HOhIIsKbWo',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/MUK9ej7HwQ',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 54,
#     'end': 77,
#     'url': 'https://t.co/olMJvTgtvP',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/I1ZwWzwqCx',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com',
#     'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#       'width': 1200,
#       'height': 630},
#      {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#       'width': 150,
#       'height': 150}],
#     'status': 200,
#     'title': 'Un juego de palabras diario',
#     'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#     'unwound_url': 'https://wordle.danielfrg.com/'},
#    {'start': 190,
#     'end': 213,
#     'url': 'https://t.co/rDDUiwd6Bi',
#     'expanded_url': 'https://worldle.teuteuf.fr',
#     'display_url': 'worldle.teuteuf.fr'}],
#   'hashtags': [{'start': 118, 'end': 126, 'tag': 'Worldle'}]},
#  {'urls': [{'start': 34,
#     'end': 57,
#     'url': 'https://t.co/TYyddpNF3G',
#     'expanded_url': 'https://twitter.com/StarkMaximum/status/1521727731209318400/photo/1',
#     'display_url': 'pic.twitter.com/TYyddpNF3G',
#     'media_key': '16_1521727717326086144'}]},
#  {},
#  {},
#  {'urls': [{'start': 47,
#     'end': 70,
#     'url': 'https://t.co/QzDLwbTcUU',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 72,
#     'end': 95,
#     'url': 'https://t.co/slFyyzMeGc',
#     'expanded_url': 'https://wordle.danielfrg.com/tildes/index.html',
#     'display_url': 'wordle.danielfrg.com/tildes/index.h…',
#     'images': [{'url': 'https://pbs.twimg.com/news_img/1521711690043170820/rO79OYE2?format=jpg&name=orig',
#       'width': 1200,
#       'height': 630},
#      {'url': 'https://pbs.twimg.com/news_img/1521711690043170820/rO79OYE2?format=jpg&name=150x150',
#       'width': 150,
#       'height': 150}],
#     'status': 200,
#     'title': 'Un juego de palabras diario',
#     'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#     'unwound_url': 'https://wordle.danielfrg.com/tildes/index.html'}]},
#  {},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/Nu1768WkBk',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 40,
#     'end': 63,
#     'url': 'https://t.co/FOtdC82PKi',
#     'expanded_url': 'https://twitter.com/komradequesti0n/status/1521727694748241920/video/1',
#     'display_url': 'pic.twitter.com/FOtdC82PKi',
#     'media_key': '7_1521727673910890497'}]},
#  {},
#  {},
#  {'urls': [{'start': 54,
#     'end': 77,
#     'url': 'https://t.co/RazjlYsyog',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {},
#  {},
#  {'urls': [{'start': 42,
#     'end': 65,
#     'url': 'https://t.co/21IONGESvL',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 42,
#     'end': 65,
#     'url': 'https://t.co/IcedQBu1Jw',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com',
#     'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#       'width': 1200,
#       'height': 630},
#      {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#       'width': 150,
#       'height': 150}],
#     'status': 200,
#     'title': 'Un juego de palabras diario',
#     'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#     'unwound_url': 'https://wordle.danielfrg.com/'}]},
#  {},
#  {'urls': [{'start': 54,
#     'end': 77,
#     'url': 'https://t.co/eh75DTpO6s',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}],
#   'mentions': [{'start': 0,
#     'end': 11,
#     'username': 'EdyPartner',
#     'id': '227724036'}]},
#  {},
#  {},
#  {'urls': [{'start': 52,
#     'end': 75,
#     'url': 'https://t.co/dhVJMewD6b',
#     'expanded_url': 'https://wordle.danielfrg.com/ciencia/',
#     'display_url': 'wordle.danielfrg.com/ciencia/'}]},
#  {},
#  {},
#  {},
#  {'urls': [{'start': 59,
#     'end': 82,
#     'url': 'https://t.co/ZKE493R8Tz',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/GAvCNv9BUe',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {'urls': [{'start': 54,
#     'end': 77,
#     'url': 'https://t.co/uB0kOAPzlj',
#     'expanded_url': 'https://wordle.louan.me',
#     'display_url': 'wordle.louan.me'}],
#   'mentions': [{'start': 8,
#     'end': 17,
#     'username': 'WordleFR',
#     'id': '1480029602105995267'}]},
#  {},
#  {},
#  {},
#  {'urls': [{'start': 60,
#     'end': 83,
#     'url': 'https://t.co/FDoSKTOkyc',
#     'expanded_url': 'https://wordle.danielfrg.com/tildes/',
#     'display_url': 'wordle.danielfrg.com/tildes/'}],
#   'mentions': [{'start': 0,
#     'end': 11,
#     'username': 'EdyPartner',
#     'id': '227724036'}]},
#  {},
#  {'urls': [{'start': 36,
#     'end': 59,
#     'url': 'https://t.co/evWeWeWkbd',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'urls': [{'start': 60,
#     'end': 83,
#     'url': 'https://t.co/ZwMprH640x',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'urls': [{'start': 42,
#     'end': 65,
#     'url': 'https://t.co/90ib5D2jSP',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {'mentions': [{'start': 0,
#     'end': 8,
#     'username': 'shweepa',
#     'id': '9559082'}]},
#  {'urls': [{'start': 54,
#     'end': 77,
#     'url': 'https://t.co/qLWnJ5ew01',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 130,
#     'end': 153,
#     'url': 'https://t.co/Ofki6ZkmHM',
#     'expanded_url': 'https://techyonic.co/swiftle',
#     'display_url': 'techyonic.co/swiftle'},
#    {'start': 154,
#     'end': 177,
#     'url': 'https://t.co/diDmnwOTur',
#     'expanded_url': 'https://twitter.com/kingkierrr/status/1521578649920884737',
#     'display_url': 'twitter.com/kingkierrr/sta…'}]},
#  {'annotations': [{'start': 12,
#     'end': 18,
#     'probability': 0.7079,
#     'type': 'Product',
#     'normalized_text': 'twitter'}]},
#  {},
#  {},
#  {},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/eeME30tPOQ',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'hashtags': [{'start': 41, 'end': 51, 'tag': 'Wordle319'}]},
#  {},
#  {},
#  {'urls': [{'start': 52,
#     'end': 75,
#     'url': 'https://t.co/jxwugzkXhD',
#     'expanded_url': 'https://wordle.mega-yadoran.jp/',
#     'display_url': 'wordle.mega-yadoran.jp'}],
#   'hashtags': [{'start': 77, 'end': 88, 'tag': 'ポケモンWordle'}]},
#  {},
#  {},
#  {},
#  {'urls': [{'start': 42,
#     'end': 65,
#     'url': 'https://t.co/xElKbOhfp7',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/AeNTZdMIej',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/dtS4cPbv3a',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {'mentions': [{'start': 0,
#     'end': 12,
#     'username': 'UsamaKhilji',
#     'id': '166949373'},
#    {'start': 13, 'end': 21, 'username': 'UncleFu', 'id': '45639812'},
#    {'start': 22, 'end': 29, 'username': 'fursid', 'id': '14196465'},
#    {'start': 30, 'end': 44, 'username': 'Sarkhail7Khan', 'id': '351656273'},
#    {'start': 45, 'end': 61, 'username': 'ChocolateCharsi', 'id': '67416132'},
#    {'start': 62, 'end': 75, 'username': 'ST_Incognito', 'id': '385400234'},
#    {'start': 76, 'end': 88, 'username': 'LahoriElite', 'id': '505836297'},
#    {'start': 89, 'end': 102, 'username': 'Peelichappal', 'id': '203482792'},
#    {'start': 103, 'end': 117, 'username': 'RizWanKenobi_', 'id': '41190561'},
#    {'start': 118, 'end': 124, 'username': 'Mzr7_', 'id': '31055922'},
#    {'start': 125, 'end': 136, 'username': 'dishoomjee', 'id': '130070771'},
#    {'start': 137, 'end': 150, 'username': 'sajjadhaider', 'id': '18988192'},
#    {'start': 151, 'end': 165, 'username': 'Preg_Goldfish', 'id': '711024456'},
#    {'start': 166,
#     'end': 182,
#     'username': 'MainKehRahaHoon',
#     'id': '63947987'}]},
#  {},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/Cas0Kw1iZT',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {},
#  {'urls': [{'start': 39,
#     'end': 62,
#     'url': 'https://t.co/sf0kwIXL5T',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 79,
#     'end': 102,
#     'url': 'https://t.co/TNfdfuVQjl',
#     'expanded_url': 'https://wordle.louan.me',
#     'display_url': 'wordle.louan.me'}],
#   'mentions': [{'start': 8,
#     'end': 17,
#     'username': 'WordleFR',
#     'id': '1480029602105995267'}]},
#  {'mentions': [{'start': 0,
#     'end': 15,
#     'username': 'richardengland',
#     'id': '25075723'}]},
#  {},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/FYw0yU6sTE',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {'urls': [{'start': 48,
#     'end': 71,
#     'url': 'https://t.co/JEkXcrI0OU',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {'urls': [{'start': 54,
#     'end': 77,
#     'url': 'https://t.co/iwX3Ucr1OH',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {},
#  {'urls': [{'start': 54,
#     'end': 77,
#     'url': 'https://t.co/IDSQUlz01h',
#     'expanded_url': 'https://wordle.danielfrg.com/',
#     'display_url': 'wordle.danielfrg.com'}]},
#  {},
#  {'urls': [{'start': 54,
#     'end': 77,
#     'url': 'https://t.co/ISyDkXazB5',
#     'expanded_url': 'https://wordle.louan.me',
#     'display_url': 'wordle.louan.me'}],
#   'mentions': [{'start': 8,
#     'end': 17,
#     'username': 'WordleFR',
#     'id': '1480029602105995267'}]},
#  {},
#  {},
#  {},
#  {'urls': [{'start': 69,
#     'end': 92,
#     'url': 'https://t.co/jxSzzhH0sp',
#     'expanded_url': 'https://wordle.belousov.one',
#     'display_url': 'wordle.belousov.one'}],
#   'hashtags': [{'start': 39, 'end': 46, 'tag': 'вордли'}]},
#  {},
#  ...]

# %% [markdown]
# ---
# ### get all keys for all json columns
#
# Refer to these later when expanding the json columns.

# %%
# gives the set of keys that show up in a list of dicts.

def get_dict_keys(list_of_dicts):
    key_ring = [
        list(entry.keys())
        for entry in list_of_dicts
    ]
    return list(reduce(np.union1d, key_ring))

# %%
json_cols_minus_context = ['entities_tweet',
 'public_metrics_tweet',
 'public_metrics_user',
 'entities_user']

# %%
# %%time
# col_keys = []
# for column in json_cols_minus_context:
#     col_keys.append([column,get_dict_keys(series_literal_eval(tudf[column]))])

# %%
# col_keys_pd = [
#     keys
#     for keys in col_keys
# ]

# %%
# pd.DataFrame(col_keys_pd, columns = ['json column','keys']).to_markdown()

# %% [markdown]
# |    | json column          | keys                                                                  |
# |---:|:---------------------|:----------------------------------------------------------------------|
# |  0 | entities_tweet       | ['annotations', 'cashtags', 'hashtags', 'mentions', 'urls']           |
# |  1 | public_metrics_tweet | ['like_count', 'quote_count', 'reply_count', 'retweet_count']         |
# |  2 | public_metrics_user  | ['followers_count', 'following_count', 'listed_count', 'tweet_count'] |
# |  3 | entities_user        | ['description', 'url']                                                |

# %%
#pandas has its own function that turns "semi-structured" json into a flat table.

#expand entities_tweet column
pd.json_normalize(entities_tweet_list)
# Out:
#                                                      urls  \
# 0       [{'start': 54, 'end': 77, 'url': 'https://t.co...
# 1       [{'start': 58, 'end': 81, 'url': 'https://t.co...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 335322                                                NaN
# 335323                                                NaN
# 335324                                                NaN
# 335325                                                NaN
# 335326                                                NaN
#
#                                                  mentions hashtags  \
# 0                                                     NaN      NaN
# 1                                                     NaN      NaN
# 2                                                     NaN      NaN
# 3                                                     NaN      NaN
# 4       [{'start': 0, 'end': 12, 'username': 'RwellsWe...      NaN
# ...                                                   ...      ...
# 335322                                                NaN      NaN
# 335323                                                NaN      NaN
# 335324                                                NaN      NaN
# 335325                                                NaN      NaN
# 335326                                                NaN      NaN
#
#        annotations cashtags
# 0              NaN      NaN
# 1              NaN      NaN
# 2              NaN      NaN
# 3              NaN      NaN
# 4              NaN      NaN
# ...            ...      ...
# 335322         NaN      NaN
# 335323         NaN      NaN
# 335324         NaN      NaN
# 335325         NaN      NaN
# 335326         NaN      NaN
#
# [335327 rows x 5 columns]

# %%
#expand entities_user column
# pd.json_normalize(series_literal_eval(tudf['entities_user']))

# %%
#expand public metrics user columns
#pd.json_normalize(series_literal_eval(tudf['public_metrics_user']))

# %%
#expand public metrics tweet column
#pd.json_normalize(series_literal_eval(tudf['public_metrics_tweet']))

# %%
# takes in a pandas DataFrame, a list of JSON-like columns, expands the columns into their own
# DataFrame with the set of all keys as columns, properly assigns the original tweet index,
# and joins the results onto the original.

def expand_json_cols(pandas_dataframe, json_cols, inplace = False, drop_json_cols = False):
    #save the original index. confirmed it creates a new object, not a link to the last one
    original_index = pandas_dataframe.index
    #make a new dataframe to return if not altering the original
    if not inplace:
        new_df = pandas_dataframe.copy()
    # perform the merges over all the json_cols
    for column in json_cols:
        #create a new DataFrame from the column's jsons.
        new_json_df = pd.json_normalize(series_literal_eval(pandas_dataframe[column]))
        #assign the same indices as the original df to prepare for join
        new_json_df.index = pandas_dataframe.index
        #rename columns with a prefix so they are tracable and don't overwrite
        new_json_df = new_json_df.add_prefix(column)
        #join the expanded json columns to the original data
        if inplace:
            pandas_dataframe = pd.merge(pandas_dataframe, new_json_df, how = 'left')
            if drop_json_cols:
                pandas_dataframe.drop(columns = column, inplace = True)
        else:
            new_df = new_df.join(new_json_df)
            if drop_json_cols:
                new_df.drop(columns = column, inplace = True)
    #when that's done, return the result
    if inplace:
        #already altered the original dataframe
        return None
    else:
        return new_df

# %%
### wait to expand json columns in eda.

#make a new "master" dataframe with expanded json columns.
#%%time
#tudf_expanded = expand_json_cols(tudf,json_cols_minus_context, inplace=False, drop_json_cols=True)
#tudf_expanded

# %% [markdown]
# ---
# ---
# ## Basic EDA

# %%
tudf.columns
# Out:
# Index(['conversation_id', 'reply_settings', 'lang', 'entities_tweet',
#        'possibly_sensitive', 'source', 'public_metrics_tweet', 'text',
#        'context_annotations', 'author_id', 'created_at', 'referenced_tweets',
#        'in_reply_to_user_id', 'attachments', 'geo', 'withheld_tweet', 'name',
#        'public_metrics_user', 'url', 'description', 'profile_image_url',
#        'location', 'protected', 'username', 'verified', 'entities_user',
#        'pinned_tweet_id', 'withheld_user'],
#       dtype='object')

# %%
cols = list(tudf.columns)

# %% [markdown]
# ### time span and tweet ids

# %%
# We'll return to time, but for now, send the created_at column to a datetime column and get the absolute basics.

# %%
tudf['created_at'] = pd.to_datetime(tudf['created_at'])

# %%
#print earliest and latest timestamps, as well as their timedelta difference.
latest = tudf['created_at'].max()
earliest = tudf['created_at'].min()
timespan = latest - earliest
earliest, latest, timespan
# Out:
# (Timestamp('2022-04-29 19:46:55+0000', tz='UTC'),
#  Timestamp('2022-05-05 21:59:57+0000', tz='UTC'),
#  Timedelta('6 days 02:13:02'))

# %%
tudf.index.max()
# Out:
# 1522335315381395456

# %%
# Look at the latest tweet by tweet id.
tudf.loc[tudf.index.max()]
# Out:
# conversation_id                                       1522335315381395456
# reply_settings                                                   everyone
# lang                                                                   en
# entities_tweet                                                         {}
# possibly_sensitive                                                  False
# source                                                    Twitter Web App
# public_metrics_tweet    {'retweet_count': 0, 'reply_count': 0, 'like_c...
# text                         Wordle 320 4/6\n\n🟨🟨⬛⬛⬛\n⬛🟩⬛🟩🟩\n⬛🟩⬛🟩🟩\n🟩🟩🟩🟩🟩
# context_annotations     [{'domain': {'id': '30', 'name': 'Entities [En...
# author_id                                                        21729445
# created_at                                      2022-05-05 21:59:57+00:00
# referenced_tweets                                                      []
# in_reply_to_user_id                                                   0.0
# attachments                                                            {}
# geo                                                                    {}
# withheld_tweet                                                         {}
# name                                                              Barry 
# public_metrics_user     {'followers_count': 217, 'following_count': 16...
# url
# description             Retired fruit sales manager.  Sports car fanat...
# profile_image_url       https://pbs.twimg.com/profile_images/82081217/...
# location                                                            SoFla
# protected                                                           False
# username                                                           iBaz66
# verified                                                            False
# entities_user                                                          {}
# pinned_tweet_id                                                       0.0
# withheld_user                                                          {}
# Name: 1522335315381395456, dtype: object

# %%
# latest tweets by created_at.
tudf.loc[tudf['created_at'] == latest]
# Out:
#                          conversation_id reply_settings lang entities_tweet  \
# tweet_id
# 1522335315381395456  1522335315381395456       everyone   en             {}
#
#                      possibly_sensitive           source  \
# tweet_id
# 1522335315381395456               False  Twitter Web App
#
#                                                   public_metrics_tweet  \
# tweet_id
# 1522335315381395456  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
#                                                              text  \
# tweet_id
# 1522335315381395456  Wordle 320 4/6\n\n🟨🟨⬛⬛⬛\n⬛🟩⬛🟩🟩\n⬛🟩⬛🟩🟩\n🟩🟩🟩🟩🟩
#
#                                                    context_annotations  \
# tweet_id
# 1522335315381395456  [{'domain': {'id': '30', 'name': 'Entities [En...
#
#                      author_id                created_at referenced_tweets  \
# tweet_id
# 1522335315381395456   21729445 2022-05-05 21:59:57+00:00                []
#
#                      in_reply_to_user_id attachments geo withheld_tweet  \
# tweet_id
# 1522335315381395456                  0.0          {}  {}             {}
#
#                         name  \
# tweet_id
# 1522335315381395456  Barry 
#
#                                                    public_metrics_user url  \
# tweet_id
# 1522335315381395456  {'followers_count': 217, 'following_count': 16...
#
#                                                            description  \
# tweet_id
# 1522335315381395456  Retired fruit sales manager.  Sports car fanat...
#
#                                                      profile_image_url  \
# tweet_id
# 1522335315381395456  https://pbs.twimg.com/profile_images/82081217/...
#
#                     location protected username verified entities_user  \
# tweet_id
# 1522335315381395456    SoFla     False   iBaz66    False            {}
#
#                      pinned_tweet_id withheld_user
# tweet_id
# 1522335315381395456              0.0            {}

# %%
#look at oldest tweet by tweet_id
tudf.loc[tudf.index.min()]
# Out:
# conversation_id                                       1520127509051944961
# reply_settings                                                   everyone
# lang                                                                   en
# entities_tweet                                                         {}
# possibly_sensitive                                                  False
# source                                                    Twitter Web App
# public_metrics_tweet    {'retweet_count': 0, 'reply_count': 0, 'like_c...
# text                         Wordle 314 4/6\n\n🟩⬛🟩🟨🟨\n🟩🟩🟩⬛🟨\n🟩🟩🟩🟩⬛\n🟩🟩🟩🟩🟩
# context_annotations     [{'domain': {'id': '30', 'name': 'Entities [En...
# author_id                                                       489622686
# created_at                                      2022-04-29 19:46:55+00:00
# referenced_tweets                                                      []
# in_reply_to_user_id                                                   0.0
# attachments                                                            {}
# geo                                                                    {}
# withheld_tweet                                                         {}
# name                                                       ♔･ﾟ✧Lᴏɢɢʏ･ﾟ✧ ♔
# public_metrics_user     {'followers_count': 9322, 'following_count': 1...
# url
# description             *:･ﾟ I lσνε @arianagrande , & @blackpink *:･ﾟ\...
# profile_image_url       https://pbs.twimg.com/profile_images/148007682...
# location                                             vote lisa and rose😃🤗
# protected                                                           False
# username                                                          loggyf2
# verified                                                            False
# entities_user           {'description': {'mentions': [{'start': 12, 'e...
# pinned_tweet_id                                      695607597261524992.0
# withheld_user                                                          {}
# Name: 1520127509051944961, dtype: object

# %%
# look at oldest tweet by created_at
tudf.loc[tudf['created_at'] == earliest]
# Out:
#                          conversation_id reply_settings lang entities_tweet  \
# tweet_id
# 1520127509051944961  1520127509051944961       everyone   en             {}
#
#                      possibly_sensitive           source  \
# tweet_id
# 1520127509051944961               False  Twitter Web App
#
#                                                   public_metrics_tweet  \
# tweet_id
# 1520127509051944961  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
#                                                              text  \
# tweet_id
# 1520127509051944961  Wordle 314 4/6\n\n🟩⬛🟩🟨🟨\n🟩🟩🟩⬛🟨\n🟩🟩🟩🟩⬛\n🟩🟩🟩🟩🟩
#
#                                                    context_annotations  \
# tweet_id
# 1520127509051944961  [{'domain': {'id': '30', 'name': 'Entities [En...
#
#                      author_id                created_at referenced_tweets  \
# tweet_id
# 1520127509051944961  489622686 2022-04-29 19:46:55+00:00                []
#
#                      in_reply_to_user_id attachments geo withheld_tweet  \
# tweet_id
# 1520127509051944961                  0.0          {}  {}             {}
#
#                                name  \
# tweet_id
# 1520127509051944961  ♔･ﾟ✧Lᴏɢɢʏ･ﾟ✧ ♔
#
#                                                    public_metrics_user url  \
# tweet_id
# 1520127509051944961  {'followers_count': 9322, 'following_count': 1...
#
#                                                            description  \
# tweet_id
# 1520127509051944961  *:･ﾟ I lσνε @arianagrande , & @blackpink *:･ﾟ\...
#
#                                                      profile_image_url  \
# tweet_id
# 1520127509051944961  https://pbs.twimg.com/profile_images/148007682...
#
#                                  location protected username verified  \
# tweet_id
# 1520127509051944961  vote lisa and rose😃🤗     False  loggyf2    False
#
#                                                          entities_user  \
# tweet_id
# 1520127509051944961  {'description': {'mentions': [{'start': 12, 'e...
#
#                      pinned_tweet_id withheld_user
# tweet_id
# 1520127509051944961     6.956076e+17            {}

# %% [markdown]
# [From the docs:](https://developer.twitter.com/en/docs/twitter-ids)
# > The full ID is composed of a timestamp, a worker number, and a sequence number.

# %%
plt.hist(tudf['created_at'])
# Out:
# (array([24056., 31152., 37548., 32618., 40488., 34453., 34570., 34597.,
#         21581., 44264.]),
#  array([19111.82424769, 19112.43348611, 19113.04272454, 19113.65196296,
#         19114.26120139, 19114.87043981, 19115.47967824, 19116.08891667,
#         19116.69815509, 19117.30739352, 19117.91663194]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### conversation Id
# The `conversation_id` is the id of the "base" tweet. If it's different from the tweet id, then the tweet is a reply somewhere in a thread with the base tweet as the root.

# %%
# What tweets have the same conversation id as index (id)?
is_reply = tudf['conversation_id'] != tudf.index
is_reply.sum()
# Out:
# 31827

# %%
is_reply.sum()/len(tudf)
# Out:
# 0.09491332341266882

# %% [markdown]
# about 9% of these tweets are in reply to another tweet. The metrics for these are kept track in public_metrics, so we'll check for numbers of replies and all that ahead.

# %% [markdown]
# ---
# ###  reply_settings
#
# Comes from `tweets`. A setting for who is allowed to reply.
# The great majority (99.6%!) are set to `everyone`. A few thousandths are reserved only for users following the tweeter, or for users mentioned in the tweet.

# %%
rsvcs = tudf['reply_settings'].value_counts(normalize='yeah')*100
rsvcs
# Out:
# everyone          99.572060
# following          0.241853
# mentionedUsers     0.186087
# Name: reply_settings, dtype: float64

# %%
plt.figure(figsize = (3,6))
plt.barh(width=rsvcs, y=rsvcs.index, log = True)
plt.title("log reply settings for each tweet")
plt.xlabel('count');

# %% [markdown]
# ---
# ### Language `lang`
#
# A JSON converter for iso language codes to their proper english names was grabbed from [github/haliaeetus iso-639](https://github.com/haliaeetus/iso-639)

# %%
with open('../iso_639-1.json', 'r', encoding='utf-8') as lang_file:
    lang_dict = json.load(lang_file)
lang_dict['und'] = {'name':'undefined'}
lang_dict['in'] = {'name':'Indonesian'} #filling in some missing ones
lang_dict['iw'] = {'name':'Hebrew'}

# %%
lang_dict['aa']
# Out:
# {'639-1': 'aa',
#  '639-2': 'aar',
#  'family': 'Afro-Asiatic',
#  'name': 'Afar',
#  'nativeName': 'Afaraf',
#  'wikiUrl': 'https://en.wikipedia.org/wiki/Afar_language'}

# %%
np.logspace(0,5,5)
# Out:
# array([1.00000000e+00, 1.77827941e+01, 3.16227766e+02, 5.62341325e+03,
#        1.00000000e+05])

# %%
#plot languages


def plot_tweet_languages(pandas_dataframe, log = True, figsize = (12,24), num_text = True, reverse = True):
    lang_vcs = pandas_dataframe['lang'].value_counts()
    if reverse:
        lang_vcs = lang_vcs[::-1]
    lang_vcs_names = [
        lang_dict[lang]['name']
        for lang in lang_vcs.index
    ]
    fig = plt.figure(figsize=figsize)
    plt.grid(axis = 'x')
    plt.barh(width=lang_vcs, y=lang_vcs_names, log = log)
    plt.title('Twitter Wordle languages' + (' (log)' if log else ''))
    plt.xlabel("number of tweets in data set")
    if num_text:
        for xpos in np.logspace(0,5,6):
            plt.text(x = xpos*1.1, y = 46, s= str(int(xpos)))
    plt.show()
    return None

plot_tweet_languages(tudf)

# %%
plot_tweet_languages(tudf, num_text=False, log = False)

# %% [markdown]
# In the preprocessing stage, the top languages will be given a boolean value for the model to grab onto.

# %% [markdown]
# ---
# ### entities_tweet
#
# These were `entities` in the tweets data. Entities are json-like columns with the following keys:

# %%
entities_tweet_keys = ['urls', 'mentions', 'hashtags', 'annotations', 'cashtags']

# %%
tudf['entities_tweet'].head()
# Out:
# tweet_id
# 1521733018293084160    {'urls': [{'start': 54, 'end': 77, 'url': 'htt...
# 1521733015738662913    {'urls': [{'start': 58, 'end': 81, 'url': 'htt...
# 1521733011414257664                                                   {}
# 1521733010504445954                                                   {}
# 1521733001981444096    {'mentions': [{'start': 0, 'end': 12, 'usernam...
# Name: entities_tweet, dtype: object

# %%
# turn the entities_tweet column into a series of columns, one for each of the possible keys.
tudf = expand_json_cols(tudf, ['entities_tweet'], drop_json_cols=True)

# %%
tudf.head(3)
# Out:
#                          conversation_id reply_settings lang  \
# tweet_id
# 1521733018293084160  1521733018293084160       everyone   en
# 1521733015738662913  1521733015738662913       everyone   es
# 1521733011414257664  1521733011414257664       everyone   en
#
#                      possibly_sensitive               source  \
# tweet_id
# 1521733018293084160               False      Twitter Web App
# 1521733015738662913               False  Twitter for Android
# 1521733011414257664               False  Twitter for Android
#
#                                                   public_metrics_tweet  \
# tweet_id
# 1521733018293084160  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521733015738662913  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521733011414257664  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
#                                                                   text  \
# tweet_id
# 1521733018293084160  Wordle (ES)  #118 5/6\r\n\r\n⬜⬜🟨🟩⬜\r\n⬜⬜🟨🟩⬜\r\...
# 1521733015738662913  Wordle Científico #52 5/6\r\n\r\n⬜⬜⬜⬜🟨\r\n🟨⬜⬜⬜...
# 1521733011414257664  Wordle 319 4/6\r\n\r\n🟨🟨⬜⬜⬜\r\n🟨⬜⬜🟩⬜\r\n🟩🟨⬜🟩🟨\...
#
#                                                    context_annotations  \
# tweet_id
# 1521733018293084160  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521733015738662913  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521733011414257664  [{'domain': {'id': '30', 'name': 'Entities [En...
#
#                                author_id                created_at  \
# tweet_id
# 1521733018293084160  1006110502043471872 2022-05-04 06:06:38+00:00
# 1521733015738662913            360002014 2022-05-04 06:06:38+00:00
# 1521733011414257664   828818052892422148 2022-05-04 06:06:37+00:00
#
#                     referenced_tweets  in_reply_to_user_id attachments geo  \
# tweet_id
# 1521733018293084160                []                  0.0          {}  {}
# 1521733015738662913                []                  0.0          {}  {}
# 1521733011414257664                []                  0.0          {}  {}
#
#                     withheld_tweet          name  \
# tweet_id
# 1521733018293084160             {}  Jose Antonio
# 1521733015738662913             {}  Ana V Garcia
# 1521733011414257664             {}             0
#
#                                                    public_metrics_user  \
# tweet_id
# 1521733018293084160  {'followers_count': 147, 'following_count': 43...
# 1521733015738662913  {'followers_count': 41, 'following_count': 136...
# 1521733011414257664                                                  0
#
#                                          url  \
# tweet_id
# 1521733018293084160
# 1521733015738662913  https://t.co/uMfikCmd0I
# 1521733011414257664                        0
#
#                                                            description  \
# tweet_id
# 1521733018293084160  Antiguo usuario bloqueado por error, pero he v...
# 1521733015738662913
# 1521733011414257664                                                  0
#
#                                                      profile_image_url  \
# tweet_id
# 1521733018293084160  https://pbs.twimg.com/profile_images/144681186...
# 1521733015738662913  https://pbs.twimg.com/profile_images/122215871...
# 1521733011414257664                                                  0
#
#                                       location protected     username  \
# tweet_id
# 1521733018293084160  Alcalá de Guadaíra, Spain     False   Joseamj_97
# 1521733015738662913          Alcalá de Henares     False  AnaVGarciaG
# 1521733011414257664                          0         0            0
#
#                     verified  \
# tweet_id
# 1521733018293084160    False
# 1521733015738662913    False
# 1521733011414257664        0
#
#                                                          entities_user  \
# tweet_id
# 1521733018293084160                                                 {}
# 1521733015738662913  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1521733011414257664                                                  0
#
#                      pinned_tweet_id withheld_user  \
# tweet_id
# 1521733018293084160              0.0            {}
# 1521733015738662913              0.0            {}
# 1521733011414257664              0.0             0
#
#                                                     entities_tweeturls  \
# tweet_id
# 1521733018293084160  [{'start': 54, 'end': 77, 'url': 'https://t.co...
# 1521733015738662913  [{'start': 58, 'end': 81, 'url': 'https://t.co...
# 1521733011414257664                                                NaN
#
#                     entities_tweetmentions entities_tweethashtags  \
# tweet_id
# 1521733018293084160                    NaN                    NaN
# 1521733015738662913                    NaN                    NaN
# 1521733011414257664                    NaN                    NaN
#
#                     entities_tweetannotations entities_tweetcashtags
# tweet_id
# 1521733018293084160                       NaN                    NaN
# 1521733015738662913                       NaN                    NaN
# 1521733011414257664                       NaN                    NaN

# %%
tudf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 335327 entries, 1521733018293084160 to 1521994876677672966
# Data columns (total 32 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   conversation_id            335327 non-null  int64
#  1   reply_settings             335327 non-null  object
#  2   lang                       335327 non-null  object
#  3   possibly_sensitive         335327 non-null  bool
#  4   source                     335327 non-null  object
#  5   public_metrics_tweet       335327 non-null  object
#  6   text                       335327 non-null  object
#  7   context_annotations        335327 non-null  object
#  8   author_id                  335327 non-null  int64
#  9   created_at                 335327 non-null  datetime64[ns, UTC]
#  10  referenced_tweets          335327 non-null  object
#  11  in_reply_to_user_id        335327 non-null  float64
#  12  attachments                335327 non-null  object
#  13  geo                        335327 non-null  object
#  14  withheld_tweet             335327 non-null  object
#  15  name                       335327 non-null  object
#  16  public_metrics_user        335327 non-null  object
#  17  url                        335327 non-null  object
#  18  description                335327 non-null  object
#  19  profile_image_url          335327 non-null  object
#  20  location                   335327 non-null  object
#  21  protected                  335327 non-null  object
#  22  username                   335327 non-null  object
#  23  verified                   335327 non-null  object
#  24  entities_user              335327 non-null  object
#  25  pinned_tweet_id            335327 non-null  float64
#  26  withheld_user              335327 non-null  object
#  27  entities_tweeturls         82211 non-null   object
#  28  entities_tweetmentions     20843 non-null   object
#  29  entities_tweethashtags     31604 non-null   object
#  30  entities_tweetannotations  2538 non-null    object
#  31  entities_tweetcashtags     1 non-null       object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(2), int64(2), object(26)
# memory usage: 90.2+ MB

# %% [markdown]
# ### entities_tweeturls
# the first key in `entities_tweet`.

# %%
tudf['entities_tweeturls'].head()
# Out:
# tweet_id
# 1521733018293084160    [{'start': 54, 'end': 77, 'url': 'https://t.co...
# 1521733015738662913    [{'start': 58, 'end': 81, 'url': 'https://t.co...
# 1521733011414257664                                                  NaN
# 1521733010504445954                                                  NaN
# 1521733001981444096                                                  NaN
# Name: entities_tweeturls, dtype: object

# %%
entities_tweeturls_vcs = tudf['entities_tweeturls'].apply(lambda x: len(x) if type(x) == list else x).value_counts()
entities_tweeturls_vcs
# Out:
# 1.0    80761
# 2.0     1318
# 3.0      106
# 4.0       22
# 6.0        3
# 5.0        1
# Name: entities_tweeturls, dtype: int64

# %%
expanded_tweet_urls = [
    entry
    for entry in tudf['entities_tweeturls'].dropna()
]
expanded_tweet_urls
# Out:
# [[{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/oJCukg4JnD',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 58,
#    'end': 81,
#    'url': 'https://t.co/ifnVQsE6bO',
#    'expanded_url': 'https://wordle.danielfrg.com/ciencia/index.html',
#    'display_url': 'wordle.danielfrg.com/ciencia/index.…',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521711979752136704/Qr2DllcV?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521711979752136704/Qr2DllcV?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/ciencia/index.html'}],
#  [{'start': 58,
#    'end': 81,
#    'url': 'https://t.co/Pxb1ZKeNoD',
#    'expanded_url': 'https://wordle.danielfrg.com/ciencia/index.html',
#    'display_url': 'wordle.danielfrg.com/ciencia/index.…',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521711979752136704/Qr2DllcV?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521711979752136704/Qr2DllcV?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/ciencia/index.html'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/IC6ZxPHDEF',
#    'expanded_url': 'https://wordle.mega-yadoran.jp/',
#    'display_url': 'wordle.mega-yadoran.jp',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1520627181159784450/oEzApr9k?format=png&name=orig',
#      'width': 200,
#      'height': 200},
#     {'url': 'https://pbs.twimg.com/news_img/1520627181159784450/oEzApr9k?format=png&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'ポケモンWordle',
#    'description': 'ポケモンWordle (ポケモンワードル)は単語当てゲーム「Wordle」のポケモン版。１０回のチャレンジでポケモンの名前を当てよう！',
#    'unwound_url': 'https://wordle.mega-yadoran.jp/'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/LqTwoZRmma',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/gVwzNU1bJE',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 43,
#    'end': 66,
#    'url': 'https://t.co/lGJkZO2hl7',
#    'expanded_url': 'https://bit.ly/wordlethai',
#    'display_url': 'bit.ly/wordlethai',
#    'status': 200,
#    'title': 'เวิร์ดเดลไทย - Thai Wordle',
#    'description': 'Wordle ฉบับภาษาไทย',
#    'unwound_url': 'https://buddhistuniversity.net/wordle-thai/'}],
#  [{'start': 51,
#    'end': 74,
#    'url': 'https://t.co/BtXcWPrgJa',
#    'expanded_url': 'http://wordle.gelozp.com',
#    'display_url': 'wordle.gelozp.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1520479054184468480/yryaukBy?format=png&name=orig',
#      'width': 400,
#      'height': 400},
#     {'url': 'https://pbs.twimg.com/news_img/1520479054184468480/yryaukBy?format=png&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'WordleCAT - Un mot diari',
#    'description': 'Endevina el mot amagat en 6 intents. Cada dia hi ha un nou mot per endevinar.',
#    'unwound_url': 'https://wordle.gelozp.com/'}],
#  [{'start': 62,
#    'end': 85,
#    'url': 'https://t.co/4wLdS1B3Eo',
#    'expanded_url': 'https://wordle.mega-yadoran.jp/',
#    'display_url': 'wordle.mega-yadoran.jp',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1520627181159784450/oEzApr9k?format=png&name=orig',
#      'width': 200,
#      'height': 200},
#     {'url': 'https://pbs.twimg.com/news_img/1520627181159784450/oEzApr9k?format=png&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'ポケモンWordle',
#    'description': 'ポケモンWordle (ポケモンワードル)は単語当てゲーム「Wordle」のポケモン版。１０回のチャレンジでポケモンの名前を当てよう！',
#    'unwound_url': 'https://wordle.mega-yadoran.jp/'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/QKa1OEBtOf',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 60,
#    'end': 83,
#    'url': 'https://t.co/rao9P4BI4l',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/xvcZIZrn1C',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 11,
#    'end': 34,
#    'url': 'https://t.co/9kAozJhfgA',
#    'expanded_url': 'https://jhlov.github.io/wordle',
#    'display_url': 'jhlov.github.io/wordle'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/IX2xW6CoFe',
#    'expanded_url': 'https://wordle.louan.me',
#    'display_url': 'wordle.louan.me'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/3C0TIloNqG',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/GM0zE5k0Hl',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 60,
#    'end': 83,
#    'url': 'https://t.co/aqLBN2A9r4',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 60,
#    'end': 83,
#    'url': 'https://t.co/Ap6i9Yy0Ya',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 85,
#    'end': 108,
#    'url': 'https://t.co/PTITgYe6Pb',
#    'expanded_url': 'https://wordle.louan.me',
#    'display_url': 'wordle.louan.me'}],
#  [{'start': 26,
#    'end': 49,
#    'url': 'https://t.co/8CnLzuBWOC',
#    'expanded_url': 'https://wordle-jp.netlify.app/',
#    'display_url': 'wordle-jp.netlify.app'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/BWjS9otbCA',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 39,
#    'end': 62,
#    'url': 'https://t.co/4ux5mq4PlD',
#    'expanded_url': 'http://wordle.gelozp.com',
#    'display_url': 'wordle.gelozp.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/VqKBtNowH3',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 57,
#    'end': 80,
#    'url': 'https://t.co/3jE1v0Kn5m',
#    'expanded_url': 'http://wordle.gelozp.com',
#    'display_url': 'wordle.gelozp.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/lSyzFOO1Z3',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 66,
#    'end': 89,
#    'url': 'https://t.co/ifLVf6959X',
#    'expanded_url': 'https://wordle.louan.me',
#    'display_url': 'wordle.louan.me'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/1XY95qobyB',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 34,
#    'end': 57,
#    'url': 'https://t.co/dABljpbPHx',
#    'expanded_url': 'https://twitter.com/deepfriedlard/status/1521369984223514624',
#    'display_url': 'twitter.com/deepfriedlard/…'}],
#  [{'start': 60,
#    'end': 83,
#    'url': 'https://t.co/UYfDx8iylz',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/uxWTQsv3kx',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/e6bPLMyyia',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 69,
#    'end': 92,
#    'url': 'https://t.co/NRzSippMRU',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/LkzSKyQdHG',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 58,
#    'end': 81,
#    'url': 'https://t.co/72uJ8rPlCp',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/VzdHJehuQL',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 82,
#    'end': 105,
#    'url': 'https://t.co/IaUEPseE62',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/uAogSyv9zJ',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 55,
#    'end': 78,
#    'url': 'https://t.co/OMYc29k8GS',
#    'expanded_url': 'http://wordle.at',
#    'display_url': 'wordle.at'}],
#  [{'start': 58,
#    'end': 81,
#    'url': 'https://t.co/Baw2N1Ljt7',
#    'expanded_url': 'https://wordle.danielfrg.com/ciencia/index.html',
#    'display_url': 'wordle.danielfrg.com/ciencia/index.…'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/9w0MwM7FHj',
#    'expanded_url': 'https://wordle.louan.me',
#    'display_url': 'wordle.louan.me'}],
#  [{'start': 28,
#    'end': 51,
#    'url': 'https://t.co/HUMP4KvGbv',
#    'expanded_url': 'https://twitter.com/priestwendy/status/1521732559331282951/photo/1',
#    'display_url': 'pic.twitter.com/HUMP4KvGbv',
#    'media_key': '16_1521732551106310145'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/Ei9OwtR6k4',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/GOymFg1AR3',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/a6FV3ZAwwa',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/LOBFASgKbQ',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/dzaLnHA7uo',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'},
#   {'start': 94,
#    'end': 117,
#    'url': 'https://t.co/2Ifo4gJe0Z',
#    'expanded_url': 'https://twitter.com/slytherinnds/status/1521732521775534081/photo/1',
#    'display_url': 'pic.twitter.com/2Ifo4gJe0Z',
#    'media_key': '16_1521732511805714432'}],
#  [{'start': 58,
#    'end': 81,
#    'url': 'https://t.co/Yz8kw4lcE3',
#    'expanded_url': 'https://wordle.danielfrg.com/ciencia/index.html',
#    'display_url': 'wordle.danielfrg.com/ciencia/index.…',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521711979752136704/Qr2DllcV?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521711979752136704/Qr2DllcV?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/ciencia/index.html'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/1w1Lfos0xN',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/aLmb1GAhgn',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 75,
#    'end': 98,
#    'url': 'https://t.co/2nsCxhOYSs',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 84,
#    'end': 107,
#    'url': 'https://t.co/usBmCsXdwu',
#    'expanded_url': 'https://wordle.danielfrg.com/#',
#    'display_url': 'wordle.danielfrg.com/#'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/FaXJnKrXWZ',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/UHmoJHttft',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/xrcyUgyil1',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 60,
#    'end': 83,
#    'url': 'https://t.co/dsJ1LY4Tfn',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/ZhqNlPPHPz',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/FzJYr0nBJ0',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 79,
#    'end': 102,
#    'url': 'https://t.co/ofC8iJnkkm',
#    'expanded_url': 'http://wordle.gelozp.com',
#    'display_url': 'wordle.gelozp.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/0ta25rI33k',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 87,
#    'end': 110,
#    'url': 'https://t.co/OHLZo1kbEY',
#    'expanded_url': 'https://wordle.belousov.one',
#    'display_url': 'wordle.belousov.one'}],
#  [{'start': 11,
#    'end': 34,
#    'url': 'https://t.co/m8GRzLztZb',
#    'expanded_url': 'https://jhlov.github.io/wordle',
#    'display_url': 'jhlov.github.io/wordle'}],
#  [{'start': 57,
#    'end': 80,
#    'url': 'https://t.co/GwBUPV9m8Q',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/IHcDFMR29n',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/N8d9xYcwzs',
#    'expanded_url': 'https://wordle.mega-yadoran.jp/',
#    'display_url': 'wordle.mega-yadoran.jp'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/ZuqiTgCbwX',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/710R09nYc9',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/b5JT8ZP9me',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 55,
#    'end': 78,
#    'url': 'https://t.co/9nlV6pL0V0',
#    'expanded_url': 'https://wordle.mega-yadoran.jp/',
#    'display_url': 'wordle.mega-yadoran.jp',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1520627181159784450/oEzApr9k?format=png&name=orig',
#      'width': 200,
#      'height': 200},
#     {'url': 'https://pbs.twimg.com/news_img/1520627181159784450/oEzApr9k?format=png&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'ポケモンWordle',
#    'description': 'ポケモンWordle (ポケモンワードル)は単語当てゲーム「Wordle」のポケモン版。１０回のチャレンジでポケモンの名前を当てよう！',
#    'unwound_url': 'https://wordle.mega-yadoran.jp/'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/OKNoQ7rEIB',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 89,
#    'end': 112,
#    'url': 'https://t.co/5h1AN61NVM',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/YdEOQja0si',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/TpKEuGxWCT',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 95,
#    'end': 118,
#    'url': 'https://t.co/gGZVEJAgMX',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 134,
#    'end': 157,
#    'url': 'https://t.co/gZc536YnSB',
#    'expanded_url': 'https://wordle.belousov.one',
#    'display_url': 'wordle.belousov.one'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/8CTKalht3i',
#    'expanded_url': 'https://wordle.louan.me',
#    'display_url': 'wordle.louan.me'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/KvvQte8kcG',
#    'expanded_url': 'https://wordle.mega-yadoran.jp/',
#    'display_url': 'wordle.mega-yadoran.jp',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1520627181159784450/oEzApr9k?format=png&name=orig',
#      'width': 200,
#      'height': 200},
#     {'url': 'https://pbs.twimg.com/news_img/1520627181159784450/oEzApr9k?format=png&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'ポケモンWordle',
#    'description': 'ポケモンWordle (ポケモンワードル)は単語当てゲーム「Wordle」のポケモン版。１０回のチャレンジでポケモンの名前を当てよう！',
#    'unwound_url': 'https://wordle.mega-yadoran.jp/'}],
#  [{'start': 39,
#    'end': 62,
#    'url': 'https://t.co/tLpC59BN9Y',
#    'expanded_url': 'http://wordle.gelozp.com',
#    'display_url': 'wordle.gelozp.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/zJA9agkM6p',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 88,
#    'end': 111,
#    'url': 'https://t.co/cLkxl43qD0',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 64,
#    'end': 87,
#    'url': 'https://t.co/KEAEO4YSBz',
#    'expanded_url': 'https://wordle.danielfrg.com/tildes/index.html',
#    'display_url': 'wordle.danielfrg.com/tildes/index.h…'}],
#  [{'start': 0,
#    'end': 23,
#    'url': 'https://t.co/hQSpbCRtcz',
#    'expanded_url': 'http://6mal5.com',
#    'display_url': '6mal5.com'}],
#  [{'start': 36,
#    'end': 59,
#    'url': 'https://t.co/qAZvZhGk6m',
#    'expanded_url': 'https://wordle.mega-yadoran.jp/',
#    'display_url': 'wordle.mega-yadoran.jp'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/RlVM954Jxi',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/qfyszTCKaD',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/oUqb22mREi',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/dvgP83ZaCf',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/4sDQPwE5cA',
#    'expanded_url': 'https://wordle.mega-yadoran.jp/',
#    'display_url': 'wordle.mega-yadoran.jp'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/dOq9ku0O4i',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/rR5XaXtZ0R',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/9R6UZYMD3x',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/uJEdGvG8UX',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 39,
#    'end': 62,
#    'url': 'https://t.co/ZakKiEKsUR',
#    'expanded_url': 'http://wordle.gelozp.com',
#    'display_url': 'wordle.gelozp.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/sgTsPs0R12',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 51,
#    'end': 74,
#    'url': 'https://t.co/yHI33ROJLe',
#    'expanded_url': 'http://wordle.gelozp.com',
#    'display_url': 'wordle.gelozp.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1520479054184468480/yryaukBy?format=png&name=orig',
#      'width': 400,
#      'height': 400},
#     {'url': 'https://pbs.twimg.com/news_img/1520479054184468480/yryaukBy?format=png&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'WordleCAT - Un mot diari',
#    'description': 'Endevina el mot amagat en 6 intents. Cada dia hi ha un nou mot per endevinar.',
#    'unwound_url': 'https://wordle.gelozp.com/'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/KguzENiojv',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/Xdj83kfUVk',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/IFecYJuJJp',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 87,
#    'end': 110,
#    'url': 'https://t.co/sVK6XzXwKR',
#    'expanded_url': 'https://wordle.belousov.one',
#    'display_url': 'wordle.belousov.one'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/K86RSzhGPS',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/buTcZv0iDv',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/9Upz0uiRag',
#    'expanded_url': 'https://www.bundle.app/wordle-tr/',
#    'display_url': 'bundle.app/wordle-tr/'}],
#  [{'start': 40,
#    'end': 63,
#    'url': 'https://t.co/8rbj6vpAXX',
#    'expanded_url': 'https://wordle.mega-yadoran.jp/',
#    'display_url': 'wordle.mega-yadoran.jp'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/GzP8bj5JAE',
#    'expanded_url': 'https://wordle.danielfrg.com/?s=08',
#    'display_url': 'wordle.danielfrg.com/?s=08'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/6LrZPELAHI',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/PzwYje5otj',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/lpkVOlJjXb',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/vuRhUEeAqs',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/lcDtyUHuY4',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/MqLf2qji4T',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/j8Hj5kq1F6',
#    'expanded_url': 'https://wordle.louan.me',
#    'display_url': 'wordle.louan.me'}],
#  [{'start': 50,
#    'end': 73,
#    'url': 'https://t.co/jMutIMOYrk',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/WOQoMbTuMB',
#    'expanded_url': 'https://wordle.danielfrg.com/tildes/index.html',
#    'display_url': 'wordle.danielfrg.com/tildes/index.h…'}],
#  [{'start': 64,
#    'end': 87,
#    'url': 'https://t.co/xqMuSEVHbx',
#    'expanded_url': 'https://wordle.danielfrg.com/tildes/index.html',
#    'display_url': 'wordle.danielfrg.com/tildes/index.h…'}],
#  [{'start': 72,
#    'end': 95,
#    'url': 'https://t.co/hq8X4VGCWI',
#    'expanded_url': 'https://wordle.danielfrg.com/tildes/index.html',
#    'display_url': 'wordle.danielfrg.com/tildes/index.h…'}],
#  [{'start': 46,
#    'end': 69,
#    'url': 'https://t.co/HFxX7CrLPD',
#    'expanded_url': 'https://wordle.danielfrg.com/ciencia/index.html',
#    'display_url': 'wordle.danielfrg.com/ciencia/index.…'}],
#  [{'start': 34,
#    'end': 57,
#    'url': 'https://t.co/CVS4FQtktG',
#    'expanded_url': 'https://twitter.com/StuartOrr1/status/1521731301337878528/photo/1',
#    'display_url': 'pic.twitter.com/CVS4FQtktG',
#    'media_key': '16_1521731293393960960'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/ZUx5iSC42e',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 67,
#    'end': 90,
#    'url': 'https://t.co/kllXvOfYBq',
#    'expanded_url': 'https://www.bundle.app/wordle-tr/',
#    'display_url': 'bundle.app/wordle-tr/'}],
#  [{'start': 47,
#    'end': 70,
#    'url': 'https://t.co/9xLUtMbvc4',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/kW2ocGC7Ug',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 43,
#    'end': 66,
#    'url': 'https://t.co/Ph6uuGEcnY',
#    'expanded_url': 'http://wordle.at',
#    'display_url': 'wordle.at'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/ZNEVRMopZ0',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 58,
#    'end': 81,
#    'url': 'https://t.co/dw3XO2k9lv',
#    'expanded_url': 'https://wordle.danielfrg.com/ciencia/index.html',
#    'display_url': 'wordle.danielfrg.com/ciencia/index.…'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/YyglqUhmFj',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/QGUBw12yWl',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 49,
#    'end': 72,
#    'url': 'https://t.co/6EV9N6mXYS',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/rKEvsWxozj',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 36,
#    'end': 59,
#    'url': 'https://t.co/VjgVhCH1t6',
#    'expanded_url': 'https://wordle.mega-yadoran.jp/',
#    'display_url': 'wordle.mega-yadoran.jp'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/of3dNdBhCb',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 88,
#    'end': 111,
#    'url': 'https://t.co/vMeaYlrMVQ',
#    'expanded_url': 'http://wordle.gelozp.com',
#    'display_url': 'wordle.gelozp.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1520479054184468480/yryaukBy?format=png&name=orig',
#      'width': 400,
#      'height': 400},
#     {'url': 'https://pbs.twimg.com/news_img/1520479054184468480/yryaukBy?format=png&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'WordleCAT - Un mot diari',
#    'description': 'Endevina el mot amagat en 6 intents. Cada dia hi ha un nou mot per endevinar.',
#    'unwound_url': 'https://wordle.gelozp.com/'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/gW5ZbaxyGW',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 36,
#    'end': 59,
#    'url': 'https://t.co/zZkmsdiqlc',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/faF8qAG5XU',
#    'expanded_url': 'https://www.wordleturkce.com/',
#    'display_url': 'wordleturkce.com'}],
#  [{'start': 41,
#    'end': 64,
#    'url': 'https://t.co/7PsaNn2WaD',
#    'expanded_url': 'https://twitter.com/sh3sg0ne/status/1521730995371724800/photo/1',
#    'display_url': 'pic.twitter.com/7PsaNn2WaD',
#    'media_key': '3_1521730992079130624'}],
#  [{'start': 59,
#    'end': 82,
#    'url': 'https://t.co/B9Gg2eMzM3',
#    'expanded_url': 'http://wordle.gelozp.com',
#    'display_url': 'wordle.gelozp.com'}],
#  [{'start': 77,
#    'end': 100,
#    'url': 'https://t.co/u6s78G5QcK',
#    'expanded_url': 'https://wordle.louan.me',
#    'display_url': 'wordle.louan.me',
#    'status': 200,
#    'title': 'Le Mot - Wordle en français',
#    'description': 'Wordle, mais en français. Devinez le mot du jour ! Totalement gratuit, en ligne, et sans pub.',
#    'unwound_url': 'https://wordle.louan.me'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/TC40Ed5b1G',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/PlNMcyllH7',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 93,
#    'end': 116,
#    'url': 'https://t.co/DwTZS6NCC2',
#    'expanded_url': 'https://wordlegame.org?challenge=c3R1ZGlv',
#    'display_url': 'wordlegame.org/?challenge=c3R…'},
#   {'start': 117,
#    'end': 140,
#    'url': 'https://t.co/VVqXq2Gf7O',
#    'expanded_url': 'https://wordlegame.org/6-letter-words-wordle',
#    'display_url': 'wordlegame.org/6-letter-words…'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/BC8YNQzcwb',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 69,
#    'end': 92,
#    'url': 'https://t.co/kNntYdX2Z5',
#    'expanded_url': 'https://wordle.mega-yadoran.jp/',
#    'display_url': 'wordle.mega-yadoran.jp'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/KbsmQFEaqB',
#    'expanded_url': 'https://wordle.danielfrg.com/ciencia/index.html',
#    'display_url': 'wordle.danielfrg.com/ciencia/index.…'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/OyTm896KLk',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 43,
#    'end': 66,
#    'url': 'https://t.co/jGE0efcn2V',
#    'expanded_url': 'http://wordle.at',
#    'display_url': 'wordle.at'}],
#  [{'start': 85,
#    'end': 108,
#    'url': 'https://t.co/ckwwTx5ryH',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/jF7YbOnpor',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/nSvzQnW1Xl',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/QgwOCNCDt5',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'},
#   {'start': 78,
#    'end': 101,
#    'url': 'https://t.co/kZdrT9cMS3',
#    'expanded_url': 'https://twitter.com/CarlosTribuno/status/1521730761933660161/photo/1',
#    'display_url': 'pic.twitter.com/kZdrT9cMS3',
#    'media_key': '16_1521730754002182150'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/GqWXeHEiXg',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 211,
#    'end': 234,
#    'url': 'https://t.co/3Tx0RtSudv',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/63Xk0S0Js9',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 28,
#    'end': 51,
#    'url': 'https://t.co/ugNbg5KHEW',
#    'expanded_url': 'https://twitter.com/TheKellyLlama/status/1521730730728038400/photo/1',
#    'display_url': 'pic.twitter.com/ugNbg5KHEW',
#    'media_key': '16_1521730723929022465'}],
#  [{'start': 62,
#    'end': 85,
#    'url': 'https://t.co/ExpdWbFM3J',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 73,
#    'end': 96,
#    'url': 'https://t.co/xrmOmjNnEX',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/oSpF15dCLr',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 46,
#    'end': 69,
#    'url': 'https://t.co/b0qyePW5VN',
#    'expanded_url': 'https://wordle.danielfrg.com/ciencia/index.html',
#    'display_url': 'wordle.danielfrg.com/ciencia/index.…'}],
#  [{'start': 84,
#    'end': 107,
#    'url': 'https://t.co/Ovr3nOl5Ix',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/8kRxEJkFiZ',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/3SqWrUNvDn',
#    'expanded_url': 'https://wordle.mega-yadoran.jp/',
#    'display_url': 'wordle.mega-yadoran.jp'}],
#  [{'start': 99,
#    'end': 122,
#    'url': 'https://t.co/jaPswgZoKM',
#    'expanded_url': 'https://wordle.belousov.one',
#    'display_url': 'wordle.belousov.one'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/M8T0IU0iSG',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 55,
#    'end': 78,
#    'url': 'https://t.co/Plup9ahX7H',
#    'expanded_url': 'http://wordle.at',
#    'display_url': 'wordle.at'}],
#  [{'start': 266,
#    'end': 289,
#    'url': 'https://t.co/3Tx0RtSudv',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/As5Lm9OcO7',
#    'expanded_url': 'https://www.bundle.app/wordle-tr/',
#    'display_url': 'bundle.app/wordle-tr/'}],
#  [{'start': 56,
#    'end': 79,
#    'url': 'https://t.co/UnXwlxoTpq',
#    'expanded_url': 'https://wordle.danielfrg.com/tildes/index.html',
#    'display_url': 'wordle.danielfrg.com/tildes/index.h…'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/ydjDr0pS1m',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 59,
#    'end': 82,
#    'url': 'https://t.co/tWKyN9LMBs',
#    'expanded_url': 'http://wordle.at',
#    'display_url': 'wordle.at'},
#   {'start': 84,
#    'end': 107,
#    'url': 'https://t.co/CiyFetYOrC',
#    'expanded_url': 'http://6mal5.com',
#    'display_url': '6mal5.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/r4ewhPm3Nf',
#    'expanded_url': 'https://www.wordleturkce.com/',
#    'display_url': 'wordleturkce.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/eP1iXOcb4s',
#    'expanded_url': 'https://bit.ly/3qnLmpT',
#    'display_url': 'bit.ly/3qnLmpT',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/KPgY3tqsIJ',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 60,
#    'end': 83,
#    'url': 'https://t.co/SFV59N4ggh',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/YtrncKhysk',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/XLEilrNa2z',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/kkrOHw2C8u',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/iewnKAVvvN',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/y2AVZZAwXJ',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 28,
#    'end': 51,
#    'url': 'https://t.co/pzrlFv1ITk',
#    'expanded_url': 'https://twitter.com/nfcresswell/status/1521730340619968513/photo/1',
#    'display_url': 'pic.twitter.com/pzrlFv1ITk',
#    'media_key': '3_1521730331677765632'}],
#  [{'start': 45,
#    'end': 68,
#    'url': 'https://t.co/xktOymzSRD',
#    'expanded_url': 'http://term.ooo',
#    'display_url': 'term.ooo'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/MhXJrYmapa',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/JXGaE2O15O',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 86,
#    'end': 109,
#    'url': 'https://t.co/WKUCUWZmdC',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/4IbPMPxJ46',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/yuXcRte5JZ',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 60,
#    'end': 83,
#    'url': 'https://t.co/y2AVZZAwXJ',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 36,
#    'end': 59,
#    'url': 'https://t.co/m1HdPnFc58',
#    'expanded_url': 'https://wordle.mega-yadoran.jp/',
#    'display_url': 'wordle.mega-yadoran.jp'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/qs2X1x9Rir',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 52,
#    'end': 75,
#    'url': 'https://t.co/E1sEtqd17z',
#    'expanded_url': 'http://wordle.gelozp.com',
#    'display_url': 'wordle.gelozp.com'}],
#  [{'start': 60,
#    'end': 83,
#    'url': 'https://t.co/yd1WnrXGVd',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/tRvTL3R8CR',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/3xCBJFRKFr',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/jS20wE1wj0',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/hQgfjN9r7t',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/R27eZJcBqP',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 45,
#    'end': 68,
#    'url': 'https://t.co/HY6BNlNi7l',
#    'expanded_url': 'http://wordle.gelozp.com',
#    'display_url': 'wordle.gelozp.com'}],
#  [{'start': 41,
#    'end': 64,
#    'url': 'https://t.co/ENaN7jx6tt',
#    'expanded_url': 'https://sutom.nocle.fr',
#    'display_url': 'sutom.nocle.fr'},
#   {'start': 120,
#    'end': 143,
#    'url': 'https://t.co/GPcTLUD73Y',
#    'expanded_url': 'https://wordle.louan.me',
#    'display_url': 'wordle.louan.me'}],
#  [{'start': 52,
#    'end': 75,
#    'url': 'https://t.co/jsqOProBop',
#    'expanded_url': 'http://sozutap.com',
#    'display_url': 'sozutap.com'}],
#  [{'start': 70,
#    'end': 93,
#    'url': 'https://t.co/0jAuZjzerG',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/UjNhczbEsj',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 58,
#    'end': 81,
#    'url': 'https://t.co/J7w4wvXMHB',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 49,
#    'end': 72,
#    'url': 'https://t.co/aknweVuYDR',
#    'expanded_url': 'http://wordle.at',
#    'display_url': 'wordle.at'}],
#  [{'start': 87,
#    'end': 110,
#    'url': 'https://t.co/nqG8t4lA60',
#    'expanded_url': 'https://wordle.belousov.one',
#    'display_url': 'wordle.belousov.one'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/Z0yOBqoghS',
#    'expanded_url': 'https://wordle.danielfrg.com/tildes/index.html',
#    'display_url': 'wordle.danielfrg.com/tildes/index.h…'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/C2tsMsnYKA',
#    'expanded_url': 'https://www.wordleturkce.com/',
#    'display_url': 'wordleturkce.com'}],
#  [{'start': 67,
#    'end': 90,
#    'url': 'https://t.co/qhAUc5SNAp',
#    'expanded_url': 'https://wordle.mega-yadoran.jp/',
#    'display_url': 'wordle.mega-yadoran.jp'}],
#  [{'start': 72,
#    'end': 95,
#    'url': 'https://t.co/a19RVywLsI',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/mpKXN3IFIl',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 55,
#    'end': 78,
#    'url': 'https://t.co/QjBeZ33Lem',
#    'expanded_url': 'http://wordle.at',
#    'display_url': 'wordle.at'}],
#  [{'start': 67,
#    'end': 90,
#    'url': 'https://t.co/nnK297hFr1',
# ...
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/DqlmNM93J8',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 51,
#    'end': 74,
#    'url': 'https://t.co/WVfYz5FnwT',
#    'expanded_url': 'http://wordle.gelozp.com',
#    'display_url': 'wordle.gelozp.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/S2XuyEul7u',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/XYlqFkYzmf',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/x4QFRAZReE',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 66,
#    'end': 89,
#    'url': 'https://t.co/DuEMLKs8an',
#    'expanded_url': 'https://wordle.louan.me',
#    'display_url': 'wordle.louan.me'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/hN59iP5oqn',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/U19Q4jQL1g',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/CHSqrXxYPO',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 57,
#    'end': 80,
#    'url': 'https://t.co/WYZMs2F1Lr',
#    'expanded_url': 'http://wordle.gelozp.com',
#    'display_url': 'wordle.gelozp.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/9OCJCwbH6B',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/mJeHcKpoSb',
#    'expanded_url': 'https://wordle.danielfrg.com/tildes/index.html',
#    'display_url': 'wordle.danielfrg.com/tildes/index.h…'}],
#  [{'start': 51,
#    'end': 74,
#    'url': 'https://t.co/AZB7RcLRIQ',
#    'expanded_url': 'http://wordle.gelozp.com',
#    'display_url': 'wordle.gelozp.com'}],
#  [{'start': 47,
#    'end': 70,
#    'url': 'https://t.co/S8eEGmBaTS',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 40,
#    'end': 63,
#    'url': 'https://t.co/7ht4uf3BkZ',
#    'expanded_url': 'https://wordle.danielfrg.com/tildes/index.html',
#    'display_url': 'wordle.danielfrg.com/tildes/index.h…'}],
#  [{'start': 85,
#    'end': 108,
#    'url': 'https://t.co/3bnsCEnGU5',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/12MoLQN5gf',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 36,
#    'end': 59,
#    'url': 'https://t.co/7MsRXhOQSs',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 62,
#    'end': 85,
#    'url': 'https://t.co/xGt6MkDDFZ',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 86,
#    'end': 109,
#    'url': 'https://t.co/rau2H5V6wd',
#    'expanded_url': 'https://wordle.louan.me',
#    'display_url': 'wordle.louan.me'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/8VKDWONQDv',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 46,
#    'end': 69,
#    'url': 'https://t.co/ya1ZDFOt6Q',
#    'expanded_url': 'https://wordle.danielfrg.com/ciencia/index.html',
#    'display_url': 'wordle.danielfrg.com/ciencia/index.…'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/rhanLs0zVd',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/1BHGDHdnaD',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/6MdGeqEBbJ',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 14,
#    'end': 37,
#    'url': 'https://t.co/xPZN2TknJy',
#    'expanded_url': 'https://jhlov.github.io/wordle',
#    'display_url': 'jhlov.github.io/wordle'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/YBHw9S3Iim',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/vIAfhnJNqf',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 106,
#    'end': 129,
#    'url': 'https://t.co/GhGUl0lDc4',
#    'expanded_url': 'https://bit.ly/Best_Wordle_C',
#    'display_url': 'bit.ly/Best_Wordle_C'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/SNx2zIVLSv',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 59,
#    'end': 82,
#    'url': 'https://t.co/irl0wDvQzX',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/EJliuSoKP3',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/X1kJYMinqI',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 99,
#    'end': 122,
#    'url': 'https://t.co/sU6XYYU48L',
#    'expanded_url': 'https://wordle.belousov.one',
#    'display_url': 'wordle.belousov.one'}],
#  [{'start': 68,
#    'end': 91,
#    'url': 'https://t.co/tz1jRnJprB',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/dqJ2ZlL3a0',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 207,
#    'end': 230,
#    'url': 'https://t.co/CiRpF3kIgY',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/n1heJT50Tw',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/G8fR16G2OS',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 117,
#    'end': 140,
#    'url': 'https://t.co/pCPEuoeHS2',
#    'expanded_url': 'http://wordle.at',
#    'display_url': 'wordle.at'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/W94IA2DvS8',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/GRZlY4KwK1',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 66,
#    'end': 89,
#    'url': 'https://t.co/rTAp3IUUcM',
#    'expanded_url': 'https://wordle.louan.me',
#    'display_url': 'wordle.louan.me'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/gJAaA24n66',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/XB57jY5euU',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 62,
#    'end': 85,
#    'url': 'https://t.co/WqETg7EgVa',
#    'expanded_url': 'https://wordle.mega-yadoran.jp/',
#    'display_url': 'wordle.mega-yadoran.jp',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1520627181159784450/oEzApr9k?format=png&name=orig',
#      'width': 200,
#      'height': 200},
#     {'url': 'https://pbs.twimg.com/news_img/1520627181159784450/oEzApr9k?format=png&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'ポケモンWordle',
#    'description': 'ポケモンWordle (ポケモンワードル)は単語当てゲーム「Wordle」のポケモン版。１０回のチャレンジでポケモンの名前を当てよう！',
#    'unwound_url': 'https://wordle.mega-yadoran.jp/'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/1mthiF8l6Z',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 50,
#    'end': 73,
#    'url': 'https://t.co/nr7HsJABNo',
#    'expanded_url': 'http://wordle.gelozp.com',
#    'display_url': 'wordle.gelozp.com'}],
#  [{'start': 58,
#    'end': 81,
#    'url': 'https://t.co/I5AHKCLvla',
#    'expanded_url': 'https://wordle.danielfrg.com/ciencia/index.html',
#    'display_url': 'wordle.danielfrg.com/ciencia/index.…',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521711979752136704/Qr2DllcV?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521711979752136704/Qr2DllcV?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/ciencia/index.html'}],
#  [{'start': 58,
#    'end': 81,
#    'url': 'https://t.co/JHdKChlNZa',
#    'expanded_url': 'https://twitter.com/Aikilime/status/1521718751011426305/photo/1',
#    'display_url': 'pic.twitter.com/JHdKChlNZa',
#    'media_key': '3_1521718742677438464'}],
#  [{'start': 23,
#    'end': 46,
#    'url': 'https://t.co/Q3eJpB5HPo',
#    'expanded_url': 'https://jhlov.github.io/wordle',
#    'display_url': 'jhlov.github.io/wordle'}],
#  [{'start': 66,
#    'end': 89,
#    'url': 'https://t.co/l9o8S7fKW4',
#    'expanded_url': 'https://wordle.louan.me',
#    'display_url': 'wordle.louan.me'}],
#  [{'start': 60,
#    'end': 83,
#    'url': 'https://t.co/RfTKIonVzb',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 69,
#    'end': 92,
#    'url': 'https://t.co/NbVtWXt8Mr',
#    'expanded_url': 'https://wordle.mega-yadoran.jp/',
#    'display_url': 'wordle.mega-yadoran.jp'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/zs2CMvptZZ',
#    'expanded_url': 'https://www.bundle.app/wordle-tr/',
#    'display_url': 'bundle.app/wordle-tr/'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/289iww8gix',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 34,
#    'end': 57,
#    'url': 'https://t.co/92zunsu1P2',
#    'expanded_url': 'https://twitter.com/loljocks_grimey/status/1521718637303894017/photo/1',
#    'display_url': 'pic.twitter.com/92zunsu1P2',
#    'media_key': '16_1521718631335440384'}],
#  [{'start': 86,
#    'end': 109,
#    'url': 'https://t.co/ZnKNgnh3PC',
#    'expanded_url': 'https://wordle.louan.me',
#    'display_url': 'wordle.louan.me'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/UR0l7LyNCl',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 60,
#    'end': 83,
#    'url': 'https://t.co/Cx4qZjRTO6',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/XuONbWBbDf',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/0OTVMJUDP0',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/FEGD26IsVo',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 52,
#    'end': 75,
#    'url': 'https://t.co/qv7sbEiQtP',
#    'expanded_url': 'https://wordle.danielfrg.com/ciencia/index.html',
#    'display_url': 'wordle.danielfrg.com/ciencia/index.…'}],
#  [{'start': 62,
#    'end': 85,
#    'url': 'https://t.co/bZ1jlfWTbN',
#    'expanded_url': 'https://wordlepeaks.com',
#    'display_url': 'wordlepeaks.com'}],
#  [{'start': 49,
#    'end': 72,
#    'url': 'https://t.co/UOTEQS9IEI',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/YUOPt1BKEX',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/bsIcZwS0pC',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 56,
#    'end': 79,
#    'url': 'https://t.co/QhkrLWLQZ0',
#    'expanded_url': 'https://wordle.danielfrg.com/tildes/index.html',
#    'display_url': 'wordle.danielfrg.com/tildes/index.h…'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/DkrhqNIihJ',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/fwUQbGDF9g',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 43,
#    'end': 66,
#    'url': 'https://t.co/MbaQNxpMX5',
#    'expanded_url': 'http://wordle.at',
#    'display_url': 'wordle.at'}],
#  [{'start': 55,
#    'end': 78,
#    'url': 'https://t.co/62HZ3W52Pz',
#    'expanded_url': 'https://wordle.mega-yadoran.jp/',
#    'display_url': 'wordle.mega-yadoran.jp',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1520627181159784450/oEzApr9k?format=png&name=orig',
#      'width': 200,
#      'height': 200},
#     {'url': 'https://pbs.twimg.com/news_img/1520627181159784450/oEzApr9k?format=png&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'ポケモンWordle',
#    'description': 'ポケモンWordle (ポケモンワードル)は単語当てゲーム「Wordle」のポケモン版。１０回のチャレンジでポケモンの名前を当てよう！',
#    'unwound_url': 'https://wordle.mega-yadoran.jp/'}],
#  [{'start': 36,
#    'end': 59,
#    'url': 'https://t.co/TgDNMM79sL',
#    'expanded_url': 'https://wordle.mega-yadoran.jp/',
#    'display_url': 'wordle.mega-yadoran.jp'}],
#  [{'start': 24,
#    'end': 47,
#    'url': 'https://t.co/VTUp3KPfgS',
#    'expanded_url': 'http://k-wordle.com',
#    'display_url': 'k-wordle.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/N4zBLOJksP',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/COFleOXX0U',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 58,
#    'end': 81,
#    'url': 'https://t.co/Wqb9SAIc2y',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  ...]

# %%
len(expanded_tweet_urls)
# Out:
# 82211

# %% [markdown]
# entities_tweeturls appear to have a base set of keys, with `start` and `end` some integers that appear to typically be 23 characters long. This is the same length as the `url` string, which appears to be a twitter-specific "bit.ly" or "tiny url" style url. These also come with `expanded_url` and `display_url` which have the original url with or without the https:// prefix.
#
# the `start` and `end` keys appear to be common amongst all of these entities. They give the location in the tweet text of the entity. I am largely uninterested in this location.
#
# There are other keys: `media_key` is a string of format `num_numnumnum`

# %%
# get all linked urls.

# %% [markdown]
# ### entities_tweetmentions
#
# A list of users mentioned in the tweet. Includes the username and user id.
#
# Each entry is a list of dicts. Each dict is itself a user.

# %%
expanded_tweet_mentions = [
    entry
    for entry in tudf['entities_tweetmentions'].dropna()
]
expanded_tweet_mentions
# Out:
# [[{'start': 0, 'end': 12, 'username': 'RwellsWells', 'id': '331622540'}],
#  [{'start': 0,
#    'end': 16,
#    'username': 'misfortunateApe',
#    'id': '1275838631891152898'},
#   {'start': 17,
#    'end': 31,
#    'username': 'SamuelAlpha77',
#    'id': '1353120743199023106'},
#   {'start': 32, 'end': 40, 'username': '1kisfud', 'id': '1495802955580297216'},
#   {'start': 41,
#    'end': 53,
#    'username': 'SumPersonal',
#    'id': '1437848652085669894'},
#   {'start': 54,
#    'end': 69,
#    'username': 'ifyouknowyk4ir',
#    'id': '1105516614978596864'},
#   {'start': 70,
#    'end': 84,
#    'username': '42Chainlink42',
#    'id': '1350970179128356866'},
#   {'start': 85,
#    'end': 101,
#    'username': 'onlyshitpost777',
#    'id': '1150564524354764800'}],
#  [{'start': 0, 'end': 9, 'username': 'albolt76', 'id': '1160130818678972416'},
#   {'start': 10,
#    'end': 24,
#    'username': 'aBitSquirrely',
#    'id': '1248231058614747137'},
#   {'start': 25, 'end': 34, 'username': 'dawardle', 'id': '1165789231'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0, 'end': 14, 'username': 'NarcissusCapM', 'id': '611788548'},
#   {'start': 15,
#    'end': 24,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'},
#   {'start': 33,
#    'end': 42,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 71, 'end': 79, 'username': 'AboutEG', 'id': '957239371'}],
#  [{'start': 0, 'end': 7, 'username': 'suwhar', 'id': '31870615'}],
#  [{'start': 66, 'end': 74, 'username': 'nytimes', 'id': '807095'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0,
#    'end': 15,
#    'username': 'DaraghO_Writer',
#    'id': '1488947351620362242'}],
#  [{'start': 0,
#    'end': 11,
#    'username': 'itsbroWken',
#    'id': '1291469818877620226'}],
#  [{'start': 0, 'end': 8, 'username': 'Pocotu4', 'id': '1259399014627377158'}],
#  [{'start': 0, 'end': 13, 'username': 'olliemasters', 'id': '86398584'}],
#  [{'start': 0, 'end': 11, 'username': 'lauravy555', 'id': '4707430889'},
#   {'start': 12, 'end': 21, 'username': 'vinamher', 'id': '300952598'},
#   {'start': 22, 'end': 37, 'username': 'garcia_chema_8', 'id': '2423128126'},
#   {'start': 38, 'end': 52, 'username': 'palomavmartin', 'id': '1370356184'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 70,
#    'end': 79,
#    'username': 'dewordle',
#    'id': '1482411529152741376'}],
#  [{'start': 52, 'end': 61, 'username': 'hvamstad', 'id': '190352471'},
#   {'start': 62, 'end': 70, 'username': 'emufear', 'id': '13545062'},
#   {'start': 71, 'end': 85, 'username': 'rovinbhandari', 'id': '471186624'},
#   {'start': 86, 'end': 94, 'username': 'linkovm', 'id': '925805345233973248'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0, 'end': 10, 'username': 'augie_pup', 'id': '2959665705'}],
#  [{'start': 0,
#    'end': 12,
#    'username': 'ITankMuchOW',
#    'id': '1282276437429379075'}],
#  [{'start': 0,
#    'end': 10,
#    'username': 'RondaAbad',
#    'id': '1343862882795188225'}],
#  [{'start': 0, 'end': 15, 'username': 'AdrianManifold', 'id': '804321630'}],
#  [{'start': 0, 'end': 12, 'username': 'TonyRenucci', 'id': '325517086'},
#   {'start': 13, 'end': 22, 'username': 'Henscher', 'id': '35743765'},
#   {'start': 31,
#    'end': 40,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0, 'end': 9, 'username': 'MoRupees', 'id': '1245246639838826497'},
#   {'start': 10, 'end': 24, 'username': 'TradingNerden', 'id': '3346402781'},
#   {'start': 25, 'end': 31, 'username': 'igge4', 'id': '468705257'},
#   {'start': 32,
#    'end': 47,
#    'username': 'A_Gustavsson83',
#    'id': '1276034256524005382'},
#   {'start': 48,
#    'end': 60,
#    'username': 'frejornberg',
#    'id': '1060132889453608960'},
#   {'start': 61, 'end': 70, 'username': 'missswee', 'id': '84899949'},
#   {'start': 71, 'end': 87, 'username': 'anders1337h4x0r', 'id': '3331600516'},
#   {'start': 88,
#    'end': 101,
#    'username': 'viccaninvest',
#    'id': '1213521062270423040'},
#   {'start': 102, 'end': 116, 'username': 'aniajohansson', 'id': '583823318'},
#   {'start': 117,
#    'end': 129,
#    'username': 'RikLangsamt',
#    'id': '1398347685971771396'},
#   {'start': 130,
#    'end': 143,
#    'username': 'alden_niklas',
#    'id': '876356830401892352'},
#   {'start': 144,
#    'end': 156,
#    'username': 'TomteTrader',
#    'id': '1370353387800252426'},
#   {'start': 157, 'end': 169, 'username': 'emil_bogren', 'id': '374650576'},
#   {'start': 170, 'end': 178, 'username': 'Grottot', 'id': '127069187'}],
#  [{'start': 26, 'end': 39, 'username': 'misterspoons', 'id': '70691724'}],
#  [{'start': 48,
#    'end': 62,
#    'username': 'DebSreeSarkar',
#    'id': '932135675997982720'}],
#  [{'start': 0, 'end': 8, 'username': 'jaberpo', 'id': '166920924'},
#   {'start': 9, 'end': 18, 'username': 'ppucedac', 'id': '263597822'},
#   {'start': 19,
#    'end': 33,
#    'username': 'Rusty76936632',
#    'id': '1164095506357936128'},
#   {'start': 34,
#    'end': 45,
#    'username': 'bertoconve',
#    'id': '741186522561556480'},
#   {'start': 46, 'end': 61, 'username': 'Pancho_Badajoz', 'id': '163801624'},
#   {'start': 62, 'end': 73, 'username': 'PabloRaso1', 'id': '559072218'},
#   {'start': 74, 'end': 85, 'username': 'Santihumor', 'id': '132365110'},
#   {'start': 86, 'end': 102, 'username': 'cmartinizkierdo', 'id': '368185661'},
#   {'start': 103, 'end': 110, 'username': 'pukyjc', 'id': '387881156'},
#   {'start': 111, 'end': 123, 'username': 'williemjose', 'id': '1706947710'},
#   {'start': 124, 'end': 139, 'username': 'juanito_aragor', 'id': '253241290'}],
#  [{'start': 3,
#    'end': 12,
#    'username': 'chutypon',
#    'id': '1516012410993356811'}],
#  [{'start': 0, 'end': 11, 'username': 'marcusreif', 'id': '14656612'}],
#  [{'start': 0, 'end': 7, 'username': 'pukyjc', 'id': '387881156'},
#   {'start': 8, 'end': 22, 'username': 'SusanaAmestoy', 'id': '363910327'},
#   {'start': 23,
#    'end': 39,
#    'username': 'Tarariquetevi19',
#    'id': '1143994676606898177'},
#   {'start': 40,
#    'end': 51,
#    'username': 'MaJoAndSol',
#    'id': '1272514678552494080'},
#   {'start': 52, 'end': 63, 'username': 'PabloRaso1', 'id': '559072218'},
#   {'start': 64,
#    'end': 74,
#    'username': 'cubanmood',
#    'id': '1060607648071073793'},
#   {'start': 75, 'end': 82, 'username': 'fjc162', 'id': '1386376867310092288'},
#   {'start': 83, 'end': 96, 'username': 'ArturoSherpa', 'id': '2383908665'},
#   {'start': 97,
#    'end': 108,
#    'username': 'trasquilon',
#    'id': '1427683457681997827'},
#   {'start': 109,
#    'end': 120,
#    'username': 'LoroParece',
#    'id': '1312493830181138433'},
#   {'start': 121, 'end': 133, 'username': 'LegoLlorchs', 'id': '2713932328'},
#   {'start': 134, 'end': 147, 'username': 'Mr_daltonico', 'id': '978867998'},
#   {'start': 148,
#    'end': 157,
#    'username': 'Tontero_',
#    'id': '1280640704537153543'}],
#  [{'start': 0,
#    'end': 10,
#    'username': 'Batwayne_',
#    'id': '711826098116427776'}],
#  [{'start': 0, 'end': 10, 'username': 'powlster_', 'id': '3000978782'},
#   {'start': 144,
#    'end': 153,
#    'username': 'dewordle',
#    'id': '1482411529152741376'}],
#  [{'start': 118,
#    'end': 129,
#    'username': 'MeuLetreco',
#    'id': '1478877251060080643'}],
#  [{'start': 74,
#    'end': 83,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0, 'end': 12, 'username': 'TomJChicago', 'id': '14542977'}],
#  [{'start': 0, 'end': 10, 'username': 'shann1972', 'id': '15107261'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 16, 'end': 25, 'username': 'dawardle', 'id': '1165789231'}],
#  [{'start': 0,
#    'end': 16,
#    'username': 'SheepishBuffalo',
#    'id': '1513783193299611649'},
#   {'start': 17,
#    'end': 28,
#    'username': 'roselogie1',
#    'id': '1452589840009138185'},
#   {'start': 29,
#    'end': 43,
#    'username': 'LynneDMNoble1',
#    'id': '1454928335054819330'},
#   {'start': 44,
#    'end': 60,
#    'username': 'SpongebobKnackp',
#    'id': '732320439565963265'},
#   {'start': 61, 'end': 70, 'username': 'yvonnegw', 'id': '552226802'}],
#  [{'start': 0, 'end': 6, 'username': 'dlhwp', 'id': '20502634'}],
#  [{'start': 0, 'end': 10, 'username': 'jimpynell', 'id': '546788032'},
#   {'start': 11, 'end': 23, 'username': 'davesaysFTS', 'id': '22590084'},
#   {'start': 24, 'end': 36, 'username': 'brychantodd', 'id': '153057814'},
#   {'start': 37, 'end': 43, 'username': 'ahx95', 'id': '71812454'},
#   {'start': 44,
#    'end': 56,
#    'username': 'BoboMartin1',
#    'id': '766675949228294148'},
#   {'start': 57, 'end': 66, 'username': 'anjagray', 'id': '47454460'},
#   {'start': 67, 'end': 80, 'username': 'burningferns', 'id': '708171405'}],
#  [{'start': 3, 'end': 12, 'username': 'Rober71S', 'id': '252057889'}],
#  [{'start': 70, 'end': 79, 'username': 'abbyokay', 'id': '1350017534'}],
#  [{'start': 3, 'end': 17, 'username': 'SHEKARSUSHEEL', 'id': '113625811'}],
#  [{'start': 0, 'end': 14, 'username': 'zainulabedeen', 'id': '15840667'}],
#  [{'start': 0, 'end': 15, 'username': 'FitStop_Hunter', 'id': '30681255'}],
#  [{'start': 0, 'end': 14, 'username': 'DabitxoPiston', 'id': '597712811'}],
#  [{'start': 15, 'end': 29, 'username': 'davidboyd_com', 'id': '44732398'}],
#  [{'start': 135,
#    'end': 143,
#    'username': 'nmbr14_',
#    'id': '1485553579658301444'},
#   {'start': 152, 'end': 164, 'username': 'TheToneWill', 'id': '410683720'},
#   {'start': 167, 'end': 180, 'username': 'mrdavecullen', 'id': '3369622053'},
#   {'start': 183, 'end': 192, 'username': 'larasam4', 'id': '254510329'}],
#  [{'start': 0, 'end': 11, 'username': 'teetee_abz', 'id': '2570496571'}],
#  [{'start': 0,
#    'end': 16,
#    'username': 'Francis_Sixers4',
#    'id': '1447671748493815818'}],
#  [{'start': 3, 'end': 15, 'username': 'honorboxdoc', 'id': '23409619'}],
#  [{'start': 0, 'end': 16, 'username': 'IreneSGuadalupo', 'id': '301666796'},
#   {'start': 17,
#    'end': 27,
#    'username': 'NisMorFer',
#    'id': '1444377035544084484'}],
#  [{'start': 0, 'end': 12, 'username': 'JaneDixon72', 'id': '254698305'}],
#  [{'start': 0, 'end': 9, 'username': 'ppucedac', 'id': '263597822'},
#   {'start': 10,
#    'end': 24,
#    'username': 'Rusty76936632',
#    'id': '1164095506357936128'},
#   {'start': 25,
#    'end': 36,
#    'username': 'bertoconve',
#    'id': '741186522561556480'},
#   {'start': 37, 'end': 53, 'username': 'mercheiglesiasc', 'id': '260686206'},
#   {'start': 54, 'end': 69, 'username': 'Pancho_Badajoz', 'id': '163801624'},
#   {'start': 70, 'end': 81, 'username': 'PabloRaso1', 'id': '559072218'},
#   {'start': 82, 'end': 93, 'username': 'Santihumor', 'id': '132365110'},
#   {'start': 94, 'end': 110, 'username': 'cmartinizkierdo', 'id': '368185661'},
#   {'start': 111, 'end': 118, 'username': 'pukyjc', 'id': '387881156'},
#   {'start': 119, 'end': 131, 'username': 'williemjose', 'id': '1706947710'},
#   {'start': 132, 'end': 147, 'username': 'juanito_aragor', 'id': '253241290'}],
#  [{'start': 78,
#    'end': 89,
#    'username': 'marco_roji',
#    'id': '1278817659963035650'},
#   {'start': 90, 'end': 100, 'username': 'mroji1973', 'id': '632986242'},
#   {'start': 101, 'end': 112, 'username': 'jjromero70', 'id': '2442630999'}],
#  [{'start': 0, 'end': 11, 'username': 'EdyPartner', 'id': '227724036'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0, 'end': 11, 'username': 'EdyPartner', 'id': '227724036'}],
#  [{'start': 0, 'end': 8, 'username': 'shweepa', 'id': '9559082'}],
#  [{'start': 0, 'end': 12, 'username': 'UsamaKhilji', 'id': '166949373'},
#   {'start': 13, 'end': 21, 'username': 'UncleFu', 'id': '45639812'},
#   {'start': 22, 'end': 29, 'username': 'fursid', 'id': '14196465'},
#   {'start': 30, 'end': 44, 'username': 'Sarkhail7Khan', 'id': '351656273'},
#   {'start': 45, 'end': 61, 'username': 'ChocolateCharsi', 'id': '67416132'},
#   {'start': 62, 'end': 75, 'username': 'ST_Incognito', 'id': '385400234'},
#   {'start': 76, 'end': 88, 'username': 'LahoriElite', 'id': '505836297'},
#   {'start': 89, 'end': 102, 'username': 'Peelichappal', 'id': '203482792'},
#   {'start': 103, 'end': 117, 'username': 'RizWanKenobi_', 'id': '41190561'},
#   {'start': 118, 'end': 124, 'username': 'Mzr7_', 'id': '31055922'},
#   {'start': 125, 'end': 136, 'username': 'dishoomjee', 'id': '130070771'},
#   {'start': 137, 'end': 150, 'username': 'sajjadhaider', 'id': '18988192'},
#   {'start': 151, 'end': 165, 'username': 'Preg_Goldfish', 'id': '711024456'},
#   {'start': 166, 'end': 182, 'username': 'MainKehRahaHoon', 'id': '63947987'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0, 'end': 15, 'username': 'richardengland', 'id': '25075723'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0, 'end': 13, 'username': 'anaesteban75', 'id': '1327786063'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0, 'end': 10, 'username': 'aleixalbo', 'id': '260893371'}],
#  [{'start': 0, 'end': 11, 'username': 'BucamanGCW', 'id': '3235667976'}],
#  [{'start': 0, 'end': 10, 'username': 'taboada73', 'id': '333024220'},
#   {'start': 11, 'end': 19, 'username': 'Zandeti', 'id': '226350165'},
#   {'start': 20, 'end': 35, 'username': 'agarfernandez4', 'id': '2303795417'}],
#  [{'start': 0, 'end': 10, 'username': 'FAShooter', 'id': '3060207447'},
#   {'start': 11, 'end': 17, 'username': 'fabvt', 'id': '102624293'},
#   {'start': 18, 'end': 29, 'username': 'MasterLudo', 'id': '11312172'},
#   {'start': 30, 'end': 40, 'username': 'SmartFury', 'id': '260718396'},
#   {'start': 41,
#    'end': 50,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'},
#   {'start': 122,
#    'end': 131,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 30, 'end': 44, 'username': 'ShaunAshmore2', 'id': '362920352'}],
#  [{'start': 0, 'end': 9, 'username': 'Seebo429', 'id': '27711247'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 46,
#    'end': 59,
#    'username': 'LewisWood365',
#    'id': '1267432515725406209'}],
#  [{'start': 0,
#    'end': 12,
#    'username': 'WordleStats',
#    'id': '1479469664623378433'}],
#  [{'start': 68,
#    'end': 77,
#    'username': 'dewordle',
#    'id': '1482411529152741376'}],
#  [{'start': 0, 'end': 7, 'username': 'mlupoi', 'id': '7414282'}],
#  [{'start': 3, 'end': 12, 'username': 'cummeal_', 'id': '751579511389585408'}],
#  [{'start': 58, 'end': 68, 'username': 'aivoges57', 'id': '295579925'}],
#  [{'start': 0, 'end': 10, 'username': 'FSuhrbier', 'id': '3323734953'}],
#  [{'start': 0,
#    'end': 15,
#    'username': 'thesejustwords',
#    'id': '1165638731279360001'}],
#  [{'start': 0, 'end': 10, 'username': 'powlster_', 'id': '3000978782'}],
#  [{'start': 0, 'end': 13, 'username': 'SheilaCalbo7', 'id': '224736574'}],
#  [{'start': 0, 'end': 9, 'username': 'horwich1', 'id': '249362277'},
#   {'start': 10, 'end': 19, 'username': 'BigLee01', 'id': '222903558'},
#   {'start': 20, 'end': 30, 'username': 'CoolTails', 'id': '42590116'},
#   {'start': 31, 'end': 47, 'username': 'antoniadeardenx', 'id': '2478876197'}],
#  [{'start': 78, 'end': 92, 'username': 'PEDRO_RUNNY69', 'id': '555223256'},
#   {'start': 93, 'end': 105, 'username': 'lolalalola8', 'id': '2774574149'},
#   {'start': 106,
#    'end': 117,
#    'username': 'TBarricart',
#    'id': '1102676466951733249'},
#   {'start': 118, 'end': 128, 'username': 'FelixMuse', 'id': '219647107'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0, 'end': 8, 'username': 'bjornfr', 'id': '14636422'}],
#  [{'start': 86, 'end': 94, 'username': 'nytimes', 'id': '807095'}],
#  [{'start': 0, 'end': 14, 'username': 'ulasdifficile', 'id': '259403476'},
#   {'start': 15, 'end': 29, 'username': 'mdemircikoglu', 'id': '805630644'}],
#  [{'start': 66,
#    'end': 78,
#    'username': 'alfred0jete',
#    'id': '1387412428691021824'}],
#  [{'start': 72, 'end': 83, 'username': 'arosmiguel', 'id': '260317143'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0, 'end': 10, 'username': 'aleixalbo', 'id': '260893371'}],
#  [{'start': 3, 'end': 12, 'username': 'niseag03', 'id': '15253284'}],
#  [{'start': 0, 'end': 9, 'username': 'SrXanadu', 'id': '1595570684'}],
#  [{'start': 0, 'end': 15, 'username': 'chrisorton2011', 'id': '399622190'}],
#  [{'start': 20, 'end': 36, 'username': 'davidfordisdead', 'id': '15298777'}],
#  [{'start': 0, 'end': 12, 'username': 'jean_marc83', 'id': '134419343'},
#   {'start': 13,
#    'end': 22,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'},
#   {'start': 31,
#    'end': 40,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0, 'end': 8, 'username': 'Jan_208', 'id': '23216026'}],
#  [{'start': 74,
#    'end': 83,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0, 'end': 10, 'username': 'nicowayan', 'id': '120739511'},
#   {'start': 11, 'end': 19, 'username': 'Judu441', 'id': '790001796'},
#   {'start': 20, 'end': 32, 'username': 'RomainBouth', 'id': '40044978'},
#   {'start': 33,
#    'end': 42,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'},
#   {'start': 51,
#    'end': 60,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 10,
#    'end': 19,
#    'username': 'WordleES',
#    'id': '1483085814422716419'}],
#  [{'start': 116, 'end': 126, 'username': 'aledelv22', 'id': '1154916649'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0, 'end': 8, 'username': 'UncleFu', 'id': '45639812'},
#   {'start': 9, 'end': 16, 'username': 'fursid', 'id': '14196465'},
#   {'start': 17, 'end': 31, 'username': 'Sarkhail7Khan', 'id': '351656273'},
#   {'start': 32, 'end': 48, 'username': 'ChocolateCharsi', 'id': '67416132'},
#   {'start': 49, 'end': 62, 'username': 'ST_Incognito', 'id': '385400234'},
#   {'start': 63, 'end': 71, 'username': 'Khushal', 'id': '5976032'},
#   {'start': 72, 'end': 84, 'username': 'LahoriElite', 'id': '505836297'},
#   {'start': 85, 'end': 98, 'username': 'Peelichappal', 'id': '203482792'},
#   {'start': 99, 'end': 113, 'username': 'RizWanKenobi_', 'id': '41190561'},
#   {'start': 114, 'end': 120, 'username': 'Mzr7_', 'id': '31055922'},
#   {'start': 121, 'end': 132, 'username': 'dishoomjee', 'id': '130070771'},
#   {'start': 133, 'end': 146, 'username': 'sajjadhaider', 'id': '18988192'},
#   {'start': 147, 'end': 161, 'username': 'Preg_Goldfish', 'id': '711024456'},
#   {'start': 162, 'end': 178, 'username': 'MainKehRahaHoon', 'id': '63947987'}],
#  [{'start': 0, 'end': 9, 'username': 'albolt76', 'id': '1160130818678972416'},
#   {'start': 10, 'end': 19, 'username': 'dawardle', 'id': '1165789231'}],
#  [{'start': 0, 'end': 16, 'username': 'hughjconsulting', 'id': '2375524495'}],
#  [{'start': 0, 'end': 9, 'username': 'javmallo', 'id': '50322606'}],
#  [{'start': 0, 'end': 10, 'username': 'AbeFroman', 'id': '432242860'}],
#  [{'start': 0, 'end': 14, 'username': 'markohalloran', 'id': '34086990'}],
#  [{'start': 0,
#    'end': 13,
#    'username': 'theonclejack',
#    'id': '1312152527924875264'},
#   {'start': 14, 'end': 27, 'username': 'Lisanlussapa', 'id': '262575379'},
#   {'start': 28, 'end': 44, 'username': 'MonicaBarcelona', 'id': '301979778'},
#   {'start': 45, 'end': 53, 'username': 'emateug', 'id': '851861378730274819'},
#   {'start': 54, 'end': 65, 'username': 'louloucruz', 'id': '232585674'},
#   {'start': 66, 'end': 76, 'username': 'Esquitx17', 'id': '399564452'},
#   {'start': 77,
#    'end': 87,
#    'username': 'ehecatram',
#    'id': '1178043378019291136'},
#   {'start': 88,
#    'end': 103,
#    'username': 'drevilsnumber2',
#    'id': '1194873103618363392'},
#   {'start': 104,
#    'end': 116,
#    'username': 'EstacioSEDR',
#    'id': '1035437066283311105'},
#   {'start': 117, 'end': 127, 'username': 'bibisole1', 'id': '2156243057'},
#   {'start': 128,
#    'end': 143,
#    'username': 'FerranReloaded',
#    'id': '1403486789957005319'},
#   {'start': 144, 'end': 154, 'username': 'albertsfx', 'id': '275605604'}],
#  [{'start': 34, 'end': 47, 'username': 'M_campelilla', 'id': '276579249'}],
#  [{'start': 155,
#    'end': 163,
#    'username': 'SoWhoaa',
#    'id': '1251012067575939072'}],
#  [{'start': 0, 'end': 14, 'username': 'SusanaAmestoy', 'id': '363910327'},
#   {'start': 15,
#    'end': 31,
#    'username': 'Tarariquetevi19',
#    'id': '1143994676606898177'},
#   {'start': 32,
#    'end': 43,
#    'username': 'MaJoAndSol',
#    'id': '1272514678552494080'},
#   {'start': 44, 'end': 55, 'username': 'PabloRaso1', 'id': '559072218'},
#   {'start': 56,
#    'end': 66,
#    'username': 'cubanmood',
#    'id': '1060607648071073793'},
#   {'start': 67, 'end': 74, 'username': 'fjc162', 'id': '1386376867310092288'},
#   {'start': 75, 'end': 88, 'username': 'ArturoSherpa', 'id': '2383908665'},
#   {'start': 89, 'end': 105, 'username': 'mercheiglesiasc', 'id': '260686206'},
#   {'start': 106,
#    'end': 117,
#    'username': 'trasquilon',
#    'id': '1427683457681997827'},
#   {'start': 118,
#    'end': 129,
#    'username': 'LoroParece',
#    'id': '1312493830181138433'},
#   {'start': 130, 'end': 142, 'username': 'LegoLlorchs', 'id': '2713932328'},
#   {'start': 143, 'end': 156, 'username': 'Mr_daltonico', 'id': '978867998'},
#   {'start': 157,
#    'end': 166,
#    'username': 'Tontero_',
#    'id': '1280640704537153543'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0, 'end': 11, 'username': 'phoebe1342', 'id': '487993613'}],
#  [{'start': 3,
#    'end': 13,
#    'username': 'nishpakch',
#    'id': '1090231841775341568'}],
#  [{'start': 76, 'end': 84, 'username': 'AndyLC7', 'id': '4198358656'},
#   {'start': 85, 'end': 95, 'username': 'fdez_dani', 'id': '540255439'},
#   {'start': 96,
#    'end': 104,
#    'username': 'Lex_cmm',
#    'id': '1090137788757041152'}],
#  [{'start': 3, 'end': 18, 'username': 'gijojoseph1982', 'id': '127226332'}],
#  [{'start': 3, 'end': 17, 'username': 'irimiabarroso', 'id': '194179893'}],
#  [{'start': 38, 'end': 53, 'username': 'Latxinamundial', 'id': '221668167'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0,
#    'end': 10,
#    'username': 'sairam_vk',
#    'id': '883149781517971460'}],
#  [{'start': 75,
#    'end': 87,
#    'username': 'khalidqkhan',
#    'id': '722060328713003008'}],
#  [{'start': 0,
#    'end': 13,
#    'username': 'annekatweiss',
#    'id': '733366009621536768'}],
#  [{'start': 0, 'end': 8, 'username': 'AndyLC7', 'id': '4198358656'},
#   {'start': 9,
#    'end': 24,
#    'username': 'AlexCasanova99',
#    'id': '1092846437279457281'},
#   {'start': 25, 'end': 35, 'username': 'fdez_dani', 'id': '540255439'}],
#  [{'start': 0,
#    'end': 16,
#    'username': 'littlefreakjosh',
#    'id': '1363222291589513217'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0, 'end': 16, 'username': 'sexxybklynsiren', 'id': '112317383'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0, 'end': 9, 'username': 'AlCatJDP', 'id': '553315935'}],
#  [{'start': 15, 'end': 24, 'username': 'starwars', 'id': '20106852'}],
#  [{'start': 0,
#    'end': 16,
#    'username': 'Tarariquetevi19',
#    'id': '1143994676606898177'},
#   {'start': 17,
#    'end': 28,
#    'username': 'MaJoAndSol',
#    'id': '1272514678552494080'},
#   {'start': 29, 'end': 40, 'username': 'PabloRaso1', 'id': '559072218'},
#   {'start': 41,
#    'end': 51,
#    'username': 'cubanmood',
#    'id': '1060607648071073793'},
#   {'start': 52, 'end': 59, 'username': 'fjc162', 'id': '1386376867310092288'},
#   {'start': 60, 'end': 73, 'username': 'ArturoSherpa', 'id': '2383908665'},
#   {'start': 74, 'end': 90, 'username': 'mercheiglesiasc', 'id': '260686206'},
#   {'start': 91,
#    'end': 102,
#    'username': 'trasquilon',
#    'id': '1427683457681997827'},
#   {'start': 103,
#    'end': 114,
#    'username': 'LoroParece',
#    'id': '1312493830181138433'},
#   {'start': 115, 'end': 127, 'username': 'LegoLlorchs', 'id': '2713932328'},
#   {'start': 128, 'end': 141, 'username': 'Mr_daltonico', 'id': '978867998'},
#   {'start': 142, 'end': 149, 'username': 'pukyjc', 'id': '387881156'},
#   {'start': 150,
#    'end': 159,
#    'username': 'Tontero_',
#    'id': '1280640704537153543'}],
#  [{'start': 0, 'end': 15, 'username': 'TebohoRMapetla', 'id': '273307914'},
#   {'start': 16, 'end': 24, 'username': 'Mocats_', 'id': '172355169'},
#   {'start': 25, 'end': 39, 'username': 'Precious_Popi', 'id': '1249935074'},
#   {'start': 40, 'end': 49, 'username': 'Tshada_M', 'id': '295048391'},
#   {'start': 50, 'end': 62, 'username': 'Maya_Legacy', 'id': '1964703835'}],
#  [{'start': 3, 'end': 18, 'username': 'virginialiliab', 'id': '484489822'},
#   {'start': 65, 'end': 75, 'username': 'Chu_layyy', 'id': '3158422640'}],
#  [{'start': 0, 'end': 15, 'username': 'TebohoRMapetla', 'id': '273307914'},
#   {'start': 16, 'end': 24, 'username': 'kanonor', 'id': '53194478'},
#   {'start': 25, 'end': 33, 'username': 'Mocats_', 'id': '172355169'},
#   {'start': 34, 'end': 43, 'username': 'Tshada_M', 'id': '295048391'},
#   {'start': 44, 'end': 56, 'username': 'Maya_Legacy', 'id': '1964703835'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0, 'end': 9, 'username': 'sudihill', 'id': '22618359'}],
#  [{'start': 0, 'end': 13, 'username': 'ori_goldberg', 'id': '314838597'}],
#  [{'start': 45, 'end': 55, 'username': 'Chu_layyy', 'id': '3158422640'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 51, 'end': 61, 'username': 'derrygals', 'id': '1602293790'}],
#  [{'start': 24, 'end': 37, 'username': 'kelci_sibley', 'id': '495665752'}],
#  [{'start': 0, 'end': 10, 'username': 'Yoli_Amat', 'id': '380183821'}],
#  [{'start': 0, 'end': 8, 'username': 'Snt_bch', 'id': '1099981484851642369'}],
#  [{'start': 0, 'end': 10, 'username': 'uniederer', 'id': '2462786292'}],
#  [{'start': 0, 'end': 16, 'username': 'personallorando', 'id': '3420962417'},
#   {'start': 17, 'end': 28, 'username': 'lauravy555', 'id': '4707430889'},
#   {'start': 29, 'end': 44, 'username': 'garcia_chema_8', 'id': '2423128126'},
#   {'start': 45, 'end': 59, 'username': 'palomavmartin', 'id': '1370356184'}],
#  [{'start': 0, 'end': 13, 'username': 'LoneSurvivor', 'id': '22601006'},
#   {'start': 14, 'end': 23, 'username': 'efingdmi', 'id': '3181066331'},
#   {'start': 97,
#    'end': 106,
#    'username': 'dewordle',
#    'id': '1482411529152741376'}],
#  [{'start': 0, 'end': 7, 'username': 'Txuli8', 'id': '724683308'}],
#  [{'start': 0, 'end': 8, 'username': 'latrwn1', 'id': '228125204'}],
#  [{'start': 1,
#    'end': 14,
#    'username': 'JohnRadioTFI',
#    'id': '1451799186786201605'}],
#  [{'start': 0, 'end': 12, 'username': 'DevorahLeah', 'id': '15755592'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0, 'end': 9, 'username': 'albolt76', 'id': '1160130818678972416'},
#   {'start': 10, 'end': 19, 'username': 'dawardle', 'id': '1165789231'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0, 'end': 13, 'username': 'JohnColton70', 'id': '796473031'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0,
#    'end': 11,
#    'username': 'PerePeries',
#    'id': '1066299001878839297'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 33, 'end': 48, 'username': 'LesleyHustler1', 'id': '407826450'},
#   {'start': 49, 'end': 57, 'username': 'abbyaug', 'id': '99167707'},
#   {'start': 58, 'end': 70, 'username': 'SwailesRuth', 'id': '2920183187'}],
#  [{'start': 0, 'end': 12, 'username': 'juliefairey', 'id': '34532693'},
#   {'start': 13, 'end': 26, 'username': 'bobbythekiwi', 'id': '44881197'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 83, 'end': 92, 'username': 'julss_13', 'id': '281729246'}],
#  [{'start': 80, 'end': 95, 'username': 'averagejoeinaz', 'id': '872110657'},
#   {'start': 98,
#    'end': 110,
#    'username': 'TommyK53062',
#    'id': '1042102056100814849'},
#   {'start': 112, 'end': 124, 'username': 'TheRavenKid', 'id': '3117335941'},
#   {'start': 126,
#    'end': 140,
#    'username': 'JustTheTip_18',
#    'id': '1377664759969972224'},
#   {'start': 142,
#    'end': 156,
#    'username': 'BoogiePhoenix',
#    'id': '1016827068246609920'},
#   {'start': 158,
#    'end': 172,
#    'username': 'RadioRandy777',
#    'id': '976644375185784832'},
#   {'start': 174, 'end': 179, 'username': 'DTE3', 'id': '44202254'},
#   {'start': 181, 'end': 193, 'username': 'KhoyRidings', 'id': '1005401982'}],
#  [{'start': 0, 'end': 16, 'username': 'benevincent1972', 'id': '3070652411'},
#   {'start': 17,
#    'end': 26,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'},
#   {'start': 52,
#    'end': 61,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0,
#    'end': 14,
#    'username': 'Rusty76936632',
#    'id': '1164095506357936128'},
#   {'start': 15,
#    'end': 26,
#    'username': 'bertoconve',
#    'id': '741186522561556480'},
#   {'start': 27, 'end': 43, 'username': 'mercheiglesiasc', 'id': '260686206'},
#   {'start': 44, 'end': 59, 'username': 'Pancho_Badajoz', 'id': '163801624'},
#   {'start': 60, 'end': 68, 'username': 'jaberpo', 'id': '166920924'},
#   {'start': 69, 'end': 80, 'username': 'PabloRaso1', 'id': '559072218'},
#   {'start': 81, 'end': 92, 'username': 'Santihumor', 'id': '132365110'},
#   {'start': 93, 'end': 109, 'username': 'cmartinizkierdo', 'id': '368185661'},
#   {'start': 110, 'end': 117, 'username': 'pukyjc', 'id': '387881156'},
#   {'start': 118, 'end': 130, 'username': 'williemjose', 'id': '1706947710'},
#   {'start': 131, 'end': 146, 'username': 'juanito_aragor', 'id': '253241290'}],
#  [{'start': 67, 'end': 79, 'username': 'jcapdeville', 'id': '290295974'},
#   {'start': 80, 'end': 95, 'username': 'and_capdeville', 'id': '255999196'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0, 'end': 12, 'username': 'TomJChicago', 'id': '14542977'}],
#  [{'start': 0, 'end': 10, 'username': 'aleixalbo', 'id': '260893371'}],
#  [{'start': 3, 'end': 10, 'username': 'Ru_a09', 'id': '1451073432'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 81, 'end': 89, 'username': 'Loretxo', 'id': '57716798'},
#   {'start': 120, 'end': 129, 'username': 'behennah', 'id': '1089789578'},
#   {'start': 130,
#    'end': 145,
#    'username': 'asierpaino1988',
#    'id': '1694910722'}],
#  [{'start': 0, 'end': 9, 'username': 'Thominou', 'id': '925590156'},
#   {'start': 10,
#    'end': 19,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'},
#   {'start': 28,
#    'end': 37,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0, 'end': 12, 'username': 'anand_srini', 'id': '257769553'}],
#  [{'start': 0,
#    'end': 11,
#    'username': 'marianiabe',
#    'id': '1247969778586865666'}],
#  [{'start': 30, 'end': 38, 'username': 'nytimes', 'id': '807095'}],
#  [{'start': 0, 'end': 14, 'username': 'StephanieMT60', 'id': '2471392716'}],
#  [{'start': 42, 'end': 55, 'username': 'kelci_sibley', 'id': '495665752'}],
#  [{'start': 0, 'end': 10, 'username': 'jcmaraver', 'id': '34366588'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 3,
#    'end': 15,
#    'username': 'BruNCompany',
#    'id': '1485768328031395840'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 3,
#    'end': 13,
#    'username': 'shinudake',
#    'id': '1423723544307855362'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 47, 'end': 60, 'username': 'djharrison99', 'id': '215336649'}],
#  [{'start': 0, 'end': 16, 'username': 'Ninvacaninloura', 'id': '2362443013'}],
#  [{'start': 0, 'end': 14, 'username': 'SusanaRLezaun', 'id': '3172214662'}],
#  [{'start': 0,
#    'end': 12,
#    'username': 'edmunddant3',
#    'id': '1099184643411230720'},
#   {'start': 13, 'end': 22, 'username': 'SoyGusHS', 'id': '980300346'},
#   {'start': 23, 'end': 38, 'username': 'yoposquien_mas', 'id': '3315357816'},
#   {'start': 39, 'end': 49, 'username': '32bitmips', 'id': '323389356'}],
#  [{'start': 3,
#    'end': 12,
#    'username': 'hey00054',
#    'id': '1275678645215006720'}],
#  [{'start': 3, 'end': 16, 'username': 'PanditGBPant', 'id': '51746444'},
#   {'start': 83, 'end': 91, 'username': 'nytimes', 'id': '807095'}],
#  [{'start': 0, 'end': 7, 'username': 'rzredj', 'id': '1342040373301047296'},
#   {'start': 8, 'end': 17, 'username': 'WordleFR', 'id': '1480029602105995267'},
#   {'start': 26,
#    'end': 35,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0, 'end': 10, 'username': 'mortentop', 'id': '30837831'}],
#  [{'start': 0, 'end': 12, 'username': 'anand_srini', 'id': '257769553'}],
#  [{'start': 0, 'end': 9, 'username': 'ACaroAlf', 'id': '1871599014'}],
#  [{'start': 0, 'end': 13, 'username': 'SuffolkJason', 'id': '1001675533'}],
#  [{'start': 0, 'end': 14, 'username': 'harshilmittal', 'id': '76061044'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0, 'end': 15, 'username': 'DrMatthewSweet', 'id': '284410889'}],
#  [{'start': 0, 'end': 16, 'username': 'Ninvacaninloura', 'id': '2362443013'}],
#  [{'start': 107, 'end': 115, 'username': 'BTS_twt', 'id': '335141638'}],
#  [{'start': 0, 'end': 7, 'username': 'Solsjo', 'id': '125342906'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 3,
#    'end': 13,
#    'username': 'KyroFluff',
#    'id': '926625021979750400'}],
#  [{'start': 46, 'end': 59, 'username': 'jacksshadows', 'id': '479302022'}],
#  [{'start': 0, 'end': 12, 'username': 'yutakanzawa', 'id': '232504317'}],
#  [{'start': 0, 'end': 12, 'username': 'DevorahLeah', 'id': '15755592'}],
#  [{'start': 16,
#    'end': 27,
#    'username': 'parrotmilf',
#    'id': '1047646373326331904'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0, 'end': 12, 'username': 'HalkatCurry', 'id': '410656713'}],
#  [{'start': 44, 'end': 56, 'username': 'bluerover77', 'id': '36167456'}],
#  [{'start': 0, 'end': 13, 'username': 'brisilla1977', 'id': '397626495'}],
#  [{'start': 2, 'end': 10, 'username': 'dosmar1', 'id': '707306550'}],
#  [{'start': 0,
#    'end': 13,
#    'username': 'theonclejack',
#    'id': '1312152527924875264'},
#   {'start': 14, 'end': 27, 'username': 'Lisanlussapa', 'id': '262575379'},
#   {'start': 28, 'end': 44, 'username': 'MonicaBarcelona', 'id': '301979778'},
#   {'start': 45, 'end': 53, 'username': 'emateug', 'id': '851861378730274819'},
#   {'start': 54, 'end': 65, 'username': 'louloucruz', 'id': '232585674'},
#   {'start': 66, 'end': 76, 'username': 'Esquitx17', 'id': '399564452'},
#   {'start': 77,
#    'end': 87,
#    'username': 'ehecatram',
#    'id': '1178043378019291136'},
#   {'start': 88, 'end': 97, 'username': 'YoseRosa', 'id': '2259516811'},
#   {'start': 98,
#    'end': 113,
#    'username': 'drevilsnumber2',
#    'id': '1194873103618363392'},
#   {'start': 114, 'end': 124, 'username': 'bibisole1', 'id': '2156243057'},
#   {'start': 125,
#    'end': 140,
#    'username': 'FerranReloaded',
#    'id': '1403486789957005319'},
#   {'start': 141, 'end': 151, 'username': 'albertsfx', 'id': '275605604'}],
#  [{'start': 0, 'end': 8, 'username': 'Xeno88_', 'id': '2153451218'},
#   {'start': 9,
#    'end': 21,
#    'username': 'keroppi7297',
#    'id': '1487290231011352580'},
#   {'start': 22, 'end': 30, 'username': 'My_coal', 'id': '45439874'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0,
#    'end': 13,
#    'username': 'theonclejack',
#    'id': '1312152527924875264'},
#   {'start': 14, 'end': 27, 'username': 'Lisanlussapa', 'id': '262575379'},
#   {'start': 28, 'end': 44, 'username': 'MonicaBarcelona', 'id': '301979778'},
#   {'start': 45, 'end': 53, 'username': 'emateug', 'id': '851861378730274819'},
#   {'start': 54, 'end': 65, 'username': 'louloucruz', 'id': '232585674'},
#   {'start': 66, 'end': 76, 'username': 'Esquitx17', 'id': '399564452'},
#   {'start': 77,
#    'end': 87,
#    'username': 'ehecatram',
#    'id': '1178043378019291136'},
#   {'start': 88, 'end': 97, 'username': 'YoseRosa', 'id': '2259516811'},
#   {'start': 98,
#    'end': 113,
#    'username': 'drevilsnumber2',
#    'id': '1194873103618363392'},
#   {'start': 114,
#    'end': 126,
#    'username': 'EstacioSEDR',
#    'id': '1035437066283311105'},
#   {'start': 127, 'end': 137, 'username': 'bibisole1', 'id': '2156243057'},
#   {'start': 138, 'end': 148, 'username': 'albertsfx', 'id': '275605604'}],
#  [{'start': 3, 'end': 10, 'username': 'Ru_a09', 'id': '1451073432'}],
#  [{'start': 0, 'end': 8, 'username': 'ioluisp', 'id': '1484016037'},
#   {'start': 9, 'end': 21, 'username': 'juliatomas3', 'id': '549998698'}],
#  [{'start': 3, 'end': 17, 'username': 'bertkreischer', 'id': '17953972'}],
#  [{'start': 0, 'end': 12, 'username': 'roshanabbas', 'id': '17685964'}],
#  [{'start': 0,
#    'end': 13,
#    'username': 'theonclejack',
#    'id': '1312152527924875264'},
#   {'start': 14, 'end': 27, 'username': 'Lisanlussapa', 'id': '262575379'},
#   {'start': 28, 'end': 44, 'username': 'MonicaBarcelona', 'id': '301979778'},
#   {'start': 45, 'end': 53, 'username': 'emateug', 'id': '851861378730274819'},
#   {'start': 54, 'end': 65, 'username': 'louloucruz', 'id': '232585674'},
#   {'start': 66, 'end': 76, 'username': 'Esquitx17', 'id': '399564452'},
#   {'start': 77,
#    'end': 87,
#    'username': 'ehecatram',
#    'id': '1178043378019291136'},
#   {'start': 88, 'end': 97, 'username': 'YoseRosa', 'id': '2259516811'},
#   {'start': 98,
#    'end': 110,
#    'username': 'EstacioSEDR',
#    'id': '1035437066283311105'},
#   {'start': 111, 'end': 121, 'username': 'bibisole1', 'id': '2156243057'},
#   {'start': 122,
#    'end': 137,
#    'username': 'FerranReloaded',
#    'id': '1403486789957005319'},
#   {'start': 138, 'end': 148, 'username': 'albertsfx', 'id': '275605604'}],
#  [{'start': 0,
#    'end': 11,
#    'username': 'JavierOres',
#    'id': '915880147009642497'}],
#  [{'start': 0,
#    'end': 11,
#    'username': 'DylanRFitz',
#    'id': '1027025778100162560'},
#   {'start': 12,
#    'end': 25,
#    'username': 'HitSaveCyril',
#    'id': '869548019645108225'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0,
#    'end': 15,
#    'username': 'QueenieBelfast',
#    'id': '1405936143804289025'},
#   {'start': 16, 'end': 30, 'username': 'RosieandRollo', 'id': '2163128190'}],
#  [{'start': 34, 'end': 47, 'username': 'Lisanlussapa', 'id': '262575379'},
#   {'start': 48, 'end': 64, 'username': 'MonicaBarcelona', 'id': '301979778'},
#   {'start': 65, 'end': 73, 'username': 'emateug', 'id': '851861378730274819'},
#   {'start': 74, 'end': 85, 'username': 'louloucruz', 'id': '232585674'},
#   {'start': 86, 'end': 96, 'username': 'Esquitx17', 'id': '399564452'},
#   {'start': 97,
#    'end': 107,
#    'username': 'ehecatram',
#    'id': '1178043378019291136'},
#   {'start': 108, 'end': 117, 'username': 'YoseRosa', 'id': '2259516811'},
#   {'start': 118,
#    'end': 133,
#    'username': 'drevilsnumber2',
#    'id': '1194873103618363392'},
#   {'start': 134,
#    'end': 146,
#    'username': 'EstacioSEDR',
#    'id': '1035437066283311105'},
#   {'start': 147, 'end': 157, 'username': 'bibisole1', 'id': '2156243057'},
#   {'start': 158,
#    'end': 173,
#    'username': 'FerranReloaded',
#    'id': '1403486789957005319'},
#   {'start': 174, 'end': 184, 'username': 'albertsfx', 'id': '275605604'}],
#  [{'start': 26, 'end': 40, 'username': 'aditya_sehgal', 'id': '127007698'}],
#  [{'start': 0,
#    'end': 11,
#    'username': 'ADVANCEDgg',
#    'id': '970233802663563264'}],
#  [{'start': 0, 'end': 8, 'username': 'Snt_bch', 'id': '1099981484851642369'}],
#  [{'start': 50, 'end': 60, 'username': 'MuggleNet', 'id': '14599470'}],
#  [{'start': 0, 'end': 14, 'username': 'JillWineBanks', 'id': '454071012'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 46, 'end': 56, 'username': '_Carabas_', 'id': '1448819178'},
#   {'start': 57, 'end': 65, 'username': 'ginporn', 'id': '1073725658583445504'},
#   {'start': 66, 'end': 73, 'username': 'St3Ski', 'id': '1109466818102657026'}],
#  [{'start': 41, 'end': 50, 'username': 'Sunzoned', 'id': '468816303'}],
#  [{'start': 41, 'end': 49, 'username': 'cehnedi', 'id': '894347799260803073'}],
#  [{'start': 0,
#    'end': 13,
#    'username': 'annekatweiss',
#    'id': '733366009621536768'}],
#  [{'start': 0, 'end': 10, 'username': 'LouCozita', 'id': '778203770220122112'},
#   {'start': 11,
#    'end': 20,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'},
#   {'start': 29,
#    'end': 38,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0, 'end': 13, 'username': 'AnthonyPucik', 'id': '149945647'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 3, 'end': 17, 'username': 'JillWineBanks', 'id': '454071012'}],
#  [{'start': 0,
#    'end': 16,
#    'username': 'usa_bestcountry',
#    'id': '993748794880671745'}],
#  [{'start': 0,
#    'end': 14,
#    'username': 'Bronwynemma03',
#    'id': '999030923244032001'},
#   {'start': 15, 'end': 31, 'username': 'rexorangecounty', 'id': '3402916535'}],
#  [{'start': 0, 'end': 11, 'username': 'AtownBrown', 'id': '34257658'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 3, 'end': 11, 'username': 'dosmar1', 'id': '707306550'}],
#  [{'start': 0, 'end': 11, 'username': 'fifiharoon', 'id': '58573593'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0, 'end': 7, 'username': 'SRuhle', 'id': '382685028'}],
#  [{'start': 51, 'end': 66, 'username': 'hayillustrates', 'id': '2377869092'}],
#  [{'start': 3, 'end': 16, 'username': 'jeremypotvin', 'id': '48599624'}],
#  [{'start': 68, 'end': 77, 'username': 'dtcooper', 'id': '17078300'},
#   {'start': 80, 'end': 88, 'username': 'Tedesco', 'id': '10100362'}],
#  [{'start': 3, 'end': 10, 'username': 'SRuhle', 'id': '382685028'}],
#  [{'start': 62, 'end': 72, 'username': 'MuggleNet', 'id': '14599470'}],
#  [{'start': 0, 'end': 11, 'username': 'trainonova', 'id': '107493656'}],
#  [{'start': 0, 'end': 11, 'username': 'misskittyf', 'id': '16541356'}],
#  [{'start': 41, 'end': 51, 'username': 'SdotRolko', 'id': '516734039'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 3, 'end': 17, 'username': 'SKYEwalker021', 'id': '3709748594'}],
#  [{'start': 3,
#    'end': 12,
#    'username': 'nao__ban',
#    'id': '1381191802246492161'}],
#  [{'start': 0, 'end': 13, 'username': 'ButteredFrog', 'id': '339700744'}],
#  [{'start': 37,
#    'end': 46,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0,
#    'end': 10,
#    'username': 'Cat_Louuu',
#    'id': '1475893427908890632'}],
#  [{'start': 80, 'end': 89, 'username': 'imvreddy', 'id': '491767057'},
#   {'start': 90, 'end': 104, 'username': 'peyton_french', 'id': '592951859'},
#   {'start': 105, 'end': 115, 'username': 'taybaby_x', 'id': '2729959624'}],
#  [{'start': 0, 'end': 13, 'username': 'LynnieYankee', 'id': '2688015749'}],
#  [{'start': 0, 'end': 12, 'username': 'orangobrain', 'id': '336909317'}],
#  [{'start': 3,
#    'end': 18,
#    'username': 'otoyo1130otoyo',
#    'id': '889021886406852609'}],
#  [{'start': 0, 'end': 10, 'username': 'brightise', 'id': '355133940'}],
#  [{'start': 0, 'end': 9, 'username': 'katy5397', 'id': '1266904876266565632'}],
#  [{'start': 0,
#    'end': 14,
#    'username': 'kurumi_nanoda',
#    'id': '1225558480888705028'}],
#  [{'start': 0, 'end': 12, 'username': 'ginger_nats', 'id': '87051281'}],
#  [{'start': 22, 'end': 34, 'username': 'Nuriaar1969', 'id': '4868447493'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 86,
#    'end': 98,
#    'username': 'TheFakeRoLo',
#    'id': '1339815116296994816'}],
#  [{'start': 3, 'end': 11, 'username': 'psankar', 'id': '13545932'},
#   {'start': 29, 'end': 42, 'username': 'tsureshkumar', 'id': '17313359'}],
#  [{'start': 0,
#    'end': 13,
#    'username': 'dollykabaria',
#    'id': '1473595139490652161'},
#   {'start': 14, 'end': 29, 'username': 'ManishMandhyan', 'id': '46286208'},
#   {'start': 30, 'end': 38, 'username': 'dijaraj', 'id': '2933212650'},
#   {'start': 39, 'end': 46, 'username': 'sachdr', 'id': '78614067'},
#   {'start': 47,
#    'end': 58,
#    'username': 'NamrataV01',
#    'id': '703440014097534976'},
#   {'start': 59, 'end': 71, 'username': 'OberaiJassi', 'id': '1484682168'},
#   {'start': 72,
#    'end': 86,
#    'username': 'BluejaywayEth',
#    'id': '1432924676569718790'},
#   {'start': 87,
#    'end': 98,
#    'username': 'sidclicks_',
#    'id': '1444891755745189894'},
#   {'start': 99, 'end': 109, 'username': 'D_Art2021', 'id': '413772630'},
#   {'start': 110, 'end': 121, 'username': 'samyukth_s', 'id': '288222296'},
#   {'start': 122, 'end': 137, 'username': 'Aniltprabhakar', 'id': '88306145'}],
#  [{'start': 0, 'end': 7, 'username': 'SRuhle', 'id': '382685028'}],
#  [{'start': 36, 'end': 48, 'username': 'WhatJennyDu', 'id': '590476627'}],
#  [{'start': 0, 'end': 11, 'username': 'StefWerner', 'id': '103243791'}],
#  [{'start': 0,
#    'end': 11,
#    'username': 'MaJoAndSol',
#    'id': '1272514678552494080'},
#   {'start': 12, 'end': 23, 'username': 'PabloRaso1', 'id': '559072218'},
#   {'start': 24,
#    'end': 34,
#    'username': 'cubanmood',
#    'id': '1060607648071073793'},
#   {'start': 35, 'end': 49, 'username': 'SusanaAmestoy', 'id': '363910327'},
#   {'start': 50, 'end': 57, 'username': 'fjc162', 'id': '1386376867310092288'},
#   {'start': 58, 'end': 71, 'username': 'ArturoSherpa', 'id': '2383908665'},
#   {'start': 72, 'end': 88, 'username': 'mercheiglesiasc', 'id': '260686206'},
#   {'start': 89,
#    'end': 100,
#    'username': 'trasquilon',
#    'id': '1427683457681997827'},
#   {'start': 101,
#    'end': 112,
#    'username': 'LoroParece',
#    'id': '1312493830181138433'},
#   {'start': 113, 'end': 125, 'username': 'LegoLlorchs', 'id': '2713932328'},
#   {'start': 126, 'end': 139, 'username': 'Mr_daltonico', 'id': '978867998'},
#   {'start': 140, 'end': 147, 'username': 'pukyjc', 'id': '387881156'},
#   {'start': 148,
#    'end': 157,
#    'username': 'Tontero_',
#    'id': '1280640704537153543'}],
#  [{'start': 54, 'end': 66, 'username': 'impoliteguy', 'id': '175366102'},
#   {'start': 69, 'end': 83, 'username': 'ganesh_takale', 'id': '448951268'},
#   {'start': 86, 'end': 96, 'username': 'b_ashishh', 'id': '358027369'},
#   {'start': 99, 'end': 108, 'username': 'Riteishd', 'id': '57998991'}],
#  [{'start': 0, 'end': 13, 'username': 'melgilmartin', 'id': '109764034'}],
#  [{'start': 5,
#    'end': 14,
#    'username': 'WordleES',
#    'id': '1483085814422716419'}],
#  [{'start': 19, 'end': 29, 'username': 'aleixalbo', 'id': '260893371'}],
#  [{'start': 0,
#    'end': 11,
#    'username': 'Maracaib01',
#    'id': '1245678685425930240'},
#   {'start': 12, 'end': 24, 'username': 'nataliacb24', 'id': '402408669'},
#   {'start': 25, 'end': 37, 'username': 'AdrianaHC22', 'id': '415085662'},
#   {'start': 38, 'end': 45, 'username': 'larxci', 'id': '337737589'},
#   {'start': 46, 'end': 58, 'username': 'raulfisiodp', 'id': '460377752'},
#   {'start': 59, 'end': 69, 'username': 'alisolotu', 'id': '431915861'},
#   {'start': 70, 'end': 78, 'username': 'rumania', 'id': '495877221'}],
#  [{'start': 41, 'end': 53, 'username': 'jesusbosque', 'id': '111314981'}],
#  [{'start': 41, 'end': 51, 'username': 'SAJones64', 'id': '731591220'}],
#  [{'start': 0, 'end': 9, 'username': '1974jrgd', 'id': '2257084204'}],
#  [{'start': 3, 'end': 18, 'username': 'TomSportsWUSA9', 'id': '19140465'}],
#  [{'start': 0, 'end': 12, 'username': 'GillesRusse', 'id': '87141457'},
#   {'start': 13,
# ...
#   {'start': 26, 'end': 38, 'username': 'dasputoasco', 'id': '2760310205'},
#   {'start': 39, 'end': 50, 'username': 'AlvarDroiD', 'id': '2675041484'}],
#  [{'start': 0, 'end': 9, 'username': 'flyknows', 'id': '1043667150'}],
#  [{'start': 0, 'end': 9, 'username': 'Carchezz', 'id': '2662707941'}],
#  [{'start': 0,
#    'end': 12,
#    'username': 'Jezadreamer',
#    'id': '983025785366867968'},
#   {'start': 13,
#    'end': 24,
#    'username': 'Friklista1',
#    'id': '1223716311928393733'},
#   {'start': 25, 'end': 33, 'username': 'serpal_', 'id': '373922633'},
#   {'start': 34, 'end': 44, 'username': 'elencita_', 'id': '1410777697'},
#   {'start': 45, 'end': 54, 'username': 'Pacarlas', 'id': '307312289'},
#   {'start': 55, 'end': 66, 'username': 'SaraPernas', 'id': '17673218'},
#   {'start': 67, 'end': 76, 'username': 'jjmmhhff', 'id': '143047250'},
#   {'start': 77, 'end': 88, 'username': 'Antonio_GM', 'id': '96798614'},
#   {'start': 89, 'end': 104, 'username': 'UnSosoCaustico', 'id': '1071256224'},
#   {'start': 105, 'end': 117, 'username': 'AnaBusteloT', 'id': '2828222112'},
#   {'start': 118, 'end': 131, 'username': 'tinaVallekas', 'id': '3001947297'},
#   {'start': 132, 'end': 139, 'username': 'Fundeu', 'id': '196955819'}],
#  [{'start': 0, 'end': 12, 'username': 'DevorahLeah', 'id': '15755592'}],
#  [{'start': 0,
#    'end': 12,
#    'username': 'oxigeno_sin',
#    'id': '1284894094288920576'},
#   {'start': 13, 'end': 25, 'username': 'wendolinpaz', 'id': '264989521'},
#   {'start': 26,
#    'end': 39,
#    'username': 'Tana02265435',
#    'id': '1106876804235694081'},
#   {'start': 40, 'end': 51, 'username': 'AlkorRules', 'id': '471864031'},
#   {'start': 52, 'end': 62, 'username': 'TiritaTNT', 'id': '418509082'},
#   {'start': 63, 'end': 73, 'username': 'RojaRojae', 'id': '134710048'},
#   {'start': 74, 'end': 89, 'username': 'perez_mpcbarna', 'id': '3059091891'},
#   {'start': 90, 'end': 104, 'username': 'Ohh_Yeahhhhhh', 'id': '2213849959'},
#   {'start': 105, 'end': 119, 'username': 'AlexDe_Large_', 'id': '2651386772'},
#   {'start': 120, 'end': 136, 'username': 'Conde_Somamones', 'id': '257494494'},
#   {'start': 137, 'end': 152, 'username': 'LuciaGavilan24', 'id': '626802956'},
#   {'start': 153,
#    'end': 166,
#    'username': 'MadridWordle',
#    'id': '1506335897582809104'},
#   {'start': 167, 'end': 179, 'username': 'sergiopitel', 'id': '339505013'},
#   {'start': 180, 'end': 191, 'username': 'carletes79', 'id': '245249468'},
#   {'start': 192,
#    'end': 201,
#    'username': 'PToadete',
#    'id': '1213791042333396993'},
#   {'start': 202, 'end': 210, 'username': 'Aratzeo', 'id': '518561917'},
#   {'start': 211,
#    'end': 220,
#    'username': 'Delgatus',
#    'id': '1186313696211021826'},
#   {'start': 221, 'end': 230, 'username': 'eskape09', 'id': '24684931'},
#   {'start': 231,
#    'end': 242,
#    'username': 'WordleGame',
#    'id': '1478755640105480200'},
#   {'start': 243, 'end': 250, 'username': 'Fundeu', 'id': '196955819'},
#   {'start': 251, 'end': 259, 'username': 'Twitter', 'id': '783214'},
#   {'start': 260,
#    'end': 267,
#    'username': 'RibMrs',
#    'id': '1336393166858186755'}],
#  [{'start': 0, 'end': 10, 'username': 'danielfrg', 'id': '18362117'}],
#  [{'start': 0, 'end': 14, 'username': 'stu_taylor173', 'id': '4921251556'}],
#  [{'start': 0, 'end': 11, 'username': 'SandyAphid', 'id': '387128131'}],
#  [{'start': 0,
#    'end': 10,
#    'username': '_Sofiia_C',
#    'id': '889130113765437441'}],
#  [{'start': 53, 'end': 69, 'username': 'RealRichardDoes', 'id': '15157872'}],
#  [{'start': 0,
#    'end': 13,
#    'username': 'JohnnyBlammo',
#    'id': '986628717396070401'},
#   {'start': 14, 'end': 25, 'username': 'D_Martin17', 'id': '57448281'},
#   {'start': 26, 'end': 39, 'username': 'seanlavery78', 'id': '30398147'},
#   {'start': 40,
#    'end': 53,
#    'username': 'Jacob__Snake',
#    'id': '1221248060333985793'}],
#  [{'start': 0, 'end': 14, 'username': 'lavecinarubia', 'id': '872086682'}],
#  [{'start': 31, 'end': 41, 'username': 'KurtWSYX6', 'id': '15601204'},
#   {'start': 44,
#    'end': 58,
#    'username': 'LowcountryLib',
#    'id': '819552178125869056'},
#   {'start': 61, 'end': 73, 'username': 'KevinBonsor', 'id': '298613160'},
#   {'start': 76, 'end': 87, 'username': 'AbsoluteLe', 'id': '37069709'},
#   {'start': 90, 'end': 101, 'username': 'EDouglasWW', 'id': '15509573'}],
#  [{'start': 0,
#    'end': 10,
#    'username': '_Sofiia_C',
#    'id': '889130113765437441'}],
#  [{'start': 0,
#    'end': 10,
#    'username': 'HansFiene',
#    'id': '707401956600389632'}],
#  [{'start': 0, 'end': 16, 'username': 'angelportas1992', 'id': '1684162632'}],
#  [{'start': 0,
#    'end': 12,
#    'username': 'Jezadreamer',
#    'id': '983025785366867968'},
#   {'start': 13,
#    'end': 24,
#    'username': 'Friklista1',
#    'id': '1223716311928393733'},
#   {'start': 25, 'end': 33, 'username': 'serpal_', 'id': '373922633'},
#   {'start': 34, 'end': 44, 'username': 'elencita_', 'id': '1410777697'},
#   {'start': 45, 'end': 54, 'username': 'Pacarlas', 'id': '307312289'},
#   {'start': 55, 'end': 66, 'username': 'SaraPernas', 'id': '17673218'},
#   {'start': 67, 'end': 76, 'username': 'jjmmhhff', 'id': '143047250'},
#   {'start': 77, 'end': 88, 'username': 'Antonio_GM', 'id': '96798614'},
#   {'start': 89, 'end': 104, 'username': 'UnSosoCaustico', 'id': '1071256224'},
#   {'start': 105, 'end': 117, 'username': 'AnaBusteloT', 'id': '2828222112'},
#   {'start': 118, 'end': 131, 'username': 'tinaVallekas', 'id': '3001947297'},
#   {'start': 132, 'end': 139, 'username': 'Fundeu', 'id': '196955819'}],
#  [{'start': 0, 'end': 11, 'username': '_Rephraser', 'id': '2724673089'}],
#  [{'start': 0, 'end': 16, 'username': 'leesinverguenza', 'id': '935214787'},
#   {'start': 17, 'end': 30, 'username': 'francesco_uv', 'id': '1717101920'},
#   {'start': 31, 'end': 43, 'username': 'dasputoasco', 'id': '2760310205'},
#   {'start': 44, 'end': 55, 'username': 'AlvarDroiD', 'id': '2675041484'}],
#  [{'start': 0, 'end': 10, 'username': 'brightise', 'id': '355133940'}],
#  [{'start': 0, 'end': 13, 'username': 'port_anfield', 'id': '34730181'}],
#  [{'start': 0, 'end': 9, 'username': 'credsal1', 'id': '314042689'}],
#  [{'start': 3,
#    'end': 12,
#    'username': 'WordleES',
#    'id': '1483085814422716419'}],
#  [{'start': 0, 'end': 12, 'username': 'RobertArnol', 'id': '633903357'}],
#  [{'start': 50, 'end': 65, 'username': 'AmerDentalAssn', 'id': '318531893'}],
#  [{'start': 0, 'end': 10, 'username': 'mmhpotter', 'id': '2398370366'}],
#  [{'start': 77,
#    'end': 86,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0, 'end': 11, 'username': 'Viryi_floi', 'id': '307379677'},
#   {'start': 12, 'end': 28, 'username': 'AntonioFdezJara', 'id': '231459661'}],
#  [{'start': 0, 'end': 11, 'username': 'Peter_Fitz', 'id': '183770461'}],
#  [{'start': 0, 'end': 16, 'username': 'ClaireSarsfield', 'id': '3022931045'}],
#  [{'start': 0, 'end': 11, 'username': 'Peter_Fitz', 'id': '183770461'}],
#  [{'start': 0,
#    'end': 11,
#    'username': 'Friklista1',
#    'id': '1223716311928393733'},
#   {'start': 12, 'end': 20, 'username': 'serpal_', 'id': '373922633'},
#   {'start': 21, 'end': 31, 'username': 'elencita_', 'id': '1410777697'},
#   {'start': 32, 'end': 41, 'username': 'jlgalego', 'id': '301629159'},
#   {'start': 42, 'end': 51, 'username': 'Pacarlas', 'id': '307312289'},
#   {'start': 52, 'end': 63, 'username': 'SaraPernas', 'id': '17673218'},
#   {'start': 64, 'end': 73, 'username': 'jjmmhhff', 'id': '143047250'},
#   {'start': 74, 'end': 85, 'username': 'Antonio_GM', 'id': '96798614'},
#   {'start': 86, 'end': 101, 'username': 'UnSosoCaustico', 'id': '1071256224'},
#   {'start': 102, 'end': 114, 'username': 'AnaBusteloT', 'id': '2828222112'},
#   {'start': 115, 'end': 128, 'username': 'tinaVallekas', 'id': '3001947297'},
#   {'start': 129, 'end': 136, 'username': 'Fundeu', 'id': '196955819'}],
#  [{'start': 0, 'end': 10, 'username': 'paulsinha', 'id': '20481697'}],
#  [{'start': 22, 'end': 36, 'username': 'JoseMartinJos', 'id': '635707464'}],
#  [{'start': 0,
#    'end': 16,
#    'username': 'itsaightbutyeah',
#    'id': '1344779221860831233'}],
#  [{'start': 0,
#    'end': 14,
#    'username': 'luciferwordle',
#    'id': '1489166747877797888'}],
#  [{'start': 0, 'end': 11, 'username': 'TechCrunch', 'id': '816653'},
#   {'start': 12, 'end': 25, 'username': 'sarahintampa', 'id': '683113'}],
#  [{'start': 0, 'end': 10, 'username': 'AaronDodd', 'id': '18621574'}],
#  [{'start': 0, 'end': 16, 'username': 'AntonioFdezJara', 'id': '231459661'},
#   {'start': 17, 'end': 29, 'username': 'veraayala93', 'id': '153093833'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0,
#    'end': 11,
#    'username': 'Melii__003',
#    'id': '1505551671530827779'}],
#  [{'start': 0,
#    'end': 13,
#    'username': 'TheHeatherEm',
#    'id': '812628603183763456'}],
#  [{'start': 51,
#    'end': 63,
#    'username': 'WordleStats',
#    'id': '1479469664623378433'}],
#  [{'start': 67, 'end': 81, 'username': 'alexjones1520', 'id': '523827275'},
#   {'start': 82, 'end': 94, 'username': 'lilisabel15', 'id': '1832339431'},
#   {'start': 95, 'end': 109, 'username': 'datvenezuelan', 'id': '257236071'},
#   {'start': 110, 'end': 116, 'username': 'GxB37', 'id': '1425576241'}],
#  [{'start': 3,
#    'end': 17,
#    'username': 'ColeCarterXxX',
#    'id': '1301582527463919619'}],
#  [{'start': 0,
#    'end': 11,
#    'username': 'cyberhell_',
#    'id': '1366774144654839816'}],
#  [{'start': 0, 'end': 9, 'username': 'flaxberg', 'id': '54253329'}],
#  [{'start': 3,
#    'end': 13,
#    'username': 'lluvata69',
#    'id': '1333201921935634435'}],
#  [{'start': 0,
#    'end': 16,
#    'username': 'GHargraveWrites',
#    'id': '1282510798229843970'}],
#  [{'start': 3, 'end': 16, 'username': 'AustenWoolfe', 'id': '32269905'}],
#  [{'start': 3,
#    'end': 18,
#    'username': 'AI_6_June_2017',
#    'id': '865816788616986624'}],
#  [{'start': 60, 'end': 76, 'username': 'ElenaSalvatella', 'id': '527660070'}],
#  [{'start': 0, 'end': 8, 'username': 'Milhaud', 'id': '18690355'},
#   {'start': 9,
#    'end': 19,
#    'username': 'NisMorFer',
#    'id': '1444377035544084484'}],
#  [{'start': 0, 'end': 8, 'username': 'Milhaud', 'id': '18690355'},
#   {'start': 9,
#    'end': 19,
#    'username': 'NisMorFer',
#    'id': '1444377035544084484'}],
#  [{'start': 0, 'end': 13, 'username': 'N0toriousKat', 'id': '2387965682'}],
#  [{'start': 62,
#    'end': 71,
#    'username': 'dewordle',
#    'id': '1482411529152741376'}],
#  [{'start': 0, 'end': 16, 'username': 'RobynUnravelled', 'id': '3247457340'},
#   {'start': 17, 'end': 26, 'username': 'Thee2dap', 'id': '22412439'}],
#  [{'start': 0,
#    'end': 16,
#    'username': 'wheresmyjuulian',
#    'id': '1495594981226074114'},
#   {'start': 17,
#    'end': 33,
#    'username': 'hunterschaferFR',
#    'id': '1456024057175019524'}],
#  [{'start': 0, 'end': 13, 'username': 'DeepFriedDNA', 'id': '582872181'}],
#  [{'start': 0,
#    'end': 16,
#    'username': 'wolfwolfwolf889',
#    'id': '1420132545165987843'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0, 'end': 8, 'username': 'Iigmari', 'id': '1513221043766374406'},
#   {'start': 9,
#    'end': 25,
#    'username': 'wheresmyjuulian',
#    'id': '1495594981226074114'}],
#  [{'start': 0, 'end': 11, 'username': 'marcusreif', 'id': '14656612'}],
#  [{'start': 0, 'end': 12, 'username': 'geoffmeeker', 'id': '16391520'}],
#  [{'start': 3, 'end': 16, 'username': 'MikeBerridge', 'id': '439983967'},
#   {'start': 18,
#    'end': 27,
#    'username': 'albolt76',
#    'id': '1160130818678972416'},
#   {'start': 28, 'end': 37, 'username': 'dawardle', 'id': '1165789231'}],
#  [{'start': 0, 'end': 7, 'username': 'suikof', 'id': '240194403'},
#   {'start': 8, 'end': 23, 'username': 'yoshua_yonatan', 'id': '105711588'},
#   {'start': 24, 'end': 39, 'username': 'corporatelabor', 'id': '259640134'},
#   {'start': 40, 'end': 49, 'username': 'Hamidahf', 'id': '49832858'},
#   {'start': 50, 'end': 57, 'username': 'mujipi', 'id': '67790077'},
#   {'start': 58,
#    'end': 68,
#    'username': 'mbakdiian',
#    'id': '1238711001840619525'},
#   {'start': 69, 'end': 79, 'username': 'yuzamulia', 'id': '83163814'},
#   {'start': 80, 'end': 91, 'username': 'bonarevano', 'id': '69223376'},
#   {'start': 92, 'end': 101, 'username': 'rionipar', 'id': '58185631'},
#   {'start': 102, 'end': 112, 'username': 'pawarestu', 'id': '1314102356'},
#   {'start': 113, 'end': 122, 'username': 'kinankin', 'id': '91585483'},
#   {'start': 123, 'end': 130, 'username': 'afifai', 'id': '74913061'},
#   {'start': 131, 'end': 145, 'username': 'barrysianturi', 'id': '2237377454'}],
#  [{'start': 0, 'end': 9, 'username': 'albolt76', 'id': '1160130818678972416'},
#   {'start': 10, 'end': 19, 'username': 'dawardle', 'id': '1165789231'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0,
#    'end': 16,
#    'username': 'YeeterMcSkeet3r',
#    'id': '1221947667326099457'}],
#  [{'start': 53, 'end': 63, 'username': 'CDUKE1217', 'id': '255127149'},
#   {'start': 65, 'end': 75, 'username': 'kevlar612', 'id': '260530916'}],
#  [{'start': 13,
#    'end': 22,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0, 'end': 9, 'username': 'flaxberg', 'id': '54253329'}],
#  [{'start': 102,
#    'end': 111,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 3, 'end': 16, 'username': 'adambspencer', 'id': '22519146'},
#   {'start': 63, 'end': 74, 'username': 'Peter_Fitz', 'id': '183770461'}],
#  [{'start': 0, 'end': 15, 'username': 'AdrianManifold', 'id': '804321630'}],
#  [{'start': 75, 'end': 82, 'username': 'lnoya_', 'id': '434138331'}],
#  [{'start': 95, 'end': 107, 'username': 'CabotMiguel', 'id': '1289330292'},
#   {'start': 108, 'end': 124, 'username': 'helenadetroya72', 'id': '42697823'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0, 'end': 11, 'username': 'phaedras25', 'id': '16245288'}],
#  [{'start': 3, 'end': 17, 'username': 'SarahThePearl', 'id': '1192372393'}],
#  [{'start': 0, 'end': 9, 'username': 'Nollie38', 'id': '18998096'}],
#  [{'start': 25,
#    'end': 37,
#    'username': 'ComuGlobera',
#    'id': '1081196352095293440'}],
#  [{'start': 0, 'end': 9, 'username': 'flaxberg', 'id': '54253329'}],
#  [{'start': 0, 'end': 12, 'username': 'AnneinParis', 'id': '50553'}],
#  [{'start': 3, 'end': 17, 'username': 'kylieNOjenner', 'id': '21237472'}],
#  [{'start': 76,
#    'end': 85,
#    'username': 'dewordle',
#    'id': '1482411529152741376'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 0, 'end': 15, 'username': 'nigel_guisboro', 'id': '529820706'}],
#  [{'start': 0, 'end': 10, 'username': 'FrauDausH', 'id': '806995261'}],
#  [{'start': 0,
#    'end': 13,
#    'username': 'tronquibiris',
#    'id': '1367229495271452679'},
#   {'start': 14, 'end': 29, 'username': 'enteraconjamon', 'id': '192726508'},
#   {'start': 30, 'end': 39, 'username': 'jossipag', 'id': '118998581'},
#   {'start': 40, 'end': 49, 'username': 'Antuki90', 'id': '189951782'},
#   {'start': 50, 'end': 60, 'username': 'pulimento', 'id': '16915767'},
#   {'start': 61, 'end': 70, 'username': 'Eledelma', 'id': '278043887'}],
#  [{'start': 3, 'end': 14, 'username': 'xLauren_Mx', 'id': '578492245'}],
#  [{'start': 8,
#    'end': 17,
#    'username': 'WordleFR',
#    'id': '1480029602105995267'}],
#  [{'start': 3, 'end': 12, 'username': 'K_Argyll', 'id': '338274860'},
#   {'start': 14,
#    'end': 23,
#    'username': 'albolt76',
#    'id': '1160130818678972416'},
#   {'start': 24,
#    'end': 34,
#    'username': 'rahhead01',
#    'id': '1002601147901857793'},
#   {'start': 35, 'end': 44, 'username': 'dawardle', 'id': '1165789231'}],
#  [{'start': 0,
#    'end': 12,
#    'username': 'BirgitHrtl2',
#    'id': '1053012833846349825'},
#   {'start': 13,
#    'end': 27,
#    'username': 'FrauPlannerer',
#    'id': '1334523858326614025'},
#   {'start': 28,
#    'end': 37,
#    'username': 'dewordle',
#    'id': '1482411529152741376'}],
#  ...]

# %%
# how many of these mentioned users are themselves tweeters in the list?

def get_mentioned_users(entities_mentioned_list, unique = False):
    extracted_mentions = []
    for this_entities_mentioned in entities_mentioned_list:
        for mentioned_user in this_entities_mentioned:
            extracted_mentions.append([mentioned_user['username'], mentioned_user['id']])
    if unique:
        return list(map(lambda extracted_mention: list(np.unique(extracted_mention)), extracted_mentions))
    return extracted_mentions

# %%
unique_mentioned_users = get_mentioned_users(expanded_tweet_mentions, unique=True)
unique_mentioned_users[:5]
# Out:
# [['331622540', 'RwellsWells'],
#  ['1275838631891152898', 'misfortunateApe'],
#  ['1353120743199023106', 'SamuelAlpha77'],
#  ['1495802955580297216', '1kisfud'],
#  ['1437848652085669894', 'SumPersonal']]

# %%
type(unique_mentioned_users[0][0])
# Out:
# numpy.str_

# %%
#at least one of the user ids in this list is a missing hexadecimal for some reason.
#del(unique_mentioned_users[321])

# %%
#check how many users are in the posted users
mentioned_users_in_users_unique = [  
    int(mentioned_user[0]) in users.index
    for mentioned_user in unique_mentioned_users
    if mentioned_user[0].isnumeric()
]

np.mean(mentioned_users_in_users_unique)
# Out:
# 0.5409774436090226

# %% [markdown]
# About 22% of mentioned users themselves are original posters. This is blind to replies, where mentions are automatically added to a tweet. The point is that over 3 out of 4 of these mentioned users aren't even posting completed Wordles themselves! Mentions may be a good way to spread the game via word-of-mouth, but one would need to track if these users eventually post themselves. Remember: a person posting their Wordle game is not IFF they played Wordle --- many of these people could be avid players.

# %%
#do the same for a list of non-unique mentions. Includes the user for every mention in the set, including repeats.
#for some reason, unique = True/False also switches the order of the username and id
all_mentioned_users = get_mentioned_users(entities_mentioned_list=expanded_tweet_mentions, unique= False)
mentioned_user_in_users = [  
    int(mentioned_user[1]) in users.index
    for mentioned_user in all_mentioned_users
    if mentioned_user[1].isnumeric()
]

np.mean(mentioned_user_in_users)
# Out:
# 0.5412868632707775

# %% [markdown]
# This is almost the same, but a tiny bit larger. Most mentions are unique.

# %% [markdown]
# ### entities_tweethashtags

# %%
tudf['entities_tweethashtags'].dropna()
# Out:
# tweet_id
# 1521732994817740800      [{'start': 67, 'end': 78, 'tag': 'ポケモンWordle'}]
# 1521732956125122561        [{'start': 0, 'end': 10, 'tag': 'WordleCAT'}]
# 1521732947589873664      [{'start': 87, 'end': 98, 'tag': 'ポケモンWordle'}]
# 1521732873975386113    [{'start': 0, 'end': 7, 'tag': 'Wordle'}, {'st...
# 1521732844640518144            [{'start': 0, 'end': 7, 'tag': 'Wordle'}]
#                                              ...
# 1521995229712183296       [{'start': 47, 'end': 57, 'tag': 'Wordle320'}]
# 1521995088444162048      [{'start': 80, 'end': 91, 'tag': 'ポケモンWordle'}]
# 1521995045569708036            [{'start': 0, 'end': 7, 'tag': 'Wordle'}]
# 1521994920067747845            [{'start': 0, 'end': 7, 'tag': 'AlWird'}]
# 1521994909661958146     [{'start': 167, 'end': 177, 'tag': 'Wordle320'}]
# Name: entities_tweethashtags, Length: 31604, dtype: object

# %%
len(tudf['entities_tweethashtags'].dropna())/len(tudf)
# Out:
# 0.09424830091224387

# %% [markdown]
# about 9% of the tweets have at least one hashtag.

# %%
# get all hashtags
def get_all_hashtags(list_of_hashtag_lists, hashtag_key='tag', flat = True):
    if flat:
        complete_hashtag_list = []
        for hashtag_list in list_of_hashtag_lists:
            for hashtag_dict in hashtag_list:
                complete_hashtag_list.append(hashtag_dict[hashtag_key])
    else:
        complete_hashtag_list = [
            [
                hashtag_dict[hashtag_key]
                for hashtag_dict in hashtag_list
            ]
            for hashtag_list in list_of_hashtag_lists
        ]
    return complete_hashtag_list

all_hashtags_df = pd.DataFrame(get_all_hashtags(tudf['entities_tweethashtags'].dropna(), flat = True), columns = ["hashtag"])

# %%
#get list of hashtags by frequency
all_hashtags_df['hashtag'].value_counts()[:50]
# Out:
# ポケモンWordle            13081
# Wordle                 6011
# wordle                 2327
# WordleCAT              1965
# dailywordleclub         960
# вордли                  812
# Wordle318               743
# Wordle316               698
# Wordle317               670
# Wordle320               605
# Heardle                 525
# dailywordchallenge      500
# Wordle315               455
# Wordle319               425
# 워들                      371
# 한글                      369
# Korean                  367
# mywordle                356
# wordleTR                349
# Worldle                 320
# AlWird                  279
# galego                  262
# WordleGalego            258
# wordle316               199
# DailyWordleClub         185
# wordle318               183
# WordleEnglish           182
# WordleEN                175
# wordle317               174
# wordle320               174
# Wordle5                 167
# wordle7                 166
# wordle6                 165
# WordleEUS               126
# hadejSlova              116
# Thwordle                113
# வேடல்                   110
# WORDLE_TAMIL            110
# wordle319               105
# Moviedle                104
# wordle315               101
# WordleES                 92
# WORDE                    90
# Wordle321                88
# Septle                   79
# WordleEspañol            76
# Wordle314                71
# WizardingWordle          63
# Enstarsdle               62
# Wordaily                 60
# Name: hashtag, dtype: int64

# %%
#export unique wordle hashtags for assigning game
all_hashtags_df.to_csv('all_hashtags.csv')

# %%
all_hashtags_vcs = all_hashtags_df['hashtag'].value_counts()[:20][::-1]
plt.figure(figsize = (12, 12))
plt.barh(width = all_hashtags_vcs, y = all_hashtags_vcs.index)
# Out:
# <BarContainer object of 20 artists>
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44544 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 50892 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 46308 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12509 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12465 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12514 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 12531 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44544 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 50892 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 46308 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12509 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12465 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12514 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 12531 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# Foreign language characters aren't in the plotting font. The top result is `ポケモンWordle`, specifically a Pokemon Wordle clone popular in Japan.
#
# Following are simply `Wordle` and `wordle`.
#
# Fourth is `WordleCAT`, for Catalan.
#
# Next, and further ahead, is `Wordle`XXX, a hashtag specifically for that day's Wordle, with XXX the number.

# %%
#get distributions of number of hashtags per tweet.
hashtag_num_distribution = pd.DataFrame(tudf['entities_tweethashtags'].apply(lambda x: len(x) if type(x) == list else 0))

# %%
#plot hashtag count distribution.
hashtag_num_distribution['entities_tweethashtags'].hist(log = True)
plt.xlabel("total number of hashtags in single tweet")
plt.ylabel("tweets")
plt.title("number of hashtags per tweet (log)");

# %%
tudf['entities_tweethashtags'].dropna().iloc[0]
# Out:
# [{'start': 67, 'end': 78, 'tag': 'ポケモンWordle'}]

# %%
#create a list of just the hashtags for each tweet.

regex = r"'tag': '(.*?)'"
text  = "[{'start': 61, 'end': 72, 'tag': 'ポケモンWordle'}]"

for match in re.findall(regex, text):
    print(f"Found {match}")

    
tudf['hashtags'] = hashtags = tudf['entities_tweethashtags'].apply(lambda entry: re.findall(regex, str(entry)) if type(entry) == list else [])
# Out:
# Found ポケモンWordle

# %%
str(tudf['entities_tweethashtags'].dropna().iloc[0])
# Out:
# "[{'start': 65, 'end': 76, 'tag': 'Enstarsdle'}]"

# %%
tudf['has_hashtags'] = tudf['hashtags'].apply(lambda hashtag_list: len(hashtag_list) > 0)

# %%
tudf['has_hashtags'].mean()
# Out:
# 0.09582178612368258

# %% [markdown]
# This length is the same as before ---- we got all of them.

# %%
tudf[tudf['has_hashtags']]['hashtags']
# Out:
# 1520127652975321088                [Enstarsdle]
# 1520127913122832391                    [Wordle]
# 1520127925055799297    [한글, 워들, Korean, Wordle]
# 1520128019846684672                [ポケモンWordle]
# 1520128136771371008                [ポケモンWordle]
#                                  ...
# 1522335060665552900         [wordle6, wordleTR]
# 1522335061801984000                [ポケモンWordle]
# 1522335069926424576                [ポケモンWordle]
# 1522335124578131969                 [Wordle320]
# 1522335240517267456                [ポケモンWordle]
# Name: hashtags, Length: 37031, dtype: object

# %%
tudf['entities_tweethashtags'].dropna()
# Out:
# 1520127652975321088      [{'start': 65, 'end': 76, 'tag': 'Enstarsdle'}]
# 1520127913122832391            [{'start': 0, 'end': 7, 'tag': 'Wordle'}]
# 1520127925055799297    [{'start': 0, 'end': 3, 'tag': '한글'}, {'start'...
# 1520128019846684672      [{'start': 61, 'end': 72, 'tag': 'ポケモンWordle'}]
# 1520128136771371008      [{'start': 61, 'end': 72, 'tag': 'ポケモンWordle'}]
#                                              ...
# 1522335060665552900    [{'start': 99, 'end': 107, 'tag': 'wordle6'}, ...
# 1522335061801984000      [{'start': 61, 'end': 72, 'tag': 'ポケモンWordle'}]
# 1522335069926424576      [{'start': 61, 'end': 72, 'tag': 'ポケモンWordle'}]
# 1522335124578131969        [{'start': 0, 'end': 10, 'tag': 'Wordle320'}]
# 1522335240517267456      [{'start': 67, 'end': 78, 'tag': 'ポケモンWordle'}]
# Name: entities_tweethashtags, Length: 40589, dtype: object

# %% [markdown]
# It appears that a small number of hashtags may be useful for assigning the game. All we really care about at this point is the text of the hashtag itself.

# %% [markdown]
# The hashtag `Wordle` appears in games that aren't "legit" Wordles from the NYTimes. These should be checked. `WordleXXX` is a hashtag that corresponds to a legitimate Wordle, but these also appear in the text.

# %% [markdown]
# ### entities_tweetsannotations
#
# Twitter has a bunch of ids for topics and assigns probabilities that a tweet is about a certain topic.
# It's cool that you can look up tweets by topic id. I guess that's how a lot of people stay on top of things for their own projects about a single topic.
#
# [The docs](https://developer.twitter.com/en/docs/twitter-api/annotations/overview) have an overview of the kinds of entities things can be. Context annotations will be looked at ahead of this section.

# %%
tudf['entities_tweetannotations'].dropna()
# Out:
# tweet_id
# 1521727434374418432    [{'start': 12, 'end': 18, 'probability': 0.707...
# 1521726764883619840    [{'start': 19, 'end': 27, 'probability': 0.318...
# 1521726119682228228    [{'start': 20, 'end': 26, 'probability': 0.474...
# 1521725413877293056    [{'start': 15, 'end': 31, 'probability': 0.366...
# 1521723789180088320    [{'start': 51, 'end': 54, 'probability': 0.593...
#                                              ...
# 1521996804979671045    [{'start': 0, 'end': 5, 'probability': 0.3086,...
# 1521996157475762176    [{'start': 140, 'end': 149, 'probability': 0.8...
# 1521995907297861633    [{'start': 0, 'end': 23, 'probability': 0.5194...
# 1521995400865107968    [{'start': 0, 'end': 5, 'probability': 0.4368,...
# 1521994909661958146    [{'start': 13, 'end': 19, 'probability': 0.361...
# Name: entities_tweetannotations, Length: 2538, dtype: object

# %%
tudf['entities_tweetannotations'].dropna().iloc[0]
# Out:
# [{'start': 12,
#   'end': 18,
#   'probability': 0.7079,
#   'type': 'Product',
#   'normalized_text': 'twitter'}]

# %%
tudf['entities_tweetannotations'].dropna().iloc[1]
# Out:
# [{'start': 19,
#   'end': 27,
#   'probability': 0.318,
#   'type': 'Other',
#   'normalized_text': 'Star Wars'}]

# %% [markdown]
# ### entities_tweetscashtags
#
# Very small number of tweets have a "cashtag." These were added as a way to keep track of stock prices. Perhaps it's a hashtag from a list of stock codes.

# %%
tudf.loc[tudf['entities_tweetcashtags'].dropna().index]
# Out:
#                          conversation_id reply_settings lang  \
# tweet_id
# 1521363122812030976  1521363122812030976       everyone   en
#
#                      possibly_sensitive              source  \
# tweet_id
# 1521363122812030976               False  Twitter for iPhone
#
#                                                   public_metrics_tweet  \
# tweet_id
# 1521363122812030976  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
#                                                                   text  \
# tweet_id
# 1521363122812030976  Wordle 318 5/6\r\n\r\n⬛⬛🟩⬛⬛\r\n⬛🟨🟩⬛⬛\r\n🟨🟩🟩⬛⬛\...
#
#                                                    context_annotations  \
# tweet_id
# 1521363122812030976  [{'domain': {'id': '30', 'name': 'Entities [En...
#
#                                author_id                created_at  \
# tweet_id
# 1521363122812030976  1447577070465429510 2022-05-03 05:36:48+00:00
#
#                     referenced_tweets  in_reply_to_user_id attachments geo  \
# tweet_id
# 1521363122812030976                []                  0.0          {}  {}
#
#                     withheld_tweet name public_metrics_user url description  \
# tweet_id
# 1521363122812030976             {}    0                   0   0           0
#
#                     profile_image_url location protected username verified  \
# tweet_id
# 1521363122812030976                 0        0         0        0        0
#
#                     entities_user  pinned_tweet_id withheld_user  \
# tweet_id
# 1521363122812030976             0              0.0             0
#
#                     entities_tweeturls entities_tweetmentions  \
# tweet_id
# 1521363122812030976                NaN                    NaN
#
#                     entities_tweethashtags entities_tweetannotations  \
# tweet_id
# 1521363122812030976                    NaN                       NaN
#
#                                      entities_tweetcashtags
# tweet_id
# 1521363122812030976  [{'start': 69, 'end': 71, 'tag': 'h'}]

# %% [markdown]
# ### possibly_sensitive
#
# Less than 1% of the tweets are marked as possibly_sensitive.

# %%
#get percentage of possibly_sensitive tweets
tudf['possibly_sensitive'].value_counts(normalize='yeah')
# Out:
# False    0.991191
# True     0.008809
# Name: possibly_sensitive, dtype: float64

# %%
tudf[tudf['possibly_sensitive']].head()
# Out:
#                          conversation_id reply_settings lang  \
# tweet_id
# 1521732020044546050  1521732020044546050       everyone  und
# 1521731907632852992  1521731907632852992       everyone   ja
# 1521731773092225024  1521731773092225024       everyone  und
# 1521731038292099075  1521731038292099075       everyone   en
# 1521730686197157889  1521730686197157889       everyone   es
#
#                      possibly_sensitive               source  \
# tweet_id
# 1521732020044546050                True   Twitter for iPhone
# 1521731907632852992                True   Twitter for iPhone
# 1521731773092225024                True   Twitter for iPhone
# 1521731038292099075                True   Twitter for iPhone
# 1521730686197157889                True  Twitter for Android
#
#                                                   public_metrics_tweet  \
# tweet_id
# 1521732020044546050  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521731907632852992  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521731773092225024  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521731038292099075  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1521730686197157889  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
#                                                                   text  \
# tweet_id
# 1521732020044546050  #WordleCAT 124 3/6\r\n\r\n🟩🟨⬜⬜🟩\r\n🟩🟩🟩⬜🟩\r\n🟩🟩...
# 1521731907632852992  ポケモンWordle 5/10\r\n\r\n⬛⬛⬛⬛🟩\r\n⬛⬛⬛⬛🟩\r\n⬛🟩⬛⬛🟩...
# 1521731773092225024  #WordleCAT 124 5/6\r\n\r\n⬜⬜⬜⬜🟩\r\n⬜🟩⬜⬜🟩\r\n⬜🟩...
# 1521731038292099075  Wordle (ES)  #118 5/6\r\n\r\n⬜🟨⬜🟨🟨\r\n🟩🟩⬜🟨⬜\r\...
# 1521730686197157889  Wordle Científico #52 3/6\r\n\r\n⬜🟩⬜⬜⬜\r\n🟨🟨🟨🟨...
#
#                                                    context_annotations  \
# tweet_id
# 1521732020044546050                                                 []
# 1521731907632852992  [{'domain': {'id': '45', 'name': 'Brand Vertic...
# 1521731773092225024                                                 []
# 1521731038292099075  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521730686197157889  [{'domain': {'id': '30', 'name': 'Entities [En...
#
#                                author_id                created_at  \
# tweet_id
# 1521732020044546050           2465123766 2022-05-04 06:02:40+00:00
# 1521731907632852992  1184725640076914691 2022-05-04 06:02:13+00:00
# 1521731773092225024           1180367820 2022-05-04 06:01:41+00:00
# 1521731038292099075            452862948 2022-05-04 05:58:46+00:00
# 1521730686197157889  1057296265195732992 2022-05-04 05:57:22+00:00
#
#                     referenced_tweets  in_reply_to_user_id attachments geo  \
# tweet_id
# 1521732020044546050                []                  0.0          {}  {}
# 1521731907632852992                []                  0.0          {}  {}
# 1521731773092225024                []                  0.0          {}  {}
# 1521731038292099075                []                  0.0          {}  {}
# 1521730686197157889                []                  0.0          {}  {}
#
#                     withheld_tweet                   name  \
# tweet_id
# 1521732020044546050             {}             Maria Font
# 1521731907632852992             {}                      0
# 1521731773092225024             {}                   Toni
# 1521731038292099075             {}  Alejandra López ❤️💛❤️
# 1521730686197157889             {}           Andoni Zalla
#
#                                                    public_metrics_user url  \
# tweet_id
# 1521732020044546050  {'followers_count': 11, 'following_count': 52,...
# 1521731907632852992                                                  0   0
# 1521731773092225024  {'followers_count': 83, 'following_count': 392...
# 1521731038292099075  {'followers_count': 412, 'following_count': 36...
# 1521730686197157889  {'followers_count': 235, 'following_count': 11...
#
#                                        description  \
# tweet_id
# 1521732020044546050
# 1521731907632852992                              0
# 1521731773092225024             Lletissó d’adopció
# 1521731038292099075  Shippeadora Turquil oficial!!
# 1521730686197157889
#
#                                                      profile_image_url  \
# tweet_id
# 1521732020044546050  https://pbs.twimg.com/profile_images/141650585...
# 1521731907632852992                                                  0
# 1521731773092225024  https://pbs.twimg.com/profile_images/144575407...
# 1521731038292099075  https://pbs.twimg.com/profile_images/139140381...
# 1521730686197157889  https://pbs.twimg.com/profile_images/141920373...
#
#                     location protected         username verified  \
# tweet_id
# 1521732020044546050              False          Mafontp    False
# 1521731907632852992        0         0                0        0
# 1521731773092225024              False      ToniRouge77    False
# 1521731038292099075  Turquía     False        alejitasi    False
# 1521730686197157889              False  joseba_zorrilla    False
#
#                     entities_user  pinned_tweet_id withheld_user  \
# tweet_id
# 1521732020044546050            {}     1.279520e+18            {}
# 1521731907632852992             0     0.000000e+00             0
# 1521731773092225024            {}     1.387744e+18            {}
# 1521731038292099075            {}     1.478831e+18            {}
# 1521730686197157889            {}     0.000000e+00            {}
#
#                                                     entities_tweeturls  \
# tweet_id
# 1521732020044546050  [{'start': 39, 'end': 62, 'url': 'https://t.co...
# 1521731907632852992  [{'start': 48, 'end': 71, 'url': 'https://t.co...
# 1521731773092225024  [{'start': 51, 'end': 74, 'url': 'https://t.co...
# 1521731038292099075  [{'start': 54, 'end': 77, 'url': 'https://t.co...
# 1521730686197157889  [{'start': 46, 'end': 69, 'url': 'https://t.co...
#
#                     entities_tweetmentions  \
# tweet_id
# 1521732020044546050                    NaN
# 1521731907632852992                    NaN
# 1521731773092225024                    NaN
# 1521731038292099075                    NaN
# 1521730686197157889                    NaN
#
#                                               entities_tweethashtags  \
# tweet_id
# 1521732020044546050    [{'start': 0, 'end': 10, 'tag': 'WordleCAT'}]
# 1521731907632852992  [{'start': 73, 'end': 84, 'tag': 'ポケモンWordle'}]
# 1521731773092225024    [{'start': 0, 'end': 10, 'tag': 'WordleCAT'}]
# 1521731038292099075                                              NaN
# 1521730686197157889                                              NaN
#
#                     entities_tweetannotations entities_tweetcashtags
# tweet_id
# 1521732020044546050                       NaN                    NaN
# 1521731907632852992                       NaN                    NaN
# 1521731773092225024                       NaN                    NaN
# 1521731038292099075                       NaN                    NaN
# 1521730686197157889                       NaN                    NaN

# %%
tudf[tudf['possibly_sensitive']]['lang'].value_counts()
# Out:
# en     1370
# ja      974
# es      215
# tr      146
# und      60
# fr       58
# de       41
# ko       37
# ru       16
# ca       13
# cs        7
# et        4
# zh        4
# th        2
# fi        1
# no        1
# tl        1
# pt        1
# da        1
# hu        1
# nl        1
# Name: lang, dtype: int64

# %%
#language distribution of possibly_sensitive tweets

# %%
type(tudf[tudf['possibly_sensitive']])
# Out:
# pandas.core.frame.DataFrame

# %%
#language distribution of possibly_sensitive
plot_tweet_languages(tudf[tudf['possibly_sensitive']], figsize = (12,6), num_text=False, reverse = False)

# %%
tudf.columns
# Out:
# Index(['conversation_id', 'reply_settings', 'lang', 'possibly_sensitive',
#        'source', 'public_metrics_tweet', 'text', 'context_annotations',
#        'author_id', 'created_at', 'referenced_tweets', 'in_reply_to_user_id',
#        'attachments', 'geo', 'withheld_tweet', 'name', 'public_metrics_user',
#        'url', 'description', 'profile_image_url', 'location', 'protected',
#        'username', 'verified', 'entities_user', 'pinned_tweet_id',
#        'withheld_user', 'entities_tweeturls', 'entities_tweetmentions',
#        'entities_tweethashtags', 'entities_tweetannotations',
#        'entities_tweetcashtags'],
#       dtype='object')

# %% [markdown]
# ### Source
#
# Source appears to be the name of the program that sent in the tweet. There are over 350 unique ones, with most of these applied to single tweets. The heavy hitters are unsurprising popular programs.
#
# |          software           |    fraction |
# |:--------------------|-----------:|
# | Twitter for iPhone  | 0.466511   |
# | Twitter for Android | 0.340715   |
# | Twitter Web App     | 0.137656   |
# | Twitter for iPad    | 0.0271263  |
# | TweetDeck           | 0.00942429 |
# | Tweetbot for iΟS    | 0.00509013 |

# %%
#look at value counts
tudf['source'].value_counts()[:6]
# Out:
# Twitter for iPhone     156426
# Twitter for Android    113244
# Twitter Web App         47042
# Twitter for iPad         9046
# TweetDeck                3185
# Tweetbot for iΟS         1730
# Name: source, dtype: int64

# %%
#generate the table above
(tudf['source'].value_counts('normalize it')[:6]*100).to_markdown(index=True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1488/1941053422.py in <module>
#       1 #generate the table above
# ----> 2 (tudf['source'].value_counts('normalize it')[:6]*100).to_markdown(index=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in to_markdown(self, buf, mode, index, storage_options, **kwargs)
#    1634         +----+----------+
#    1635         """
# -> 1636         return self.to_frame().to_markdown(
#    1637             buf, mode, index, storage_options=storage_options, **kwargs
#    1638         )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in to_markdown(self, buf, mode, index, storage_options, **kwargs)
#    2565         kwargs.setdefault("tablefmt", "pipe")
#    2566         kwargs.setdefault("showindex", index)
# -> 2567         tabulate = import_optional_dependency("tabulate")
#    2568         result = tabulate.tabulate(self, **kwargs)
#    2569         if buf is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\compat\_optional.py in import_optional_dependency(name, extra, errors, min_version)
#     116     except ImportError:
#     117         if errors == "raise":
# --> 118             raise ImportError(msg) from None
#     119         else:
#     120             return None
#
# ImportError: Missing optional dependency 'tabulate'.  Use pip or conda to install tabulate.

# %%
#plot them, both with log and linear scales.
top_source_vcs = tudf['source'].value_counts()[:6][::-1]

plt.figure(figsize = (12,6))
plt.barh(width = top_source_vcs, y=top_source_vcs.index, log = True)
plt.xlabel('number of tweets sent via software')
plt.ylabel("tweeting software")
plt.title("tweets sent by software (log)");
plt.show()


plt.figure(figsize = (12,6))
plt.barh(width = top_source_vcs, y=top_source_vcs.index, log = False)
plt.xlabel('number of tweets sent via software')
plt.ylabel("tweeting software")
plt.title("tweets sent by software");
plt.show()

# %% [markdown]
# ### public_metrics_tweet
#
# These consist of:
# - retweet_count
# - reply_count
# - like_count
# - quote_count

# %%
tudf['public_metrics_tweet'].iloc[0]
# Out:
# "{'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}"

# %%
#turn the public_metrics_tweet column into a series of columns.
# turn the entities_tweet column into a series of columns, one for each of the possible keys.
tudf = expand_json_cols(tudf, ['public_metrics_tweet'], drop_json_cols=True)

# %%
tudf[tudf.columns[-4:]].head()
# Out:
#                      public_metrics_tweetretweet_count  \
# tweet_id
# 1521733018293084160                                  0
# 1521733015738662913                                  0
# 1521733011414257664                                  0
# 1521733010504445954                                  0
# 1521733001981444096                                  0
#
#                      public_metrics_tweetreply_count  \
# tweet_id
# 1521733018293084160                                0
# 1521733015738662913                                0
# 1521733011414257664                                0
# 1521733010504445954                                0
# 1521733001981444096                                0
#
#                      public_metrics_tweetlike_count  \
# tweet_id
# 1521733018293084160                               0
# 1521733015738662913                               0
# 1521733011414257664                               0
# 1521733010504445954                               0
# 1521733001981444096                               0
#
#                      public_metrics_tweetquote_count
# tweet_id
# 1521733018293084160                                0
# 1521733015738662913                                0
# 1521733011414257664                                0
# 1521733010504445954                                0
# 1521733001981444096                                0

# %% [markdown]
# ### public_metrics_tweetretweet_count
#
# The vast majority are not retweeted.
#
# There are a few that were tweeted a huge number of times!

# %%
tudf['public_metrics_tweetretweet_count'].value_counts()
# Out:
# 0       330575
# 1         3600
# 2          354
# 3          121
# 4           71
# 41          68
# 10          52
# 140         49
# 58          47
# 5           38
# 35          37
# 8           36
# 34          32
# 6           30
# 25          24
# 20          20
# 21          19
# 23          16
# 138         16
# 139         14
# 12          13
# 11          11
# 7            8
# 16           7
# 15           6
# 18           5
# 30           5
# 72           3
# 71           3
# 134          3
# 70           3
# 2742         3
# 9            3
# 74           2
# 14           2
# 48           2
# 1713         2
# 558          2
# 131          2
# 345          2
# 135          2
# 19           1
# 40           1
# 367          1
# 263          1
# 129          1
# 239          1
# 8587         1
# 6921         1
# 31           1
# 32           1
# 184          1
# 559          1
# 24           1
# 343          1
# 961          1
# 121          1
# 69           1
# 1499         1
# 8588         1
# Name: public_metrics_tweetretweet_count, dtype: int64

# %%
tudf['public_metrics_tweetretweet_count'].hist(bins = 20, log = True, figsize = (12,6))
plt.title("retweet count histogram");

# %%
tudf[tudf['public_metrics_tweetretweet_count'] > 500]
# Out:
#                          conversation_id reply_settings lang  \
# tweet_id
# 1521523004508975104  1521523004508975104       everyone   en
# 1521496553231425539  1521496553231425539       everyone   en
# 1521492943080759298  1521492943080759298       everyone   en
# 1521292805355843587  1521292805355843587       everyone   en
# 1521087200901103616  1521087200901103616       everyone   ko
# 1520845001495879685  1520845001495879685       everyone   en
# 1520740351178416128  1520740351178416128       everyone   en
# 1520588597346578432  1520588597346578432       everyone   en
# 1520496674656903178  1520496674656903178       everyone   en
# 1520262808159588352  1520262808159588352       everyone   en
# 1522236897879158784  1522236897879158784       everyone   ko
# 1522236847724064771  1522236847724064771       everyone   ko
# 1522083083939454976  1522083083939454976       everyone   ko
#
#                      possibly_sensitive               source  \
# tweet_id
# 1521523004508975104               False   Twitter for iPhone
# 1521496553231425539               False  Twitter for Android
# 1521492943080759298               False  Twitter for Android
# 1521292805355843587               False     Twitter for iPad
# 1521087200901103616               False      Twitter Web App
# 1520845001495879685               False      Twitter Web App
# 1520740351178416128               False      Twitter Web App
# 1520588597346578432               False   Twitter for iPhone
# 1520496674656903178               False   Twitter for iPhone
# 1520262808159588352               False      Twitter Web App
# 1522236897879158784               False  Twitter for Android
# 1522236847724064771               False  Twitter for Android
# 1522083083939454976               False  Twitter for Android
#
#                                                                   text  \
# tweet_id
# 1521523004508975104  RT @cametek: Wordle 235\r\n\r\n⬛⬛⬛⬛⬛\r\n⬛⬛⬛⬛⬛\...
# 1521496553231425539  RT @GeorgeNootFound: Wordle 229 X/6\r\n\r\n🟨🟨⬛...
# 1521492943080759298  RT @VorosTwins: Today's Wordle is SUS\r\n\r\n⬛...
# 1521292805355843587  RT @VorosTwins: Today's Wordle is SUS\r\n\r\n⬛...
# 1521087200901103616  RT @cehigi: #Wordle 중독증 3/6\n\n⬜⬜⬜⬜⬜\n⬜🟩⬜🟨⬜\n🟩...
# 1520845001495879685  RT @VorosTwins: Today's Wordle is SUS\n\n⬛🟩🟩🟩 ...
# 1520740351178416128  RT @GeorgeNootFound: Wordle 229 X/6\n\n🟨🟨⬛🟨🟨\n...
# 1520588597346578432  RT @Peace_wrwrd: Wordle 233 5/6\n\n⬛⬛⬛⬛⬛\n⬛⬛⬛⬛...
# 1520496674656903178  RT @GeorgeNootFound: Wordle 229 X/6\n\n🟨🟨⬛🟨🟨\n...
# 1520262808159588352  RT @cametek: Wordle 235\n\n⬛⬛⬛⬛⬛\n⬛⬛⬛⬛⬛\n⬛⬛🟪⬛⬛...
# 1522236897879158784  RT @WE_THE_BOYZ: [켑]\n\nWordle 228 3/6\n\n⬛⬛⬛⬛...
# 1522236847724064771  RT @WE_THE_BOYZ: [켑] 🥲\nWordle 232 4/6\n\n⬛⬛⬛⬛...
# 1522083083939454976  RT @WE_THE_BOYZ: [켑] 🥲\nWordle 232 4/6\n\n⬛⬛⬛⬛...
#
#                                                    context_annotations  \
# tweet_id
# 1521523004508975104  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521496553231425539  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521492943080759298  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521292805355843587  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521087200901103616  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1520845001495879685  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1520740351178416128  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1520588597346578432  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1520496674656903178  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1520262808159588352  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1522236897879158784  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1522236847724064771  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1522083083939454976  [{'domain': {'id': '30', 'name': 'Entities [En...
#
#                                author_id                created_at  \
# tweet_id
# 1521523004508975104  1501400213025550345 2022-05-03 16:12:07+00:00
# 1521496553231425539   825691456895455232 2022-05-03 14:27:00+00:00
# 1521492943080759298            701785116 2022-05-03 14:12:40+00:00
# 1521292805355843587           4473988098 2022-05-03 00:57:23+00:00
# 1521087200901103616  1432335794262343687 2022-05-02 11:20:23+00:00
# 1520845001495879685  1062694393742802944 2022-05-01 19:17:58+00:00
# 1520740351178416128   945158559658110976 2022-05-01 12:22:08+00:00
# 1520588597346578432  1479394890715140097 2022-05-01 02:19:07+00:00
# 1520496674656903178  1366073394102476800 2022-04-30 20:13:51+00:00
# 1520262808159588352  1330585341674315781 2022-04-30 04:44:33+00:00
# 1522236897879158784  1349295220471459840 2022-05-05 15:28:52+00:00
# 1522236847724064771  1349295220471459840 2022-05-05 15:28:40+00:00
# 1522083083939454976  1481135780294713349 2022-05-05 05:17:40+00:00
#
#                                                      referenced_tweets  \
# tweet_id
# 1521523004508975104  [{'type': 'retweeted', 'id': '1491263558923210...
# 1521496553231425539  [{'type': 'retweeted', 'id': '1489268441374597...
# 1521492943080759298  [{'type': 'retweeted', 'id': '1516797822238031...
# 1521292805355843587  [{'type': 'retweeted', 'id': '1516797822238031...
# 1521087200901103616  [{'type': 'retweeted', 'id': '1486992649982967...
# 1520845001495879685  [{'type': 'retweeted', 'id': '1516797822238031...
# 1520740351178416128  [{'type': 'retweeted', 'id': '1489268441374597...
# 1520588597346578432  [{'type': 'retweeted', 'id': '1490626396485558...
# 1520496674656903178  [{'type': 'retweeted', 'id': '1489268441374597...
# 1520262808159588352  [{'type': 'retweeted', 'id': '1491263558923210...
# 1522236897879158784  [{'type': 'retweeted', 'id': '1489042888936026...
# 1522236847724064771  [{'type': 'retweeted', 'id': '1490510685700517...
# 1522083083939454976  [{'type': 'retweeted', 'id': '1490510685700517...
#
#                      in_reply_to_user_id  \
# tweet_id
# 1521523004508975104                  0.0
# 1521496553231425539                  0.0
# 1521492943080759298                  0.0
# 1521292805355843587                  0.0
# 1521087200901103616                  0.0
# 1520845001495879685                  0.0
# 1520740351178416128                  0.0
# 1520588597346578432                  0.0
# 1520496674656903178                  0.0
# 1520262808159588352                  0.0
# 1522236897879158784                  0.0
# 1522236847724064771                  0.0
# 1522083083939454976                  0.0
#
#                                                    attachments geo  \
# tweet_id
# 1521523004508975104                                         {}  {}
# 1521496553231425539                                         {}  {}
# 1521492943080759298                                         {}  {}
# 1521292805355843587                                         {}  {}
# 1521087200901103616  {'media_keys': ['3_1486992170259476484']}  {}
# 1520845001495879685                                         {}  {}
# 1520740351178416128                                         {}  {}
# 1520588597346578432                                         {}  {}
# 1520496674656903178                                         {}  {}
# 1520262808159588352                                         {}  {}
# 1522236897879158784                                         {}  {}
# 1522236847724064771  {'media_keys': ['3_1490510673398628359']}  {}
# 1522083083939454976  {'media_keys': ['3_1490510673398628359']}  {}
#
#                     withheld_tweet             name  \
# tweet_id
# 1521523004508975104             {}                0
# 1521496553231425539             {}         Leigh⁷🇵🇭
# 1521492943080759298             {}         Biscotte
# 1521292805355843587             {}        GOBBIFIED
# 1521087200901103616             {}                0
# 1520845001495879685             {}  DeniceBenice !!
# 1520740351178416128             {}             Neon
# 1520588597346578432             {}                0
# 1520496674656903178             {}            karro
# 1520262808159588352             {}                0
# 1522236897879158784             {}        ➀'ᵐ🫐마라◡̈🚲
# 1522236847724064771             {}        ➀'ᵐ🫐마라◡̈🚲
# 1522083083939454976             {}                0
#
#                                                    public_metrics_user  \
# tweet_id
# 1521523004508975104                                                  0
# 1521496553231425539  {'followers_count': 501, 'following_count': 12...
# 1521492943080759298  {'followers_count': 183, 'following_count': 69...
# 1521292805355843587  {'followers_count': 78, 'following_count': 198...
# 1521087200901103616                                                  0
# 1520845001495879685  {'followers_count': 165, 'following_count': 33...
# 1520740351178416128  {'followers_count': 79, 'following_count': 914...
# 1520588597346578432                                                  0
# 1520496674656903178  {'followers_count': 5, 'following_count': 115,...
# 1520262808159588352                                                  0
# 1522236897879158784  {'followers_count': 1694, 'following_count': 1...
# 1522236847724064771  {'followers_count': 1694, 'following_count': 1...
# 1522083083939454976                                                  0
#
#                                          url  \
# tweet_id
# 1521523004508975104                        0
# 1521496553231425539
# 1521492943080759298
# 1521292805355843587
# 1521087200901103616                        0
# 1520845001495879685  https://t.co/nOCiNnNfxS
# 1520740351178416128
# 1520588597346578432                        0
# 1520496674656903178
# 1520262808159588352                        0
# 1522236897879158784  https://t.co/ieqW5yukcy
# 1522236847724064771  https://t.co/ieqW5yukcy
# 1522083083939454976                        0
#
#                                                            description  \
# tweet_id
# 1521523004508975104                                                  0
# 1521496553231425539  🏳‍🌈early gang gigglechamp | gimme lore crumbs pls
# 1521492943080759298  j'ai 21 ans, il/he, Je suis un Jojofag, j'ador...
# 1521292805355843587  「Google LeShoes, at your service! (OUT OF ORDE...
# 1521087200901103616                                                  0
# 1520845001495879685                                I draw occasionally
# 1520740351178416128                           I play minecraft to much
# 1520588597346578432                                                  0
# 1520496674656903178                               karro, he/they/them?
# 1520262808159588352                                                  0
# 1522236897879158784  웰캄 뚜 마이 아쿤 all 🌌\ni'm 박 마라 you can call me 마라 ...
# 1522236847724064771  웰캄 뚜 마이 아쿤 all 🌌\ni'm 박 마라 you can call me 마라 ...
# 1522083083939454976                                                  0
#
#                                                      profile_image_url  \
# tweet_id
# 1521523004508975104                                                  0
# 1521496553231425539  https://pbs.twimg.com/profile_images/150650238...
# 1521492943080759298  https://pbs.twimg.com/profile_images/144676852...
# 1521292805355843587  https://pbs.twimg.com/profile_images/150529566...
# 1521087200901103616                                                  0
# 1520845001495879685  https://pbs.twimg.com/profile_images/143430278...
# 1520740351178416128  https://pbs.twimg.com/profile_images/150177978...
# 1520588597346578432                                                  0
# 1520496674656903178  https://pbs.twimg.com/profile_images/151818832...
# 1520262808159588352                                                  0
# 1522236897879158784  https://pbs.twimg.com/profile_images/146248959...
# 1522236847724064771  https://pbs.twimg.com/profile_images/146248959...
# 1522083083939454976                                                  0
#
#                                         location protected         username  \
# tweet_id
# 1521523004508975104                            0         0                0
# 1521496553231425539  Republic of the Philippines     False  thejintoyurjoon
# 1521492943080759298                                  False        pierre590
# 1521292805355843587                                  False    GlNGADENSETSU
# 1521087200901103616                            0         0                0
# 1520845001495879685                   (she/they)     False     DeniceBenice
# 1520740351178416128                     Hide out     False  Samayawilliams3
# 1520588597346578432                            0         0                0
# 1520496674656903178             Chelmsford, East     False        BieneLive
# 1520262808159588352                            0         0                0
# 1522236897879158784                theb_village🏖     False    Dear_EYICKSON
# 1522236847724064771                theb_village🏖     False    Dear_EYICKSON
# 1522083083939454976                            0         0                0
#
#                     verified  \
# tweet_id
# 1521523004508975104        0
# 1521496553231425539    False
# 1521492943080759298    False
# 1521292805355843587    False
# 1521087200901103616        0
# 1520845001495879685    False
# 1520740351178416128    False
# 1520588597346578432        0
# 1520496674656903178    False
# 1520262808159588352        0
# 1522236897879158784    False
# 1522236847724064771    False
# 1522083083939454976        0
#
#                                                          entities_user  \
# tweet_id
# 1521523004508975104                                                  0
# 1521496553231425539                                                 {}
# 1521492943080759298  {'description': {'mentions': [{'start': 97, 'e...
# 1521292805355843587                                                 {}
# 1521087200901103616                                                  0
# 1520845001495879685  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1520740351178416128                                                 {}
# 1520588597346578432                                                  0
# 1520496674656903178                                                 {}
# 1520262808159588352                                                  0
# 1522236897879158784  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1522236847724064771  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1522083083939454976                                                  0
#
#                      pinned_tweet_id withheld_user  \
# tweet_id
# 1521523004508975104     0.000000e+00             0
# 1521496553231425539     0.000000e+00            {}
# 1521492943080759298     1.477292e+18            {}
# 1521292805355843587     1.492770e+18            {}
# 1521087200901103616     0.000000e+00             0
# 1520845001495879685     1.250518e+18            {}
# 1520740351178416128     0.000000e+00            {}
# 1520588597346578432     0.000000e+00             0
# 1520496674656903178     0.000000e+00            {}
# 1520262808159588352     0.000000e+00             0
# 1522236897879158784     0.000000e+00            {}
# 1522236847724064771     0.000000e+00            {}
# 1522083083939454976     0.000000e+00             0
#
#                                                     entities_tweeturls  \
# tweet_id
# 1521523004508975104                                                NaN
# 1521496553231425539                                                NaN
# 1521492943080759298                                                NaN
# 1521292805355843587                                                NaN
# 1521087200901103616  [{'start': 47, 'end': 70, 'url': 'https://t.co...
# 1520845001495879685                                                NaN
# 1520740351178416128                                                NaN
# 1520588597346578432                                                NaN
# 1520496674656903178                                                NaN
# 1520262808159588352                                                NaN
# 1522236897879158784                                                NaN
# 1522236847724064771  [{'start': 63, 'end': 86, 'url': 'https://t.co...
# 1522083083939454976  [{'start': 63, 'end': 86, 'url': 'https://t.co...
#
#                                                 entities_tweetmentions  \
# tweet_id
# 1521523004508975104  [{'start': 3, 'end': 11, 'username': 'cametek'...
# 1521496553231425539  [{'start': 3, 'end': 19, 'username': 'GeorgeNo...
# 1521492943080759298  [{'start': 3, 'end': 14, 'username': 'VorosTwi...
# 1521292805355843587  [{'start': 3, 'end': 14, 'username': 'VorosTwi...
# 1521087200901103616  [{'start': 3, 'end': 10, 'username': 'cehigi',...
# 1520845001495879685  [{'start': 3, 'end': 14, 'username': 'VorosTwi...
# 1520740351178416128  [{'start': 3, 'end': 19, 'username': 'GeorgeNo...
# 1520588597346578432  [{'start': 3, 'end': 15, 'username': 'Peace_wr...
# 1520496674656903178  [{'start': 3, 'end': 19, 'username': 'GeorgeNo...
# 1520262808159588352  [{'start': 3, 'end': 11, 'username': 'cametek'...
# 1522236897879158784  [{'start': 3, 'end': 15, 'username': 'WE_THE_B...
# 1522236847724064771  [{'start': 3, 'end': 15, 'username': 'WE_THE_B...
# 1522083083939454976  [{'start': 3, 'end': 15, 'username': 'WE_THE_B...
#
#                                           entities_tweethashtags  \
# tweet_id
# 1521523004508975104                                          NaN
# 1521496553231425539                                          NaN
# 1521492943080759298                                          NaN
# 1521292805355843587                                          NaN
# 1521087200901103616  [{'start': 12, 'end': 19, 'tag': 'Wordle'}]
# 1520845001495879685                                          NaN
# 1520740351178416128                                          NaN
# 1520588597346578432                                          NaN
# 1520496674656903178                                          NaN
# 1520262808159588352                                          NaN
# 1522236897879158784                                          NaN
# 1522236847724064771                                          NaN
# 1522083083939454976                                          NaN
#
#                                              entities_tweetannotations  \
# tweet_id
# 1521523004508975104                                                NaN
# 1521496553231425539                                                NaN
# 1521492943080759298  [{'start': 24, 'end': 29, 'probability': 0.379...
# 1521292805355843587  [{'start': 24, 'end': 29, 'probability': 0.379...
# 1521087200901103616                                                NaN
# 1520845001495879685  [{'start': 24, 'end': 29, 'probability': 0.379...
# 1520740351178416128                                                NaN
# 1520588597346578432                                                NaN
# 1520496674656903178                                                NaN
# 1520262808159588352                                                NaN
# 1522236897879158784                                                NaN
# 1522236847724064771                                                NaN
# 1522083083939454976                                                NaN
#
#                     entities_tweetcashtags  public_metrics_tweetretweet_count  \
# tweet_id
# 1521523004508975104                    NaN                               1713
# 1521496553231425539                    NaN                               2742
# 1521492943080759298                    NaN                                559
# 1521292805355843587                    NaN                                558
# 1521087200901103616                    NaN                                961
# 1520845001495879685                    NaN                                558
# 1520740351178416128                    NaN                               2742
# 1520588597346578432                    NaN                               1499
# 1520496674656903178                    NaN                               2742
# 1520262808159588352                    NaN                               1713
# 1522236897879158784                    NaN                               6921
# 1522236847724064771                    NaN                               8587
# 1522083083939454976                    NaN                               8588
#
#                      public_metrics_tweetreply_count  \
# tweet_id
# 1521523004508975104                                0
# 1521496553231425539                                0
# 1521492943080759298                                0
# 1521292805355843587                                0
# 1521087200901103616                                0
# 1520845001495879685                                0
# 1520740351178416128                                0
# 1520588597346578432                                0
# 1520496674656903178                                0
# 1520262808159588352                                0
# 1522236897879158784                                0
# 1522236847724064771                                0
# 1522083083939454976                                0
#
#                      public_metrics_tweetlike_count  \
# tweet_id
# 1521523004508975104                               0
# 1521496553231425539                               0
# 1521492943080759298                               0
# 1521292805355843587                               0
# 1521087200901103616                               0
# 1520845001495879685                               0
# 1520740351178416128                               0
# 1520588597346578432                               0
# 1520496674656903178                               0
# 1520262808159588352                               0
# 1522236897879158784                               0
# 1522236847724064771                               0
# 1522083083939454976                               0
#
#                      public_metrics_tweetquote_count
# tweet_id
# 1521523004508975104                                0
# 1521496553231425539                                0
# 1521492943080759298                                0
# 1521292805355843587                                0
# 1521087200901103616                                0
# 1520845001495879685                                0
# 1520740351178416128                                0
# 1520588597346578432                                0
# 1520496674656903178                                0
# 1520262808159588352                                0
# 1522236897879158784                                0
# 1522236847724064771                                0
# 1522083083939454976                                0

# %% [markdown]
# ![500+ RT tweet: today's wordle is sus.](./pix/sustweet.png)

# %% [markdown]
# This one is a retweet of a popular tweet with an Among Us nintendo character in it. The game led to a rise in the use of the word "sus" as short for suspicious.
#
# Perhaps retweet counts are inherited by retweets.
#
# All of the tweets with >500 retweets are themselves retweets.

# %% [markdown]
# ### public_metrics_tweettweet_replycount

# %%
tudf['public_metrics_tweetreply_count'].hist(bins = 50,log = True, figsize = (12,6))
plt.title("reply counts by tweet (log)");

# %%
tudf['public_metrics_tweetreply_count'].hist(bins = 150,log = True, figsize = (12,6))
plt.title("reply counts by tweet (log, less than 100 replies)")
plt.xlim(0,150);

# %% [markdown]
# ### public_metrics_tweetlike_count

# %%
tudf['public_metrics_tweetlike_count'].hist(bins = 50,log = True, figsize = (12,6))
plt.title("like counts by tweet (log)");

# %%
tudf['public_metrics_tweetlike_count'].hist(bins = 150,log = True, figsize = (12,6))
plt.title("like counts by tweet (log, less than 400 likes)")
plt.xlim(0,400);

# %%
#look at tweets with more than 250 likes
tudf[tudf['public_metrics_tweetlike_count'] > 250]
# Out:
#                          conversation_id reply_settings lang  \
# tweet_id
# 1521446701801910272  1521446701801910272       everyone   en
# 1520833608272867328  1520833608272867328       everyone   en
# 1520805744710356992  1520805744710356992       everyone   en
# 1520713571054850048  1520713571054850048       everyone   en
# 1520644473142788097  1520644473142788097       everyone   en
# 1520305212245827586  1520305212245827586       everyone   en
# 1520227908526415874  1520227908526415874       everyone   en
# 1522218860417482759  1522218860417482759       everyone   en
# 1522197381265174528  1522197381265174528       everyone   en
# 1522185105422360577  1522185105422360577       everyone   en
# 1522083575524384774  1522083575524384774       everyone   en
# 1522041110209921024  1522041110209921024       everyone   en
# 1521995762787254272  1521995762787254272       everyone   en
# 1521995129409753094  1521995129409753094       everyone   en
#
#                      possibly_sensitive               source  \
# tweet_id
# 1521446701801910272               False   Twitter for iPhone
# 1520833608272867328               False      Twitter Web App
# 1520805744710356992               False   Twitter for iPhone
# 1520713571054850048               False  Twitter for Android
# 1520644473142788097               False  Twitter for Android
# 1520305212245827586               False  Twitter for Android
# 1520227908526415874               False   Twitter for iPhone
# 1522218860417482759               False   Twitter for iPhone
# 1522197381265174528               False   Twitter for iPhone
# 1522185105422360577               False   Twitter for iPhone
# 1522083575524384774               False  Twitter for Android
# 1522041110209921024               False   Twitter for iPhone
# 1521995762787254272                True   Twitter for iPhone
# 1521995129409753094               False   Twitter for iPhone
#
#                                                                   text  \
# tweet_id
# 1521446701801910272              Wordle 318 2/6*\r\n\r\n⬛🟩⬛⬛⬛\r\n🟩🟩🟩🟩🟩
# 1520833608272867328  Today was a tough one #Wordle315 \nWordle 316 ...
# 1520805744710356992  I’m giving a hint because the Wordle Master is...
# 1520713571054850048  Wow\nWordle 316 6/6\n\n⬛⬛⬛⬛🟨\n⬛🟩🟩⬛⬛\n🟩🟩🟩⬛⬛\n🟩🟩...
# 1520644473142788097  Is it cheating to use a dictionary? \nWordle 3...
# 1520305212245827586  Tricky tonight\nWordle 315 4/6\n\n🟨⬜⬜⬜⬜\n⬜🟨🟨⬜⬜...
# 1520227908526415874  Wordle 315 5/6 another toughie \n\n⬛⬛⬛⬛⬛\n⬛⬛⬛⬛...
# 1522218860417482759  Wordle 320 X/6*\n\n⬛🟨⬛⬛🟨\n🟨⬛⬛🟩🟩\n⬛🟩⬛🟩🟩\n⬛🟩⬛🟩🟩\...
# 1522197381265174528  Wordle 320 X/6\n\n⬛⬛🟨⬛🟩\n⬛🟩⬛🟩🟩\n⬛🟩⬛🟩🟩\n⬛🟩⬛🟩🟩\n...
# 1522185105422360577  Wordle 320 X/6\n\n⬜⬜⬜🟨⬜\n🟨🟩⬜🟩⬜\n⬜🟩⬜🟩🟩\n⬜🟩⬜🟩🟩\n...
# 1522083575524384774  It's over! The streak s broken at 90 days.\nWo...
# 1522041110209921024  Wordle 320 X/6\n\n🟨⬜🟨🟨⬜\n⬜🟨🟨⬜🟨\n⬜🟩🟨🟩⬜\n⬜🟩⬜🟩🟩\n...
# 1521995762787254272  Wordle 319 3/6\n\n🟨⬜⬜🟩⬜\n⬜🟨🟩🟩🟨\n🟩🟩🟩🟩🟩 https://...
# 1521995129409753094  Could this night get ANY WORSE!!?! 😭😭😭 \n\nWor...
#
#                                                    context_annotations  \
# tweet_id
# 1521446701801910272  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1520833608272867328  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 1520805744710356992  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 1520713571054850048  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1520644473142788097  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 1520305212245827586  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 1520227908526415874  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 1522218860417482759  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 1522197381265174528  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 1522185105422360577  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 1522083575524384774  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1522041110209921024  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521995762787254272  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521995129409753094  [{'domain': {'id': '30', 'name': 'Entities [En...
#
#                                author_id                created_at  \
# tweet_id
# 1521446701801910272  1294500310191349760 2022-05-03 11:08:55+00:00
# 1520833608272867328             17953972 2022-05-01 18:32:42+00:00
# 1520805744710356992             27491578 2022-05-01 16:41:59+00:00
# 1520713571054850048            381091977 2022-05-01 10:35:43+00:00
# 1520644473142788097            454071012 2022-05-01 06:01:09+00:00
# 1520305212245827586            454071012 2022-04-30 07:33:03+00:00
# 1520227908526415874             57998991 2022-04-30 02:25:52+00:00
# 1522218860417482759             14939981 2022-05-05 14:17:12+00:00
# 1522197381265174528             48100887 2022-05-05 12:51:51+00:00
# 1522185105422360577             70725301 2022-05-05 12:03:04+00:00
# 1522083575524384774            804321630 2022-05-05 05:19:38+00:00
# 1522041110209921024             92932981 2022-05-05 02:30:53+00:00
# 1521995762787254272  1228018114555592704 2022-05-04 23:30:41+00:00
# 1521995129409753094             48706026 2022-05-04 23:28:10+00:00
#
#                     referenced_tweets  in_reply_to_user_id  \
# tweet_id
# 1521446701801910272                []                  0.0
# 1520833608272867328                []                  0.0
# 1520805744710356992                []                  0.0
# 1520713571054850048                []                  0.0
# 1520644473142788097                []                  0.0
# 1520305212245827586                []                  0.0
# 1520227908526415874                []                  0.0
# 1522218860417482759                []                  0.0
# 1522197381265174528                []                  0.0
# 1522185105422360577                []                  0.0
# 1522083575524384774                []                  0.0
# 1522041110209921024                []                  0.0
# 1521995762787254272                []                  0.0
# 1521995129409753094                []                  0.0
#
#                                                     attachments  \
# tweet_id
# 1521446701801910272                                          {}
# 1520833608272867328                                          {}
# 1520805744710356992                                          {}
# 1520713571054850048   {'media_keys': ['3_1520713567443501057']}
# 1520644473142788097                                          {}
# 1520305212245827586                                          {}
# 1520227908526415874                                          {}
# 1522218860417482759  {'media_keys': ['16_1522218853027045378']}
# 1522197381265174528                                          {}
# 1522185105422360577                                          {}
# 1522083575524384774                                          {}
# 1522041110209921024                                          {}
# 1521995762787254272   {'media_keys': ['3_1521995758341267458']}
# 1521995129409753094                                          {}
#
#                                                   geo withheld_tweet  \
# tweet_id
# 1521446701801910272                                {}             {}
# 1520833608272867328                                {}             {}
# 1520805744710356992                                {}             {}
# 1520713571054850048                                {}             {}
# 1520644473142788097                                {}             {}
# 1520305212245827586                                {}             {}
# 1520227908526415874                                {}             {}
# 1522218860417482759                                {}             {}
# 1522197381265174528                                {}             {}
# 1522185105422360577                                {}             {}
# 1522083575524384774  {'place_id': '1c13c0e8dcfa95a3'}             {}
# 1522041110209921024                                {}             {}
# 1521995762787254272                                {}             {}
# 1521995129409753094                                {}             {}
#
#                                                         name  \
# tweet_id
# 1521446701801910272                              hannie ross
# 1520833608272867328                           bert kreischer
# 1520805744710356992                          Nancy Lee Grahn
# 1520713571054850048           Arno/daily wordle😜/boots/music
# 1520644473142788097                          Jill Wine-Banks
# 1520305212245827586                          Jill Wine-Banks
# 1520227908526415874                         Riteish Deshmukh
# 1522218860417482759  ?uesto Is The Army, Better Yet The Navy
# 1522197381265174528                               Andy Cohen
# 1522185105422360577                           Renee Paquette
# 1522083575524384774                             Ady Manifold
# 1522041110209921024                                Jane Caro
# 1521995762787254272                               Zaddy Zick
# 1521995129409753094                            Jason Manford
#
#                                                    public_metrics_user  \
# tweet_id
# 1521446701801910272  {'followers_count': 283709, 'following_count':...
# 1520833608272867328  {'followers_count': 881888, 'following_count':...
# 1520805744710356992  {'followers_count': 170985, 'following_count':...
# 1520713571054850048  {'followers_count': 537, 'following_count': 28...
# 1520644473142788097  {'followers_count': 573498, 'following_count':...
# 1520305212245827586  {'followers_count': 573498, 'following_count':...
# 1520227908526415874  {'followers_count': 11281565, 'following_count...
# 1522218860417482759  {'followers_count': 3428500, 'following_count'...
# 1522197381265174528  {'followers_count': 2455213, 'following_count'...
# 1522185105422360577  {'followers_count': 1229550, 'following_count'...
# 1522083575524384774  {'followers_count': 34388, 'following_count': ...
# 1522041110209921024  {'followers_count': 158993, 'following_count':...
# 1521995762787254272  {'followers_count': 127637, 'following_count':...
# 1521995129409753094  {'followers_count': 421568, 'following_count':...
#
#                                          url  \
# tweet_id
# 1521446701801910272  https://t.co/2yDWVPTkOK
# 1520833608272867328  https://t.co/KYSpUUG31B
# 1520805744710356992  https://t.co/APsFdvSgme
# 1520713571054850048
# 1520644473142788097  https://t.co/1bXqjHUIoa
# 1520305212245827586  https://t.co/1bXqjHUIoa
# 1520227908526415874  https://t.co/gXJDUXJqdK
# 1522218860417482759  https://t.co/IqyF2MDNlY
# 1522197381265174528  https://t.co/3MR5FJs97Y
# 1522185105422360577  https://t.co/c62OEld7sF
# 1522083575524384774
# 1522041110209921024  https://t.co/YDUmdfZLzO
# 1521995762787254272  https://t.co/nQe6hU46ss
# 1521995129409753094  https://t.co/6qzqNj8Mbr
#
#                                                            description  \
# tweet_id
# 1521446701801910272  main: @hannahxxrose | #rosetwt | banner: @neex...
# 1520833608272867328  I am a Party Animal, Comedian, Actor, Author, ...
# 1520805744710356992  I act on TV and as a citizen. The opinions her...
# 1520713571054850048  He/him.  Musician. Be the best you can be, alw...
# 1520644473142788097  MSNBC legal analyst. Author #TheWatergateGirl....
# 1520305212245827586  MSNBC legal analyst. Author #TheWatergateGirl....
# 1520227908526415874  Actor, Architect, Producer : Mumbai Film Compa...
# 1522218860417482759                                      ❓❤.y.at it me
# 1522197381265174528  Dad, Host,Producer, 4x Bestselling Author WATC...
# 1522185105422360577            Proud supporter of the Canadian Tuxedo.
# 1522083575524384774
# 1522041110209921024  AM. Walkley award winner. Author of ‘The Mothe...
# 1521995762787254272            OnlyFans & JFF links in pinned tweet👇🏻🔥
# 1521995129409753094  Brand new podcast, only on audible. https://t....
#
#                                                      profile_image_url  \
# tweet_id
# 1521446701801910272  https://pbs.twimg.com/profile_images/148368167...
# 1520833608272867328  https://pbs.twimg.com/profile_images/119139535...
# 1520805744710356992  https://pbs.twimg.com/profile_images/105601465...
# 1520713571054850048  https://pbs.twimg.com/profile_images/151070535...
# 1520644473142788097  https://pbs.twimg.com/profile_images/146686684...
# 1520305212245827586  https://pbs.twimg.com/profile_images/146686684...
# 1520227908526415874  https://pbs.twimg.com/profile_images/143544280...
# 1522218860417482759  https://pbs.twimg.com/profile_images/140271602...
# 1522197381265174528  https://pbs.twimg.com/profile_images/908707590...
# 1522185105422360577  https://pbs.twimg.com/profile_images/149009562...
# 1522083575524384774  https://pbs.twimg.com/profile_images/126635603...
# 1522041110209921024  https://pbs.twimg.com/profile_images/149659024...
# 1521995762787254272  https://pbs.twimg.com/profile_images/122842142...
# 1521995129409753094  https://pbs.twimg.com/profile_images/151754924...
#
#                                            location protected        username  \
# tweet_id
# 1521446701801910272                                     False    hanniexxrose
# 1520833608272867328                     Los Angeles     False   bertkreischer
# 1520805744710356992                    A blue state     False   NancyLeeGrahn
# 1520713571054850048                                     False      arnojones1
# 1520644473142788097                     Chicago, IL     False   JillWineBanks
# 1520305212245827586                     Chicago, IL     False   JillWineBanks
# 1520227908526415874                   Mumbai, India     False        Riteishd
# 1522218860417482759  Illadelph & Fi-Di NYC & 31Rock     False       questlove
# 1522197381265174528        ÜT: 40.735225,-74.006791     False            Andy
# 1522185105422360577                       OH and TO     False   ReneePaquette
# 1522083575524384774                                     False  AdrianManifold
# 1522041110209921024               Sydney, Australia     False        JaneCaro
# 1521995762787254272               San Francisco, CA     False   thatzaddyzick
# 1521995129409753094                      Manchester     False    JasonManford
#
#                     verified  \
# tweet_id
# 1521446701801910272    False
# 1520833608272867328     True
# 1520805744710356992     True
# 1520713571054850048    False
# 1520644473142788097     True
# 1520305212245827586     True
# 1520227908526415874     True
# 1522218860417482759     True
# 1522197381265174528     True
# 1522185105422360577     True
# 1522083575524384774    False
# 1522041110209921024     True
# 1521995762787254272    False
# 1521995129409753094     True
#
#                                                          entities_user  \
# tweet_id
# 1521446701801910272  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1520833608272867328  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1520805744710356992  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1520713571054850048                                                 {}
# 1520644473142788097  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1520305212245827586  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1520227908526415874  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1522218860417482759  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1522197381265174528  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1522185105422360577  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1522083575524384774                                                 {}
# 1522041110209921024  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1521995762787254272  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1521995129409753094  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
#
#                      pinned_tweet_id withheld_user  \
# tweet_id
# 1521446701801910272     1.510697e+18            {}
# 1520833608272867328     1.520475e+18            {}
# 1520805744710356992     1.498707e+18            {}
# 1520713571054850048     0.000000e+00            {}
# 1520644473142788097     1.368981e+18            {}
# 1520305212245827586     1.368981e+18            {}
# 1520227908526415874     0.000000e+00            {}
# 1522218860417482759     1.468467e+18            {}
# 1522197381265174528     1.252564e+18            {}
# 1522185105422360577     0.000000e+00            {}
# 1522083575524384774     0.000000e+00            {}
# 1522041110209921024     1.521299e+18            {}
# 1521995762787254272     1.522665e+18            {}
# 1521995129409753094     0.000000e+00            {}
#
#                                                     entities_tweeturls  \
# tweet_id
# 1521446701801910272                                                NaN
# 1520833608272867328                                                NaN
# 1520805744710356992                                                NaN
# 1520713571054850048  [{'start': 56, 'end': 79, 'url': 'https://t.co...
# 1520644473142788097                                                NaN
# 1520305212245827586                                                NaN
# 1520227908526415874                                                NaN
# 1522218860417482759  [{'start': 53, 'end': 76, 'url': 'https://t.co...
# 1522197381265174528                                                NaN
# 1522185105422360577                                                NaN
# 1522083575524384774                                                NaN
# 1522041110209921024                                                NaN
# 1521995762787254272  [{'start': 34, 'end': 57, 'url': 'https://t.co...
# 1521995129409753094                                                NaN
#
#                     entities_tweetmentions  \
# tweet_id
# 1521446701801910272                    NaN
# 1520833608272867328                    NaN
# 1520805744710356992                    NaN
# 1520713571054850048                    NaN
# 1520644473142788097                    NaN
# 1520305212245827586                    NaN
# 1520227908526415874                    NaN
# 1522218860417482759                    NaN
# 1522197381265174528                    NaN
# 1522185105422360577                    NaN
# 1522083575524384774                    NaN
# 1522041110209921024                    NaN
# 1521995762787254272                    NaN
# 1521995129409753094                    NaN
#
#                                              entities_tweethashtags  \
# tweet_id
# 1521446701801910272                                             NaN
# 1520833608272867328  [{'start': 22, 'end': 32, 'tag': 'Wordle315'}]
# 1520805744710356992                                             NaN
# 1520713571054850048                                             NaN
# 1520644473142788097                                             NaN
# 1520305212245827586                                             NaN
# 1520227908526415874                                             NaN
# 1522218860417482759                                             NaN
# 1522197381265174528                                             NaN
# 1522185105422360577                                             NaN
# 1522083575524384774                                             NaN
# 1522041110209921024                                             NaN
# 1521995762787254272                                             NaN
# 1521995129409753094                                             NaN
#
#                                              entities_tweetannotations  \
# tweet_id
# 1521446701801910272                                                NaN
# 1520833608272867328                                                NaN
# 1520805744710356992  [{'start': 30, 'end': 42, 'probability': 0.408...
# 1520713571054850048                                                NaN
# 1520644473142788097                                                NaN
# 1520305212245827586                                                NaN
# 1520227908526415874                                                NaN
# 1522218860417482759                                                NaN
# 1522197381265174528                                                NaN
# 1522185105422360577                                                NaN
# 1522083575524384774                                                NaN
# 1522041110209921024                                                NaN
# 1521995762787254272                                                NaN
# 1521995129409753094                                                NaN
#
#                     entities_tweetcashtags  public_metrics_tweetretweet_count  \
# tweet_id
# 1521446701801910272                    NaN                                 10
# 1520833608272867328                    NaN                                  4
# 1520805744710356992                    NaN                                  4
# 1520713571054850048                    NaN                                 23
# 1520644473142788097                    NaN                                 21
# 1520305212245827586                    NaN                                  8
# 1520227908526415874                    NaN                                 11
# 1522218860417482759                    NaN                                  8
# 1522197381265174528                    NaN                                 15
# 1522185105422360577                    NaN                                  2
# 1522083575524384774                    NaN                                  5
# 1522041110209921024                    NaN                                 25
# 1521995762787254272                    NaN                                140
# 1521995129409753094                    NaN                                  2
#
#                      public_metrics_tweetreply_count  \
# tweet_id
# 1521446701801910272                               26
# 1520833608272867328                               68
# 1520805744710356992                               69
# 1520713571054850048                                6
# 1520644473142788097                              373
# 1520305212245827586                               63
# 1520227908526415874                               16
# 1522218860417482759                              150
# 1522197381265174528                              376
# 1522185105422360577                               50
# 1522083575524384774                               31
# 1522041110209921024                              510
# 1521995762787254272                               13
# 1521995129409753094                               69
#
#                      public_metrics_tweetlike_count  \
# tweet_id
# 1521446701801910272                            1722
# 1520833608272867328                             411
# 1520805744710356992                             256
# 1520713571054850048                             286
# 1520644473142788097                             715
# 1520305212245827586                             263
# 1520227908526415874                             342
# 1522218860417482759                             785
# 1522197381265174528                            1981
# 1522185105422360577                             283
# 1522083575524384774                             492
# 1522041110209921024                            1725
# 1521995762787254272                            1415
# 1521995129409753094                             340
#
#                      public_metrics_tweetquote_count
# tweet_id
# 1521446701801910272                                0
# 1520833608272867328                                0
# 1520805744710356992                                2
# 1520713571054850048                                0
# 1520644473142788097                               13
# 1520305212245827586                                0
# 1520227908526415874                                0
# 1522218860417482759                                8
# 1522197381265174528                               15
# 1522185105422360577                                0
# 1522083575524384774                                0
# 1522041110209921024                               15
# 1521995762787254272                                2
# 1521995129409753094                                2

# %% [markdown]
# ### public_metrics_tweetquote_count
#
# Quoting is not a popular feature.

# %%
#number of quotes by fraction
tudf['public_metrics_tweetquote_count'].value_counts('nromalize')
# Out:
# 0     0.996490
# 1     0.003415
# 2     0.000054
# 3     0.000012
# 5     0.000006
# 8     0.000006
# 15    0.000006
# 6     0.000003
# 4     0.000003
# 7     0.000003
# 13    0.000003
# Name: public_metrics_tweetquote_count, dtype: float64

# %%
# plot quote number histogram
tudf['public_metrics_tweetquote_count'].hist(bins = 50,log = True, figsize = (12,6))
plt.title("quote counts by tweet (log)");

# %%
#look at tweets with quotes.
tudf[tudf['public_metrics_tweetquote_count'] > 0]
# Out:
#                          conversation_id reply_settings lang  \
# tweet_id
# 1521725904065548289  1521725904065548289       everyone   en
# 1521721108583563264  1521721108583563264       everyone   en
# 1521718751011426305  1521718751011426305       everyone   en
# 1521711300791136256  1521711300791136256       everyone   ko
# 1521702550189363202  1521702550189363202       everyone   en
# ...                                  ...            ...  ...
# 1521996614612701184  1521996614612701184       everyone   en
# 1521995762787254272  1521995762787254272       everyone   en
# 1521995477318787072  1521995477318787072       everyone   en
# 1521995129409753094  1521995129409753094       everyone   en
# 1521994898974588929  1521994898974588929       everyone   en
#
#                      possibly_sensitive               source  \
# tweet_id
# 1521725904065548289               False   Twitter for iPhone
# 1521721108583563264               False   Twitter for iPhone
# 1521718751011426305               False      Twitter Web App
# 1521711300791136256               False  Twitter for Android
# 1521702550189363202               False  Twitter for Android
# ...                                 ...                  ...
# 1521996614612701184               False  Twitter for Android
# 1521995762787254272                True   Twitter for iPhone
# 1521995477318787072               False  Twitter for Android
# 1521995129409753094               False   Twitter for iPhone
# 1521994898974588929               False            TweetDeck
#
#                                                                   text  \
# tweet_id
# 1521725904065548289  Wordle 319 3/6\r\n\r\n⬜⬜🟩⬜⬜\r\n🟩🟩🟩🟩⬜\r\n🟩🟩🟩🟩🟩\...
# 1521721108583563264  Wordle 319 3/6\r\n\r\n⬛🟩🟩🟨⬛\r\n⬛🟩🟩⬛🟩\r\n🟩🟩🟩🟩🟩\...
# 1521718751011426305  Wordle 319 5/6\r\n\r\n🟨⬜⬜🟩⬜\r\n⬜🟨⬜🟩⬜\r\n⬜⬜🟩🟩🟨\...
# 1521711300791136256  워들 206 X/6\r\nhttps://t.co/Q3eJpB5HPo\r\n\r\n거...
# 1521702550189363202  Wordle (ES)  #117 6/6\r\n\r\n🟨⬜⬜⬜🟩\r\n⬜🟨⬜⬜🟩\r\...
# ...                                                                ...
# 1521996614612701184              Wordle 320 3/6\n\n⬜🟨⬜🟨🟨\n🟩⬜🟩🟩⬜\n🟩🟩🟩🟩🟩
# 1521995762787254272  Wordle 319 3/6\n\n🟨⬜⬜🟩⬜\n⬜🟨🟩🟩🟨\n🟩🟩🟩🟩🟩 https://...
# 1521995477318787072  Pants (and vest). \n\n#Wordle 320 6/6\n\n⬛⬛⬛🟨🟨...
# 1521995129409753094  Could this night get ANY WORSE!!?! 😭😭😭 \n\nWor...
# 1521994898974588929  properly rubbish\n\nWordle 320 X/6*\n\n⬛🟨⬛🟩⬛\n...
#
#                                                    context_annotations  \
# tweet_id
# 1521725904065548289  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521721108583563264  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521718751011426305  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521711300791136256                                                 []
# 1521702550189363202  [{'domain': {'id': '30', 'name': 'Entities [En...
# ...                                                                ...
# 1521996614612701184  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521995762787254272  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521995477318787072  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521995129409753094  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521994898974588929  [{'domain': {'id': '30', 'name': 'Entities [En...
#
#                                author_id                created_at  \
# tweet_id
# 1521725904065548289            571864971 2022-05-04 05:38:22+00:00
# 1521721108583563264             38226081 2022-05-04 05:19:19+00:00
# 1521718751011426305   715654161493139456 2022-05-04 05:09:57+00:00
# 1521711300791136256           1451073432 2022-05-04 04:40:20+00:00
# 1521702550189363202  1371573064044060680 2022-05-04 04:05:34+00:00
# ...                                  ...                       ...
# 1521996614612701184           2561782624 2022-05-04 23:34:04+00:00
# 1521995762787254272  1228018114555592704 2022-05-04 23:30:41+00:00
# 1521995477318787072             20798291 2022-05-04 23:29:33+00:00
# 1521995129409753094             48706026 2022-05-04 23:28:10+00:00
# 1521994898974588929            626288465 2022-05-04 23:27:15+00:00
#
#                     referenced_tweets  in_reply_to_user_id  \
# tweet_id
# 1521725904065548289                []                  0.0
# 1521721108583563264                []                  0.0
# 1521718751011426305                []                  0.0
# 1521711300791136256                []                  0.0
# 1521702550189363202                []                  0.0
# ...                               ...                  ...
# 1521996614612701184                []                  0.0
# 1521995762787254272                []                  0.0
# 1521995477318787072                []                  0.0
# 1521995129409753094                []                  0.0
# 1521994898974588929                []                  0.0
#
#                                                    attachments geo  \
# tweet_id
# 1521725904065548289                                         {}  {}
# 1521721108583563264                                         {}  {}
# 1521718751011426305  {'media_keys': ['3_1521718742677438464']}  {}
# 1521711300791136256                                         {}  {}
# 1521702550189363202                                         {}  {}
# ...                                                        ...  ..
# 1521996614612701184                                         {}  {}
# 1521995762787254272  {'media_keys': ['3_1521995758341267458']}  {}
# 1521995477318787072                                         {}  {}
# 1521995129409753094                                         {}  {}
# 1521994898974588929                                         {}  {}
#
#                     withheld_tweet             name  \
# tweet_id
# 1521725904065548289             {}       MarkFitz90
# 1521721108583563264             {}  Meridith Nordin
# 1521718751011426305             {}          Ailey 🍒
# 1521711300791136256             {}          루아(Rua)
# 1521702550189363202             {}                0
# ...                            ...              ...
# 1521996614612701184             {}    oluwadarasimi
# 1521995762787254272             {}       Zaddy Zick
# 1521995477318787072             {}        Gem Alkış
# 1521995129409753094             {}    Jason Manford
# 1521994898974588929             {}          Del-4Ri
#
#                                                    public_metrics_user  \
# tweet_id
# 1521725904065548289  {'followers_count': 942, 'following_count': 11...
# 1521721108583563264  {'followers_count': 441, 'following_count': 45...
# 1521718751011426305  {'followers_count': 564, 'following_count': 76...
# 1521711300791136256  {'followers_count': 4323, 'following_count': 3...
# 1521702550189363202                                                  0
# ...                                                                ...
# 1521996614612701184  {'followers_count': 389, 'following_count': 50...
# 1521995762787254272  {'followers_count': 127637, 'following_count':...
# 1521995477318787072  {'followers_count': 636, 'following_count': 25...
# 1521995129409753094  {'followers_count': 421568, 'following_count':...
# 1521994898974588929  {'followers_count': 766, 'following_count': 75...
#
#                                          url  \
# tweet_id
# 1521725904065548289
# 1521721108583563264
# 1521718751011426305  https://t.co/MOstQZkzMe
# 1521711300791136256
# 1521702550189363202                        0
# ...                                      ...
# 1521996614612701184
# 1521995762787254272  https://t.co/nQe6hU46ss
# 1521995477318787072
# 1521995129409753094  https://t.co/6qzqNj8Mbr
# 1521994898974588929  https://t.co/YYTzDBaNmL
#
#                                                            description  \
# tweet_id
# 1521725904065548289  Ex “Job”, NHS, & Charity worker. Enjoys 🚴 🏊‍♂️...
# 1521721108583563264  My interests are diverse...Sports,travel, musi...
# 1521718751011426305  your local milkman ☆ art: @shuppeii ☆ private:...
# 1521711300791136256  🇰🇷KOR Cosplayer | RUA | Team.CSL | 👋변계체블\r\n🚫D...
# 1521702550189363202                                                  0
# ...                                                                ...
# 1521996614612701184  FC Barcelona. Pep. Federer. Osaka. \nWe are ti...
# 1521995762787254272            OnlyFans & JFF links in pinned tweet👇🏻🔥
# 1521995477318787072  Theatre/wordplay/#SCD enthusiast. #Stagey #Gem...
# 1521995129409753094  Brand new podcast, only on audible. https://t....
# 1521994898974588929  Mars images, science, 3D, software coding, pho...
#
#                                                      profile_image_url  \
# tweet_id
# 1521725904065548289  https://pbs.twimg.com/profile_images/136053711...
# 1521721108583563264  https://pbs.twimg.com/profile_images/109194618...
# 1521718751011426305  https://pbs.twimg.com/profile_images/152046973...
# 1521711300791136256  https://pbs.twimg.com/profile_images/151161630...
# 1521702550189363202                                                  0
# ...                                                                ...
# 1521996614612701184  https://pbs.twimg.com/profile_images/152018457...
# 1521995762787254272  https://pbs.twimg.com/profile_images/122842142...
# 1521995477318787072  https://pbs.twimg.com/profile_images/134463932...
# 1521995129409753094  https://pbs.twimg.com/profile_images/151754924...
# 1521994898974588929  https://pbs.twimg.com/profile_images/150602417...
#
#                                            location protected       username  \
# tweet_id
# 1521725904065548289                    Chesterfield     False     Fitz90MARK
# 1521721108583563264        ÜT: 44.684937,-93.282909     False     Meridith19
# 1521718751011426305               she/they 🏳️‍⚧️ 19     False       Aikilime
# 1521711300791136256  Weibo: RUA_cos / Insta: ru_a09     False         Ru_a09
# 1521702550189363202                               0         0              0
# ...                                             ...       ...            ...
# 1521996614612701184               Orimattila, Suomi     False     TheOdejobi
# 1521995762787254272               San Francisco, CA     False  thatzaddyzick
# 1521995477318787072                 London, England     False       GemAlkis
# 1521995129409753094                      Manchester     False   JasonManford
# 1521994898974588929       Mars and south Hampshire.     False  WolfieSmiffed
#
#                     verified  \
# tweet_id
# 1521725904065548289    False
# 1521721108583563264    False
# 1521718751011426305    False
# 1521711300791136256    False
# 1521702550189363202        0
# ...                      ...
# 1521996614612701184    False
# 1521995762787254272    False
# 1521995477318787072    False
# 1521995129409753094     True
# 1521994898974588929    False
#
#                                                          entities_user  \
# tweet_id
# 1521725904065548289                                                 {}
# 1521721108583563264                                                 {}
# 1521718751011426305  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1521711300791136256                                                 {}
# 1521702550189363202                                                  0
# ...                                                                ...
# 1521996614612701184                                                 {}
# 1521995762787254272  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1521995477318787072  {'description': {'hashtags': [{'start': 17, 'e...
# 1521995129409753094  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1521994898974588929  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
#
#                      pinned_tweet_id withheld_user  \
# tweet_id
# 1521725904065548289     1.450819e+18            {}
# 1521721108583563264     0.000000e+00            {}
# 1521718751011426305     1.488746e+18            {}
# 1521711300791136256     1.519938e+18            {}
# 1521702550189363202     0.000000e+00             0
# ...                              ...           ...
# 1521996614612701184     8.558066e+17            {}
# 1521995762787254272     1.522665e+18            {}
# 1521995477318787072     6.206636e+17            {}
# 1521995129409753094     0.000000e+00            {}
# 1521994898974588929     1.521127e+18            {}
#
#                                                     entities_tweeturls  \
# tweet_id
# 1521725904065548289                                                NaN
# 1521721108583563264                                                NaN
# 1521718751011426305  [{'start': 58, 'end': 81, 'url': 'https://t.co...
# 1521711300791136256  [{'start': 11, 'end': 34, 'url': 'https://t.co...
# 1521702550189363202  [{'start': 60, 'end': 83, 'url': 'https://t.co...
# ...                                                                ...
# 1521996614612701184                                                NaN
# 1521995762787254272  [{'start': 34, 'end': 57, 'url': 'https://t.co...
# 1521995477318787072                                                NaN
# 1521995129409753094                                                NaN
# 1521994898974588929                                                NaN
#
#                     entities_tweetmentions  \
# tweet_id
# 1521725904065548289                    NaN
# 1521721108583563264                    NaN
# 1521718751011426305                    NaN
# 1521711300791136256                    NaN
# 1521702550189363202                    NaN
# ...                                    ...
# 1521996614612701184                    NaN
# 1521995762787254272                    NaN
# 1521995477318787072                    NaN
# 1521995129409753094                    NaN
# 1521994898974588929                    NaN
#
#                                           entities_tweethashtags  \
# tweet_id
# 1521725904065548289                                          NaN
# 1521721108583563264                                          NaN
# 1521718751011426305                                          NaN
# 1521711300791136256                                          NaN
# 1521702550189363202                                          NaN
# ...                                                          ...
# 1521996614612701184                                          NaN
# 1521995762787254272                                          NaN
# 1521995477318787072  [{'start': 20, 'end': 27, 'tag': 'Wordle'}]
# 1521995129409753094                                          NaN
# 1521994898974588929                                          NaN
#
#                     entities_tweetannotations entities_tweetcashtags  \
# tweet_id
# 1521725904065548289                       NaN                    NaN
# 1521721108583563264                       NaN                    NaN
# 1521718751011426305                       NaN                    NaN
# 1521711300791136256                       NaN                    NaN
# 1521702550189363202                       NaN                    NaN
# ...                                       ...                    ...
# 1521996614612701184                       NaN                    NaN
# 1521995762787254272                       NaN                    NaN
# 1521995477318787072                       NaN                    NaN
# 1521995129409753094                       NaN                    NaN
# 1521994898974588929                       NaN                    NaN
#
#                      public_metrics_tweetretweet_count  \
# tweet_id
# 1521725904065548289                                  0
# 1521721108583563264                                  0
# 1521718751011426305                                  0
# 1521711300791136256                                  2
# 1521702550189363202                                  0
# ...                                                ...
# 1521996614612701184                                  0
# 1521995762787254272                                140
# 1521995477318787072                                  0
# 1521995129409753094                                  2
# 1521994898974588929                                  0
#
#                      public_metrics_tweetreply_count  \
# tweet_id
# 1521725904065548289                                0
# 1521721108583563264                                0
# 1521718751011426305                                2
# 1521711300791136256                                1
# 1521702550189363202                                0
# ...                                              ...
# 1521996614612701184                                0
# 1521995762787254272                               13
# 1521995477318787072                                0
# 1521995129409753094                               69
# 1521994898974588929                                1
#
#                      public_metrics_tweetlike_count  \
# tweet_id
# 1521725904065548289                               1
# 1521721108583563264                               1
# 1521718751011426305                               0
# 1521711300791136256                               1
# 1521702550189363202                               0
# ...                                             ...
# 1521996614612701184                               0
# 1521995762787254272                            1415
# 1521995477318787072                               2
# 1521995129409753094                             340
# 1521994898974588929                               1
#
#                      public_metrics_tweetquote_count
# tweet_id
# 1521725904065548289                                1
# 1521721108583563264                                1
# 1521718751011426305                                1
# 1521711300791136256                                1
# 1521702550189363202                                1
# ...                                              ...
# 1521996614612701184                                1
# 1521995762787254272                                2
# 1521995477318787072                                1
# 1521995129409753094                                2
# 1521994898974588929                                1
#
# [1177 rows x 35 columns]

# %% [markdown]
# # Text
#
# This is the text of the tweet! There are all sorts of things we could do with this. Tweets were specifically found using the search term `🟩 Wordle`, looking for any tweet with `Wordle` and `🟩`.
#
# In 3_data_cleanup.ipynb, tweets with complete Wordle games had their games stripped from the text. These were saved as strings of digits, with 2 as 🟩, 1 as 🟨, and 0 as ⬛/⬜. They are all in a row, but the length is a multiple of 5, so the number of game rows is implied by `len(string)/5`.

# %% [markdown]
# ### game

# %%
#import wordle games
wordle_games_path = '../merged_data/wordle_games.csv'
wordle_games = pd.read_csv(wordle_games_path, index_col = 'id')

# %%
wordle_games.head()
# Out:
#                                   wordle_games
# id
# 1521733018293084160  0012000120000220202222222
# 1521733015738662913  0000110002020020202222222
# 1521733011414257664       11000100202102122222
# 1521733010504445954            020102222022222
# 1521733001981444096                 0020122222

# %%
wordle_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243245 entries, 1521733018293084160 to 1520733408237916161
# Data columns (total 1 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   wordle_games  243245 non-null  object
# dtypes: object(1)
# memory usage: 3.7+ MB

# %%
wordle_games.rename(columns={'wordle_games':'game'}, inplace = True)

# %%
#create new columns with info and statistics on the games.

#add encoded game to main dataframe
tudf = tudf.join(wordle_games)

# %% [markdown]
# ### win

# %%
#whether a win occured. This is guessing the word in 6 or fewer tries.
tudf['win'] = tudf['game'].apply(lambda game: str(game)[-5:] == '22222')

# %%
#wins
tudf['win'].value_counts()
# Out:
# True     228074
# False    158383
# Name: win, dtype: int64

# %%
# That's a lot of wins, but there are a lot of tweets that aren't proper Wordles. Cut these out and look again.

#value counts for 'win' only for games with a non-null `game`
tudf.loc[tudf['game'].dropna().index]['win'].value_counts()
# Out:
# True     353242
# False     22905
# Name: win, dtype: int64

# %%
# value counts for wins by percentage
tudf.loc[tudf['game'].dropna().index]['win'].value_counts('mormamose')
# Out:
# True     0.939106
# False    0.060894
# Name: win, dtype: float64

# %% [markdown]
# about 94% of shared wordle games were winners. What do losing games look like?

# %%
tudf[tudf['win'] == False & tudf['game'].notna()] #.loc[1520127524377972737]['text']
# Out:
#                          conversation_id reply_settings lang  \
# 1520127509051944961  1520127509051944961       everyone   en
# 1520127524377972737  1520127524377972737       everyone   en
# 1520127566845149185  1520127566845149185       everyone   ja
# 1520127576676704256  1520127576676704256       everyone   en
# 1520127578593726464  1520127578593726464       everyone   ja
# ...                                  ...            ...  ...
# 1522335287988346882  1522335287988346882       everyone   en
# 1522335296007847937  1522335296007847937       everyone   en
# 1522335298574852103  1520887819216080898       everyone   en
# 1522335308712497153  1522100467987320832       everyone   de
# 1522335315381395456  1522335315381395456       everyone   en
#
#                      possibly_sensitive               source  \
# 1520127509051944961               False      Twitter Web App
# 1520127524377972737               False   Twitter for iPhone
# 1520127566845149185               False      Twitter Web App
# 1520127576676704256               False   Twitter for iPhone
# 1520127578593726464               False   Twitter for iPhone
# ...                                 ...                  ...
# 1522335287988346882               False  Twitter for Android
# 1522335296007847937               False   Twitter for iPhone
# 1522335298574852103               False  Twitter for Android
# 1522335308712497153               False   Twitter for iPhone
# 1522335315381395456               False      Twitter Web App
#
#                                                                   text  \
# 1520127509051944961       Wordle 314 4/6\n\n🟩⬛🟩🟨🟨\n🟩🟩🟩⬛🟨\n🟩🟩🟩🟩⬛\n🟩🟩🟩🟩🟩
# 1520127524377972737           😈💅😈💅😈💅\n\nWordle 314 2/6\n\n🟩⬛🟩🟨🟨\n🟩🟩🟩🟩🟩
# 1520127566845149185  Wordle 315 4/6\n\n⬜⬜🟨⬜⬜\n⬜⬜⬜🟨⬜\n⬜⬜⬜⬜⬜\n🟩🟩🟩🟩🟩\n...
# 1520127576676704256  this is the best I've done so far \n\nWordle 3...
# 1520127578593726464  最近はめっきり知らない単語ばっかり。\n\nWordle 315 5/6\n\n⬛⬛⬛🟨⬛\...
# ...                                                                ...
# 1522335287988346882              Wordle 320 3/6\n\n🟩🟩⬜⬜🟨\n🟩🟩⬜🟩⬜\n🟩🟩🟩🟩🟩
# 1522335296007847937  Wordle 320 5/6\n\n⬜🟨⬜⬜🟨\n🟩⬜🟨⬜⬜\n🟩🟩⬜🟩🟩\n🟩🟩⬜🟩🟩\n...
# 1522335298574852103  Wordle (ES)  #119 6/6\n\n🟨⬜🟩⬜🟩\n⬜🟩🟩⬜🟩\n⬜🟩🟩⬜🟩\n...
# 1522335308712497153  @marcusreif Wördl 320 6/6 🔥3\n\n⬜⬜⬜🟨⬜\n🟨🟨⬜🟨⬜\n...
# 1522335315381395456       Wordle 320 4/6\n\n🟨🟨⬛⬛⬛\n⬛🟩⬛🟩🟩\n⬛🟩⬛🟩🟩\n🟩🟩🟩🟩🟩
#
#                                                    context_annotations  \
# 1520127509051944961  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1520127524377972737  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1520127566845149185  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1520127576676704256  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1520127578593726464  [{'domain': {'id': '30', 'name': 'Entities [En...
# ...                                                                ...
# 1522335287988346882  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1522335296007847937  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1522335298574852103  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1522335308712497153  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1522335315381395456  [{'domain': {'id': '30', 'name': 'Entities [En...
#
#                                author_id                created_at  \
# 1520127509051944961            489622686 2022-04-29 19:46:55+00:00
# 1520127524377972737             25239815 2022-04-29 19:46:59+00:00
# 1520127566845149185            176229015 2022-04-29 19:47:09+00:00
# 1520127576676704256  1471956208181514243 2022-04-29 19:47:11+00:00
# 1520127578593726464  1220315666508464130 2022-04-29 19:47:11+00:00
# ...                                  ...                       ...
# 1522335287988346882  1178989169416298497 2022-05-05 21:59:50+00:00
# 1522335296007847937           3031584784 2022-05-05 21:59:52+00:00
# 1522335298574852103             48402699 2022-05-05 21:59:53+00:00
# 1522335308712497153   729318582937657344 2022-05-05 21:59:55+00:00
# 1522335315381395456             21729445 2022-05-05 21:59:57+00:00
#
#                                                      referenced_tweets  \
# 1520127509051944961                                                 []
# 1520127524377972737                                                 []
# 1520127566845149185                                                 []
# 1520127576676704256                                                 []
# 1520127578593726464                                                 []
# ...                                                                ...
# 1522335287988346882                                                 []
# 1522335296007847937                                                 []
# 1522335298574852103  [{'type': 'replied_to', 'id': '152198222645134...
# 1522335308712497153  [{'type': 'replied_to', 'id': '152210046798732...
# 1522335315381395456                                                 []
#
#                      in_reply_to_user_id attachments geo withheld_tweet  \
# 1520127509051944961                  0.0          {}  {}             {}
# 1520127524377972737                  0.0          {}  {}             {}
# 1520127566845149185                  0.0          {}  {}             {}
# 1520127576676704256                  0.0          {}  {}             {}
# 1520127578593726464                  0.0          {}  {}             {}
# ...                                  ...         ...  ..            ...
# 1522335287988346882                  0.0          {}  {}             {}
# 1522335296007847937                  0.0          {}  {}             {}
# 1522335298574852103           48402699.0          {}  {}             {}
# 1522335308712497153           14656612.0          {}  {}             {}
# 1522335315381395456                  0.0          {}  {}             {}
#
#                                                name  \
# 1520127509051944961                  ♔･ﾟ✧Lᴏɢɢʏ･ﾟ✧ ♔
# 1520127524377972737  Carly Garza | Commissions Open
# 1520127566845149185                            折笠美冬
# 1520127576676704256                               0
# 1520127578593726464                               0
# ...                                             ...
# 1522335287988346882                               0
# 1522335296007847937                         Jaki Mc
# 1522335298574852103                              H.
# 1522335308712497153              Harald Ackerschott
# 1522335315381395456                         Barry 
#
#                                                    public_metrics_user  \
# 1520127509051944961  {'followers_count': 9322, 'following_count': 1...
# 1520127524377972737  {'followers_count': 714, 'following_count': 95...
# 1520127566845149185  {'followers_count': 94, 'following_count': 253...
# 1520127576676704256                                                  0
# 1520127578593726464                                                  0
# ...                                                                ...
# 1522335287988346882                                                  0
# 1522335296007847937  {'followers_count': 11, 'following_count': 27,...
# 1522335298574852103  {'followers_count': 9214, 'following_count': 9...
# 1522335308712497153  {'followers_count': 282, 'following_count': 10...
# 1522335315381395456  {'followers_count': 217, 'following_count': 16...
#
#                                          url  \
# 1520127509051944961
# 1520127524377972737  https://t.co/OqVqYWdqMx
# 1520127566845149185
# 1520127576676704256                        0
# 1520127578593726464                        0
# ...                                      ...
# 1522335287988346882                        0
# 1522335296007847937
# 1522335298574852103  https://t.co/UmOidW23FT
# 1522335308712497153  https://t.co/SZbjKWVCSi
# 1522335315381395456
#
#                                                            description  \
# 1520127509051944961  *:･ﾟ I lσνε @arianagrande , & @blackpink *:･ﾟ\...
# 1520127524377972737  she/they | queer multidisciplinary artist | Cu...
# 1520127566845149185  基本的にゲームのことばかり呟いてます。\r\n呟きの内容に画像レスを含むことがあるので、不快...
# 1520127576676704256                                                  0
# 1520127578593726464                                                  0
# ...                                                                ...
# 1522335287988346882                                                  0
# 1522335296007847937  Daughter, sister, wife, mother, and friend! Lo...
# 1522335298574852103  Si soy el eco y no el grito, no soy real. \r\n...
# 1522335308712497153  came here to follow @bhorsetrials, found @MFra...
# 1522335315381395456  Retired fruit sales manager.  Sports car fanat...
#
#                                                      profile_image_url  \
# 1520127509051944961  https://pbs.twimg.com/profile_images/148007682...
# 1520127524377972737  https://pbs.twimg.com/profile_images/145323946...
# 1520127566845149185  https://pbs.twimg.com/profile_images/122182835...
# 1520127576676704256                                                  0
# 1520127578593726464                                                  0
# ...                                                                ...
# 1522335287988346882                                                  0
# 1522335296007847937  https://pbs.twimg.com/profile_images/847574313...
# 1522335298574852103  https://pbs.twimg.com/profile_images/147770084...
# 1522335308712497153  https://pbs.twimg.com/profile_images/117420698...
# 1522335315381395456  https://pbs.twimg.com/profile_images/82081217/...
#
#                                  location protected        username verified  \
# 1520127509051944961  vote lisa and rose😃🤗     False         loggyf2    False
# 1520127524377972737            Texas, USA     False     carlyagarza    False
# 1520127566845149185               まいづるちほー     False        orichan5    False
# 1520127576676704256                     0         0               0        0
# 1520127578593726464                     0         0               0        0
# ...                                   ...       ...             ...      ...
# 1522335287988346882                     0         0               0        0
# 1522335296007847937         United States     False       jaki_mc99    False
# 1522335298574852103    Medellín, Colombia     False         _Sileno    False
# 1522335308712497153           Deutschland     False  Ha_Ackerschott    False
# 1522335315381395456                 SoFla     False          iBaz66    False
#
#                                                          entities_user  \
# 1520127509051944961  {'description': {'mentions': [{'start': 12, 'e...
# 1520127524377972737  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1520127566845149185                                                 {}
# 1520127576676704256                                                  0
# 1520127578593726464                                                  0
# ...                                                                ...
# 1522335287988346882                                                  0
# 1522335296007847937                                                 {}
# 1522335298574852103  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1522335308712497153  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1522335315381395456                                                 {}
#
#                      pinned_tweet_id withheld_user  \
# 1520127509051944961     6.956076e+17            {}
# 1520127524377972737     1.468007e+18            {}
# 1520127566845149185     0.000000e+00            {}
# 1520127576676704256     0.000000e+00             0
# 1520127578593726464     0.000000e+00             0
# ...                              ...           ...
# 1522335287988346882     0.000000e+00             0
# 1522335296007847937     0.000000e+00            {}
# 1522335298574852103     1.520888e+18            {}
# 1522335308712497153     1.146357e+18            {}
# 1522335315381395456     0.000000e+00            {}
#
#                                                     entities_tweeturls  \
# 1520127509051944961                                                NaN
# 1520127524377972737                                                NaN
# 1520127566845149185                                                NaN
# 1520127576676704256                                                NaN
# 1520127578593726464                                                NaN
# ...                                                                ...
# 1522335287988346882                                                NaN
# 1522335296007847937                                                NaN
# 1522335298574852103  [{'start': 60, 'end': 83, 'url': 'https://t.co...
# 1522335308712497153  [{'start': 67, 'end': 90, 'url': 'https://t.co...
# 1522335315381395456                                                NaN
#
#                                                 entities_tweetmentions  \
# 1520127509051944961                                                NaN
# 1520127524377972737                                                NaN
# 1520127566845149185                                                NaN
# 1520127576676704256                                                NaN
# 1520127578593726464                                                NaN
# ...                                                                ...
# 1522335287988346882                                                NaN
# 1522335296007847937                                                NaN
# 1522335298574852103                                                NaN
# 1522335308712497153  [{'start': 0, 'end': 11, 'username': 'marcusre...
# 1522335315381395456                                                NaN
#
#                     entities_tweethashtags entities_tweetannotations  \
# 1520127509051944961                    NaN                       NaN
# 1520127524377972737                    NaN                       NaN
# 1520127566845149185                    NaN                       NaN
# 1520127576676704256                    NaN                       NaN
# 1520127578593726464                    NaN                       NaN
# ...                                    ...                       ...
# 1522335287988346882                    NaN                       NaN
# 1522335296007847937                    NaN                       NaN
# 1522335298574852103                    NaN                       NaN
# 1522335308712497153                    NaN                       NaN
# 1522335315381395456                    NaN                       NaN
#
#                     entities_tweetcashtags  public_metrics_tweetretweet_count  \
# 1520127509051944961                    NaN                                  0
# 1520127524377972737                    NaN                                  0
# 1520127566845149185                    NaN                                  0
# 1520127576676704256                    NaN                                  0
# 1520127578593726464                    NaN                                  0
# ...                                    ...                                ...
# 1522335287988346882                    NaN                                  0
# 1522335296007847937                    NaN                                  0
# 1522335298574852103                    NaN                                  0
# 1522335308712497153                    NaN                                  0
# 1522335315381395456                    NaN                                  0
#
#                      public_metrics_tweetreply_count  \
# 1520127509051944961                                0
# 1520127524377972737                                1
# 1520127566845149185                                0
# 1520127576676704256                                0
# 1520127578593726464                                0
# ...                                              ...
# 1522335287988346882                                0
# 1522335296007847937                                0
# 1522335298574852103                                1
# 1522335308712497153                                0
# 1522335315381395456                                0
#
#                      public_metrics_tweetlike_count  \
# 1520127509051944961                               2
# 1520127524377972737                               2
# 1520127566845149185                               0
# 1520127576676704256                               0
# 1520127578593726464                               0
# ...                                             ...
# 1522335287988346882                               4
# 1522335296007847937                               0
# 1522335298574852103                               0
# 1522335308712497153                               1
# 1522335315381395456                               0
#
#                      public_metrics_tweetquote_count game    win
# 1520127509051944961                                0  NaN  False
# 1520127524377972737                                0  NaN  False
# 1520127566845149185                                0  NaN  False
# 1520127576676704256                                0  NaN  False
# 1520127578593726464                                0  NaN  False
# ...                                              ...  ...    ...
# 1522335287988346882                                0  NaN  False
# 1522335296007847937                                0  NaN  False
# 1522335298574852103                                0  NaN  False
# 1522335308712497153                                0  NaN  False
# 1522335315381395456                                0  NaN  False
#
# [158383 rows x 37 columns]

# %% [markdown]
# Many of these are still Pokemon wordles. They must be removed. There are likely lots of other Wordle alternatives that aren't easily traced by `lang`. It is probably a good idea to see how accurately I can pick out which language is which based on url links or other info.

# %%
#save the word pokemon in kana
pokemon_string = 'ポケモン'

#make a new column to keep track of pokemon games
poke_list = tudf['text'].apply(lambda text: pokemon_string in text)
tudf['is_poke'] = poke_list

# %%
# look at a couple of the pokemon wordles
tudf[tudf['is_poke']].head(2)
# Out:
#                          conversation_id reply_settings lang  \
# 1520128019846684672  1520128019846684672       everyone   ja
# 1520128136771371008  1520128136771371008       everyone   ja
#
#                      possibly_sensitive               source  \
# 1520128019846684672               False  Twitter for Android
# 1520128136771371008               False   Twitter for iPhone
#
#                                                                   text  \
# 1520128019846684672  ポケモンWordle 3/10\n\n⬛🟨⬛⬛⬛\n🟨⬛⬛⬛🟨\n🟩🟩🟩🟩🟩\n\nhttp...
# 1520128136771371008  ポケモンWordle 3/10\n\n⬛🟨⬛⬛⬛\n⬛🟨⬛🟩⬛\n🟩🟩🟩🟩🟩\n\nhttp...
#
#                                                    context_annotations  \
# 1520128019846684672  [{'domain': {'id': '45', 'name': 'Brand Vertic...
# 1520128136771371008  [{'domain': {'id': '45', 'name': 'Brand Vertic...
#
#                               author_id                created_at  \
# 1520128019846684672          2410477404 2022-04-29 19:48:57+00:00
# 1520128136771371008  751235352984055809 2022-04-29 19:49:25+00:00
#
#                     referenced_tweets  in_reply_to_user_id attachments geo  \
# 1520128019846684672                []                  0.0          {}  {}
# 1520128136771371008                []                  0.0          {}  {}
#
#                     withheld_tweet   name  \
# 1520128019846684672             {}  ひりき物語
# 1520128136771371008             {}      0
#
#                                                    public_metrics_user url  \
# 1520128019846684672  {'followers_count': 71, 'following_count': 87,...
# 1520128136771371008                                                  0   0
#
#                                                            description  \
# 1520128019846684672  食物語/ヒプマイARB/放置少女　\r\n性能より見た目派。ネタバレはしますされます。天井はデフォ
# 1520128136771371008                                                  0
#
#                                                      profile_image_url  \
# 1520128019846684672  https://pbs.twimg.com/profile_images/150943595...
# 1520128136771371008                                                  0
#
#                        location protected    username verified entities_user  \
# 1520128019846684672  イナカ・ディビジョン     False  hirikimono    False            {}
# 1520128136771371008           0         0           0        0             0
#
#                      pinned_tweet_id withheld_user  \
# 1520128019846684672     1.494876e+18            {}
# 1520128136771371008     0.000000e+00             0
#
#                                                     entities_tweeturls  \
# 1520128019846684672  [{'start': 36, 'end': 59, 'url': 'https://t.co...
# 1520128136771371008  [{'start': 36, 'end': 59, 'url': 'https://t.co...
#
#                     entities_tweetmentions  \
# 1520128019846684672                    NaN
# 1520128136771371008                    NaN
#
#                                               entities_tweethashtags  \
# 1520128019846684672  [{'start': 61, 'end': 72, 'tag': 'ポケモンWordle'}]
# 1520128136771371008  [{'start': 61, 'end': 72, 'tag': 'ポケモンWordle'}]
#
#                     entities_tweetannotations entities_tweetcashtags  \
# 1520128019846684672                       NaN                    NaN
# 1520128136771371008                       NaN                    NaN
#
#                      public_metrics_tweetretweet_count  \
# 1520128019846684672                                  0
# 1520128136771371008                                  0
#
#                      public_metrics_tweetreply_count  \
# 1520128019846684672                                0
# 1520128136771371008                                0
#
#                      public_metrics_tweetlike_count  \
# 1520128019846684672                               0
# 1520128136771371008                               0
#
#                      public_metrics_tweetquote_count game    win  is_poke
# 1520128019846684672                                0  NaN  False     True
# 1520128136771371008                                0  NaN  False     True

# %% [markdown]
# Others are Wordle (ES) in Spanish, Wordle CAT for Catalan.

# %%
tudf[tudf['lang'] == 'es'].head(3)
# Out:
#                          conversation_id reply_settings lang  \
# 1520127913122832391  1520127913122832391       everyone   es
# 1520128712515104769  1520128712515104769       everyone   es
# 1520128939758436352  1520128939758436352       everyone   es
#
#                      possibly_sensitive               source  \
# 1520127913122832391               False      Twitter Web App
# 1520128712515104769               False  Twitter for Android
# 1520128939758436352               False   Twitter for iPhone
#
#                                                                   text  \
# 1520127913122832391  #Wordle (ES)  #113 4/6\n\n⬜⬜🟨🟨🟩\n🟨🟨⬜⬜🟩\n⬜🟨🟨🟩🟩\...
# 1520128712515104769  Word #119 (🇪🇸 - Clásico) - 4/6\nVersión app, s...
# 1520128939758436352  Wordle Científico #47 6/6\n\n⬜🟨⬜⬜🟨⬜\n⬜🟨⬜🟨🟩⬜\n⬜...
#
#                                                    context_annotations  \
# 1520127913122832391  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1520128712515104769  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1520128939758436352  [{'domain': {'id': '30', 'name': 'Entities [En...
#
#                      author_id                created_at referenced_tweets  \
# 1520127913122832391   11477652 2022-04-29 19:48:31+00:00                []
# 1520128712515104769   26210001 2022-04-29 19:51:42+00:00                []
# 1520128939758436352  346858116 2022-04-29 19:52:36+00:00                []
#
#                      in_reply_to_user_id attachments  \
# 1520127913122832391                  0.0          {}
# 1520128712515104769                  0.0          {}
# 1520128939758436352                  0.0          {}
#
#                                                   geo withheld_tweet  \
# 1520127913122832391                                {}             {}
# 1520128712515104769  {'place_id': '01d487de3c4e0807'}             {}
# 1520128939758436352                                {}             {}
#
#                                                    name  \
# 1520127913122832391  Ajenjo ♉️💚🔻ASegarra #FreePalestina
# 1520128712515104769                Me gusta tu infierno
# 1520128939758436352                                Яᗩυℓ
#
#                                                    public_metrics_user  \
# 1520127913122832391  {'followers_count': 510, 'following_count': 37...
# 1520128712515104769  {'followers_count': 238, 'following_count': 33...
# 1520128939758436352  {'followers_count': 421, 'following_count': 33...
#
#                                          url  \
# 1520127913122832391  https://t.co/HSXCWb6LmO
# 1520128712515104769
# 1520128939758436352
#
#                                                            description  \
# 1520127913122832391  Coleccionista, fan de Hellblazer, Dominion y S...
# 1520128712515104769                          El amor es mi kriptonita.
# 1520128939758436352  🏠 Zamora / 🎓 Salamanca / 📍Madrid / Chemical En...
#
#                                                      profile_image_url  \
# 1520127913122832391  https://pbs.twimg.com/profile_images/241948841...
# 1520128712515104769  https://pbs.twimg.com/profile_images/152148623...
# 1520128939758436352  https://pbs.twimg.com/profile_images/122291393...
#
#                                     location protected    username verified  \
# 1520127913122832391  Quart de Poblet, España     False      ajenjo    False
# 1520128712515104769            Jose Ignacio      False  MariaVelia    False
# 1520128939758436352                Salamanca     False   coast_man    False
#
#                                                          entities_user  \
# 1520127913122832391  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1520128712515104769                                                 {}
# 1520128939758436352  {'description': {'mentions': [{'start': 82, 'e...
#
#                      pinned_tweet_id withheld_user  \
# 1520127913122832391     8.489641e+17            {}
# 1520128712515104769     0.000000e+00            {}
# 1520128939758436352     1.259869e+18            {}
#
#                                                     entities_tweeturls  \
# 1520127913122832391  [{'start': 49, 'end': 72, 'url': 'https://t.co...
# 1520128712515104769  [{'start': 93, 'end': 116, 'url': 'https://t.c...
# 1520128939758436352  [{'start': 70, 'end': 93, 'url': 'https://t.co...
#
#                     entities_tweetmentions  \
# 1520127913122832391                    NaN
# 1520128712515104769                    NaN
# 1520128939758436352                    NaN
#
#                                                 entities_tweethashtags  \
# 1520127913122832391          [{'start': 0, 'end': 7, 'tag': 'Wordle'}]
# 1520128712515104769  [{'start': 118, 'end': 125, 'tag': 'wordle'}, ...
# 1520128939758436352                                                NaN
#
#                     entities_tweetannotations entities_tweetcashtags  \
# 1520127913122832391                       NaN                    NaN
# 1520128712515104769                       NaN                    NaN
# 1520128939758436352                       NaN                    NaN
#
#                      public_metrics_tweetretweet_count  \
# 1520127913122832391                                  0
# 1520128712515104769                                  0
# 1520128939758436352                                  0
#
#                      public_metrics_tweetreply_count  \
# 1520127913122832391                                0
# 1520128712515104769                                0
# 1520128939758436352                                0
#
#                      public_metrics_tweetlike_count  \
# 1520127913122832391                               0
# 1520128712515104769                               0
# 1520128939758436352                               0
#
#                      public_metrics_tweetquote_count game    win  is_poke
# 1520127913122832391                                0  NaN  False    False
# 1520128712515104769                                0  NaN  False    False
# 1520128939758436352                                0  NaN  False    False

# %%
tudf[tudf['lang'] == 'ca'].head(3)
# Out:
#                          conversation_id reply_settings lang  \
# 1520146347524956161  1520146347524956161       everyone   ca
# 1520149798690738176  1480145315193831430       everyone   ca
# 1520158911550177281  1482290400471756803       everyone   ca
#
#                      possibly_sensitive               source  \
# 1520146347524956161               False   Twitter for iPhone
# 1520149798690738176               False      Twitter Web App
# 1520158911550177281               False  Twitter for Android
#
#                                                                   text  \
# 1520146347524956161  Wordle (ES)  #113 2/6\n\n⬜🟨🟩🟩🟩\n🟩🟩🟩🟩🟩\n\nWordl...
# 1520149798690738176  Wordle 314 4/6\n\n⬜🟨⬜🟨⬜\n⬜⬜⬜🟨⬜\n🟩🟩🟩⬜⬜\n🟩🟩🟩🟩🟩\n...
# 1520158911550177281  @wendolinpaz @Tana02265435 @TiritaTNT @oxigeno...
#
#                                                    context_annotations  \
# 1520146347524956161  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1520149798690738176  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1520158911550177281  [{'domain': {'id': '30', 'name': 'Entities [En...
#
#                                author_id                created_at  \
# 1520146347524956161  1211913433928519680 2022-04-29 21:01:46+00:00
# 1520149798690738176            223505019 2022-04-29 21:15:29+00:00
# 1520158911550177281            278142338 2022-04-29 21:51:42+00:00
#
#                                                      referenced_tweets  \
# 1520146347524956161                                                 []
# 1520149798690738176  [{'type': 'replied_to', 'id': '151964083010498...
# 1520158911550177281  [{'type': 'replied_to', 'id': '152015142908790...
#
#                      in_reply_to_user_id attachments geo withheld_tweet  \
# 1520146347524956161                  0.0          {}  {}             {}
# 1520149798690738176          223505019.0          {}  {}             {}
# 1520158911550177281          278142338.0          {}  {}             {}
#
#                         name  \
# 1520146347524956161        ค
# 1520149798690738176    Leyre
# 1520158911550177281  MariMar
#
#                                                    public_metrics_user  \
# 1520146347524956161  {'followers_count': 76, 'following_count': 173...
# 1520149798690738176  {'followers_count': 98, 'following_count': 372...
# 1520158911550177281  {'followers_count': 742, 'following_count': 12...
#
#                                          url  description  \
# 1520146347524956161                           ambivertida
# 1520149798690738176
# 1520158911550177281  https://t.co/t1XtmUADD9
#
#                                                      profile_image_url  \
# 1520146347524956161  https://pbs.twimg.com/profile_images/138169538...
# 1520149798690738176  https://pbs.twimg.com/profile_images/980205041...
# 1520158911550177281  https://pbs.twimg.com/profile_images/101475200...
#
#                             location protected         username verified  \
# 1520146347524956161                      False      ciertamujer    False
# 1520149798690738176  Vitoria-Gasteiz     False          LeyrePM    False
# 1520158911550177281         Alcorcon     False  MariMar_Laurana    False
#
#                                                          entities_user  \
# 1520146347524956161                                                 {}
# 1520149798690738176                                                 {}
# 1520158911550177281  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
#
#                      pinned_tweet_id withheld_user  \
# 1520146347524956161              0.0            {}
# 1520149798690738176              0.0            {}
# 1520158911550177281              0.0            {}
#
#                                                     entities_tweeturls  \
# 1520146347524956161                                                NaN
# 1520149798690738176  [{'start': 83, 'end': 106, 'url': 'https://t.c...
# 1520158911550177281  [{'start': 362, 'end': 385, 'url': 'https://t....
#
#                                                 entities_tweetmentions  \
# 1520146347524956161                                                NaN
# 1520149798690738176                                                NaN
# 1520158911550177281  [{'start': 0, 'end': 12, 'username': 'wendolin...
#
#                     entities_tweethashtags entities_tweetannotations  \
# 1520146347524956161                    NaN                       NaN
# 1520149798690738176                    NaN                       NaN
# 1520158911550177281                    NaN                       NaN
#
#                     entities_tweetcashtags  public_metrics_tweetretweet_count  \
# 1520146347524956161                    NaN                                  0
# 1520149798690738176                    NaN                                  0
# 1520158911550177281                    NaN                                  0
#
#                      public_metrics_tweetreply_count  \
# 1520146347524956161                                1
# 1520149798690738176                                1
# 1520158911550177281                                1
#
#                      public_metrics_tweetlike_count  \
# 1520146347524956161                               1
# 1520149798690738176                               0
# 1520158911550177281                               4
#
#                      public_metrics_tweetquote_count game    win  is_poke
# 1520146347524956161                                0  NaN  False    False
# 1520149798690738176                                0  NaN  False    False
# 1520158911550177281                                0  NaN  False    False

# %% [markdown]
# I don't want to throw out games of English Wordle if someone is writing in Spanish otherwise in the tweet, for example, and Twitter assigns it 'es'. I should be able to filter these out. This could be done with links. Do legitimate Wordle tweets link to the nytimes page, or does Twitter find an associated link to them?

# %%
#list made in a previous section
expanded_tweet_urls
# Out:
# [[{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/oJCukg4JnD',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 58,
#    'end': 81,
#    'url': 'https://t.co/ifnVQsE6bO',
#    'expanded_url': 'https://wordle.danielfrg.com/ciencia/index.html',
#    'display_url': 'wordle.danielfrg.com/ciencia/index.…',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521711979752136704/Qr2DllcV?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521711979752136704/Qr2DllcV?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/ciencia/index.html'}],
#  [{'start': 58,
#    'end': 81,
#    'url': 'https://t.co/Pxb1ZKeNoD',
#    'expanded_url': 'https://wordle.danielfrg.com/ciencia/index.html',
#    'display_url': 'wordle.danielfrg.com/ciencia/index.…',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521711979752136704/Qr2DllcV?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521711979752136704/Qr2DllcV?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/ciencia/index.html'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/IC6ZxPHDEF',
#    'expanded_url': 'https://wordle.mega-yadoran.jp/',
#    'display_url': 'wordle.mega-yadoran.jp',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1520627181159784450/oEzApr9k?format=png&name=orig',
#      'width': 200,
#      'height': 200},
#     {'url': 'https://pbs.twimg.com/news_img/1520627181159784450/oEzApr9k?format=png&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'ポケモンWordle',
#    'description': 'ポケモンWordle (ポケモンワードル)は単語当てゲーム「Wordle」のポケモン版。１０回のチャレンジでポケモンの名前を当てよう！',
#    'unwound_url': 'https://wordle.mega-yadoran.jp/'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/LqTwoZRmma',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/gVwzNU1bJE',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 43,
#    'end': 66,
#    'url': 'https://t.co/lGJkZO2hl7',
#    'expanded_url': 'https://bit.ly/wordlethai',
#    'display_url': 'bit.ly/wordlethai',
#    'status': 200,
#    'title': 'เวิร์ดเดลไทย - Thai Wordle',
#    'description': 'Wordle ฉบับภาษาไทย',
#    'unwound_url': 'https://buddhistuniversity.net/wordle-thai/'}],
#  [{'start': 51,
#    'end': 74,
#    'url': 'https://t.co/BtXcWPrgJa',
#    'expanded_url': 'http://wordle.gelozp.com',
#    'display_url': 'wordle.gelozp.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1520479054184468480/yryaukBy?format=png&name=orig',
#      'width': 400,
#      'height': 400},
#     {'url': 'https://pbs.twimg.com/news_img/1520479054184468480/yryaukBy?format=png&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'WordleCAT - Un mot diari',
#    'description': 'Endevina el mot amagat en 6 intents. Cada dia hi ha un nou mot per endevinar.',
#    'unwound_url': 'https://wordle.gelozp.com/'}],
#  [{'start': 62,
#    'end': 85,
#    'url': 'https://t.co/4wLdS1B3Eo',
#    'expanded_url': 'https://wordle.mega-yadoran.jp/',
#    'display_url': 'wordle.mega-yadoran.jp',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1520627181159784450/oEzApr9k?format=png&name=orig',
#      'width': 200,
#      'height': 200},
#     {'url': 'https://pbs.twimg.com/news_img/1520627181159784450/oEzApr9k?format=png&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'ポケモンWordle',
#    'description': 'ポケモンWordle (ポケモンワードル)は単語当てゲーム「Wordle」のポケモン版。１０回のチャレンジでポケモンの名前を当てよう！',
#    'unwound_url': 'https://wordle.mega-yadoran.jp/'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/QKa1OEBtOf',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 60,
#    'end': 83,
#    'url': 'https://t.co/rao9P4BI4l',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/xvcZIZrn1C',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 11,
#    'end': 34,
#    'url': 'https://t.co/9kAozJhfgA',
#    'expanded_url': 'https://jhlov.github.io/wordle',
#    'display_url': 'jhlov.github.io/wordle'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/IX2xW6CoFe',
#    'expanded_url': 'https://wordle.louan.me',
#    'display_url': 'wordle.louan.me'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/3C0TIloNqG',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/GM0zE5k0Hl',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 60,
#    'end': 83,
#    'url': 'https://t.co/aqLBN2A9r4',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 60,
#    'end': 83,
#    'url': 'https://t.co/Ap6i9Yy0Ya',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 85,
#    'end': 108,
#    'url': 'https://t.co/PTITgYe6Pb',
#    'expanded_url': 'https://wordle.louan.me',
#    'display_url': 'wordle.louan.me'}],
#  [{'start': 26,
#    'end': 49,
#    'url': 'https://t.co/8CnLzuBWOC',
#    'expanded_url': 'https://wordle-jp.netlify.app/',
#    'display_url': 'wordle-jp.netlify.app'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/BWjS9otbCA',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 39,
#    'end': 62,
#    'url': 'https://t.co/4ux5mq4PlD',
#    'expanded_url': 'http://wordle.gelozp.com',
#    'display_url': 'wordle.gelozp.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/VqKBtNowH3',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 57,
#    'end': 80,
#    'url': 'https://t.co/3jE1v0Kn5m',
#    'expanded_url': 'http://wordle.gelozp.com',
#    'display_url': 'wordle.gelozp.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/lSyzFOO1Z3',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 66,
#    'end': 89,
#    'url': 'https://t.co/ifLVf6959X',
#    'expanded_url': 'https://wordle.louan.me',
#    'display_url': 'wordle.louan.me'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/1XY95qobyB',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 34,
#    'end': 57,
#    'url': 'https://t.co/dABljpbPHx',
#    'expanded_url': 'https://twitter.com/deepfriedlard/status/1521369984223514624',
#    'display_url': 'twitter.com/deepfriedlard/…'}],
#  [{'start': 60,
#    'end': 83,
#    'url': 'https://t.co/UYfDx8iylz',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/uxWTQsv3kx',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/e6bPLMyyia',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 69,
#    'end': 92,
#    'url': 'https://t.co/NRzSippMRU',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/LkzSKyQdHG',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 58,
#    'end': 81,
#    'url': 'https://t.co/72uJ8rPlCp',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/VzdHJehuQL',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 82,
#    'end': 105,
#    'url': 'https://t.co/IaUEPseE62',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/uAogSyv9zJ',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 55,
#    'end': 78,
#    'url': 'https://t.co/OMYc29k8GS',
#    'expanded_url': 'http://wordle.at',
#    'display_url': 'wordle.at'}],
#  [{'start': 58,
#    'end': 81,
#    'url': 'https://t.co/Baw2N1Ljt7',
#    'expanded_url': 'https://wordle.danielfrg.com/ciencia/index.html',
#    'display_url': 'wordle.danielfrg.com/ciencia/index.…'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/9w0MwM7FHj',
#    'expanded_url': 'https://wordle.louan.me',
#    'display_url': 'wordle.louan.me'}],
#  [{'start': 28,
#    'end': 51,
#    'url': 'https://t.co/HUMP4KvGbv',
#    'expanded_url': 'https://twitter.com/priestwendy/status/1521732559331282951/photo/1',
#    'display_url': 'pic.twitter.com/HUMP4KvGbv',
#    'media_key': '16_1521732551106310145'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/Ei9OwtR6k4',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/GOymFg1AR3',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/a6FV3ZAwwa',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/LOBFASgKbQ',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/dzaLnHA7uo',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'},
#   {'start': 94,
#    'end': 117,
#    'url': 'https://t.co/2Ifo4gJe0Z',
#    'expanded_url': 'https://twitter.com/slytherinnds/status/1521732521775534081/photo/1',
#    'display_url': 'pic.twitter.com/2Ifo4gJe0Z',
#    'media_key': '16_1521732511805714432'}],
#  [{'start': 58,
#    'end': 81,
#    'url': 'https://t.co/Yz8kw4lcE3',
#    'expanded_url': 'https://wordle.danielfrg.com/ciencia/index.html',
#    'display_url': 'wordle.danielfrg.com/ciencia/index.…',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521711979752136704/Qr2DllcV?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521711979752136704/Qr2DllcV?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/ciencia/index.html'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/1w1Lfos0xN',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/aLmb1GAhgn',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 75,
#    'end': 98,
#    'url': 'https://t.co/2nsCxhOYSs',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 84,
#    'end': 107,
#    'url': 'https://t.co/usBmCsXdwu',
#    'expanded_url': 'https://wordle.danielfrg.com/#',
#    'display_url': 'wordle.danielfrg.com/#'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/FaXJnKrXWZ',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/UHmoJHttft',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/xrcyUgyil1',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 60,
#    'end': 83,
#    'url': 'https://t.co/dsJ1LY4Tfn',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/ZhqNlPPHPz',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/FzJYr0nBJ0',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 79,
#    'end': 102,
#    'url': 'https://t.co/ofC8iJnkkm',
#    'expanded_url': 'http://wordle.gelozp.com',
#    'display_url': 'wordle.gelozp.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/0ta25rI33k',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 87,
#    'end': 110,
#    'url': 'https://t.co/OHLZo1kbEY',
#    'expanded_url': 'https://wordle.belousov.one',
#    'display_url': 'wordle.belousov.one'}],
#  [{'start': 11,
#    'end': 34,
#    'url': 'https://t.co/m8GRzLztZb',
#    'expanded_url': 'https://jhlov.github.io/wordle',
#    'display_url': 'jhlov.github.io/wordle'}],
#  [{'start': 57,
#    'end': 80,
#    'url': 'https://t.co/GwBUPV9m8Q',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/IHcDFMR29n',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/N8d9xYcwzs',
#    'expanded_url': 'https://wordle.mega-yadoran.jp/',
#    'display_url': 'wordle.mega-yadoran.jp'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/ZuqiTgCbwX',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/710R09nYc9',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/b5JT8ZP9me',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 55,
#    'end': 78,
#    'url': 'https://t.co/9nlV6pL0V0',
#    'expanded_url': 'https://wordle.mega-yadoran.jp/',
#    'display_url': 'wordle.mega-yadoran.jp',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1520627181159784450/oEzApr9k?format=png&name=orig',
#      'width': 200,
#      'height': 200},
#     {'url': 'https://pbs.twimg.com/news_img/1520627181159784450/oEzApr9k?format=png&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'ポケモンWordle',
#    'description': 'ポケモンWordle (ポケモンワードル)は単語当てゲーム「Wordle」のポケモン版。１０回のチャレンジでポケモンの名前を当てよう！',
#    'unwound_url': 'https://wordle.mega-yadoran.jp/'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/OKNoQ7rEIB',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 89,
#    'end': 112,
#    'url': 'https://t.co/5h1AN61NVM',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/YdEOQja0si',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/TpKEuGxWCT',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 95,
#    'end': 118,
#    'url': 'https://t.co/gGZVEJAgMX',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 134,
#    'end': 157,
#    'url': 'https://t.co/gZc536YnSB',
#    'expanded_url': 'https://wordle.belousov.one',
#    'display_url': 'wordle.belousov.one'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/8CTKalht3i',
#    'expanded_url': 'https://wordle.louan.me',
#    'display_url': 'wordle.louan.me'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/KvvQte8kcG',
#    'expanded_url': 'https://wordle.mega-yadoran.jp/',
#    'display_url': 'wordle.mega-yadoran.jp',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1520627181159784450/oEzApr9k?format=png&name=orig',
#      'width': 200,
#      'height': 200},
#     {'url': 'https://pbs.twimg.com/news_img/1520627181159784450/oEzApr9k?format=png&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'ポケモンWordle',
#    'description': 'ポケモンWordle (ポケモンワードル)は単語当てゲーム「Wordle」のポケモン版。１０回のチャレンジでポケモンの名前を当てよう！',
#    'unwound_url': 'https://wordle.mega-yadoran.jp/'}],
#  [{'start': 39,
#    'end': 62,
#    'url': 'https://t.co/tLpC59BN9Y',
#    'expanded_url': 'http://wordle.gelozp.com',
#    'display_url': 'wordle.gelozp.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/zJA9agkM6p',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 88,
#    'end': 111,
#    'url': 'https://t.co/cLkxl43qD0',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 64,
#    'end': 87,
#    'url': 'https://t.co/KEAEO4YSBz',
#    'expanded_url': 'https://wordle.danielfrg.com/tildes/index.html',
#    'display_url': 'wordle.danielfrg.com/tildes/index.h…'}],
#  [{'start': 0,
#    'end': 23,
#    'url': 'https://t.co/hQSpbCRtcz',
#    'expanded_url': 'http://6mal5.com',
#    'display_url': '6mal5.com'}],
#  [{'start': 36,
#    'end': 59,
#    'url': 'https://t.co/qAZvZhGk6m',
#    'expanded_url': 'https://wordle.mega-yadoran.jp/',
#    'display_url': 'wordle.mega-yadoran.jp'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/RlVM954Jxi',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/qfyszTCKaD',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/oUqb22mREi',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/dvgP83ZaCf',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/4sDQPwE5cA',
#    'expanded_url': 'https://wordle.mega-yadoran.jp/',
#    'display_url': 'wordle.mega-yadoran.jp'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/dOq9ku0O4i',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/rR5XaXtZ0R',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/9R6UZYMD3x',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/uJEdGvG8UX',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 39,
#    'end': 62,
#    'url': 'https://t.co/ZakKiEKsUR',
#    'expanded_url': 'http://wordle.gelozp.com',
#    'display_url': 'wordle.gelozp.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/sgTsPs0R12',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 51,
#    'end': 74,
#    'url': 'https://t.co/yHI33ROJLe',
#    'expanded_url': 'http://wordle.gelozp.com',
#    'display_url': 'wordle.gelozp.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1520479054184468480/yryaukBy?format=png&name=orig',
#      'width': 400,
#      'height': 400},
#     {'url': 'https://pbs.twimg.com/news_img/1520479054184468480/yryaukBy?format=png&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'WordleCAT - Un mot diari',
#    'description': 'Endevina el mot amagat en 6 intents. Cada dia hi ha un nou mot per endevinar.',
#    'unwound_url': 'https://wordle.gelozp.com/'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/KguzENiojv',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/Xdj83kfUVk',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/IFecYJuJJp',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 87,
#    'end': 110,
#    'url': 'https://t.co/sVK6XzXwKR',
#    'expanded_url': 'https://wordle.belousov.one',
#    'display_url': 'wordle.belousov.one'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/K86RSzhGPS',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/buTcZv0iDv',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/9Upz0uiRag',
#    'expanded_url': 'https://www.bundle.app/wordle-tr/',
#    'display_url': 'bundle.app/wordle-tr/'}],
#  [{'start': 40,
#    'end': 63,
#    'url': 'https://t.co/8rbj6vpAXX',
#    'expanded_url': 'https://wordle.mega-yadoran.jp/',
#    'display_url': 'wordle.mega-yadoran.jp'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/GzP8bj5JAE',
#    'expanded_url': 'https://wordle.danielfrg.com/?s=08',
#    'display_url': 'wordle.danielfrg.com/?s=08'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/6LrZPELAHI',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/PzwYje5otj',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/lpkVOlJjXb',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/vuRhUEeAqs',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/lcDtyUHuY4',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/MqLf2qji4T',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/j8Hj5kq1F6',
#    'expanded_url': 'https://wordle.louan.me',
#    'display_url': 'wordle.louan.me'}],
#  [{'start': 50,
#    'end': 73,
#    'url': 'https://t.co/jMutIMOYrk',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/WOQoMbTuMB',
#    'expanded_url': 'https://wordle.danielfrg.com/tildes/index.html',
#    'display_url': 'wordle.danielfrg.com/tildes/index.h…'}],
#  [{'start': 64,
#    'end': 87,
#    'url': 'https://t.co/xqMuSEVHbx',
#    'expanded_url': 'https://wordle.danielfrg.com/tildes/index.html',
#    'display_url': 'wordle.danielfrg.com/tildes/index.h…'}],
#  [{'start': 72,
#    'end': 95,
#    'url': 'https://t.co/hq8X4VGCWI',
#    'expanded_url': 'https://wordle.danielfrg.com/tildes/index.html',
#    'display_url': 'wordle.danielfrg.com/tildes/index.h…'}],
#  [{'start': 46,
#    'end': 69,
#    'url': 'https://t.co/HFxX7CrLPD',
#    'expanded_url': 'https://wordle.danielfrg.com/ciencia/index.html',
#    'display_url': 'wordle.danielfrg.com/ciencia/index.…'}],
#  [{'start': 34,
#    'end': 57,
#    'url': 'https://t.co/CVS4FQtktG',
#    'expanded_url': 'https://twitter.com/StuartOrr1/status/1521731301337878528/photo/1',
#    'display_url': 'pic.twitter.com/CVS4FQtktG',
#    'media_key': '16_1521731293393960960'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/ZUx5iSC42e',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 67,
#    'end': 90,
#    'url': 'https://t.co/kllXvOfYBq',
#    'expanded_url': 'https://www.bundle.app/wordle-tr/',
#    'display_url': 'bundle.app/wordle-tr/'}],
#  [{'start': 47,
#    'end': 70,
#    'url': 'https://t.co/9xLUtMbvc4',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/kW2ocGC7Ug',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 43,
#    'end': 66,
#    'url': 'https://t.co/Ph6uuGEcnY',
#    'expanded_url': 'http://wordle.at',
#    'display_url': 'wordle.at'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/ZNEVRMopZ0',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 58,
#    'end': 81,
#    'url': 'https://t.co/dw3XO2k9lv',
#    'expanded_url': 'https://wordle.danielfrg.com/ciencia/index.html',
#    'display_url': 'wordle.danielfrg.com/ciencia/index.…'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/YyglqUhmFj',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/QGUBw12yWl',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 49,
#    'end': 72,
#    'url': 'https://t.co/6EV9N6mXYS',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/rKEvsWxozj',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 36,
#    'end': 59,
#    'url': 'https://t.co/VjgVhCH1t6',
#    'expanded_url': 'https://wordle.mega-yadoran.jp/',
#    'display_url': 'wordle.mega-yadoran.jp'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/of3dNdBhCb',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 88,
#    'end': 111,
#    'url': 'https://t.co/vMeaYlrMVQ',
#    'expanded_url': 'http://wordle.gelozp.com',
#    'display_url': 'wordle.gelozp.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1520479054184468480/yryaukBy?format=png&name=orig',
#      'width': 400,
#      'height': 400},
#     {'url': 'https://pbs.twimg.com/news_img/1520479054184468480/yryaukBy?format=png&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'WordleCAT - Un mot diari',
#    'description': 'Endevina el mot amagat en 6 intents. Cada dia hi ha un nou mot per endevinar.',
#    'unwound_url': 'https://wordle.gelozp.com/'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/gW5ZbaxyGW',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 36,
#    'end': 59,
#    'url': 'https://t.co/zZkmsdiqlc',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/faF8qAG5XU',
#    'expanded_url': 'https://www.wordleturkce.com/',
#    'display_url': 'wordleturkce.com'}],
#  [{'start': 41,
#    'end': 64,
#    'url': 'https://t.co/7PsaNn2WaD',
#    'expanded_url': 'https://twitter.com/sh3sg0ne/status/1521730995371724800/photo/1',
#    'display_url': 'pic.twitter.com/7PsaNn2WaD',
#    'media_key': '3_1521730992079130624'}],
#  [{'start': 59,
#    'end': 82,
#    'url': 'https://t.co/B9Gg2eMzM3',
#    'expanded_url': 'http://wordle.gelozp.com',
#    'display_url': 'wordle.gelozp.com'}],
#  [{'start': 77,
#    'end': 100,
#    'url': 'https://t.co/u6s78G5QcK',
#    'expanded_url': 'https://wordle.louan.me',
#    'display_url': 'wordle.louan.me',
#    'status': 200,
#    'title': 'Le Mot - Wordle en français',
#    'description': 'Wordle, mais en français. Devinez le mot du jour ! Totalement gratuit, en ligne, et sans pub.',
#    'unwound_url': 'https://wordle.louan.me'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/TC40Ed5b1G',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/PlNMcyllH7',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 93,
#    'end': 116,
#    'url': 'https://t.co/DwTZS6NCC2',
#    'expanded_url': 'https://wordlegame.org?challenge=c3R1ZGlv',
#    'display_url': 'wordlegame.org/?challenge=c3R…'},
#   {'start': 117,
#    'end': 140,
#    'url': 'https://t.co/VVqXq2Gf7O',
#    'expanded_url': 'https://wordlegame.org/6-letter-words-wordle',
#    'display_url': 'wordlegame.org/6-letter-words…'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/BC8YNQzcwb',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 69,
#    'end': 92,
#    'url': 'https://t.co/kNntYdX2Z5',
#    'expanded_url': 'https://wordle.mega-yadoran.jp/',
#    'display_url': 'wordle.mega-yadoran.jp'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/KbsmQFEaqB',
#    'expanded_url': 'https://wordle.danielfrg.com/ciencia/index.html',
#    'display_url': 'wordle.danielfrg.com/ciencia/index.…'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/OyTm896KLk',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 43,
#    'end': 66,
#    'url': 'https://t.co/jGE0efcn2V',
#    'expanded_url': 'http://wordle.at',
#    'display_url': 'wordle.at'}],
#  [{'start': 85,
#    'end': 108,
#    'url': 'https://t.co/ckwwTx5ryH',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/jF7YbOnpor',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/nSvzQnW1Xl',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/QgwOCNCDt5',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'},
#   {'start': 78,
#    'end': 101,
#    'url': 'https://t.co/kZdrT9cMS3',
#    'expanded_url': 'https://twitter.com/CarlosTribuno/status/1521730761933660161/photo/1',
#    'display_url': 'pic.twitter.com/kZdrT9cMS3',
#    'media_key': '16_1521730754002182150'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/GqWXeHEiXg',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 211,
#    'end': 234,
#    'url': 'https://t.co/3Tx0RtSudv',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/63Xk0S0Js9',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 28,
#    'end': 51,
#    'url': 'https://t.co/ugNbg5KHEW',
#    'expanded_url': 'https://twitter.com/TheKellyLlama/status/1521730730728038400/photo/1',
#    'display_url': 'pic.twitter.com/ugNbg5KHEW',
#    'media_key': '16_1521730723929022465'}],
#  [{'start': 62,
#    'end': 85,
#    'url': 'https://t.co/ExpdWbFM3J',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 73,
#    'end': 96,
#    'url': 'https://t.co/xrmOmjNnEX',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/oSpF15dCLr',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 46,
#    'end': 69,
#    'url': 'https://t.co/b0qyePW5VN',
#    'expanded_url': 'https://wordle.danielfrg.com/ciencia/index.html',
#    'display_url': 'wordle.danielfrg.com/ciencia/index.…'}],
#  [{'start': 84,
#    'end': 107,
#    'url': 'https://t.co/Ovr3nOl5Ix',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/8kRxEJkFiZ',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/3SqWrUNvDn',
#    'expanded_url': 'https://wordle.mega-yadoran.jp/',
#    'display_url': 'wordle.mega-yadoran.jp'}],
#  [{'start': 99,
#    'end': 122,
#    'url': 'https://t.co/jaPswgZoKM',
#    'expanded_url': 'https://wordle.belousov.one',
#    'display_url': 'wordle.belousov.one'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/M8T0IU0iSG',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 55,
#    'end': 78,
#    'url': 'https://t.co/Plup9ahX7H',
#    'expanded_url': 'http://wordle.at',
#    'display_url': 'wordle.at'}],
#  [{'start': 266,
#    'end': 289,
#    'url': 'https://t.co/3Tx0RtSudv',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/As5Lm9OcO7',
#    'expanded_url': 'https://www.bundle.app/wordle-tr/',
#    'display_url': 'bundle.app/wordle-tr/'}],
#  [{'start': 56,
#    'end': 79,
#    'url': 'https://t.co/UnXwlxoTpq',
#    'expanded_url': 'https://wordle.danielfrg.com/tildes/index.html',
#    'display_url': 'wordle.danielfrg.com/tildes/index.h…'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/ydjDr0pS1m',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 59,
#    'end': 82,
#    'url': 'https://t.co/tWKyN9LMBs',
#    'expanded_url': 'http://wordle.at',
#    'display_url': 'wordle.at'},
#   {'start': 84,
#    'end': 107,
#    'url': 'https://t.co/CiyFetYOrC',
#    'expanded_url': 'http://6mal5.com',
#    'display_url': '6mal5.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/r4ewhPm3Nf',
#    'expanded_url': 'https://www.wordleturkce.com/',
#    'display_url': 'wordleturkce.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/eP1iXOcb4s',
#    'expanded_url': 'https://bit.ly/3qnLmpT',
#    'display_url': 'bit.ly/3qnLmpT',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/KPgY3tqsIJ',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 60,
#    'end': 83,
#    'url': 'https://t.co/SFV59N4ggh',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/YtrncKhysk',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/XLEilrNa2z',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/kkrOHw2C8u',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/iewnKAVvvN',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/y2AVZZAwXJ',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 28,
#    'end': 51,
#    'url': 'https://t.co/pzrlFv1ITk',
#    'expanded_url': 'https://twitter.com/nfcresswell/status/1521730340619968513/photo/1',
#    'display_url': 'pic.twitter.com/pzrlFv1ITk',
#    'media_key': '3_1521730331677765632'}],
#  [{'start': 45,
#    'end': 68,
#    'url': 'https://t.co/xktOymzSRD',
#    'expanded_url': 'http://term.ooo',
#    'display_url': 'term.ooo'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/MhXJrYmapa',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/JXGaE2O15O',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 86,
#    'end': 109,
#    'url': 'https://t.co/WKUCUWZmdC',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/4IbPMPxJ46',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/yuXcRte5JZ',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 60,
#    'end': 83,
#    'url': 'https://t.co/y2AVZZAwXJ',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 36,
#    'end': 59,
#    'url': 'https://t.co/m1HdPnFc58',
#    'expanded_url': 'https://wordle.mega-yadoran.jp/',
#    'display_url': 'wordle.mega-yadoran.jp'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/qs2X1x9Rir',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 52,
#    'end': 75,
#    'url': 'https://t.co/E1sEtqd17z',
#    'expanded_url': 'http://wordle.gelozp.com',
#    'display_url': 'wordle.gelozp.com'}],
#  [{'start': 60,
#    'end': 83,
#    'url': 'https://t.co/yd1WnrXGVd',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/tRvTL3R8CR',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/3xCBJFRKFr',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/jS20wE1wj0',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/hQgfjN9r7t',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/R27eZJcBqP',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 45,
#    'end': 68,
#    'url': 'https://t.co/HY6BNlNi7l',
#    'expanded_url': 'http://wordle.gelozp.com',
#    'display_url': 'wordle.gelozp.com'}],
#  [{'start': 41,
#    'end': 64,
#    'url': 'https://t.co/ENaN7jx6tt',
#    'expanded_url': 'https://sutom.nocle.fr',
#    'display_url': 'sutom.nocle.fr'},
#   {'start': 120,
#    'end': 143,
#    'url': 'https://t.co/GPcTLUD73Y',
#    'expanded_url': 'https://wordle.louan.me',
#    'display_url': 'wordle.louan.me'}],
#  [{'start': 52,
#    'end': 75,
#    'url': 'https://t.co/jsqOProBop',
#    'expanded_url': 'http://sozutap.com',
#    'display_url': 'sozutap.com'}],
#  [{'start': 70,
#    'end': 93,
#    'url': 'https://t.co/0jAuZjzerG',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/UjNhczbEsj',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 58,
#    'end': 81,
#    'url': 'https://t.co/J7w4wvXMHB',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 49,
#    'end': 72,
#    'url': 'https://t.co/aknweVuYDR',
#    'expanded_url': 'http://wordle.at',
#    'display_url': 'wordle.at'}],
#  [{'start': 87,
#    'end': 110,
#    'url': 'https://t.co/nqG8t4lA60',
#    'expanded_url': 'https://wordle.belousov.one',
#    'display_url': 'wordle.belousov.one'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/Z0yOBqoghS',
#    'expanded_url': 'https://wordle.danielfrg.com/tildes/index.html',
#    'display_url': 'wordle.danielfrg.com/tildes/index.h…'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/C2tsMsnYKA',
#    'expanded_url': 'https://www.wordleturkce.com/',
#    'display_url': 'wordleturkce.com'}],
#  [{'start': 67,
#    'end': 90,
#    'url': 'https://t.co/qhAUc5SNAp',
#    'expanded_url': 'https://wordle.mega-yadoran.jp/',
#    'display_url': 'wordle.mega-yadoran.jp'}],
#  [{'start': 72,
#    'end': 95,
#    'url': 'https://t.co/a19RVywLsI',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/mpKXN3IFIl',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 55,
#    'end': 78,
#    'url': 'https://t.co/QjBeZ33Lem',
#    'expanded_url': 'http://wordle.at',
#    'display_url': 'wordle.at'}],
#  [{'start': 67,
#    'end': 90,
#    'url': 'https://t.co/nnK297hFr1',
# ...
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/DqlmNM93J8',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 51,
#    'end': 74,
#    'url': 'https://t.co/WVfYz5FnwT',
#    'expanded_url': 'http://wordle.gelozp.com',
#    'display_url': 'wordle.gelozp.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/S2XuyEul7u',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/XYlqFkYzmf',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/x4QFRAZReE',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 66,
#    'end': 89,
#    'url': 'https://t.co/DuEMLKs8an',
#    'expanded_url': 'https://wordle.louan.me',
#    'display_url': 'wordle.louan.me'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/hN59iP5oqn',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/U19Q4jQL1g',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/CHSqrXxYPO',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 57,
#    'end': 80,
#    'url': 'https://t.co/WYZMs2F1Lr',
#    'expanded_url': 'http://wordle.gelozp.com',
#    'display_url': 'wordle.gelozp.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/9OCJCwbH6B',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/mJeHcKpoSb',
#    'expanded_url': 'https://wordle.danielfrg.com/tildes/index.html',
#    'display_url': 'wordle.danielfrg.com/tildes/index.h…'}],
#  [{'start': 51,
#    'end': 74,
#    'url': 'https://t.co/AZB7RcLRIQ',
#    'expanded_url': 'http://wordle.gelozp.com',
#    'display_url': 'wordle.gelozp.com'}],
#  [{'start': 47,
#    'end': 70,
#    'url': 'https://t.co/S8eEGmBaTS',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 40,
#    'end': 63,
#    'url': 'https://t.co/7ht4uf3BkZ',
#    'expanded_url': 'https://wordle.danielfrg.com/tildes/index.html',
#    'display_url': 'wordle.danielfrg.com/tildes/index.h…'}],
#  [{'start': 85,
#    'end': 108,
#    'url': 'https://t.co/3bnsCEnGU5',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/12MoLQN5gf',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 36,
#    'end': 59,
#    'url': 'https://t.co/7MsRXhOQSs',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 62,
#    'end': 85,
#    'url': 'https://t.co/xGt6MkDDFZ',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 86,
#    'end': 109,
#    'url': 'https://t.co/rau2H5V6wd',
#    'expanded_url': 'https://wordle.louan.me',
#    'display_url': 'wordle.louan.me'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/8VKDWONQDv',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 46,
#    'end': 69,
#    'url': 'https://t.co/ya1ZDFOt6Q',
#    'expanded_url': 'https://wordle.danielfrg.com/ciencia/index.html',
#    'display_url': 'wordle.danielfrg.com/ciencia/index.…'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/rhanLs0zVd',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/1BHGDHdnaD',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/6MdGeqEBbJ',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 14,
#    'end': 37,
#    'url': 'https://t.co/xPZN2TknJy',
#    'expanded_url': 'https://jhlov.github.io/wordle',
#    'display_url': 'jhlov.github.io/wordle'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/YBHw9S3Iim',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/vIAfhnJNqf',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 106,
#    'end': 129,
#    'url': 'https://t.co/GhGUl0lDc4',
#    'expanded_url': 'https://bit.ly/Best_Wordle_C',
#    'display_url': 'bit.ly/Best_Wordle_C'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/SNx2zIVLSv',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 59,
#    'end': 82,
#    'url': 'https://t.co/irl0wDvQzX',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/EJliuSoKP3',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/X1kJYMinqI',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 99,
#    'end': 122,
#    'url': 'https://t.co/sU6XYYU48L',
#    'expanded_url': 'https://wordle.belousov.one',
#    'display_url': 'wordle.belousov.one'}],
#  [{'start': 68,
#    'end': 91,
#    'url': 'https://t.co/tz1jRnJprB',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/dqJ2ZlL3a0',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 207,
#    'end': 230,
#    'url': 'https://t.co/CiRpF3kIgY',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/n1heJT50Tw',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/G8fR16G2OS',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 117,
#    'end': 140,
#    'url': 'https://t.co/pCPEuoeHS2',
#    'expanded_url': 'http://wordle.at',
#    'display_url': 'wordle.at'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/W94IA2DvS8',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/GRZlY4KwK1',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 66,
#    'end': 89,
#    'url': 'https://t.co/rTAp3IUUcM',
#    'expanded_url': 'https://wordle.louan.me',
#    'display_url': 'wordle.louan.me'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/gJAaA24n66',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/XB57jY5euU',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 62,
#    'end': 85,
#    'url': 'https://t.co/WqETg7EgVa',
#    'expanded_url': 'https://wordle.mega-yadoran.jp/',
#    'display_url': 'wordle.mega-yadoran.jp',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1520627181159784450/oEzApr9k?format=png&name=orig',
#      'width': 200,
#      'height': 200},
#     {'url': 'https://pbs.twimg.com/news_img/1520627181159784450/oEzApr9k?format=png&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'ポケモンWordle',
#    'description': 'ポケモンWordle (ポケモンワードル)は単語当てゲーム「Wordle」のポケモン版。１０回のチャレンジでポケモンの名前を当てよう！',
#    'unwound_url': 'https://wordle.mega-yadoran.jp/'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/1mthiF8l6Z',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 50,
#    'end': 73,
#    'url': 'https://t.co/nr7HsJABNo',
#    'expanded_url': 'http://wordle.gelozp.com',
#    'display_url': 'wordle.gelozp.com'}],
#  [{'start': 58,
#    'end': 81,
#    'url': 'https://t.co/I5AHKCLvla',
#    'expanded_url': 'https://wordle.danielfrg.com/ciencia/index.html',
#    'display_url': 'wordle.danielfrg.com/ciencia/index.…',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521711979752136704/Qr2DllcV?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521711979752136704/Qr2DllcV?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/ciencia/index.html'}],
#  [{'start': 58,
#    'end': 81,
#    'url': 'https://t.co/JHdKChlNZa',
#    'expanded_url': 'https://twitter.com/Aikilime/status/1521718751011426305/photo/1',
#    'display_url': 'pic.twitter.com/JHdKChlNZa',
#    'media_key': '3_1521718742677438464'}],
#  [{'start': 23,
#    'end': 46,
#    'url': 'https://t.co/Q3eJpB5HPo',
#    'expanded_url': 'https://jhlov.github.io/wordle',
#    'display_url': 'jhlov.github.io/wordle'}],
#  [{'start': 66,
#    'end': 89,
#    'url': 'https://t.co/l9o8S7fKW4',
#    'expanded_url': 'https://wordle.louan.me',
#    'display_url': 'wordle.louan.me'}],
#  [{'start': 60,
#    'end': 83,
#    'url': 'https://t.co/RfTKIonVzb',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 69,
#    'end': 92,
#    'url': 'https://t.co/NbVtWXt8Mr',
#    'expanded_url': 'https://wordle.mega-yadoran.jp/',
#    'display_url': 'wordle.mega-yadoran.jp'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/zs2CMvptZZ',
#    'expanded_url': 'https://www.bundle.app/wordle-tr/',
#    'display_url': 'bundle.app/wordle-tr/'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/289iww8gix',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 34,
#    'end': 57,
#    'url': 'https://t.co/92zunsu1P2',
#    'expanded_url': 'https://twitter.com/loljocks_grimey/status/1521718637303894017/photo/1',
#    'display_url': 'pic.twitter.com/92zunsu1P2',
#    'media_key': '16_1521718631335440384'}],
#  [{'start': 86,
#    'end': 109,
#    'url': 'https://t.co/ZnKNgnh3PC',
#    'expanded_url': 'https://wordle.louan.me',
#    'display_url': 'wordle.louan.me'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/UR0l7LyNCl',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 60,
#    'end': 83,
#    'url': 'https://t.co/Cx4qZjRTO6',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/XuONbWBbDf',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/0OTVMJUDP0',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/FEGD26IsVo',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 52,
#    'end': 75,
#    'url': 'https://t.co/qv7sbEiQtP',
#    'expanded_url': 'https://wordle.danielfrg.com/ciencia/index.html',
#    'display_url': 'wordle.danielfrg.com/ciencia/index.…'}],
#  [{'start': 62,
#    'end': 85,
#    'url': 'https://t.co/bZ1jlfWTbN',
#    'expanded_url': 'https://wordlepeaks.com',
#    'display_url': 'wordlepeaks.com'}],
#  [{'start': 49,
#    'end': 72,
#    'url': 'https://t.co/UOTEQS9IEI',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/YUOPt1BKEX',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/bsIcZwS0pC',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=orig',
#      'width': 1200,
#      'height': 630},
#     {'url': 'https://pbs.twimg.com/news_img/1521670739459411968/tTDycHOP?format=jpg&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'Un juego de palabras diario',
#    'description': 'Adivina la palabra oculta en 6 intentos. Un nuevo puzzle cada día.',
#    'unwound_url': 'https://wordle.danielfrg.com/'}],
#  [{'start': 56,
#    'end': 79,
#    'url': 'https://t.co/QhkrLWLQZ0',
#    'expanded_url': 'https://wordle.danielfrg.com/tildes/index.html',
#    'display_url': 'wordle.danielfrg.com/tildes/index.h…'}],
#  [{'start': 54,
#    'end': 77,
#    'url': 'https://t.co/DkrhqNIihJ',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/fwUQbGDF9g',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 43,
#    'end': 66,
#    'url': 'https://t.co/MbaQNxpMX5',
#    'expanded_url': 'http://wordle.at',
#    'display_url': 'wordle.at'}],
#  [{'start': 55,
#    'end': 78,
#    'url': 'https://t.co/62HZ3W52Pz',
#    'expanded_url': 'https://wordle.mega-yadoran.jp/',
#    'display_url': 'wordle.mega-yadoran.jp',
#    'images': [{'url': 'https://pbs.twimg.com/news_img/1520627181159784450/oEzApr9k?format=png&name=orig',
#      'width': 200,
#      'height': 200},
#     {'url': 'https://pbs.twimg.com/news_img/1520627181159784450/oEzApr9k?format=png&name=150x150',
#      'width': 150,
#      'height': 150}],
#    'status': 200,
#    'title': 'ポケモンWordle',
#    'description': 'ポケモンWordle (ポケモンワードル)は単語当てゲーム「Wordle」のポケモン版。１０回のチャレンジでポケモンの名前を当てよう！',
#    'unwound_url': 'https://wordle.mega-yadoran.jp/'}],
#  [{'start': 36,
#    'end': 59,
#    'url': 'https://t.co/TgDNMM79sL',
#    'expanded_url': 'https://wordle.mega-yadoran.jp/',
#    'display_url': 'wordle.mega-yadoran.jp'}],
#  [{'start': 24,
#    'end': 47,
#    'url': 'https://t.co/VTUp3KPfgS',
#    'expanded_url': 'http://k-wordle.com',
#    'display_url': 'k-wordle.com'}],
#  [{'start': 42,
#    'end': 65,
#    'url': 'https://t.co/N4zBLOJksP',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 48,
#    'end': 71,
#    'url': 'https://t.co/COFleOXX0U',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  [{'start': 58,
#    'end': 81,
#    'url': 'https://t.co/Wqb9SAIc2y',
#    'expanded_url': 'https://wordle.danielfrg.com/',
#    'display_url': 'wordle.danielfrg.com'}],
#  ...]

# %%
just_the_urls_list = [
    [
        this_dict['expanded_url']
        for this_dict in this_list
    ]
    for this_list in expanded_tweet_urls
]

just_the_urls = pd.DataFrame(just_the_urls_list)

# %%
just_the_urls
# Out:
#                                                        0     1     2     3  \
# 0                          https://wordle.danielfrg.com/  None  None  None
# 1        https://wordle.danielfrg.com/ciencia/index.html  None  None  None
# 2        https://wordle.danielfrg.com/ciencia/index.html  None  None  None
# 3                        https://wordle.mega-yadoran.jp/  None  None  None
# 4                          https://wordle.danielfrg.com/  None  None  None
# ...                                                  ...   ...   ...   ...
# 82206  https://twitter.com/scottiestar/status/1521794...  None  None  None
# 82207                      https://wordle.danielfrg.com/  None  None  None
# 82208                            https://wordle.louan.me  None  None  None
# 82209                    https://wordle.mega-yadoran.jp/  None  None  None
# 82210                      https://wordle.danielfrg.com/  None  None  None
#
#           4     5
# 0      None  None
# 1      None  None
# 2      None  None
# 3      None  None
# 4      None  None
# ...     ...   ...
# 82206  None  None
# 82207  None  None
# 82208  None  None
# 82209  None  None
# 82210  None  None
#
# [82211 rows x 6 columns]

# %% [markdown]
# Some of the tweets have more than one url, up to 5. What's the distribution of these urls counts?

# %%
just_the_urls[0]
# Out:
# 0                            https://wordle.danielfrg.com/
# 1          https://wordle.danielfrg.com/ciencia/index.html
# 2          https://wordle.danielfrg.com/ciencia/index.html
# 3                          https://wordle.mega-yadoran.jp/
# 4                            https://wordle.danielfrg.com/
#                                ...
# 82206    https://twitter.com/scottiestar/status/1521794...
# 82207                        https://wordle.danielfrg.com/
# 82208                              https://wordle.louan.me
# 82209                      https://wordle.mega-yadoran.jp/
# 82210                        https://wordle.danielfrg.com/
# Name: 0, Length: 82211, dtype: object

# %%
# get the numbers of tweets with each number of urls attached
filled_number = [len(tudf)]
for column_num in just_the_urls.columns:
    filled_number.append( (len(just_the_urls[column_num].dropna())))
    #need to subtract the number from all previous or else it counts the same tweet multiple times
    for j in range(column_num):
        filled_number[j] = filled_number[j] - filled_number[column_num]
filled_number
# Out:
# [302634, 80599, 1288, 102, 22, 4, 3]

# %% [markdown]
# It looks like there are about 700 unaccounted for in this tally.

# %%
plt.figure(figsize = (8,12))
plt.barh(width = filled_number, y = range(0,7), log = True)
plt.title('Number of links in tweet (log)')
plt.xlabel('number of tweets')
plt.ylabel('number of links in tweet');

# %%
# get all the urls in a flat list.
all_url_list = list(np.concatenate(just_the_urls_list))

# %%
#make that list a series so we can call value_counts easily.
all_url_list_series = pd.Series(all_url_list)
all_url_list_series
# Out:
# 0                            https://wordle.danielfrg.com/
# 1          https://wordle.danielfrg.com/ciencia/index.html
# 2          https://wordle.danielfrg.com/ciencia/index.html
# 3                          https://wordle.mega-yadoran.jp/
# 4                            https://wordle.danielfrg.com/
#                                ...
# 83821    https://twitter.com/scottiestar/status/1521794...
# 83822                        https://wordle.danielfrg.com/
# 83823                              https://wordle.louan.me
# 83824                      https://wordle.mega-yadoran.jp/
# 83825                        https://wordle.danielfrg.com/
# Length: 83826, dtype: object

# %%
url_counts = all_url_list_series.value_counts()

# %%
number_urls_to_plot = 30

plt.figure(figsize = (6,12))
plt.barh(width = url_counts[:number_urls_to_plot],
         y = url_counts[:number_urls_to_plot].index,
         log = True)
# Out:
# <BarContainer object of 30 artists>

# %% [markdown]
# Most of these are foreign language alternatives. Some are different games based on the original (Pokemon, Heardle, Framed, Worldle).
# - [wordle.danielfrg.com](wordle.danielfrg.com) is a Spanish language game
# - [wordle.mega-yadoran.jp](https://wordle.mega-yadoran.jp/) is the Japanese language Pokemon Wordle
# - [www.bundle.app/wordle-tr](http://www.bundle.app/wordle-tr) is Turkish
# - [wordle.louan.me](https://wordle.louan.me) Le Mot - Wordle en français
# - [wordle.gelozp.com](https://wordle.gelozp.com) Wordle CAT (Catalan)
# - [wordle.at](http://wordle.at) is German (.at is for austria)
# - [wordleturkce.com](http://www.wordleturkce.com/) is a(nother? or not?) Turkish variant.
# - [https://jhlov.github.io/wordle/#/](https://jhlov.github.io/wordle/#/) Korean
# - [belousov.one](https://wordle.belousov.one/) Russian
# - [https://wordle-jp.netlify.app/](https://wordle-jp.netlify.app/) Japanese
# - [nytimes.com](https://www.nytimes.com/games/wordle/index.html) The actual real New York Times Wordle page!
# - [onelink.to](onelink.to/wordlegame) This is a link to [a google play app](https://play.google.com/store/apps/details?id=io.digitalsnacks.wordchallenge) that seems to be a wordle clone. Onelink appears to be a redirection service.
# - The next two are danielfrg/Spanish language topic specified with tildes and science words.
# - [k-wordle.com](k-wordle.com) Another Korean site
# - [inertia-yehu.github.io/wordsnipe](inertia-yehu.github.io/wordsnipe)
# - [Wordle Galego](https://wordlegalego.appspot.com/) Wordle Galego in Galician
# - [Wordle Wekele](https://wordle.wekele.com/) Wordle in many languages
# - [Worldle](https://worldle.teuteuf.fr/) "Worldle" Wordle variant based on country identification with shape and distance
# - [Heardle](https://www.heardle.app) Heardle --- identifying a pop song based on the introduction
# - [Framed](https://framed.wtf) Framed --- identifying a film based on screenshots
#
# The presence of one of these is probably a good identifier of the tweet NOT representing a legit Wordle game.

# %%
tudf.columns
# Out:
# Index(['conversation_id', 'reply_settings', 'lang', 'possibly_sensitive',
#        'source', 'text', 'context_annotations', 'author_id', 'created_at',
#        'referenced_tweets', 'in_reply_to_user_id', 'attachments', 'geo',
#        'withheld_tweet', 'name', 'public_metrics_user', 'url', 'description',
#        'profile_image_url', 'location', 'protected', 'username', 'verified',
#        'entities_user', 'pinned_tweet_id', 'withheld_user',
#        'entities_tweeturls', 'entities_tweetmentions',
#        'entities_tweethashtags', 'entities_tweetannotations',
#        'entities_tweetcashtags', 'public_metrics_tweetretweet_count',
#        'public_metrics_tweetreply_count', 'public_metrics_tweetlike_count',
#        'public_metrics_tweetquote_count', 'game', 'win', 'is_poke'],
#       dtype='object')

# %% [markdown]
# # Description

# %%
# how many user descriptions are filled?
tudf['user_has_description'] = tudf['description'] != 0
tudf['user_has_description'].value_counts('norm'), tudf['user_has_description'].value_counts()
# Out:
# (True     0.844055
#  False    0.155945
#  Name: user_has_description, dtype: float64,
#  True     326191
#  False     60266
#  Name: user_has_description, dtype: int64)

# %% [markdown]
# 77758 of the tweets are by users with descriptions. This is about 32% of the tweets.

# %%
tudf['url'].where(tudf['url']!=0).dropna().head(49)
# Out:
# 1520127509051944961
# 1520127524377972737    https://t.co/OqVqYWdqMx
# 1520127566845149185
# 1520127583047852032
# 1520127597388128261
# 1520127651951882241
# 1520127652975321088    https://t.co/TOovGMTisZ
# 1520127659266686976
# 1520127671346159616
# 1520127676912123910    https://t.co/fk1uSjIp9x
# 1520127682624643072    https://t.co/CshKFa39ld
# 1520127687997591552
# 1520127745497473026
# 1520127766221713408
# 1520127766699683845
# 1520127789420081152
# 1520127805169848327
# 1520127834492076033    https://t.co/9Z6Tww1Dxj
# 1520127851294507011    https://t.co/esZTtDusqa
# 1520127854415167489    https://t.co/L4fbhZ669O
# 1520127882223550465    https://t.co/B8Q8PJtsI1
# 1520127899453427712     http://t.co/23vQnEHQmE
# 1520127900187561984    https://t.co/7zIN8K6cAF
# 1520127913122832391    https://t.co/HSXCWb6LmO
# 1520127925055799297
# 1520127926410387457
# 1520127940570324993
# 1520127962955145218
# 1520127981527523464
# 1520127981985103872
# 1520127987676499968
# 1520127996010635266
# 1520128019846684672
# 1520128033058803712
# 1520128054357413888
# 1520128066239967232    https://t.co/iAuuS9yqhB
# 1520128079917895680
# 1520128079942668288
# 1520128094522441733    https://t.co/aUgvGJdm3Y
# 1520128163686322176
# 1520128210415071232
# 1520128213913157633
# 1520128219885686785    https://t.co/nmcS5cyfza
# 1520128235610120193    https://t.co/AlLXEVDZpT
# 1520128243172397056
# 1520128245059960834
# 1520128271907954688
# 1520128302039588873    https://t.co/nIpL1g9dsq
# 1520128317294538752
# Name: url, dtype: object

# %% [markdown]
# # Missing user data
#
# Unfortunately, lots of the gathered user data just doesn't seem to pair appropriately with the tweet data. There are user IDs (both in the index and the Unnamed: 0 column that were merged, before the "fix" was done) that appear in a saved `users_xx.csv` but not in the corresponding tweet data, and vice versa.

# %%
user_id_list = list(users.index.astype(np.int64))

# %%
# %%time
#how many "author_ids" are not in the user data?
user_id_list = list(users.index.astype(np.int64))
tudf['author_id'][::10].astype(np.int64).apply(lambda this_id: this_id in user_id_list).sum()
# Out:
# Wall time: 25.8 s
# 32645

# %%
len(tudf)
# Out:
# 386457

# %% [markdown]
# This first run may not work well due to lots of zero-differences since the last tweet. To fix this ahead, take an average of times since last tweet to get a positive number rather than zero. for 1/(time since last tweet)

# %%
tudf['created_at'] = pd.to_datetime(tudf['created_at'])

# %%
tudf.sort_values(by = 'created_at', inplace= True)

# %%
tudf['created_at'].dtype
# Out:
# datetime64[ns, UTC]

# %%
# Not sure why ths is needed
tudf['wordle_tweet_number'] = range(len(tudf))

# %%
# create a list of ones to easily perform multiplicative inversion
tudf['ones'] = np.ones(len(tudf))

# %%
# latest and earliest tweet dates have already been grabbed
print(f'Tweets were gathered from\n{earliest} to\n{latest}, spanning\n{timespan}.')
# Out:
# Tweets were gathered from
# 2022-04-29 19:46:55+00:00 to
# 2022-05-05 21:59:57+00:00, spanning
# 6 days 02:13:02.

# %%
# create a column giving the timedelta since the last tweet.
tudf.sort_values(by = 'created_at', inplace= True)
tudf['time_since_last_tweet'] = tudf['created_at'].diff()
# turn timedeltas into simple seconds.
tudf['time_since_last_tweet'] = tudf['time_since_last_tweet'].apply(lambda this_timedelta: this_timedelta.total_seconds())

# create a column 
tudf['wordle_tweet_rate'] = tudf['ones']/tudf['time_since_last_tweet']

# %%
tudf['time_since_last_tweet']
# Out:
# 1520127509051944961     NaN
# 1520127524377972737     4.0
# 1520127566845149185    10.0
# 1520127576676704256     2.0
# 1520127578593726464     0.0
#                        ...
# 1522335287988346882     7.0
# 1522335296007847937     2.0
# 1522335298574852103     1.0
# 1522335308712497153     2.0
# 1522335315381395456     2.0
# Name: time_since_last_tweet, Length: 386457, dtype: float64

# %%
tudf[tudf['time_since_last_tweet'] < 30]['time_since_last_tweet'].hist(bins = range(31), log = True, figsize = (12,6))
plt.title( 'time since last tweet (s) histogram (log)' );
plt.xlabel('sec');

# %%
tudf[tudf['time_since_last_tweet'] < 30]['time_since_last_tweet'].hist(bins = range(31), log = False, figsize = (12,6))
plt.title( 'time since last tweet histogram' );
plt.xlabel('sec')
# Out:
# Text(0.5, 0, 'sec')

# %%
#play with picking out the weird times.
tudf[tudf['created_at'] > tudf.iloc[100000]['created_at']]
# Out:
#                          conversation_id reply_settings lang  \
# 1520827917109915649  1520827917109915649       everyone   ja
# 1520827920561807364  1520827920561807364       everyone   en
# 1520827921979518977  1520827921979518977       everyone   en
# 1520827932045885440  1520827932045885440       everyone   en
# 1520827951981416449  1481275686686011392       everyone   en
# ...                                  ...            ...  ...
# 1522335287988346882  1522335287988346882       everyone   en
# 1522335296007847937  1522335296007847937       everyone   en
# 1522335298574852103  1520887819216080898       everyone   en
# 1522335308712497153  1522100467987320832       everyone   de
# 1522335315381395456  1522335315381395456       everyone   en
#
#                      possibly_sensitive               source  \
# 1520827917109915649               False           Tweetlogix
# 1520827920561807364               False   Twitter for iPhone
# 1520827921979518977               False  Twitter for Android
# 1520827932045885440               False  Twitter for Android
# 1520827951981416449               False  Twitter for Android
# ...                                 ...                  ...
# 1522335287988346882               False  Twitter for Android
# 1522335296007847937               False   Twitter for iPhone
# 1522335298574852103               False  Twitter for Android
# 1522335308712497153               False   Twitter for iPhone
# 1522335315381395456               False      Twitter Web App
#
#                                                                   text  \
# 1520827917109915649  2回目で当てたかった\n\nWordle 317 3/6\n\n🟨⬜🟨⬜🟨\n🟨🟨⬜⬜🟨\n...
# 1520827920561807364       Wordle 317 4/6\n\n⬛⬛⬛🟨🟨\n⬛⬛⬛⬛⬛\n⬛🟨⬛⬛🟩\n🟩🟩🟩🟩🟩
# 1520827921979518977  Wordle (ES)  #115 3/6\n\n🟩⬜⬜⬜🟨\n🟩⬜⬜🟨⬜\n🟩🟩🟩🟩🟩\n...
# 1520827932045885440  Wordle 316 5/6\n\n⬜🟩⬜⬜⬜\n🟨🟩⬜⬜⬜\n⬜🟩🟩⬜⬜\n🟩🟩🟩⬜⬜\n...
# 1520827951981416449  Wordle 316 5/6\n\n⬛⬛⬛⬛⬛\n⬛🟩⬛⬛⬛\n⬛🟩🟨⬛⬛\n⬛🟩🟩🟨⬛\n...
# ...                                                                ...
# 1522335287988346882              Wordle 320 3/6\n\n🟩🟩⬜⬜🟨\n🟩🟩⬜🟩⬜\n🟩🟩🟩🟩🟩
# 1522335296007847937  Wordle 320 5/6\n\n⬜🟨⬜⬜🟨\n🟩⬜🟨⬜⬜\n🟩🟩⬜🟩🟩\n🟩🟩⬜🟩🟩\n...
# 1522335298574852103  Wordle (ES)  #119 6/6\n\n🟨⬜🟩⬜🟩\n⬜🟩🟩⬜🟩\n⬜🟩🟩⬜🟩\n...
# 1522335308712497153  @marcusreif Wördl 320 6/6 🔥3\n\n⬜⬜⬜🟨⬜\n🟨🟨⬜🟨⬜\n...
# 1522335315381395456       Wordle 320 4/6\n\n🟨🟨⬛⬛⬛\n⬛🟩⬛🟩🟩\n⬛🟩⬛🟩🟩\n🟩🟩🟩🟩🟩
#
#                                                    context_annotations  \
# 1520827917109915649  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1520827920561807364  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1520827921979518977  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1520827932045885440  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1520827951981416449  [{'domain': {'id': '30', 'name': 'Entities [En...
# ...                                                                ...
# 1522335287988346882  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1522335296007847937  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1522335298574852103  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1522335308712497153  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1522335315381395456  [{'domain': {'id': '30', 'name': 'Entities [En...
#
#                                author_id                created_at  \
# 1520827917109915649             15963257 2022-05-01 18:10:05+00:00
# 1520827920561807364  1324153288825032704 2022-05-01 18:10:06+00:00
# 1520827921979518977           2835373809 2022-05-01 18:10:06+00:00
# 1520827932045885440             86948703 2022-05-01 18:10:09+00:00
# 1520827951981416449             56433208 2022-05-01 18:10:14+00:00
# ...                                  ...                       ...
# 1522335287988346882  1178989169416298497 2022-05-05 21:59:50+00:00
# 1522335296007847937           3031584784 2022-05-05 21:59:52+00:00
# 1522335298574852103             48402699 2022-05-05 21:59:53+00:00
# 1522335308712497153   729318582937657344 2022-05-05 21:59:55+00:00
# 1522335315381395456             21729445 2022-05-05 21:59:57+00:00
#
#                                                      referenced_tweets  \
# 1520827917109915649                                                 []
# 1520827920561807364                                                 []
# 1520827921979518977                                                 []
# 1520827932045885440                                                 []
# 1520827951981416449  [{'type': 'replied_to', 'id': '152026240988945...
# ...                                                                ...
# 1522335287988346882                                                 []
# 1522335296007847937                                                 []
# 1522335298574852103  [{'type': 'replied_to', 'id': '152198222645134...
# 1522335308712497153  [{'type': 'replied_to', 'id': '152210046798732...
# 1522335315381395456                                                 []
#
#                      in_reply_to_user_id attachments geo withheld_tweet  \
# 1520827917109915649                  0.0          {}  {}             {}
# 1520827920561807364                  0.0          {}  {}             {}
# 1520827921979518977                  0.0          {}  {}             {}
# 1520827932045885440                  0.0          {}  {}             {}
# 1520827951981416449           56433208.0          {}  {}             {}
# ...                                  ...         ...  ..            ...
# 1522335287988346882                  0.0          {}  {}             {}
# 1522335296007847937                  0.0          {}  {}             {}
# 1522335298574852103           48402699.0          {}  {}             {}
# 1522335308712497153           14656612.0          {}  {}             {}
# 1522335315381395456                  0.0          {}  {}             {}
#
#                                         name  \
# 1520827917109915649                      にゃい
# 1520827920561807364            mistressfoxy🦊
# 1520827921979518977  G҈ a҈ b҈ y҈ G҈ a҈ b҈ y҈
# 1520827932045885440                Vintage10
# 1520827951981416449                    Keyye
# ...                                      ...
# 1522335287988346882                        0
# 1522335296007847937                  Jaki Mc
# 1522335298574852103                       H.
# 1522335308712497153       Harald Ackerschott
# 1522335315381395456                  Barry 
#
#                                                    public_metrics_user  \
# 1520827917109915649  {'followers_count': 925, 'following_count': 87...
# 1520827920561807364  {'followers_count': 2532, 'following_count': 9...
# 1520827921979518977  {'followers_count': 421, 'following_count': 36...
# 1520827932045885440  {'followers_count': 50, 'following_count': 393...
# 1520827951981416449  {'followers_count': 91, 'following_count': 90,...
# ...                                                                ...
# 1522335287988346882                                                  0
# 1522335296007847937  {'followers_count': 11, 'following_count': 27,...
# 1522335298574852103  {'followers_count': 9214, 'following_count': 9...
# 1522335308712497153  {'followers_count': 282, 'following_count': 10...
# 1522335315381395456  {'followers_count': 217, 'following_count': 16...
#
#                                          url  \
# 1520827917109915649  https://t.co/qJaHtOp5Oy
# 1520827920561807364
# 1520827921979518977
# 1520827932045885440
# 1520827951981416449
# ...                                      ...
# 1522335287988346882                        0
# 1522335296007847937
# 1522335298574852103  https://t.co/UmOidW23FT
# 1522335308712497153  https://t.co/SZbjKWVCSi
# 1522335315381395456
#
#                                                            description  \
# 1520827917109915649  コスメと文具と攻殻に反応します。 基本は体調不良です。 気づけばあのチビッコもなんと13歳。...
# 1520827920561807364  FEMDOM | FINDOM | Sissification sane, safe & c...
# 1520827921979518977  Adoro el invierno ☃ ❄️\r\n⚖️La diplomacia, te ...
# 1520827932045885440  Indian, Rationalist, Atheist\r\nLoves History ...
# 1520827951981416449  I must confess I was drawn to the ocean.  I th...
# ...                                                                ...
# 1522335287988346882                                                  0
# 1522335296007847937  Daughter, sister, wife, mother, and friend! Lo...
# 1522335298574852103  Si soy el eco y no el grito, no soy real. \r\n...
# 1522335308712497153  came here to follow @bhorsetrials, found @MFra...
# 1522335315381395456  Retired fruit sales manager.  Sports car fanat...
#
#                                                      profile_image_url  \
# 1520827917109915649  https://pbs.twimg.com/profile_images/124500815...
# 1520827920561807364  https://pbs.twimg.com/profile_images/134970088...
# 1520827921979518977  https://pbs.twimg.com/profile_images/152181345...
# 1520827932045885440  https://pbs.twimg.com/profile_images/116241151...
# 1520827951981416449  https://pbs.twimg.com/profile_images/347806925...
# ...                                                                ...
# 1522335287988346882                                                  0
# 1522335296007847937  https://pbs.twimg.com/profile_images/847574313...
# 1522335298574852103  https://pbs.twimg.com/profile_images/147770084...
# 1522335308712497153  https://pbs.twimg.com/profile_images/117420698...
# 1522335315381395456  https://pbs.twimg.com/profile_images/82081217/...
#
#                                 location protected        username verified  \
# 1520827917109915649                          False          nyaism    False
# 1520827920561807364                          False   mistressfoxy1    False
# 1520827921979518977  Merlo, Buenos Aires     False       gabyizq07    False
# 1520827932045885440          Maharashtra     False        VinayT10    False
# 1520827951981416449            The Ocean     False           keyye    False
# ...                                  ...       ...             ...      ...
# 1522335287988346882                    0         0               0        0
# 1522335296007847937        United States     False       jaki_mc99    False
# 1522335298574852103   Medellín, Colombia     False         _Sileno    False
# 1522335308712497153          Deutschland     False  Ha_Ackerschott    False
# 1522335315381395456                SoFla     False          iBaz66    False
#
#                                                          entities_user  \
# 1520827917109915649  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1520827920561807364                                                 {}
# 1520827921979518977                                                 {}
# 1520827932045885440                                                 {}
# 1520827951981416449                                                 {}
# ...                                                                ...
# 1522335287988346882                                                  0
# 1522335296007847937                                                 {}
# 1522335298574852103  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1522335308712497153  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1522335315381395456                                                 {}
#
#                      pinned_tweet_id withheld_user  \
# 1520827917109915649     0.000000e+00            {}
# 1520827920561807364     1.479133e+18            {}
# 1520827921979518977     0.000000e+00            {}
# 1520827932045885440     0.000000e+00            {}
# 1520827951981416449     0.000000e+00            {}
# ...                              ...           ...
# 1522335287988346882     0.000000e+00             0
# 1522335296007847937     0.000000e+00            {}
# 1522335298574852103     1.520888e+18            {}
# 1522335308712497153     1.146357e+18            {}
# 1522335315381395456     0.000000e+00            {}
#
#                                                     entities_tweeturls  \
# 1520827917109915649                                                NaN
# 1520827920561807364                                                NaN
# 1520827921979518977  [{'start': 42, 'end': 65, 'url': 'https://t.co...
# 1520827932045885440                                                NaN
# 1520827951981416449                                                NaN
# ...                                                                ...
# 1522335287988346882                                                NaN
# 1522335296007847937                                                NaN
# 1522335298574852103  [{'start': 60, 'end': 83, 'url': 'https://t.co...
# 1522335308712497153  [{'start': 67, 'end': 90, 'url': 'https://t.co...
# 1522335315381395456                                                NaN
#
#                                                 entities_tweetmentions  \
# 1520827917109915649                                                NaN
# 1520827920561807364                                                NaN
# 1520827921979518977                                                NaN
# 1520827932045885440                                                NaN
# 1520827951981416449                                                NaN
# ...                                                                ...
# 1522335287988346882                                                NaN
# 1522335296007847937                                                NaN
# 1522335298574852103                                                NaN
# 1522335308712497153  [{'start': 0, 'end': 11, 'username': 'marcusre...
# 1522335315381395456                                                NaN
#
#                     entities_tweethashtags entities_tweetannotations  \
# 1520827917109915649                    NaN                       NaN
# 1520827920561807364                    NaN                       NaN
# 1520827921979518977                    NaN                       NaN
# 1520827932045885440                    NaN                       NaN
# 1520827951981416449                    NaN                       NaN
# ...                                    ...                       ...
# 1522335287988346882                    NaN                       NaN
# 1522335296007847937                    NaN                       NaN
# 1522335298574852103                    NaN                       NaN
# 1522335308712497153                    NaN                       NaN
# 1522335315381395456                    NaN                       NaN
#
#                     entities_tweetcashtags  public_metrics_tweetretweet_count  \
# 1520827917109915649                    NaN                                  0
# 1520827920561807364                    NaN                                  0
# 1520827921979518977                    NaN                                  0
# 1520827932045885440                    NaN                                  0
# 1520827951981416449                    NaN                                  0
# ...                                    ...                                ...
# 1522335287988346882                    NaN                                  0
# 1522335296007847937                    NaN                                  0
# 1522335298574852103                    NaN                                  0
# 1522335308712497153                    NaN                                  0
# 1522335315381395456                    NaN                                  0
#
#                      public_metrics_tweetreply_count  \
# 1520827917109915649                                0
# 1520827920561807364                                0
# 1520827921979518977                                0
# 1520827932045885440                                0
# 1520827951981416449                                1
# ...                                              ...
# 1522335287988346882                                0
# 1522335296007847937                                0
# 1522335298574852103                                1
# 1522335308712497153                                0
# 1522335315381395456                                0
#
#                      public_metrics_tweetlike_count  \
# 1520827917109915649                               0
# 1520827920561807364                               0
# 1520827921979518977                               0
# 1520827932045885440                               0
# 1520827951981416449                               0
# ...                                             ...
# 1522335287988346882                               4
# 1522335296007847937                               0
# 1522335298574852103                               0
# 1522335308712497153                               1
# 1522335315381395456                               0
#
#                      public_metrics_tweetquote_count  \
# 1520827917109915649                                0
# 1520827920561807364                                0
# 1520827921979518977                                0
# 1520827932045885440                                0
# 1520827951981416449                                0
# ...                                              ...
# 1522335287988346882                                0
# 1522335296007847937                                0
# 1522335298574852103                                0
# 1522335308712497153                                0
# 1522335315381395456                                0
#
#                                           game    win  is_poke  \
# 1520827917109915649            101011100122222   True    False
# 1520827920561807364       00011000000100222222   True    False
# 1520827921979518977            200012001022222   True    False
# 1520827932045885440  0200012000022002220022222   True    False
# 1520827951981416449  0000002000021000221022222   True    False
# ...                                        ...    ...      ...
# 1522335287988346882                        NaN  False    False
# 1522335296007847937                        NaN  False    False
# 1522335298574852103                        NaN  False    False
# 1522335308712497153                        NaN  False    False
# 1522335315381395456                        NaN  False    False
#
#                      user_has_description  wordle_tweet_number  ones  \
# 1520827917109915649                  True               100001   1.0
# 1520827920561807364                  True               100002   1.0
# 1520827921979518977                  True               100003   1.0
# 1520827932045885440                  True               100004   1.0
# 1520827951981416449                  True               100005   1.0
# ...                                   ...                  ...   ...
# 1522335287988346882                 False               386452   1.0
# 1522335296007847937                  True               386453   1.0
# 1522335298574852103                  True               386454   1.0
# 1522335308712497153                  True               386455   1.0
# 1522335315381395456                  True               386456   1.0
#
#                      time_since_last_tweet  wordle_tweet_rate
# 1520827917109915649                    1.0           1.000000
# 1520827920561807364                    1.0           1.000000
# 1520827921979518977                    0.0                inf
# 1520827932045885440                    3.0           0.333333
# 1520827951981416449                    5.0           0.200000
# ...                                    ...                ...
# 1522335287988346882                    7.0           0.142857
# 1522335296007847937                    2.0           0.500000
# 1522335298574852103                    1.0           1.000000
# 1522335308712497153                    2.0           0.500000
# 1522335315381395456                    2.0           0.500000
#
# [286456 rows x 43 columns]

# %%
plt.figure(figsize = (12,6))

tudf.plot('created_at','wordle_tweet_rate');

# %%
tudf[tudf['created_at'] > tudf.iloc[160000]['created_at']].plot('created_at', 'wordle_tweet_rate', figsize = (12,12), ylim=(0,2));

# %%
tudf['created_at'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ~~What happened in there? why are there so few tweets in those spans? The end of 5-04 I believe is simply a time of no gathered tweets. The time at the afternoon of 5-03 into morning of 5-04 still has values, just much lower. Could I have adding in extra copies of a tweet, dropping this rate to zero? Why is it capping at 1? Is this a /0 problem?~~
#
# Tweets from late 5/03 to early 5/04.

# %%
tudf
# Out:
#                          conversation_id reply_settings lang  \
# 1520127509051944961  1520127509051944961       everyone   en
# 1520127524377972737  1520127524377972737       everyone   en
# 1520127566845149185  1520127566845149185       everyone   ja
# 1520127576676704256  1520127576676704256       everyone   en
# 1520127578593726464  1520127578593726464       everyone   ja
# ...                                  ...            ...  ...
# 1522335287988346882  1522335287988346882       everyone   en
# 1522335296007847937  1522335296007847937       everyone   en
# 1522335298574852103  1520887819216080898       everyone   en
# 1522335308712497153  1522100467987320832       everyone   de
# 1522335315381395456  1522335315381395456       everyone   en
#
#                      possibly_sensitive               source  \
# 1520127509051944961               False      Twitter Web App
# 1520127524377972737               False   Twitter for iPhone
# 1520127566845149185               False      Twitter Web App
# 1520127576676704256               False   Twitter for iPhone
# 1520127578593726464               False   Twitter for iPhone
# ...                                 ...                  ...
# 1522335287988346882               False  Twitter for Android
# 1522335296007847937               False   Twitter for iPhone
# 1522335298574852103               False  Twitter for Android
# 1522335308712497153               False   Twitter for iPhone
# 1522335315381395456               False      Twitter Web App
#
#                                                                   text  \
# 1520127509051944961       Wordle 314 4/6\n\n🟩⬛🟩🟨🟨\n🟩🟩🟩⬛🟨\n🟩🟩🟩🟩⬛\n🟩🟩🟩🟩🟩
# 1520127524377972737           😈💅😈💅😈💅\n\nWordle 314 2/6\n\n🟩⬛🟩🟨🟨\n🟩🟩🟩🟩🟩
# 1520127566845149185  Wordle 315 4/6\n\n⬜⬜🟨⬜⬜\n⬜⬜⬜🟨⬜\n⬜⬜⬜⬜⬜\n🟩🟩🟩🟩🟩\n...
# 1520127576676704256  this is the best I've done so far \n\nWordle 3...
# 1520127578593726464  最近はめっきり知らない単語ばっかり。\n\nWordle 315 5/6\n\n⬛⬛⬛🟨⬛\...
# ...                                                                ...
# 1522335287988346882              Wordle 320 3/6\n\n🟩🟩⬜⬜🟨\n🟩🟩⬜🟩⬜\n🟩🟩🟩🟩🟩
# 1522335296007847937  Wordle 320 5/6\n\n⬜🟨⬜⬜🟨\n🟩⬜🟨⬜⬜\n🟩🟩⬜🟩🟩\n🟩🟩⬜🟩🟩\n...
# 1522335298574852103  Wordle (ES)  #119 6/6\n\n🟨⬜🟩⬜🟩\n⬜🟩🟩⬜🟩\n⬜🟩🟩⬜🟩\n...
# 1522335308712497153  @marcusreif Wördl 320 6/6 🔥3\n\n⬜⬜⬜🟨⬜\n🟨🟨⬜🟨⬜\n...
# 1522335315381395456       Wordle 320 4/6\n\n🟨🟨⬛⬛⬛\n⬛🟩⬛🟩🟩\n⬛🟩⬛🟩🟩\n🟩🟩🟩🟩🟩
#
#                                                    context_annotations  \
# 1520127509051944961  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1520127524377972737  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1520127566845149185  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1520127576676704256  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1520127578593726464  [{'domain': {'id': '30', 'name': 'Entities [En...
# ...                                                                ...
# 1522335287988346882  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1522335296007847937  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1522335298574852103  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1522335308712497153  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1522335315381395456  [{'domain': {'id': '30', 'name': 'Entities [En...
#
#                                author_id                created_at  \
# 1520127509051944961            489622686 2022-04-29 19:46:55+00:00
# 1520127524377972737             25239815 2022-04-29 19:46:59+00:00
# 1520127566845149185            176229015 2022-04-29 19:47:09+00:00
# 1520127576676704256  1471956208181514243 2022-04-29 19:47:11+00:00
# 1520127578593726464  1220315666508464130 2022-04-29 19:47:11+00:00
# ...                                  ...                       ...
# 1522335287988346882  1178989169416298497 2022-05-05 21:59:50+00:00
# 1522335296007847937           3031584784 2022-05-05 21:59:52+00:00
# 1522335298574852103             48402699 2022-05-05 21:59:53+00:00
# 1522335308712497153   729318582937657344 2022-05-05 21:59:55+00:00
# 1522335315381395456             21729445 2022-05-05 21:59:57+00:00
#
#                                                      referenced_tweets  \
# 1520127509051944961                                                 []
# 1520127524377972737                                                 []
# 1520127566845149185                                                 []
# 1520127576676704256                                                 []
# 1520127578593726464                                                 []
# ...                                                                ...
# 1522335287988346882                                                 []
# 1522335296007847937                                                 []
# 1522335298574852103  [{'type': 'replied_to', 'id': '152198222645134...
# 1522335308712497153  [{'type': 'replied_to', 'id': '152210046798732...
# 1522335315381395456                                                 []
#
#                      in_reply_to_user_id attachments geo withheld_tweet  \
# 1520127509051944961                  0.0          {}  {}             {}
# 1520127524377972737                  0.0          {}  {}             {}
# 1520127566845149185                  0.0          {}  {}             {}
# 1520127576676704256                  0.0          {}  {}             {}
# 1520127578593726464                  0.0          {}  {}             {}
# ...                                  ...         ...  ..            ...
# 1522335287988346882                  0.0          {}  {}             {}
# 1522335296007847937                  0.0          {}  {}             {}
# 1522335298574852103           48402699.0          {}  {}             {}
# 1522335308712497153           14656612.0          {}  {}             {}
# 1522335315381395456                  0.0          {}  {}             {}
#
#                                                name  \
# 1520127509051944961                  ♔･ﾟ✧Lᴏɢɢʏ･ﾟ✧ ♔
# 1520127524377972737  Carly Garza | Commissions Open
# 1520127566845149185                            折笠美冬
# 1520127576676704256                               0
# 1520127578593726464                               0
# ...                                             ...
# 1522335287988346882                               0
# 1522335296007847937                         Jaki Mc
# 1522335298574852103                              H.
# 1522335308712497153              Harald Ackerschott
# 1522335315381395456                         Barry 
#
#                                                    public_metrics_user  \
# 1520127509051944961  {'followers_count': 9322, 'following_count': 1...
# 1520127524377972737  {'followers_count': 714, 'following_count': 95...
# 1520127566845149185  {'followers_count': 94, 'following_count': 253...
# 1520127576676704256                                                  0
# 1520127578593726464                                                  0
# ...                                                                ...
# 1522335287988346882                                                  0
# 1522335296007847937  {'followers_count': 11, 'following_count': 27,...
# 1522335298574852103  {'followers_count': 9214, 'following_count': 9...
# 1522335308712497153  {'followers_count': 282, 'following_count': 10...
# 1522335315381395456  {'followers_count': 217, 'following_count': 16...
#
#                                          url  \
# 1520127509051944961
# 1520127524377972737  https://t.co/OqVqYWdqMx
# 1520127566845149185
# 1520127576676704256                        0
# 1520127578593726464                        0
# ...                                      ...
# 1522335287988346882                        0
# 1522335296007847937
# 1522335298574852103  https://t.co/UmOidW23FT
# 1522335308712497153  https://t.co/SZbjKWVCSi
# 1522335315381395456
#
#                                                            description  \
# 1520127509051944961  *:･ﾟ I lσνε @arianagrande , & @blackpink *:･ﾟ\...
# 1520127524377972737  she/they | queer multidisciplinary artist | Cu...
# 1520127566845149185  基本的にゲームのことばかり呟いてます。\r\n呟きの内容に画像レスを含むことがあるので、不快...
# 1520127576676704256                                                  0
# 1520127578593726464                                                  0
# ...                                                                ...
# 1522335287988346882                                                  0
# 1522335296007847937  Daughter, sister, wife, mother, and friend! Lo...
# 1522335298574852103  Si soy el eco y no el grito, no soy real. \r\n...
# 1522335308712497153  came here to follow @bhorsetrials, found @MFra...
# 1522335315381395456  Retired fruit sales manager.  Sports car fanat...
#
#                                                      profile_image_url  \
# 1520127509051944961  https://pbs.twimg.com/profile_images/148007682...
# 1520127524377972737  https://pbs.twimg.com/profile_images/145323946...
# 1520127566845149185  https://pbs.twimg.com/profile_images/122182835...
# 1520127576676704256                                                  0
# 1520127578593726464                                                  0
# ...                                                                ...
# 1522335287988346882                                                  0
# 1522335296007847937  https://pbs.twimg.com/profile_images/847574313...
# 1522335298574852103  https://pbs.twimg.com/profile_images/147770084...
# 1522335308712497153  https://pbs.twimg.com/profile_images/117420698...
# 1522335315381395456  https://pbs.twimg.com/profile_images/82081217/...
#
#                                  location protected        username verified  \
# 1520127509051944961  vote lisa and rose😃🤗     False         loggyf2    False
# 1520127524377972737            Texas, USA     False     carlyagarza    False
# 1520127566845149185               まいづるちほー     False        orichan5    False
# 1520127576676704256                     0         0               0        0
# 1520127578593726464                     0         0               0        0
# ...                                   ...       ...             ...      ...
# 1522335287988346882                     0         0               0        0
# 1522335296007847937         United States     False       jaki_mc99    False
# 1522335298574852103    Medellín, Colombia     False         _Sileno    False
# 1522335308712497153           Deutschland     False  Ha_Ackerschott    False
# 1522335315381395456                 SoFla     False          iBaz66    False
#
#                                                          entities_user  \
# 1520127509051944961  {'description': {'mentions': [{'start': 12, 'e...
# 1520127524377972737  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1520127566845149185                                                 {}
# 1520127576676704256                                                  0
# 1520127578593726464                                                  0
# ...                                                                ...
# 1522335287988346882                                                  0
# 1522335296007847937                                                 {}
# 1522335298574852103  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1522335308712497153  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1522335315381395456                                                 {}
#
#                      pinned_tweet_id withheld_user  \
# 1520127509051944961     6.956076e+17            {}
# 1520127524377972737     1.468007e+18            {}
# 1520127566845149185     0.000000e+00            {}
# 1520127576676704256     0.000000e+00             0
# 1520127578593726464     0.000000e+00             0
# ...                              ...           ...
# 1522335287988346882     0.000000e+00             0
# 1522335296007847937     0.000000e+00            {}
# 1522335298574852103     1.520888e+18            {}
# 1522335308712497153     1.146357e+18            {}
# 1522335315381395456     0.000000e+00            {}
#
#                                                     entities_tweeturls  \
# 1520127509051944961                                                NaN
# 1520127524377972737                                                NaN
# 1520127566845149185                                                NaN
# 1520127576676704256                                                NaN
# 1520127578593726464                                                NaN
# ...                                                                ...
# 1522335287988346882                                                NaN
# 1522335296007847937                                                NaN
# 1522335298574852103  [{'start': 60, 'end': 83, 'url': 'https://t.co...
# 1522335308712497153  [{'start': 67, 'end': 90, 'url': 'https://t.co...
# 1522335315381395456                                                NaN
#
#                                                 entities_tweetmentions  \
# 1520127509051944961                                                NaN
# 1520127524377972737                                                NaN
# 1520127566845149185                                                NaN
# 1520127576676704256                                                NaN
# 1520127578593726464                                                NaN
# ...                                                                ...
# 1522335287988346882                                                NaN
# 1522335296007847937                                                NaN
# 1522335298574852103                                                NaN
# 1522335308712497153  [{'start': 0, 'end': 11, 'username': 'marcusre...
# 1522335315381395456                                                NaN
#
#                     entities_tweethashtags entities_tweetannotations  \
# 1520127509051944961                    NaN                       NaN
# 1520127524377972737                    NaN                       NaN
# 1520127566845149185                    NaN                       NaN
# 1520127576676704256                    NaN                       NaN
# 1520127578593726464                    NaN                       NaN
# ...                                    ...                       ...
# 1522335287988346882                    NaN                       NaN
# 1522335296007847937                    NaN                       NaN
# 1522335298574852103                    NaN                       NaN
# 1522335308712497153                    NaN                       NaN
# 1522335315381395456                    NaN                       NaN
#
#                     entities_tweetcashtags  public_metrics_tweetretweet_count  \
# 1520127509051944961                    NaN                                  0
# 1520127524377972737                    NaN                                  0
# 1520127566845149185                    NaN                                  0
# 1520127576676704256                    NaN                                  0
# 1520127578593726464                    NaN                                  0
# ...                                    ...                                ...
# 1522335287988346882                    NaN                                  0
# 1522335296007847937                    NaN                                  0
# 1522335298574852103                    NaN                                  0
# 1522335308712497153                    NaN                                  0
# 1522335315381395456                    NaN                                  0
#
#                      public_metrics_tweetreply_count  \
# 1520127509051944961                                0
# 1520127524377972737                                1
# 1520127566845149185                                0
# 1520127576676704256                                0
# 1520127578593726464                                0
# ...                                              ...
# 1522335287988346882                                0
# 1522335296007847937                                0
# 1522335298574852103                                1
# 1522335308712497153                                0
# 1522335315381395456                                0
#
#                      public_metrics_tweetlike_count  \
# 1520127509051944961                               2
# 1520127524377972737                               2
# 1520127566845149185                               0
# 1520127576676704256                               0
# 1520127578593726464                               0
# ...                                             ...
# 1522335287988346882                               4
# 1522335296007847937                               0
# 1522335298574852103                               0
# 1522335308712497153                               1
# 1522335315381395456                               0
#
#                      public_metrics_tweetquote_count game    win  is_poke  \
# 1520127509051944961                                0  NaN  False    False
# 1520127524377972737                                0  NaN  False    False
# 1520127566845149185                                0  NaN  False    False
# 1520127576676704256                                0  NaN  False    False
# 1520127578593726464                                0  NaN  False    False
# ...                                              ...  ...    ...      ...
# 1522335287988346882                                0  NaN  False    False
# 1522335296007847937                                0  NaN  False    False
# 1522335298574852103                                0  NaN  False    False
# 1522335308712497153                                0  NaN  False    False
# 1522335315381395456                                0  NaN  False    False
#
#                      user_has_description  wordle_tweet_number  ones  \
# 1520127509051944961                  True                    0   1.0
# 1520127524377972737                  True                    1   1.0
# 1520127566845149185                  True                    2   1.0
# 1520127576676704256                 False                    3   1.0
# 1520127578593726464                 False                    4   1.0
# ...                                   ...                  ...   ...
# 1522335287988346882                 False               386452   1.0
# 1522335296007847937                  True               386453   1.0
# 1522335298574852103                  True               386454   1.0
# 1522335308712497153                  True               386455   1.0
# 1522335315381395456                  True               386456   1.0
#
#                      time_since_last_tweet  wordle_tweet_rate
# 1520127509051944961                    NaN                NaN
# 1520127524377972737                    4.0           0.250000
# 1520127566845149185                   10.0           0.100000
# 1520127576676704256                    2.0           0.500000
# 1520127578593726464                    0.0                inf
# ...                                    ...                ...
# 1522335287988346882                    7.0           0.142857
# 1522335296007847937                    2.0           0.500000
# 1522335298574852103                    1.0           1.000000
# 1522335308712497153                    2.0           0.500000
# 1522335315381395456                    2.0           0.500000
#
# [386457 rows x 43 columns]

# %%
#rough times between tweets. rolling average of 60.
# since tweets aren't evenly spaced, more of the width of this plot applies to longer times between.
# but given slowly changing tweet rates, it's a good measure.
tudf['time_since_last_tweet_rolling_60'] = tudf['time_since_last_tweet'].rolling(60).mean()

# %%
#plot times between all tweets
plt.figure(figsize = (16,8))
plt.plot(tudf['created_at'], tudf['time_since_last_tweet_rolling_60'])
plt.xlabel('date (UTC)')
plt.ylabel('time since last tweet (s)')
plt.title('Time since last tweet (rolling average of 60)');

# %%
#plot times between all tweets ---- smaller y
plt.figure(figsize = (16,8))
plt.plot(tudf['created_at'], tudf['time_since_last_tweet_rolling_60'])
plt.xlabel('date (UTC)')
plt.ylabel('time since last tweet (s)')
plt.ylim(-.1,5)
plt.title('Time since last tweet (rolling average of 60)');

# %%
UTC = tz.gettz('UTC')
tudf[tudf['created_at']< datetime(2022, 5, 4, 17, 58, 0, 0, tzinfo = UTC)].sort_values(by = 'created_at', ascending = False)
# Out:
#                          conversation_id reply_settings lang  \
# 1521911830817521664  1521911830817521664       everyone   en
# 1521911829244440577  1521911829244440577       everyone   en
# 1521911819077505026  1521911819077505026       everyone   en
# 1521911810563190785  1521911810563190785       everyone   en
# 1521911808176451586  1521911808176451586       everyone   en
# ...                                  ...            ...  ...
# 1520127578593726464  1520127578593726464       everyone   ja
# 1520127576676704256  1520127576676704256       everyone   en
# 1520127566845149185  1520127566845149185       everyone   ja
# 1520127524377972737  1520127524377972737       everyone   en
# 1520127509051944961  1520127509051944961       everyone   en
#
#                      possibly_sensitive               source  \
# 1521911830817521664               False   Twitter for iPhone
# 1521911829244440577               False  Twitter for Android
# 1521911819077505026               False  Twitter for Android
# 1521911810563190785               False   Twitter for iPhone
# 1521911808176451586               False   Twitter for iPhone
# ...                                 ...                  ...
# 1520127578593726464               False   Twitter for iPhone
# 1520127576676704256               False   Twitter for iPhone
# 1520127566845149185               False      Twitter Web App
# 1520127524377972737               False   Twitter for iPhone
# 1520127509051944961               False      Twitter Web App
#
#                                                                   text  \
# 1521911830817521664  Wordle 319 3/6\r\n\r\n🟨⬛⬛⬛⬛\r\n⬛⬛🟩⬛🟨\r\n🟩🟩🟩🟩🟩a...
# 1521911829244440577  Wordle 320 4/6\r\n\r\n⬜⬜⬜⬜🟨\r\n⬜⬜⬜🟩🟩\r\n⬜🟩⬜🟩🟩\...
# 1521911819077505026      Wordle 319 3/6\r\n\r\n🟩🟨⬛⬛⬛\r\n🟩⬛🟨🟨⬛\r\n🟩🟩🟩🟩🟩
# 1521911810563190785  Wordle 319 4/6\r\n\r\n🟩⬛🟨⬛⬛\r\n🟩🟩🟩🟩⬛\r\n🟩🟩🟩🟩⬛\...
# 1521911808176451586  Wordle 320 6/6\r\n\r\n⬛⬛⬛🟩⬛\r\n⬛⬛⬛🟩⬛\r\n⬛🟩⬛🟩🟩\...
# ...                                                                ...
# 1520127578593726464  最近はめっきり知らない単語ばっかり。\n\nWordle 315 5/6\n\n⬛⬛⬛🟨⬛\...
# 1520127576676704256  this is the best I've done so far \n\nWordle 3...
# 1520127566845149185  Wordle 315 4/6\n\n⬜⬜🟨⬜⬜\n⬜⬜⬜🟨⬜\n⬜⬜⬜⬜⬜\n🟩🟩🟩🟩🟩\n...
# 1520127524377972737           😈💅😈💅😈💅\n\nWordle 314 2/6\n\n🟩⬛🟩🟨🟨\n🟩🟩🟩🟩🟩
# 1520127509051944961       Wordle 314 4/6\n\n🟩⬛🟩🟨🟨\n🟩🟩🟩⬛🟨\n🟩🟩🟩🟩⬛\n🟩🟩🟩🟩🟩
#
#                                                    context_annotations  \
# 1521911830817521664  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521911829244440577  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521911819077505026  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521911810563190785  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521911808176451586  [{'domain': {'id': '30', 'name': 'Entities [En...
# ...                                                                ...
# 1520127578593726464  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1520127576676704256  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1520127566845149185  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1520127524377972737  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1520127509051944961  [{'domain': {'id': '30', 'name': 'Entities [En...
#
#                                author_id                created_at  \
# 1521911830817521664            584425453 2022-05-04 17:57:10+00:00
# 1521911829244440577   979964880878034944 2022-05-04 17:57:10+00:00
# 1521911819077505026  1211847567614431232 2022-05-04 17:57:08+00:00
# 1521911810563190785  1484236785932808195 2022-05-04 17:57:06+00:00
# 1521911808176451586             35214039 2022-05-04 17:57:05+00:00
# ...                                  ...                       ...
# 1520127578593726464  1220315666508464130 2022-04-29 19:47:11+00:00
# 1520127576676704256  1471956208181514243 2022-04-29 19:47:11+00:00
# 1520127566845149185            176229015 2022-04-29 19:47:09+00:00
# 1520127524377972737             25239815 2022-04-29 19:46:59+00:00
# 1520127509051944961            489622686 2022-04-29 19:46:55+00:00
#
#                     referenced_tweets  in_reply_to_user_id attachments geo  \
# 1521911830817521664                []                  0.0          {}  {}
# 1521911829244440577                []                  0.0          {}  {}
# 1521911819077505026                []                  0.0          {}  {}
# 1521911810563190785                []                  0.0          {}  {}
# 1521911808176451586                []                  0.0          {}  {}
# ...                               ...                  ...         ...  ..
# 1520127578593726464                []                  0.0          {}  {}
# 1520127576676704256                []                  0.0          {}  {}
# 1520127566845149185                []                  0.0          {}  {}
# 1520127524377972737                []                  0.0          {}  {}
# 1520127509051944961                []                  0.0          {}  {}
#
#                     withheld_tweet                            name  \
# 1521911830817521664             {}                               .
# 1521911829244440577             {}                           anima
# 1521911819077505026             {}                            Wild
# 1521911810563190785             {}                               0
# 1521911808176451586             {}                    Jerico Rañin
# ...                            ...                             ...
# 1520127578593726464             {}                               0
# 1520127576676704256             {}                               0
# 1520127566845149185             {}                            折笠美冬
# 1520127524377972737             {}  Carly Garza | Commissions Open
# 1520127509051944961             {}                  ♔･ﾟ✧Lᴏɢɢʏ･ﾟ✧ ♔
#
#                                                    public_metrics_user  \
# 1521911830817521664  {'followers_count': 291, 'following_count': 26...
# 1521911829244440577  {'followers_count': 12, 'following_count': 179...
# 1521911819077505026  {'followers_count': 32, 'following_count': 80,...
# 1521911810563190785                                                  0
# 1521911808176451586  {'followers_count': 373, 'following_count': 11...
# ...                                                                ...
# 1520127578593726464                                                  0
# 1520127576676704256                                                  0
# 1520127566845149185  {'followers_count': 94, 'following_count': 253...
# 1520127524377972737  {'followers_count': 714, 'following_count': 95...
# 1520127509051944961  {'followers_count': 9322, 'following_count': 1...
#
#                                          url  \
# 1521911830817521664
# 1521911829244440577
# 1521911819077505026
# 1521911810563190785                        0
# 1521911808176451586  https://t.co/4Z4CgwFFbx
# ...                                      ...
# 1520127578593726464                        0
# 1520127576676704256                        0
# 1520127566845149185
# 1520127524377972737  https://t.co/OqVqYWdqMx
# 1520127509051944961
#
#                                                            description  \
# 1521911830817521664                                      One and done.
# 1521911829244440577
# 1521911819077505026                               LEFT is always right
# 1521911810563190785                                                  0
# 1521911808176451586
# ...                                                                ...
# 1520127578593726464                                                  0
# 1520127576676704256                                                  0
# 1520127566845149185  基本的にゲームのことばかり呟いてます。\r\n呟きの内容に画像レスを含むことがあるので、不快...
# 1520127524377972737  she/they | queer multidisciplinary artist | Cu...
# 1520127509051944961  *:･ﾟ I lσνε @arianagrande , & @blackpink *:･ﾟ\...
#
#                                                      profile_image_url  \
# 1521911830817521664  https://pbs.twimg.com/profile_images/150922502...
# 1521911829244440577  https://pbs.twimg.com/profile_images/980222581...
# 1521911819077505026  https://pbs.twimg.com/profile_images/137949129...
# 1521911810563190785                                                  0
# 1521911808176451586  https://pbs.twimg.com/profile_images/151674968...
# ...                                                                ...
# 1520127578593726464                                                  0
# 1520127576676704256                                                  0
# 1520127566845149185  https://pbs.twimg.com/profile_images/122182835...
# 1520127524377972737  https://pbs.twimg.com/profile_images/145323946...
# 1520127509051944961  https://pbs.twimg.com/profile_images/148007682...
#
#                                         location protected        username  \
# 1521911830817521664                   Dallas, TX     False   TexasHammerrr
# 1521911829244440577                                  False    imagineanima
# 1521911819077505026                                  False    Wild83206947
# 1521911810563190785                            0         0               0
# 1521911808176451586  Republic of the Philippines     False  thejericoranin
# ...                                          ...       ...             ...
# 1520127578593726464                            0         0               0
# 1520127576676704256                            0         0               0
# 1520127566845149185                      まいづるちほー     False        orichan5
# 1520127524377972737                   Texas, USA     False     carlyagarza
# 1520127509051944961         vote lisa and rose😃🤗     False         loggyf2
#
#                     verified  \
# 1521911830817521664    False
# 1521911829244440577    False
# 1521911819077505026    False
# 1521911810563190785        0
# 1521911808176451586    False
# ...                      ...
# 1520127578593726464        0
# 1520127576676704256        0
# 1520127566845149185    False
# 1520127524377972737    False
# 1520127509051944961    False
#
#                                                          entities_user  \
# 1521911830817521664                                                 {}
# 1521911829244440577                                                 {}
# 1521911819077505026                                                 {}
# 1521911810563190785                                                  0
# 1521911808176451586  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# ...                                                                ...
# 1520127578593726464                                                  0
# 1520127576676704256                                                  0
# 1520127566845149185                                                 {}
# 1520127524377972737  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1520127509051944961  {'description': {'mentions': [{'start': 12, 'e...
#
#                      pinned_tweet_id withheld_user entities_tweeturls  \
# 1521911830817521664     1.490016e+18            {}                NaN
# 1521911829244440577     0.000000e+00            {}                NaN
# 1521911819077505026     0.000000e+00            {}                NaN
# 1521911810563190785     0.000000e+00             0                NaN
# 1521911808176451586     0.000000e+00            {}                NaN
# ...                              ...           ...                ...
# 1520127578593726464     0.000000e+00             0                NaN
# 1520127576676704256     0.000000e+00             0                NaN
# 1520127566845149185     0.000000e+00            {}                NaN
# 1520127524377972737     1.468007e+18            {}                NaN
# 1520127509051944961     6.956076e+17            {}                NaN
#
#                     entities_tweetmentions entities_tweethashtags  \
# 1521911830817521664                    NaN                    NaN
# 1521911829244440577                    NaN                    NaN
# 1521911819077505026                    NaN                    NaN
# 1521911810563190785                    NaN                    NaN
# 1521911808176451586                    NaN                    NaN
# ...                                    ...                    ...
# 1520127578593726464                    NaN                    NaN
# 1520127576676704256                    NaN                    NaN
# 1520127566845149185                    NaN                    NaN
# 1520127524377972737                    NaN                    NaN
# 1520127509051944961                    NaN                    NaN
#
#                     entities_tweetannotations entities_tweetcashtags  \
# 1521911830817521664                       NaN                    NaN
# 1521911829244440577                       NaN                    NaN
# 1521911819077505026                       NaN                    NaN
# 1521911810563190785                       NaN                    NaN
# 1521911808176451586                       NaN                    NaN
# ...                                       ...                    ...
# 1520127578593726464                       NaN                    NaN
# 1520127576676704256                       NaN                    NaN
# 1520127566845149185                       NaN                    NaN
# 1520127524377972737                       NaN                    NaN
# 1520127509051944961                       NaN                    NaN
#
#                      public_metrics_tweetretweet_count  \
# 1521911830817521664                                  0
# 1521911829244440577                                  0
# 1521911819077505026                                  0
# 1521911810563190785                                  0
# 1521911808176451586                                  0
# ...                                                ...
# 1520127578593726464                                  0
# 1520127576676704256                                  0
# 1520127566845149185                                  0
# 1520127524377972737                                  0
# 1520127509051944961                                  0
#
#                      public_metrics_tweetreply_count  \
# 1521911830817521664                                0
# 1521911829244440577                                0
# 1521911819077505026                                0
# 1521911810563190785                                0
# 1521911808176451586                                0
# ...                                              ...
# 1520127578593726464                                0
# 1520127576676704256                                0
# 1520127566845149185                                0
# 1520127524377972737                                1
# 1520127509051944961                                0
#
#                      public_metrics_tweetlike_count  \
# 1521911830817521664                               0
# 1521911829244440577                               0
# 1521911819077505026                               0
# 1521911810563190785                               0
# 1521911808176451586                               0
# ...                                             ...
# 1520127578593726464                               0
# 1520127576676704256                               0
# 1520127566845149185                               0
# 1520127524377972737                               2
# 1520127509051944961                               2
#
#                      public_metrics_tweetquote_count  \
# 1521911830817521664                                0
# 1521911829244440577                                0
# 1521911819077505026                                0
# 1521911810563190785                                0
# 1521911808176451586                                0
# ...                                              ...
# 1520127578593726464                                0
# 1520127576676704256                                0
# 1520127566845149185                                0
# 1520127524377972737                                0
# 1520127509051944961                                0
#
#                                                game    win  is_poke  \
# 1521911830817521664                 100000020122222   True    False
# 1521911829244440577            00001000220202222222   True    False
# 1521911819077505026                 210002011022222   True    False
# 1521911810563190785            20100222202222022222   True    False
# 1521911808176451586  000200002002022020220202222222   True    False
# ...                                             ...    ...      ...
# 1520127578593726464                             NaN  False    False
# 1520127576676704256                             NaN  False    False
# 1520127566845149185                             NaN  False    False
# 1520127524377972737                             NaN  False    False
# 1520127509051944961                             NaN  False    False
#
#                      user_has_description  wordle_tweet_number  ones  \
# 1521911830817521664                  True               322779   1.0
# 1521911829244440577                  True               322780   1.0
# 1521911819077505026                  True               322778   1.0
# 1521911810563190785                 False               322777   1.0
# 1521911808176451586                  True               322776   1.0
# ...                                   ...                  ...   ...
# 1520127578593726464                 False                    4   1.0
# 1520127576676704256                 False                    3   1.0
# 1520127566845149185                  True                    2   1.0
# 1520127524377972737                  True                    1   1.0
# 1520127509051944961                  True                    0   1.0
#
#                      time_since_last_tweet  wordle_tweet_rate  \
# 1521911830817521664                    0.0                inf
# 1521911829244440577                    2.0               0.50
# 1521911819077505026                    2.0               0.50
# 1521911810563190785                    1.0               1.00
# 1521911808176451586                    1.0               1.00
# ...                                    ...                ...
# 1520127578593726464                    0.0                inf
# 1520127576676704256                    2.0               0.50
# 1520127566845149185                   10.0               0.10
# 1520127524377972737                    4.0               0.25
# 1520127509051944961                    NaN                NaN
#
#                      time_since_last_tweet_rolling_60
# 1521911830817521664                          2.850000
# 1521911829244440577                          2.850000
# 1521911819077505026                          2.816667
# 1521911810563190785                          2.800000
# 1521911808176451586                          2.816667
# ...                                               ...
# 1520127578593726464                               NaN
# 1520127576676704256                               NaN
# 1520127566845149185                               NaN
# 1520127524377972737                               NaN
# 1520127509051944961                               NaN
#
# [322781 rows x 44 columns]

# %%
tudf[tudf['created_at']> datetime(2022, 5, 4, 23,26, 0 ,0, tzinfo =UTC)]
# Out:
#                          conversation_id reply_settings lang  \
# 1521994876677672966  1521994876677672966       everyone   en
# 1521994883032039424  1521994883032039424       everyone   en
# 1521994886941413376  1521994886941413376       everyone   en
# 1521994898974588929  1521994898974588929       everyone   en
# 1521994904523706368  1521994904523706368       everyone   en
# ...                                  ...            ...  ...
# 1522335287988346882  1522335287988346882       everyone   en
# 1522335296007847937  1522335296007847937       everyone   en
# 1522335298574852103  1520887819216080898       everyone   en
# 1522335308712497153  1522100467987320832       everyone   de
# 1522335315381395456  1522335315381395456       everyone   en
#
#                      possibly_sensitive               source  \
# 1521994876677672966               False  Twitter for Android
# 1521994883032039424               False   Twitter for iPhone
# 1521994886941413376               False  Twitter for Android
# 1521994898974588929               False            TweetDeck
# 1521994904523706368               False   Twitter for iPhone
# ...                                 ...                  ...
# 1522335287988346882               False  Twitter for Android
# 1522335296007847937               False   Twitter for iPhone
# 1522335298574852103               False  Twitter for Android
# 1522335308712497153               False   Twitter for iPhone
# 1522335315381395456               False      Twitter Web App
#
#                                                                   text  \
# 1521994876677672966                     Wordle 320 2/6\n\n⬜🟨⬜🟩⬜\n🟩🟩🟩🟩🟩
# 1521994883032039424  Wordle 320 6/6\n\n⬜⬜⬜🟩⬜\n⬜🟨⬜🟩⬜\n⬜🟨🟨🟩⬜\n🟩🟩⬜🟩🟩\n...
# 1521994886941413376       Wordle 320 4/6\n\n🟨⬛🟨⬛⬛\n⬛⬛🟨🟨🟨\n⬛🟩⬛🟩🟩\n🟩🟩🟩🟩🟩
# 1521994898974588929  properly rubbish\n\nWordle 320 X/6*\n\n⬛🟨⬛🟩⬛\n...
# 1521994904523706368  Wordle 320 5/6\n\n⬛🟨🟨⬛⬛\n🟨🟨⬛⬛⬛\n⬛⬛⬛🟨🟩\n⬛🟩⬛🟩🟩\n...
# ...                                                                ...
# 1522335287988346882              Wordle 320 3/6\n\n🟩🟩⬜⬜🟨\n🟩🟩⬜🟩⬜\n🟩🟩🟩🟩🟩
# 1522335296007847937  Wordle 320 5/6\n\n⬜🟨⬜⬜🟨\n🟩⬜🟨⬜⬜\n🟩🟩⬜🟩🟩\n🟩🟩⬜🟩🟩\n...
# 1522335298574852103  Wordle (ES)  #119 6/6\n\n🟨⬜🟩⬜🟩\n⬜🟩🟩⬜🟩\n⬜🟩🟩⬜🟩\n...
# 1522335308712497153  @marcusreif Wördl 320 6/6 🔥3\n\n⬜⬜⬜🟨⬜\n🟨🟨⬜🟨⬜\n...
# 1522335315381395456       Wordle 320 4/6\n\n🟨🟨⬛⬛⬛\n⬛🟩⬛🟩🟩\n⬛🟩⬛🟩🟩\n🟩🟩🟩🟩🟩
#
#                                                    context_annotations  \
# 1521994876677672966  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521994883032039424  [{'domain': {'id': '29', 'name': 'Events [Enti...
# 1521994886941413376  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521994898974588929  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1521994904523706368  [{'domain': {'id': '30', 'name': 'Entities [En...
# ...                                                                ...
# 1522335287988346882  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1522335296007847937  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1522335298574852103  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1522335308712497153  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1522335315381395456  [{'domain': {'id': '30', 'name': 'Entities [En...
#
#                                author_id                created_at  \
# 1521994876677672966            125443746 2022-05-04 23:27:10+00:00
# 1521994883032039424            592259279 2022-05-04 23:27:12+00:00
# 1521994886941413376  1348171206910873600 2022-05-04 23:27:13+00:00
# 1521994898974588929            626288465 2022-05-04 23:27:15+00:00
# 1521994904523706368            939561834 2022-05-04 23:27:17+00:00
# ...                                  ...                       ...
# 1522335287988346882  1178989169416298497 2022-05-05 21:59:50+00:00
# 1522335296007847937           3031584784 2022-05-05 21:59:52+00:00
# 1522335298574852103             48402699 2022-05-05 21:59:53+00:00
# 1522335308712497153   729318582937657344 2022-05-05 21:59:55+00:00
# 1522335315381395456             21729445 2022-05-05 21:59:57+00:00
#
#                                                      referenced_tweets  \
# 1521994876677672966                                                 []
# 1521994883032039424                                                 []
# 1521994886941413376                                                 []
# 1521994898974588929                                                 []
# 1521994904523706368                                                 []
# ...                                                                ...
# 1522335287988346882                                                 []
# 1522335296007847937                                                 []
# 1522335298574852103  [{'type': 'replied_to', 'id': '152198222645134...
# 1522335308712497153  [{'type': 'replied_to', 'id': '152210046798732...
# 1522335315381395456                                                 []
#
#                      in_reply_to_user_id attachments geo withheld_tweet  \
# 1521994876677672966                  0.0          {}  {}             {}
# 1521994883032039424                  0.0          {}  {}             {}
# 1521994886941413376                  0.0          {}  {}             {}
# 1521994898974588929                  0.0          {}  {}             {}
# 1521994904523706368                  0.0          {}  {}             {}
# ...                                  ...         ...  ..            ...
# 1522335287988346882                  0.0          {}  {}             {}
# 1522335296007847937                  0.0          {}  {}             {}
# 1522335298574852103           48402699.0          {}  {}             {}
# 1522335308712497153           14656612.0          {}  {}             {}
# 1522335315381395456                  0.0          {}  {}             {}
#
#                                    name  \
# 1521994876677672966    Martin O' Connor
# 1521994883032039424      Christian Dodd
# 1521994886941413376               Sam 😃
# 1521994898974588929             Del-4Ri
# 1521994904523706368                 amz
# ...                                 ...
# 1522335287988346882                   0
# 1522335296007847937             Jaki Mc
# 1522335298574852103                  H.
# 1522335308712497153  Harald Ackerschott
# 1522335315381395456             Barry 
#
#                                                    public_metrics_user  \
# 1521994876677672966  {'followers_count': 80, 'following_count': 221...
# 1521994883032039424  {'followers_count': 57, 'following_count': 121...
# 1521994886941413376  {'followers_count': 592, 'following_count': 12...
# 1521994898974588929  {'followers_count': 766, 'following_count': 75...
# 1521994904523706368  {'followers_count': 331, 'following_count': 32...
# ...                                                                ...
# 1522335287988346882                                                  0
# 1522335296007847937  {'followers_count': 11, 'following_count': 27,...
# 1522335298574852103  {'followers_count': 9214, 'following_count': 9...
# 1522335308712497153  {'followers_count': 282, 'following_count': 10...
# 1522335315381395456  {'followers_count': 217, 'following_count': 16...
#
#                                          url  \
# 1521994876677672966
# 1521994883032039424
# 1521994886941413376
# 1521994898974588929  https://t.co/YYTzDBaNmL
# 1521994904523706368
# ...                                      ...
# 1522335287988346882                        0
# 1522335296007847937
# 1522335298574852103  https://t.co/UmOidW23FT
# 1522335308712497153  https://t.co/SZbjKWVCSi
# 1522335315381395456
#
#                                                            description  \
# 1521994876677672966
# 1521994883032039424  Former cruise ship entertainment host. Dr Pepp...
# 1521994886941413376                      Equal is equal. \r\n\r\nEFC🖤❤
# 1521994898974588929  Mars images, science, 3D, software coding, pho...
# 1521994904523706368                                         🏴󠁧󠁢󠁳󠁣󠁴󠁿|🇲🇾
# ...                                                                ...
# 1522335287988346882                                                  0
# 1522335296007847937  Daughter, sister, wife, mother, and friend! Lo...
# 1522335298574852103  Si soy el eco y no el grito, no soy real. \r\n...
# 1522335308712497153  came here to follow @bhorsetrials, found @MFra...
# 1522335315381395456  Retired fruit sales manager.  Sports car fanat...
#
#                                                      profile_image_url  \
# 1521994876677672966  https://pbs.twimg.com/profile_images/675596289...
# 1521994883032039424  https://pbs.twimg.com/profile_images/134787990...
# 1521994886941413376  https://pbs.twimg.com/profile_images/134818135...
# 1521994898974588929  https://pbs.twimg.com/profile_images/150602417...
# 1521994904523706368  https://pbs.twimg.com/profile_images/151604059...
# ...                                                                ...
# 1522335287988346882                                                  0
# 1522335296007847937  https://pbs.twimg.com/profile_images/847574313...
# 1522335298574852103  https://pbs.twimg.com/profile_images/147770084...
# 1522335308712497153  https://pbs.twimg.com/profile_images/117420698...
# 1522335315381395456  https://pbs.twimg.com/profile_images/82081217/...
#
#                                       location protected        username  \
# 1521994876677672966                                False      martincjoc
# 1521994883032039424             United Kingdom     False      doddoneout
# 1521994886941413376                                False   equalisequal5
# 1521994898974588929  Mars and south Hampshire.     False   WolfieSmiffed
# 1521994904523706368                     Dundee     False       Amininnnn
# ...                                        ...       ...             ...
# 1522335287988346882                          0         0               0
# 1522335296007847937              United States     False       jaki_mc99
# 1522335298574852103         Medellín, Colombia     False         _Sileno
# 1522335308712497153                Deutschland     False  Ha_Ackerschott
# 1522335315381395456                      SoFla     False          iBaz66
#
#                     verified  \
# 1521994876677672966    False
# 1521994883032039424    False
# 1521994886941413376    False
# 1521994898974588929    False
# 1521994904523706368    False
# ...                      ...
# 1522335287988346882        0
# 1522335296007847937    False
# 1522335298574852103    False
# 1522335308712497153    False
# 1522335315381395456    False
#
#                                                          entities_user  \
# 1521994876677672966                                                 {}
# 1521994883032039424                                                 {}
# 1521994886941413376                                                 {}
# 1521994898974588929  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1521994904523706368                                                 {}
# ...                                                                ...
# 1522335287988346882                                                  0
# 1522335296007847937                                                 {}
# 1522335298574852103  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1522335308712497153  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1522335315381395456                                                 {}
#
#                      pinned_tweet_id withheld_user  \
# 1521994876677672966     0.000000e+00            {}
# 1521994883032039424     1.241151e+18            {}
# 1521994886941413376     1.463028e+18            {}
# 1521994898974588929     1.521127e+18            {}
# 1521994904523706368     1.492959e+18            {}
# ...                              ...           ...
# 1522335287988346882     0.000000e+00             0
# 1522335296007847937     0.000000e+00            {}
# 1522335298574852103     1.520888e+18            {}
# 1522335308712497153     1.146357e+18            {}
# 1522335315381395456     0.000000e+00            {}
#
#                                                     entities_tweeturls  \
# 1521994876677672966                                                NaN
# 1521994883032039424                                                NaN
# 1521994886941413376                                                NaN
# 1521994898974588929                                                NaN
# 1521994904523706368                                                NaN
# ...                                                                ...
# 1522335287988346882                                                NaN
# 1522335296007847937                                                NaN
# 1522335298574852103  [{'start': 60, 'end': 83, 'url': 'https://t.co...
# 1522335308712497153  [{'start': 67, 'end': 90, 'url': 'https://t.co...
# 1522335315381395456                                                NaN
#
#                                                 entities_tweetmentions  \
# 1521994876677672966                                                NaN
# 1521994883032039424                                                NaN
# 1521994886941413376                                                NaN
# 1521994898974588929                                                NaN
# 1521994904523706368                                                NaN
# ...                                                                ...
# 1522335287988346882                                                NaN
# 1522335296007847937                                                NaN
# 1522335298574852103                                                NaN
# 1522335308712497153  [{'start': 0, 'end': 11, 'username': 'marcusre...
# 1522335315381395456                                                NaN
#
#                     entities_tweethashtags entities_tweetannotations  \
# 1521994876677672966                    NaN                       NaN
# 1521994883032039424                    NaN                       NaN
# 1521994886941413376                    NaN                       NaN
# 1521994898974588929                    NaN                       NaN
# 1521994904523706368                    NaN                       NaN
# ...                                    ...                       ...
# 1522335287988346882                    NaN                       NaN
# 1522335296007847937                    NaN                       NaN
# 1522335298574852103                    NaN                       NaN
# 1522335308712497153                    NaN                       NaN
# 1522335315381395456                    NaN                       NaN
#
#                     entities_tweetcashtags  public_metrics_tweetretweet_count  \
# 1521994876677672966                    NaN                                  0
# 1521994883032039424                    NaN                                  0
# 1521994886941413376                    NaN                                  0
# 1521994898974588929                    NaN                                  0
# 1521994904523706368                    NaN                                  0
# ...                                    ...                                ...
# 1522335287988346882                    NaN                                  0
# 1522335296007847937                    NaN                                  0
# 1522335298574852103                    NaN                                  0
# 1522335308712497153                    NaN                                  0
# 1522335315381395456                    NaN                                  0
#
#                      public_metrics_tweetreply_count  \
# 1521994876677672966                                0
# 1521994883032039424                                0
# 1521994886941413376                                0
# 1521994898974588929                                1
# 1521994904523706368                                0
# ...                                              ...
# 1522335287988346882                                0
# 1522335296007847937                                0
# 1522335298574852103                                1
# 1522335308712497153                                0
# 1522335315381395456                                0
#
#                      public_metrics_tweetlike_count  \
# 1521994876677672966                               0
# 1521994883032039424                               0
# 1521994886941413376                               0
# 1521994898974588929                               1
# 1521994904523706368                               0
# ...                                             ...
# 1522335287988346882                               4
# 1522335296007847937                               0
# 1522335298574852103                               0
# 1522335308712497153                               1
# 1522335315381395456                               0
#
#                      public_metrics_tweetquote_count game    win  is_poke  \
# 1521994876677672966                                0  NaN  False    False
# 1521994883032039424                                0  NaN  False    False
# 1521994886941413376                                0  NaN  False    False
# 1521994898974588929                                1  NaN  False    False
# 1521994904523706368                                0  NaN  False    False
# ...                                              ...  ...    ...      ...
# 1522335287988346882                                0  NaN  False    False
# 1522335296007847937                                0  NaN  False    False
# 1522335298574852103                                0  NaN  False    False
# 1522335308712497153                                0  NaN  False    False
# 1522335315381395456                                0  NaN  False    False
#
#                      user_has_description  wordle_tweet_number  ones  \
# 1521994876677672966                  True               322781   1.0
# 1521994883032039424                  True               322782   1.0
# 1521994886941413376                  True               322783   1.0
# 1521994898974588929                  True               322784   1.0
# 1521994904523706368                  True               322785   1.0
# ...                                   ...                  ...   ...
# 1522335287988346882                 False               386452   1.0
# 1522335296007847937                  True               386453   1.0
# 1522335298574852103                  True               386454   1.0
# 1522335308712497153                  True               386455   1.0
# 1522335315381395456                  True               386456   1.0
#
#                      time_since_last_tweet  wordle_tweet_rate  \
# 1521994876677672966                19800.0           0.000051
# 1521994883032039424                    2.0           0.500000
# 1521994886941413376                    1.0           1.000000
# 1521994898974588929                    2.0           0.500000
# 1521994904523706368                    2.0           0.500000
# ...                                    ...                ...
# 1522335287988346882                    7.0           0.142857
# 1522335296007847937                    2.0           0.500000
# 1522335298574852103                    1.0           1.000000
# 1522335308712497153                    2.0           0.500000
# 1522335315381395456                    2.0           0.500000
#
#                      time_since_last_tweet_rolling_60
# 1521994876677672966                        332.750000
# 1521994883032039424                        332.766667
# 1521994886941413376                        332.766667
# 1521994898974588929                        332.716667
# 1521994904523706368                        332.716667
# ...                                               ...
# 1522335287988346882                          1.650000
# 1522335296007847937                          1.633333
# 1522335298574852103                          1.633333
# 1522335308712497153                          1.650000
# 1522335315381395456                          1.666667
#
# [63676 rows x 44 columns]

# %%
#make rolling 600 times
tudf['time_since_last_tweet_rolling_600'] = tudf['time_since_last_tweet'].rolling(600).mean()

#plot times between all tweets
plt.figure(figsize = (16,8))
plt.plot(tudf['created_at'], tudf['time_since_last_tweet_rolling_600'])
plt.xlabel('date (UTC)')
plt.ylabel('time since last tweet (s)')
plt.title('Time since last tweet (rolling average of 600)');

# %%
#plot times between all tweets at 600 rolling with tighter y

plt.figure(figsize = (16,8))
plt.plot(tudf['created_at'], tudf['time_since_last_tweet_rolling_600'])
plt.xlabel('date (UTC)')
plt.ylabel('time since last tweet (s)')
plt.ylim(-.1,5)
plt.title('Time since last tweet (rolling average of 600)');

# %% [markdown]
# ---

# %%
plt.figure(figsize=(16,8))
plt.plot(tudf['created_at'], tudf['ones']/tudf['time_since_last_tweet_rolling_60'])
plt.title("Wordle tweet rate (from rolling average of 60)")
plt.xlabel("date (UTC)")
plt.ylabel("tweets/sec")
# Out:
# Text(0, 0.5, 'tweets/sec')

# %%
#make special times for certain parts of the country


edt_offset = 4 # 4 am utc == midnight east coast usa. gmt -4
pdt_offset = 6 #6 am == midnight west coast usa. gmt -6
tokyo_offset = 15 # 3pm UTC == midnight japan, korea. gmt +9
turkey_offset = 21  # 9pm UTC == midnight turkey, israel. gmt +3
france_offset = 22 #10 pm UTC = midnight france, germany. gmt +2
canberra_offset = 14 # 2 pm UTC == midnight ACT eastern australia. GMT + 10

#more appropriately, should make tzinfo the corresponding type. but.
def midnight_datetime_may2(offset, tzinfo = UTC):
    midnight = datetime(2022, 5, 2, 0 + offset, 0, 0 ,tzinfo = tzinfo)
    return midnight

# %%
edt_text_position = datetime(2022, 4, 29, 21, 0, 0, tzinfo = UTC)
jp_text_position = datetime(2022, 4, 29, 13, 0, 0, tzinfo = UTC)
pdt_text_position = datetime(2022, 4, 29, 16, 0 ,0, tzinfo = UTC)

plt.figure(figsize=(16,8))
plt.plot(tudf['created_at'], tudf['ones']/tudf['time_since_last_tweet_rolling_600'])
plt.title("Wordle tweet rate (from rolling average of 600)")
plt.xlabel("date (UTC)")
plt.ylabel("tweets/sec")
plt.text(edt_text_position, 2, "EDT midnight", color = 'orange')
plt.text(jp_text_position, 2.25, "JP midnight", color = 'r')
plt.text(pdt_text_position, 1.75, "PDT midnight", color = 'b')
for day_offset in range(-2,5):
    plt.axvline(dt.timedelta(days=day_offset)+datetime(2022, 5, 1, 0 + pdt_offset, 0 , 0, tzinfo = UTC), color = colors.to_rgba('b', 0.5))
    plt.axvline(dt.timedelta(days=day_offset)+datetime(2022, 5, 1, 0 + tokyo_offset, 0 ,0 ,tzinfo = UTC), color = colors.to_rgba('r', 0.5))
    plt.axvline(dt.timedelta(days=day_offset)+datetime(2022, 5, 1, 0 + edt_offset, 0, 0 ,tzinfo = UTC), color = colors.to_rgba('orange',0.5))

# %%
tudf['tweet_rate_60'] = tudf['ones']/tudf['time_since_last_tweet_rolling_60']
tudf['tweet_rate_600'] = tudf['ones']/tudf['time_since_last_tweet_rolling_600']

# %%
# #do the same with rolling averages.
# plt.figure(figsize = (12,6))
# #make a line at UTC = 9pm, which is 6pm EDT.
# for fivepeeem in tudf[tudf['created_at'].apply(lambda x: x.hour == 21)]['created_at']:
#     plt.axvline(fivepeeem)
# #make a line at UTC = 4pm, which is noon EDT.
# for lunchtime in tudf[tudf['created_at'].apply(lambda x: x.hour == 16)]['created_at']:
#     plt.axvline(lunchtime, color = 'orange')    
# plt.plot(tudf['created_at'],tudf['time_since_last_tweet_mean60'])
# plt.ylim(0,5)
# plt.title("time since last tweet (rolling average --- 60 tweets)")
# plt.xlabel("date")
# plt.ylabel("average wait time (s)")

# %%
# #plot rolling averages in one day.
# plt.figure(figsize = (12,6))
# plt.xlim(datetime(2022, 5,2,0,0,0, tzinfo = UTC), datetime(2022, 5,3,0,0,0, tzinfo = UTC))
# plt.plot(tudf['created_at'],tudf['time_since_last_tweet_mean60'])
# plt.ylim(0,5)
# plt.title("time since last tweet (rolling average --- 60 tweets)")
# plt.xlabel("date")
# plt.ylabel("average wait time (s)")

# %%
# #plot the inverse. This is tweet frequency.

# UTC = tz.gettz('UTC')

# edt_offset = 4 # 4 am utc == midnight east coast usa. gmt -4
# pdt_offset = 6 #6 am == midnight west coast usa. gmt -6
# tokyo_offset = 15 # 3pm UTC == midnight japan, korea. gmt +9
# turkey_offset = 21  # 9pm UTC == midnight turkey, israel. gmt +3
# france_offset = 22 #10 pm UTC = midnight france, germany. gmt +2
# canberra_offset = 14 # 2 pm UTC == midnight ACT eastern australia. GMT + 10

# #more appropriately, should make tzinfo the corresponding type. but.
# def midnight_datetime_may2(offset, tzinfo = UTC):
#     midnight = datetime(2022, 5, 2, 0 + offset, 0, 0 ,tzinfo = tzinfo)
#     return midnight

# edt_midnight = midnight_datetime_may2(edt_offset)
# tokyo_midnight =  midnight_datetime_may2(tokyo_offset)
# turkey_midnight =  midnight_datetime_may2(turkey_offset)
# france_midnight = midnight_datetime_may2(france_offset)


# plt.figure(figsize = (12,6))
# plt.xlim(datetime(2022, 5,2,0,0,0, tzinfo = UTC), datetime(2022, 5,3,0,0,0, tzinfo = UTC))
# plt.plot(tudf['created_at'], tudf['ones']/tudf['time_since_last_tweet_mean60'])
# plt.ylim(0,3)
# plt.title("Wordle tweet frequency on May 2, 2022 (UTC) and midnights")
# plt.xlabel("date (UTC)")
# plt.ylabel("Frequency (hz)")

# plt.axvline(edt_midnight,  color = colors.to_rgba('orange',0.5))
# plt.axvline(tokyo_midnight, color = colors.to_rgba('orange',0.5))
# plt.axvline(turkey_midnight,  color = colors.to_rgba('orange',0.5))
# plt.axvline(france_midnight,  color = colors.to_rgba('orange',0.5))

# plt.text(edt_midnight, 2.5, "   EDT", color = 'orange')
# plt.text(tokyo_midnight, 2.5, "     Japan\n     Korea", color = 'orange')
# plt.text(turkey_midnight, 2.5, "     Turkey\n     Israel ", color = 'orange')
# plt.text(france_midnight, 2., "     France\n     Germany\n     Spain", color = 'orange')

# %%
#This is UTC, leading east coast USA by four hours. Some of these features definitely repeat.

# %% [markdown]
# # making the time series regular
#
# ### traces
#
# The time data is irregular. Follow [this stack overflow](https://stackoverflow.com/questions/25234941/python-regularise-irregular-time-series-with-linear-interpolation) answer to use `traces` to make a regular time series.
#
# > You can do this with traces. First, create a TimeSeries with your irregular measurements like you would a dictionary:
# ```python
#     ts = traces.TimeSeries([
#     (datetime(1992, 8, 27, 7, 46, 48), 28.0),
#     (datetime(1992, 8, 27, 8, 0, 48), 28.2),
#     ...
#     (datetime(1992, 8, 27, 9, 3, 48), 30.0),
# ])
# ```
#
# Then regularize using the sample method:
#
# ```python
#     ts.sample(
#     sampling_period=timedelta(minutes=15),
#     start=datetime(1992, 8, 27, 8),
#     end=datetime(1992, 8, 27, 9),
#     interpolate='linear',
# ```
# > This results in the following regularized version, where the gray dots are the original data and the orange is the regularized version with linear interpolation.

# %%
# # Install a pip package in the current Jupyter kernel
# import sys
# !{sys.executable} -m pip install traces

# %% [markdown]
# [traces is pretty cool](https://traces.readthedocs.io/en/latest/#:~:text=The%20main%20object%20in%20traces,%3A45%3A56am%2C%20etc.&text=What%20if%20you%20want%20to,one%20of%20the%20measurement%20times.). It makes TimeSeries objects that interpolate between the data points by default. You can put any datetime in.

# %%
tudf['created_at']
# Out:
# 1520127509051944961   2022-04-29 19:46:55+00:00
# 1520127524377972737   2022-04-29 19:46:59+00:00
# 1520127566845149185   2022-04-29 19:47:09+00:00
# 1520127576676704256   2022-04-29 19:47:11+00:00
# 1520127578593726464   2022-04-29 19:47:11+00:00
#                                  ...
# 1522335287988346882   2022-05-05 21:59:50+00:00
# 1522335296007847937   2022-05-05 21:59:52+00:00
# 1522335298574852103   2022-05-05 21:59:53+00:00
# 1522335308712497153   2022-05-05 21:59:55+00:00
# 1522335315381395456   2022-05-05 21:59:57+00:00
# Name: created_at, Length: 386457, dtype: datetime64[ns, UTC]

# %%
# import traces

from datetime import datetime

from dateutil import tz

# %%
# #make a time series of all tweets rate, rolling 600
# ts = traces.TimeSeries(
#         zip( tudf['created_at'],
#             tudf['ones']/tudf['time_since_last_tweet_rolling_600']
#         )
#     )

# tudf.iloc[0]['created_at']

# %%
#Give the time series tz awareness when making values.

# UTC = tz.gettz('UTC')
# ts[datetime(2042, 2, 1,  6,  0,  0, tzinfo = UTC)]

# %%
#make a histogram of the time series.
# histogram = ts.distribution(
# start=tudf['created_at'].min(),
# end=tudf['created_at'].max()
# )
# histogram.median()

# %% [markdown]
# ### resampling with pandas

# %%
###### make an evenly spaced timeseries without traces... just pandas
resample_rule = '60S'
#once a minute resampling
resampled_tudf = tudf[['tweet_rate_60', 'tweet_rate_600','time_since_last_tweet_rolling_60','time_since_last_tweet_rolling_600','created_at']].resample(resample_rule,  on ='created_at')

# %%
#plot the resampled tweet rate
resampled_tudf.mean()['tweet_rate_60'].plot(figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='created_at'>

# %% [markdown]
# ## seasonal decomposing

# %%
# just look at the resampled df
resampled_tudf.mean().dropna()
# Out:
#                            tweet_rate_60  tweet_rate_600  \
# created_at
# 2022-04-29 20:14:00+00:00       0.385661        0.359842
# 2022-04-29 20:15:00+00:00       0.401913        0.361531
# 2022-04-29 20:16:00+00:00       0.377319        0.363095
# 2022-04-29 20:17:00+00:00       0.338322        0.363912
# 2022-04-29 20:18:00+00:00       0.307473        0.364595
# ...                                  ...             ...
# 2022-05-05 21:55:00+00:00       0.688653        0.655620
# 2022-05-05 21:56:00+00:00       0.665937        0.649971
# 2022-05-05 21:57:00+00:00       0.573858        0.643458
# 2022-05-05 21:58:00+00:00       0.645358        0.639689
# 2022-05-05 21:59:00+00:00       0.632271        0.636048
#
#                            time_since_last_tweet_rolling_60  \
# created_at
# 2022-04-29 20:14:00+00:00                          2.596000
# 2022-04-29 20:15:00+00:00                          2.492982
# 2022-04-29 20:16:00+00:00                          2.651754
# 2022-04-29 20:17:00+00:00                          2.962281
# 2022-04-29 20:18:00+00:00                          3.257778
# ...                                                     ...
# 2022-05-05 21:55:00+00:00                          1.453333
# 2022-05-05 21:56:00+00:00                          1.504687
# 2022-05-05 21:57:00+00:00                          1.744298
# 2022-05-05 21:58:00+00:00                          1.558865
# 2022-05-05 21:59:00+00:00                          1.582716
#
#                            time_since_last_tweet_rolling_600
# created_at
# 2022-04-29 20:14:00+00:00                           2.779000
# 2022-04-29 20:15:00+00:00                           2.766053
# 2022-04-29 20:16:00+00:00                           2.754123
# 2022-04-29 20:17:00+00:00                           2.747982
# 2022-04-29 20:18:00+00:00                           2.742889
# ...                                                      ...
# 2022-05-05 21:55:00+00:00                           1.525292
# 2022-05-05 21:56:00+00:00                           1.538542
# 2022-05-05 21:57:00+00:00                           1.554123
# 2022-05-05 21:58:00+00:00                           1.563298
# 2022-05-05 21:59:00+00:00                           1.572222
#
# [8417 rows x 4 columns]

# %% [markdown]
# ### Decompose by day --- tweet rate 600

# %%
from statsmodels.tsa.seasonal import seasonal_decompose





decomp_date_end = datetime(2022, 5, 4, 12, 0, 0, tzinfo = UTC)

decomp = seasonal_decompose(resampled_tudf['tweet_rate_600'].mean().dropna(), period = 60*24)

# plt.rc('figure', figsize(12,6))
# decomp.plot();

# %%
plt.rc('figure',figsize = (12,32))
decomp.plot();

# %% [markdown]
# ### Decompose by hour --- tweet rate 600

# %%
decomp_date_end = datetime(2022, 5, 4, 12, 0, 0, tzinfo = UTC)
decomp = seasonal_decompose(resampled_tudf['tweet_rate_600'].mean().dropna(), period = 60)

# %%
plt.rc('figure',figsize = (12,32))
decomp.plot();

# %% [markdown]
# ### autocorrelation

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
resampled_tudf['tweet_rate_600'].mean().dropna()
# Out:
# created_at
# 2022-04-29 20:14:00+00:00    0.359842
# 2022-04-29 20:15:00+00:00    0.361531
# 2022-04-29 20:16:00+00:00    0.363095
# 2022-04-29 20:17:00+00:00    0.363912
# 2022-04-29 20:18:00+00:00    0.364595
#                                ...
# 2022-05-05 21:55:00+00:00    0.655620
# 2022-05-05 21:56:00+00:00    0.649971
# 2022-05-05 21:57:00+00:00    0.643458
# 2022-05-05 21:58:00+00:00    0.639689
# 2022-05-05 21:59:00+00:00    0.636048
# Name: tweet_rate_600, Length: 8417, dtype: float64

# %%
# Plot autocorrelation for lags up to one full day.
# There is a kink at 60 minutes, and at 23 and 24 hours.

plt.rc('figure',figsize = (16,6))
plot_acf(resampled_tudf['tweet_rate_600'].mean().dropna(), lags = 60*24);

# %% [markdown]
# ### Partial autocorrelation

# %%
plt.rc('figure',figsize = (16,6))
plot_pacf(resampled_tudf['tweet_rate_600'].mean().dropna(), lags = 60*24);

# %%
plt.rc('figure',figsize = (16,6))
pacf_plot = plot_pacf(resampled_tudf['tweet_rate_600'].mean().dropna(), lags = 60*24);
pacf_plot.axes[0].set_ylim([-0.15,0.15])
# Out:
# (-0.15, 0.15)

# %%
pacf_plot.axes[0].set_ylim([-0.05,0.05])
pacf_plot

# %%
# save time series data up to here for practice with time series models
resampled_tudf.mean().to_csv('../merged_data/resampled_tudf_minute_basic.csv', index = True)

# %%
resampled_tudf.mean().index
# Out:
# DatetimeIndex(['2022-04-29 19:46:00+00:00', '2022-04-29 19:47:00+00:00',
#                '2022-04-29 19:48:00+00:00', '2022-04-29 19:49:00+00:00',
#                '2022-04-29 19:50:00+00:00', '2022-04-29 19:51:00+00:00',
#                '2022-04-29 19:52:00+00:00', '2022-04-29 19:53:00+00:00',
#                '2022-04-29 19:54:00+00:00', '2022-04-29 19:55:00+00:00',
#                ...
#                '2022-05-05 21:50:00+00:00', '2022-05-05 21:51:00+00:00',
#                '2022-05-05 21:52:00+00:00', '2022-05-05 21:53:00+00:00',
#                '2022-05-05 21:54:00+00:00', '2022-05-05 21:55:00+00:00',
#                '2022-05-05 21:56:00+00:00', '2022-05-05 21:57:00+00:00',
#                '2022-05-05 21:58:00+00:00', '2022-05-05 21:59:00+00:00'],
#               dtype='datetime64[ns, UTC]', name='created_at', length=8774, freq='60S')

# %% [markdown]
# # geo and location
#
# `geo` is a geocode corresponding to a location. They are also called `place_id`. The great majority of tweets do not have a geo code. Location comes from the user data, rather than the tweet itself.
#
# According to [Get information about a place](https://developer.twitter.com/en/docs/twitter-api/v1/geo/place-information/api-reference/get-geo-id-place_id) in the Twitter docs,
# > These IDs can be retrieved from geo/reverse_geocode.
#
# `location` is a very general string.

# %%
tudf.columns
# Out:
# Index(['conversation_id', 'reply_settings', 'lang', 'possibly_sensitive',
#        'source', 'text', 'context_annotations', 'author_id', 'created_at',
#        'referenced_tweets', 'in_reply_to_user_id', 'attachments', 'geo',
#        'withheld_tweet', 'name', 'public_metrics_user', 'url', 'description',
#        'profile_image_url', 'location', 'protected', 'username', 'verified',
#        'entities_user', 'pinned_tweet_id', 'withheld_user',
#        'entities_tweeturls', 'entities_tweetmentions',
#        'entities_tweethashtags', 'entities_tweetannotations',
#        'entities_tweetcashtags', 'public_metrics_tweetretweet_count',
#        'public_metrics_tweetreply_count', 'public_metrics_tweetlike_count',
#        'public_metrics_tweetquote_count', 'game', 'win', 'is_poke',
#        'user_has_description', 'wordle_tweet_number', 'ones',
#        'time_since_last_tweet', 'wordle_tweet_rate',
#        'time_since_last_tweet_rolling_60', 'time_since_last_tweet_rolling_600',
#        'tweet_rate_60', 'tweet_rate_600'],
#       dtype='object')

# %%
tudf['geo'].value_counts()
# Out:
# {}                                  380358
# {'place_id': '206c436ce43a43a3'}       148
# {'place_id': '018f1cde6bad9747'}        86
# {'place_id': '3797791ff9c0e4c6'}        64
# {'place_id': '0161be1b3f98d6c3'}        48
#                                      ...
# {'place_id': '5552c90a5411d6b2'}         1
# {'place_id': '013522304ee10b39'}         1
# {'place_id': '231af294750b236e'}         1
# {'place_id': '699e7e72554fee2a'}         1
# {'place_id': '019cbbb8154486f2'}         1
# Name: geo, Length: 1762, dtype: int64

# %%
len(tudf)
# Out:
# 386457

# %%
#she/her is a location according to 239 of these

# %%
tudf['location'].value_counts().loc['Irvine, CA']
# Out:
# 23

# %%
tudf['location'].value_counts().iloc[-50:]
# Out:
# Richmond-Upon-Thames             1
# Cuji, Canagaua / 그지, 가나가와        1
# Houston, TX via Waterbury, CT    1
# Athens, Attica                   1
# 16 . aesop ☍ they/them           1
# Valloria, Soria                  1
# Sandbach, England                1
# London and Maidenhead            1
# konya                            1
# Poole, Dorset                    1
# almería - granada                1
# Sivakasi, Tamil Nadu, India      1
# Rogano Oyster Bar, Glasgow       1
# Swat/Islamabad                   1
# Agüimes                          1
# Tamworth, England                1
# Currently In Kuala Lumpur        1
# Lympsham, England                1
# Jagera Yuggera Ugarapul Land     1
# Snug as a bee bean               1
# Bk                               1
# London || Los Angeles            1
# Illescas, España                 1
# York YO32 9TW                    1
# Zushi                            1
# At Nearest Tea Stall             1
# Mapperley, England               1
# trying to find myself            1
# Inca                             1
# 리퀘박스도 있어요                        1
# Federal Capital Territory        1
# Albocàsser, España               1
# Up North UK                      1
# España, AntiNazifascistas        1
# +33                              1
# atlannuh                         1
# San Fernando, Spain              1
# Lochgelly, Scotland              1
# Midlands                         1
# عنيزة                            1
# Muriwai Beach, New Zealand       1
#  South Bedfordshire, UK          1
# Ibagué, Tolima                   1
# Botswana, Africa                 1
# BKK, Thailand.                   1
# Gotham City, U.S.A.              1
# 23区のはじっこ                         1
# Hanford, CA                      1
# Linares, Spain                   1
# downstairs                       1
# Name: location, dtype: int64

# %%
tudf['entities_user'].iloc[2]
# Out:
# '{}'

# %%
#export the list of unique locations
pd.Series(tudf['location'].value_counts().index).to_csv('unique_locations.csv')

#import dict of "binned" locations
loc_bin_path = './loc_dict.json'
with open(loc_bin_path, 'r') as file:
    locs = json.loads(file.read())
locs
# Out:
# {'United States': 'USA',
#  'Los Angeles, CA': 'USA',
#  'London': 'UK',
#  'London, England': 'UK',
#  'India': 'IN',
#  'Chicago, IL': 'USA',
#  '日本': 'JPN',
#  'Canada': 'CA',
#  'Madrid': 'ES',
#  'New York, NY': 'USA',
#  'she/her': 'GENDER',
#  'United Kingdom': 'UK',
#  'Japan': 'JPN',
#  'Australia': 'ASTL',
#  'Atlanta, GA': 'USAE',
#  'California, USA': 'USAW',
#  'UK': 'UK',
#  'England, United Kingdom': 'UK',
#  'España': 'ES',
#  'Washington, DC': 'USAE',
#  'USA': 'USA',
#  'Toronto, Ontario': 'CAE',
#  'Seattle, WA': 'USAW',
#  'Tokyo': 'JPN',
#  'Buenos Aires, Argentina': 'AR',
#  'Ireland': 'IE',
#  'Madrid, Comunidad de Madrid': 'ES',
#  'Argentina': 'AR',
#  '東京': 'JPN',
#  'Florida, USA': 'USAE',
#  'Brooklyn, NY': 'USAE',
#  'Houston, TX': 'USAC',
#  '東京都': 'JPN',
#  'Philadelphia, PA': 'USAE',
#  'Toronto': 'CAE',
#  'New York, USA': 'USAE',
#  'Melbourne, Victoria': 'ASTL',
#  'Boston, MA': 'USAE',
#  'Texas, USA': 'USAC',
#  'Santiago, Chile': 'CL',
#  'Mumbai, India': 'IN',
#  'New York': 'USAE',
#  'Austin, TX': 'USAC',
#  'New Jersey, USA': 'USAE',
#  'Tokyo, Japan': 'JPN',
#  'Earth': 'Earth',
#  'Philippines': 'PH',
#  'Chicago': 'USAC',
#  'California': 'USAW',
#  'Barcelona': 'ES',
#  'Mumbai': 'IN',
#  'NYC': 'USAE',
#  'Bengaluru, India': 'IN',
#  'Los Angeles': 'USAW',
#  'Spain': 'ES',
#  'Dallas, TX': 'USAC',
#  'Singapore': 'SG',
#  'Malaysia': 'MY',
#  'San Diego, CA': 'USAE',
#  'İstanbul, Türkiye': 'TK',
#  'Portland, OR': 'USAW',
#  'Massachusetts, USA': 'USAE',
#  'Chennai, India': 'IN',
#  'Scotland': 'UK',
#  'Bangalore': 'IN',
#  'Ontario, Canada': 'CAE',
#  'Pittsburgh, PA': 'USAE',
#  'Las Vegas, NV': 'USAW',
#  'Texas': 'USAC',
#  'Sydney, New South Wales': 'ASTL',
#  'San Francisco, CA': 'USAW',
#  'Michigan, USA': 'USAE',
#  'Nashville, TN': 'USAC',
#  'Melbourne, Australia': 'ASTL',
#  '日本 東京': 'JPN',
#  'Charlotte, NC': 'USAE',
#  'Ohio, USA': 'USAE',
#  'Buenos Aires': 'AR',
#  'Pennsylvania, USA': 'USAE',
#  'Virginia, USA': 'USAE',
#  'he/him': 'GENDER',
#  'Chile': 'CL',
#  'New Delhi, India': 'IN',
#  'North Carolina, USA': 'USA',
#  'New Zealand': 'NZ',
#  'Dublin': 'IE',
#  'Melbourne': 'ASTL',
#  'Scotland, United Kingdom': 'UK',
#  'Glasgow, Scotland': 'UK',
#  'England': 'UK',
#  'Orlando, FL': 'USAE',
#  'Barcelona, España': 'ES',
#  'Indonesia': 'ID',
#  'Sydney, Australia': 'ASTL',
#  'Ciudad Autónoma de Buenos Aire': 'AR',
#  'Manchester, England': 'UK',
#  'Sevilla': 'ES',
#  'Denver, CO': 'USAM',
#  'New Jersey': 'USAE',
#  'Sydney': 'ASTL',
#  'Manchester': 'UK',
#  'Maryland, USA': 'USA',
#  'Baltimore, MD': 'USA',
#  'South Africa': 'SA',
#  'Bangkok, Thailand': 'TH',
#  'Johannesburg, South Africa': 'SA',
#  'New York City': 'USAE',
#  'México': 'MX',
#  '神奈川県': 'JPN',
#  'Phoenix, AZ': 'USAM',
#  'Minneapolis, MN': 'USAE',
#  'Illinois, USA': 'USAC',
#  'Colorado, USA': 'USAM',
#  'Vancouver, British Columbia': 'CAW',
#  'Republic of the Philippines': 'PH',
#  'Auckland, New Zealand': 'NZ',
#  'Istanbul': 'TK',
#  '大阪': 'JPN',
#  'Toronto, Canada': 'CAE',
#  'Edinburgh, Scotland': 'UK',
#  'Glasgow': 'UK',
#  'Columbus, OH': 'USAE',
#  'Málaga, España': 'ES',
#  'Cincinnati, OH': 'USA',
#  'Hyderabad, India': 'IN',
#  'Germany': 'DE',
#  'London, UK': 'UK',
#  'Bogotá, D.C., Colombia': 'CO',
#  'Cleveland, OH': 'USAE',
#  'Mexico': 'MX',
#  'Dublin, Ireland': 'IE',
#  'Michigan': 'USAE',
#  'İstanbul': 'TK',
#  'Connecticut, USA': 'USAE',
#  'Valencia': 'ES',
#  'France': 'FR',
#  'Ottawa, Ontario': 'CAE',
#  'Miami, FL': 'USAE',
#  'Valencia, España': 'ES',
#  'Chennai': 'IN',
#  'Sevilla, España': 'ES',
#  'Ohio': 'USAE',
#  'Raleigh, NC': 'USAE',
#  'Jamaica': 'JAM',
#  'Edmonton, Alberta': 'CAM',
#  'Arizona, USA': 'USAM',
#  'Madrid, España': 'ES',
#  'Minnesota, USA': 'USAC',
#  'Nairobi, Kenya': 'KE',
#  'Dublin City, Ireland': 'IE',
#  'Wisconsin, USA': 'USAC',
#  'Hong Kong': 'HK',
#  'San Antonio, TX': 'USAC',
#  'NJ': 'USAE',
#  'Florida': 'USAE',
#  'Edinburgh': 'UK',
#  'North West, England': 'UK',
#  'Milwaukee, WI': 'USAC',
#  'Boston': 'USAE',
#  'Kansas City, MO': 'USAC',
#  'Trinidad and Tobago': 'TT',
#  'Liverpool, England': 'UK',
#  'Brisbane, Queensland': 'ASTL',
#  'Thailand': 'TH',
#  'Louisville, KY': 'USAE',
#  'Georgia, USA': 'USAE',
#  'South East, England': 'UK',
#  'Buffalo, NY': 'USAE',
#  'Seattle': 'USAW',
#  '愛知県': 'JPN',
#  'she/they': 'GENDER',
#  'Birmingham, England': 'UK',
#  'Calgary, Alberta': 'CAM',
#  'Montevideo, Uruguay': 'UR',
#  'Catalunya': 'CAT',
#  'Minnesota': 'USAC',
#  'Cape Town, South Africa': 'SA',
#  'Indianapolis, IN': 'USAE',
#  'Leeds, England': 'UK',
#  'North Carolina': 'USAE',
#  'Massachusetts': 'USAE',
#  'Tennessee, USA': 'USAE',
#  'NY': 'USAE',
#  'Rochester, NY': 'USAE',
#  'Monterrey, Nuevo León': 'MX',
#  'Oregon, USA': 'USAW',
#  'Washington, USA': 'USAW',
#  'they/them': 'GENDER',
#  'Pune, India': 'IN',
#  'Winnipeg, Manitoba': 'CAC',
#  'İzmir, Türkiye': 'TK',
#  'Paris, France': 'FR',
#  'Indiana, USA': 'USAE',
#  'Queens, NY': 'USAE',
#  'Fort Worth, TX': 'USAC',
#  'Cork, Ireland': 'IE',
#  'Pennsylvania': 'USAE',
#  'Indiana': 'USAE',
#  'Zaragoza, España': 'ES',
#  'Wales, United Kingdom': 'UK',
#  'Detroit, MI': 'USAE',
#  'Tucson, AZ': 'USAM',
#  'Virginia': 'USAE',
#  'Dubai, United Arab Emirates': 'UAE',
#  'Colombia': 'CO',
#  'Taiwan': 'TW',
#  'New Delhi': 'IN',
#  'Cape Town': 'SA',
#  'Wisconsin': 'USAC',
#  'Sacramento, CA': 'USAW',
#  'La Plata, Argentina': 'AR',
#  'Costa Rica': 'CR',
#  'Rosario, Argentina': 'AR',
#  'Adelaide, South Australia': 'ASTL',
#  'Missouri, USA': 'USAC',
#  'Richmond, VA': 'USAE',
#  'South Carolina, USA': 'USAE',
#  'Vancouver, BC': 'CAW',
#  'San Francisco': 'USAW',
#  'Zaragoza': 'ES',
#  'Europe': 'EUR',
#  'St Louis, MO': 'USAC',
#  'Liverpool': 'UK',
#  'Córdoba, Argentina': 'AR',
#  'Türkiye': 'TK',
#  'Omaha, NE': 'USAC',
#  'tokyo': 'JPN',
#  'Montréal, Québec': 'CAE',
#  'istanbul': 'TK',
#  'Lagos, Nigeria': 'NG',
#  'Leeds': 'UK',
#  'Tampa, FL': 'USAE',
#  'British Columbia, Canada': 'CAW',
#  'New Orleans, LA': 'USAC',
#  'Southern California': 'USAW',
#  'Guatemala': 'GUAT',
#  'Madrid, Spain': 'ES',
#  'Durham, NC': 'USAE',
#  'Bilbao': 'ES',
#  'Illinois': 'USAC',
#  'San Jose, CA': 'USAW',
#  'SoCal': 'USAW',
#  'Philadelphia': 'USAE',
#  '大阪府': 'JPN',
#  'Tokyo-to, Japan': 'JPN',
#  'Málaga': 'ES',
#  'Manhattan, NY': 'USAE',
#  '関西': 'JPN',
#  'Somewhere': 'CLEVER',
#  '関東': 'JPN',
#  '神奈川': 'JPN',
#  'Hyderabad': 'IN',
#  'Maryland': 'USAE',
#  'Cairo, Egypt': 'EG',
#  'Iowa, USA': 'USAC',
#  'Atlanta': 'USAE',
#  'West Midlands, England': 'UK',
#  'Murcia, España': 'ES',
#  'Kuala Lumpur': 'MY',
#  'Halifax, Nova Scotia': 'CAE',
#  'madrid': 'ES',
#  'Oakland, CA': 'USAW',
#  'Alberta, Canada': 'CAM',
#  'Berlin, Germany': 'DE',
#  'Memphis, TN': 'USAC',
#  'Valencia, Spain': 'ES',
#  '横浜': 'JPN',
#  'Kentucky, USA': 'USAE',
#  'Turkey': 'TK',
#  'Newcastle Upon Tyne, England': 'UK',
#  'Sri Lanka': 'SL',
#  '北海道': 'JPN',
#  'Sheffield': 'UK',
#  'Wales': 'UK',
#  'Barcelona, Catalunya': 'ES',
#  'Malaga, Spain': 'ES',
#  'Bogotá': 'CO',
#  'Panama': 'PA',
#  'Essex': 'UK',
#  '千葉県': 'JPN',
#  'Mexico City': 'MX',
#  'Oregon': 'USAW',
#  'Manila, Philippines': 'PH',
#  'South West, England': 'UK',
#  'Johannesburg': 'SA',
#  'Georgia': 'USAE',
#  'Brisbane': 'ASTL',
#  'Comunidad de Madrid, España': 'ES',
#  'Uruguay': 'UR',
#  'Planet Earth': 'Earth',
#  'New England': 'USAE',
#  'Northern Ireland': 'UK',
#  'Long Beach, CA': 'USAW',
#  'Nottingham, England': 'UK',
#  'Brooklyn': 'USAE',
#  'Ankara, Türkiye': 'TK',
#  'Berlin': 'DE',
#  'New York, New York': 'USAE',
#  'Perth, Western Australia': 'ASTL',
#  'Jakarta': 'ID',
#  'Osaka': 'JPN',
#  'Pittsburgh': 'USAE',
#  'Asturias': 'ES',
#  'Deutschland': 'DE',
#  'TOKYO': 'JPN',
#  '千葉': 'JPN',
#  'Bogotá, Colombia': 'CO',
#  'Columbia, SC': 'USAE',
#  'Barcelona, Spain': 'ES',
#  'Italy': 'EUR',
#  'Here': 'CLEVER',
#  'NC': 'USAE',
#  'Murcia': 'ES',
#  'Colorado': 'USAM',
#  'Salamanca, España': 'ES',
#  'Gurgaon, India': 'IN',
#  'She/Her': 'GENDER',
#  'Vancouver': 'CAW',
#  'Birmingham': 'UK',
#  'North East, England': 'UK',
#  'Sheffield, England': 'UK',
#  'Brisbane, Australia': 'ASTL',
#  'Toronto, ON': 'CAE',
#  'Everywhere': 'CLEVER',
#  'Delhi': 'IN',
#  'CDMX': 'MX',
#  'Bristol': 'UK',
#  'Knoxville, TN': 'USAC',
#  'Queensland, Australia': 'ASTL',
#  '横浜市': 'JPN',
#  'JAPAN': 'JPN',
#  'Arkansas, USA': 'USAC',
#  'Lima, Perú': 'PE',
#  'Pakistan': 'PK',
#  'Wellington, New Zealand': 'NZ',
#  'Bronx, NY': 'USAE',
#  'New Hampshire, USA': 'USAE',
#  'Granada': 'ES',
#  '대한민국': 'KOR',
#  'He/Him': 'GENDER',
#  'Ottawa': 'CAE',
#  'Bay Area': 'USAW',
#  'Granada, Spain': 'ES',
#  'Washington, D.C.': 'USAE',
#  'The Netherlands': 'EUR',
#  'Bristol, England': 'UK',
#  'PA': 'USAE',
#  'Lima, Peru': 'PE',
#  'Alexandria, VA': 'CAW',
#  '神奈川県横浜市': 'JPN',
#  'Bangkok': 'TH',
#  'Baltimore': 'USAE',
#  'Edmonton': 'CAW',
#  'Jacksonville, FL': 'USAE',
#  'Yokohama': 'JPN',
#  'Cardiff, Wales': 'UK',
#  'Caracas': 'VE',
#  'Baton Rouge, LA': 'USAC',
#  'Cardiff': 'UK',
#  'Victoria, Australia': 'ASTL',
#  'Maine, USA': 'USAE',
#  'カントー地方': 'JPN',
#  'Jakarta, Indonesia': 'ID',
#  'Karachi, Pakistan': 'PK',
#  'Tallahassee, FL': 'USAE',
#  'おふとん': 'JPN',
#  '埼玉': 'JPN',
#  'Bay Area: CA': 'USAW',
#  'Valladolid': 'MX',
#  'Arizona': 'USAM',
#  'Auckland': 'NZ',
#  'Birmingham, UK': 'UK',
#  'Hell': 'CLEVER',
#  'Trinidad': 'TT',
#  'Oklahoma City, OK': 'USAC',
#  'Kansas City': 'USAC',
#  'Santiago de Chile': 'CL',
#  'Albuquerque, NM': 'USAM',
#  'Israel': 'IL',
#  'Canberra': 'ASTL',
#  'Valladolid, España': 'ES',
#  'Kolkata, India': 'IN',
#  'Salt Lake City, UT': 'USAM',
#  'Panamá': 'PA',
#  '家': 'JPN',
#  'She/her': 'GENDER',
#  'Bangalore, India': 'IN',
#  'Alexandria, Egypt': 'EG',
#  'Alabama': 'USAC',
#  'Almería, España': 'ES',
#  'Wellington City, New Zealand': 'NZ',
#  'Long Island, NY': 'USAE',
#  'Oklahoma, USA': 'USAC',
#  'Nova Scotia, Canada': 'CAE',
#  'nowhere': 'CLEVER',
#  'Yorkshire': 'UK',
#  'Arlington, VA': 'USAE',
#  'DMV': 'CLEVER',
#  'Birmingham, AL': 'USAE',
#  'Seoul': 'KOR',
#  'Madison, WI': 'USAC',
#  'Islamabad, Pakistan': 'PK',
#  'Venezuela': 'VE',
#  'Cantabria, España': 'ES',
#  'Paris': 'FR',
#  '京都': 'JPN',
#  'Bengaluru South, India': 'IN',
#  'Louisiana, USA': 'USAC',
#  'Tennessee': 'USAC',
#  'El Salvador': 'ELSL',
#  'Jersey City, NJ': 'USAE',
#  'Sevilla, Andalucía': 'ES',
#  'she/her ': 'GENDER',
#  'Pacific Northwest': 'USAW',
#  'Nottingham': 'UK',
#  'Tulsa, OK': 'USAC',
#  'Rosario': 'AR',
#  'Seoul, Republic of Korea': 'KOR',
#  'Brighton, England': 'UK',
#  'Alabama, USA': 'USAE',
#  'Community of Madrid, Spain': 'ES',
#  'Osaka, Japan': 'JPN',
#  'Oklahoma': 'USAC',
#  'Calgary, AB': 'CAM',
#  'Parts Unknown': 'CLEVER',
#  'Aotearoa': 'NZ',
#  'Nigeria': 'NG',
#  '自宅': 'JPN',
#  'Austin, Texas': 'USAC',
#  'Charleston, SC': 'USAE',
#  '埼玉県': 'JPN',
#  'Cleveland, Ohio': 'USAE',
#  'Berkeley, CA': 'USAW',
#  'Brasil': 'BR',
#  'TX': 'USAC',
#  'Las Vegas': 'USAW',
#  'Belfast, Northern Ireland': 'UK',
#  'Salamanca': 'ES',
#  'Lahore, Pakistan': 'PK',
#  'Asuncion, Paraguay': 'PARA',
#  'Anaheim, CA': 'USAW',
#  'South Carolina': 'USAE',
#  'Twitter': 'CLEVER',
#  'Adelaide, Australia': 'ASTL',
#  'Manila': 'PH',
#  'Malaga': 'ES',
#  'York, England': 'UK',
#  'Granada, España': 'ES',
#  'Chicagoland': 'USAC',
#  'japan': 'JPN',
#  'Ciudad de México': 'MX',
#  'Grand Rapids, MI': 'USAE',
#  'any pronouns': 'GENDER',
#  '地球': 'JPN',
#  'Utah, USA': 'USAM',
#  'St. Louis': 'USAC',
#  '福岡県': 'JPN',
#  'chennai': 'IN',
#  'Toronto, Ontario, Canada': 'CAE',
#  'Lincoln, NE': 'USAC',
#  'Somerset': 'UK',
#  'Coimbatore, India': 'IN',
#  'Cincinnati': 'USAE',
#  'Galway, Ireland': 'IE',
#  'Ecuador': 'EC',
#  'argentina': 'AR',
#  'earth': 'CLEVER',
#  'Vitoria-Gasteiz': 'ES',
#  'Mendoza, Argentina': 'AR',
#  'Honolulu, HI': 'HI',
#  'Montreal': 'CAE',
#  'PNW': 'USAW',
#  '🇨🇦': 'CA',
#  'Medellín, Colombia': 'CO',
#  'Leicester': 'UK',
#  'Iowa': 'USAC',
#  'Aberdeen, Scotland': 'UK',
#  'Leicester, England': 'UK',
#  'he/they': 'GENDER',
#  'Columbus, Ohio': 'USAE',
#  'Santiago': 'ES',
#  '神奈川県川崎市': 'JPN',
#  'London, United Kingdom': 'UK',
#  'Paraguay': 'PARA',
#  'Norway': 'EUR',
#  'Jakarta Capital Region': 'ID',
#  'Belgium': 'EUR',
#  'Lexington, KY': 'USAE',
#  'Manchester, UK': 'UK',
#  'Kenya': 'KE',
#  'Murcia, Spain': 'ES',
#  'Valparaíso, Chile': 'CL',
#  'Dayton, OH': 'USAE',
#  'さいたま': 'JPN',
#  'Bombay': 'IN',
#  'Sweden': 'EUR',
#  'St. Louis, MO': 'USAC',
#  'CA': 'CA',
#  'Houston': 'USAC',
#  'Minneapolis': 'USAC',
#  'Southampton, England': 'UK',
#  '兵庫県': 'JPN',
#  'Belfast': 'UK',
#  'Hertfordshire': 'UK',
#  'Ankara': 'TK',
#  'Istanbul, Turkey': 'TK',
#  '名古屋': 'JPN',
#  'Nashville': 'USAC',
#  'Reno, NV': 'USAW',
#  'Guayaquil, Ecuador': 'EC',
#  'Alicante, Spain': 'ES',
#  'Boise, ID': 'USAM',
#  'ヒスイ地方': 'JPN',
#  'Chattanooga, TN': 'USAC',
#  'Greensboro, NC': 'USAE',
#  'Des Moines, IA': 'USA',
#  'New Orleans': 'USAC',
#  'Orange County, CA': 'USAW',
#  'Winnipeg': 'CAC',
#  'Selangor, Malaysia': 'MY',
#  'Seoul, Korea': 'KOR',
#  'Adelaide': 'ASTL',
#  'Kent': 'UK',
#  'Staten Island, NY': 'USAE',
#  'Louisiana': 'USAC',
#  'uk': 'UK',
#  'Madrid ': 'ES',
#  'Cambridge, England': 'UK',
#  'San Diego': 'USAW',
#  'Mars': 'CLEVER',
#  'South Florida': 'USAE',
#  '大阪市': 'JPN',
#  'Oxford, England': 'UK',
#  'Hampshire': 'UK',
#  '札幌': 'JPN',
#  'Maine': 'USAE',
#  'Cincinnati, Ohio': 'USAE',
#  'Hamburg, Germany': 'DE',
#  'New Hampshire': 'USAE',
#  'Peru': 'PE',
#  'London, Ontario': 'CAE',
#  'Kuala Lumpur, Malaysia': 'MY',
#  'VA': 'VA',
#  'Quezon City': 'PH',
#  'おうち': 'JPN',
#  'St Paul, MN': 'USAC',
#  'Tatooine': 'CLEVER',
#  'Dundee, Scotland': 'UK',
#  'Limerick, Ireland': 'IE',
#  'Global': 'Earth',
#  'Quezon City, Philippines': 'PH',
#  'Hogwarts': 'CLEVER',
#  '神戸': 'JPN',
#  'Providence, RI': 'USAE',
#  'Little Rock, AR': 'USAC',
#  'A Coruña': 'ES',
#  'Egypt': 'EG',
#  '愛知': 'JPN',
#  'Kuala Lumpur City': 'MY',
#  'Bahamas': 'BA',
#  'nyc': 'USAE',
#  'Calgary': 'CAM',
#  'here': 'CLEVER',
#  'Santiago de Compostela': 'ES',
#  'Delaware, USA': 'USAE',
#  'Greenville, SC': 'USAE',
#  '福岡': 'JPN',
#  'Northern Virginia': 'USAE',
#  'FL': 'USAE',
#  'Los Angeles, California': 'USAW',
#  'Tamil Nadu, India': 'IN',
#  'Norwich, England': 'UK',
#  'Indianapolis': 'USAC',
#  'Kansas, USA': 'USAC',
#  'Dallas, Texas': 'USAC',
#  'Stockholm, Sweden': 'EUR',
#  'Huelva, Spain': 'ES',
#  'Connecticut': 'USAE',
#  'Utah': 'USAM',
#  'everywhere': 'CLEVER',
#  'Lebanon': 'LEBN',
#  'Maldives': 'MLDV',
#  'Andalucía, España': 'ES',
#  'Asheville, NC': 'USAE',
#  'Galicia, España': 'ES',
#  'Seville, Spain': 'ES',
#  'Kentucky': 'USAE',
#  'Switzerland': 'EUR',
#  'Neverland': 'CLEVER',
#  'Tacoma, WA': 'USAW',
#  'Nowhere': 'CLEVER',
#  'Arlington, TX': 'USAC',
#  'Santa Cruz de Tenerife, Spain': 'ES',
#  'Huntsville, AL': 'USAE',
#  'Santa Monica, CA': 'USAW',
#  'Nairobi': 'KE',
#  '18': 'CLEVER',
#  'Pune': 'IN',
#  'Norman, OK': 'USAC',
#  'Spokane, WA': 'USAW',
#  'Guadalajara, Jalisco': 'MX',
#  'Worldwide': 'Earth',
#  'Pretoria, South Africa': 'SA',
#  'Hamilton, Ontario': 'CAE',
#  'Sao Paulo, Brazil': 'BR',
#  'Kuwait': 'KZ',
#  'Ottawa, Ontario, Canada': 'CAE',
#  'São Paulo': 'BR',
#  'Surrey': 'UK',
#  'PH': 'PH',
#  'Yorkshire and The Humber': 'UK',
#  'Amsterdam, The Netherlands': 'EUR',
#  'South Dublin, Ireland': 'IE',
#  '日本 埼玉': 'JPN',
#  'Denver': 'USAM',
#  'Atlanta, Georgia': 'USAE',
#  'Bengaluru': 'IN',
#  '대한민국 서울': 'KOR',
#  'Philly': 'USAE',
#  'West Sussex': 'UK',
#  'Sioux Falls, SD': 'USAC',
#  'Christchurch City, New Zealand': 'NZ',
#  'los angeles': 'USAW',
#  'Italia': 'EUR',
#  'Wakanda': 'CLEVER',
#  'Mesa, AZ': 'USAM',
#  'ATL': 'USAE',
#  'Bristol, UK': 'UK',
#  'Chesterfield, England': 'UK',
#  'La Plata': 'AR',
#  'San Francisco Bay Area': 'USAW',
#  'Mississauga, Ontario': 'CAE',
#  '広島': 'JPN',
#  'West Midlands': 'UK',
#  '日本 愛知': 'JPN',
#  'Rhode Island': 'USAE',
#  'Durban, South Africa': 'SA',
#  'Narnia': 'CLEVER',
#  '日本 大阪': 'JPN',
#  'Corunna, Galicia': 'ES',
#  'New South Wales, Australia': 'ASTL',
#  'Arkansas': 'USAE',
#  'St Petersburg, FL': 'USAE',
#  'Home': 'CLEVER',
#  'Honduras': 'HO',
#  'Oslo, Norway': 'EUR',
#  'Alicante, España': 'ES',
#  'london': 'UK',
#  'Vermont, USA': 'USAE',
#  'Mississippi, USA': 'USAC',
#  'Iowa City, IA': 'USAC',
#  'Caceres, Spain': 'ES',
#  'españa': 'ES',
#  'New Mexico, USA': 'USAM',
#  'Wichita, KS': 'USAC',
#  'Houston, Texas': 'USAC',
#  'Badalona': 'ES',
#  'El Paso, TX': 'USAC',
#  'Alicante': 'ES',
#  'Tokyo,Japan': 'JPN',
#  'Caracas, Venezuela': 'VE',
#  'Somewhere over the rainbow': 'CLEVER',
#  'Gotham City': 'CLEVER',
#  '北': 'JPN',
#  'Azerbaijan': 'AZR',
#  'Bahrain': 'BAHR',
#  'Derbyshire': 'UK',
#  'Nepal': 'NEP',
#  'Aberdeen': 'UK',
#  'she/her 21': 'GENDER',
#  'Ponferrada, Spain': 'ES',
#  'Badajoz': 'ES',
#  'Cambridge, MA': 'USAE',
#  'Calgary, Alberta, Canada': 'USAM',
#  'Finland': 'EUR',
#  'Lima': 'PE',
#  'Jerez de la Frontera, España': 'ES',
#  'Lincoln, England': 'UK',
#  'Greece': 'EUR',
#  'DC': 'USAE',
#  'Winston-Salem, NC': 'USAE',
#  'Missouri': 'USAC',
#  'Barcelona, Cataluña': 'ES',
#  'Concepción, Chile': 'CL',
#  'Chandigarh, India': 'IN',
#  'Murcia, Región de Murcia': 'ES',
#  'Derby, England': 'UK',
#  'Hawaii, USA': 'HI',
#  'CT': 'USAE',
#  'Principado de Asturias, España': 'ES',
#  'Riyadh': 'ZA',
#  'Osaka-fu, Japan': 'JPN',
#  'Las Palmas de Gran Canaria': 'ES',
#  'Cymru': 'UK',
#  'Kanagawa, Japan': 'JPN',
#  'Kalamazoo, MI': 'USAE',
#  'Puebla, México': 'MX',
#  'Córdoba, España': 'ES',
#  'Accra, Ghana': 'GHAN',
#  '北海道 札幌市': 'JPN',
#  '布団の中': 'JPN',
#  'Columbia, MD': 'USAE',
#  'Valladolid, Spain': 'ES',
#  'Kolkata': 'IN',
#  'Saragossa, Spain': 'ES',
#  'NorCal': 'USAW',
#  '試される大地': 'JPN',
#  'Behind you': 'CLEVER',
#  'South Jersey': 'USAE',
#  'Wien': 'AT',
#  'Lugo': 'ES',
#  'West Virginia, USA': 'USAE',
#  'Córdoba': 'ES',
#  'Christchurch, New Zealand': 'NZ',
#  'そのへん': 'JPN',
#  'Noida, India': 'IN',
#  'Bogota': 'CO',
#  'North Yorkshire': 'UK',
#  'Kansas': 'USAE',
#  'Bandung, Indonesia': 'ID',
#  'Dubai': 'UAE',
#  'Inverness, Scotland': 'UK',
#  'Mar del Plata, Argentina': 'AR',
#  'Yokohama, Japan': 'JPN',
#  'Wonderland': 'CLEVER',
#  'LA': 'USAW',
#  'Elche': 'ES',
#  'Saitama, Japan': 'JPN',
#  'A Coruña, España': 'ES',
#  'Evansville, IN': 'USAE',
#  'Brazil': 'BR',
#  'Newfoundland and Labrador': 'CAE',
#  'Jersey': 'USAE',
#  'South Australia': 'ASTL',
#  'Bolivia': 'BO',
#  'ohio': 'USAE',
#  'sevilla': 'ES',
#  'Sarasota, FL': 'USAE',
#  'Lagos': 'NG',
#  'Cairo': 'EG',
#  'Cornwall': 'UK',
#  'Baltimore, Maryland': 'USAE',
#  'Kyoto': 'JPN',
#  'Brighton': 'UK',
#  'Gijón, España': 'ES',
#  'Wadawurrung Country': 'ASTL',
#  'Taipei City, Taiwan': 'TW',
#  'Athens, GA': 'USAE',
#  'South Korea': 'KOR',
#  '🌎': 'Earth',
#  'Green Bay, WI': 'USAC',
#  'hell': 'CLEVER',
#  'República Catalana': 'CAT',
#  'Fort Lauderdale, FL': 'USAE',
#  'Boulder, CO': 'USAM',
#  'Taichung, Taiwan': 'TW',
#  '岐阜': 'JPN',
#  'Belgrade, Republic of Serbia': 'RS',
#  '🌌': 'CLEVER',
#  '田舎': 'JPN',
#  'india': 'IN',
#  'Comunidad Valenciana, España': 'ES',
#  'Jakarta Selatan, DKI Jakarta': 'ID',
#  'Bursa, Türkiye': 'TK',
#  'Washington DC': 'USAE',
#  'Puerto Rico, USA': 'USAE',
#  'Ile-de-France, France': 'FR',
#  'Perú': 'PE',
#  'Goa, India': 'IN',
#  'Navi Mumbai, India': 'IN',
#  'valencia': 'ES',
#  'Newcastle upon Tyne': 'UK',
#  'Regina, Saskatchewan': 'CAM',
#  'somewhere': 'CLEVER',
#  '虚無': 'JPN',
#  'Russia': 'RU',
#  'Antarctica': 'AT',
#  'Sydney Australia': 'ASTL',
#  'Vienna, Austria': 'AT',
#  '日本 ': 'JPN',
#  'Newcastle': 'UK',
#  'Worcester, MA': 'USAE',
#  'Charlottesville, VA': 'USAE',
#  'South Wales': 'UK',
#  'Kuala Lumpur Federal Territory': 'MY',
#  'Antalya, Türkiye': 'TK',
#  'JPN': 'JPN',
#  'Yorkshire and The Humber, Engl': 'UK',
#  'Oviedo': 'ES',
#  'Vitoria-Gasteiz, Euskadi': 'ES',
#  'U.K.': 'UK',
#  'she/her 19': 'GENDER',
#  'Lusaka, Zambia': 'ZM',
#  'Redmond, WA': 'USAW',
#  'Shropshire': 'UK',
#  'Badajoz, España': 'ES',
#  '京都市': 'JPN',
#  'philippines': 'PH',
#  'Lincolnshire': 'UK',
#  'Málaga, Andalucía': 'ES',
#  'Andalusia, Spain': 'ES',
#  'Nebraska, USA': 'USAC',
#  'Mar del Plata': 'ES',
#  'Fayetteville, AR': 'USAC',
#  'Anchorage, AK': 'AK',
#  '九州': 'JPN',
#  'Vancouver, Canada': 'CAW',
#  'Edmonton, AB': 'CAM',
#  'South Dakota, USA': 'USAC',
#  'Devon': 'UK',
#  'Virginia Beach, VA': 'USAE',
#  'Cleveland': 'USAE',
#  'Amsterdam': 'EUR',
#  '都内': 'JPN',
#  'they/she': 'GENDER',
#  'Burbank, CA': 'USAW',
#  'new york': 'USAE',
#  'Topeka, KS': 'USAC',
#  'Wirral': 'UK',
#  'Melbourne, Victoria, Australia': 'ASTL',
#  'Québec, Canada': 'CAE',
#  'US': 'USA',
#  'Bellingham, WA': 'USAW',
#  'Durham, UK': 'UK',
#  'とうきょう': 'JPN',
#  'Portugal': 'PT',
#  'Salamanca, Spain': 'ES',
#  '🌍': 'Earth',
#  'Burnaby, British Columbia': 'CAW',
#  'Cary, NC': 'USAE',
#  '127.0.0.1': 'CLEVER',
#  'Fukuoka': 'JPN',
#  'Silver Spring, MD': 'USAE',
#  'NZ': 'NZ',
#  'Milwaukee': 'USAC',
#  'Gainesville, FL': 'USAE',
#  'Miami': 'USAE',
#  'Madrid (España)': 'ES',
#  'Worthing, England': 'UK',
#  'Canada ': 'CA',
#  'Galiza': 'ES',
#  '犬小屋': 'JPN',
#  'Lancashire': 'UK',
#  'Stillwater, OK': 'USAC',
#  '.': None,
#  'Ontario': 'CAE',
#  'He/him': 'GENDER',
#  'Los Angeles ': 'USAW',
#  'Kingston, Jamaica': 'JAM',
#  'Albany, NY': 'USAE',
#  'Kent, UK': 'UK',
#  'Northern California': 'USAW',
#  'Montevideo': 'UR',
#  'Upstate NY': 'USAE',
#  'East, England': 'UK',
#  'Silicon Valley': 'USAW',
#  'Reading, England': 'UK',
#  'New Brunswick, Canada': 'CAE',
#  'Milton Keynes': 'UK',
#  'HTX': 'USAC',
#  'Cheshire': 'UK',
#  'San José, Costa Rica': 'CR',
#  'Tempe, AZ': 'USAM',
#  'Santa Coloma de Gramenet, Espa': 'ES',
#  'ちば': 'JPN',
#  'Chandler, AZ': 'USAM',
#  'Norwich': 'UK',
#  'Fife, Scotland': 'UK',
#  'Recoleta, Chile': 'CL',
#  'Alpharetta, GA': 'USAE',
#  '成人済': 'JPN',
#  'Decatur, GA': 'USAE',
#  'Santa Clara, CA': 'USAW',
#  'America': 'USA',
#  'Elche, España': 'ES',
#  'Melbourne Australia': 'ASTL',
#  'にぽん。いろしま・もなむー': 'JPN',
#  'Wiltshire': 'UK',
#  'El mundo': 'Earth',
#  'León, España': 'ES',
#  'iPhone: 0.000000,0.000000': 'CLEVER',
#  'SF Bay Area': 'USAW',
#  'Antalya, Turkey': 'TK',
#  'Wicklow, Ireland': 'IE',
#  'Norfolk, VA': 'USAE',
#  'Toledo, OH': 'USAE',
#  'México, D.F.': 'MX',
#  '実家': 'JPN',
#  'East Midlands, England': 'UK',
#  '東京都新宿区': 'JPN',
#  'Netherlands': 'EUR',
#  '東京都中央区': 'JPN',
#  'Oxfordshire': 'UK',
#  'Riverside, CA': 'USAW',
#  'North London': 'UK',
#  'Midwest': 'USAC',
#  '愛知 名古屋市': 'JPN',
#  'Kobe': 'JPN',
#  'Almería, Spain': 'ES',
#  'Alcorcón, Spain': 'ES',
#  'Syracuse, NY': 'USAE',
#  'Tucson, Arizona': 'USAM',
#  'Quilmes, Argentina': 'AR',
#  'さいたま市': 'JPN',
#  'Halifax': 'CAE',
#  'Chapel Hill, NC': 'USAE',
#  'indonesia': 'ID',
#  'canada': 'CA',
#  'Newcastle Upon Tyne': 'UK',
#  'St. Catharines, Ontario': 'CAE',
#  'Montclair, NJ': 'USAE',
#  '北関東': 'JPN',
#  '🇵🇭': 'PH',
#  '修羅の国': 'JPN',
#  'Durham, England': 'UK',
#  'Buckinghamshire': 'UK',
#  'Bodrum, Türkiye': 'UK',
#  'Calapan | Manila | Pasig': 'PH',
#  'MD': 'USAE',
#  'Oakville, Ontario': 'CAE',
#  'Bath': 'UK',
#  'Guadalajara': 'MX',
#  'Charleston, WV': 'USAE',
#  'Ghana': 'GH',
#  'chicago': 'USAC',
#  '東京都江東区': 'JPN',
#  'Columbia, MO': 'USAC',
#  'Newark, DE': 'USAE',
#  'Plano, TX': 'USAC',
#  'Gran Canaria': 'ES',
#  '20': 'CLEVER',
#  'Washington State': 'USAW',
#  'Hampshire, UK': 'UK',
#  'Scottsdale, AZ': 'USAM',
#  'Miami, Florida': 'USAE',
#  'Kent, England': 'UK',
#  'Peterborough, England': 'UK',
#  'Ottawa, Canada': 'CAE',
#  'CABA': 'AR',
#  '🇺🇸': 'USA',
#  'Fresno, CA': 'USAW',
#  'Murfreesboro, TN': 'USAC',
#  'Lucknow, India': 'IN',
#  'La Paz - Bolivia': 'BO',
#  'Northampton': 'UK',
#  'Las Palmas de Gran Canaria, Es': 'ES',
#  '狭間の地': 'JPN',
#  'AZ': 'USAM',
#  'よこはま': 'JPN',
#  'El Puerto de Santa María': 'ES',
#  'KCMO': 'USAC',
#  'United States of America': 'USA',
#  'Western Australia, Australia': 'ASTL',
#  'Huesca': 'ES',
#  'Bakersfield, CA': 'USAW',
#  'KWANGYA': 'KOR',
#  'Ann Arbor, MI': 'USAE',
#  'Milano': 'EUR',
#  'Puerto Rico': 'PR',
#  'Perth, Australia': 'ASTL',
#  'Avilés': 'ES',
#  'Wigan, England': 'UK',
#  'Hobart, Tasmania': 'ASTL',
#  'Tampa': 'USAE',
#  'Auckland, NZ': 'NZ',
#  'Saskatchewan, Canada': 'CA',
#  'Princeton, NJ': 'USAE',
#  'Indy': 'USAE',
#  'Long Island, New York': 'USAE',
#  'Portland, ME': 'USAE',
#  'Colchester, England': 'UK',
#  'Southampton': 'UK',
#  'Cádiz, España': 'ES',
#  'Terrassa': 'ES',
#  'Copenhagen, Denmark': 'EUR',
#  'Akron, OH': 'USAE',
#  'Surprise, AZ': 'USAM',
#  'Cáceres': 'ES',
#  'Earth ': 'Earth',
#  'Nook Inc. 보물쥐도': 'KOR',
#  'Canberra, Australia': 'ASTL',
#  'Kawasaki': 'JPN',
#  'Newfoundland, Canada': 'CAE',
#  '岐阜県': 'JPN',
#  'Fukuoka, Japan': 'JPN',
#  '東京 渋谷区': 'JPN',
#  'North Wales': 'UK',
#  'Ahmedabad': 'IN',
#  'Kingston, Ontario': 'CAE',
#  'Jaipur, India': 'IN',
#  'Cyprus': 'EUR',
#  'Toronto ': 'CAE',
#  'Tokyo Japan': 'JPN',
#  'Shanghai': '',
#  'Delhi, India': 'IN',
#  'Irvine, CA': 'USAW',
#  'Milton Keynes, England': 'UK'}

# %%
len(locs)
# Out:
# 997

# %% [markdown]
# This dictionary's keys are nearly 1000 of the top values found for `geo`. The values are broad regions, usually country. USA, Canada are divided into time zones according to some really good guesses.

# %%
[
    key 
    for key in locs.keys()
    if locs[key] == "CA"
]
# Out:
# ['Canada', '🇨🇦', 'CA', 'Canada ', 'canada', 'Saskatchewan, Canada']

# %%
# look at the unique location values
set(locs.values())
# Out:
# {'',
#  'AK',
#  'AR',
#  'ASTL',
#  'AT',
#  'AZR',
#  'BA',
#  'BAHR',
#  'BO',
#  'BR',
#  'CA',
#  'CAC',
#  'CAE',
#  'CAM',
#  'CAT',
#  'CAW',
#  'CL',
#  'CLEVER',
#  'CO',
#  'CR',
#  'DE',
#  'EC',
#  'EG',
#  'ELSL',
#  'ES',
#  'EUR',
#  'Earth',
#  'FR',
#  'GENDER',
#  'GH',
#  'GHAN',
#  'GUAT',
#  'HI',
#  'HK',
#  'HO',
#  'ID',
#  'IE',
#  'IL',
#  'IN',
#  'JAM',
#  'JPN',
#  'KE',
#  'KOR',
#  'KZ',
#  'LEBN',
#  'MLDV',
#  'MX',
#  'MY',
#  'NEP',
#  'NG',
#  'NZ',
#  None,
#  'PA',
#  'PARA',
#  'PE',
#  'PH',
#  'PK',
#  'PR',
#  'PT',
#  'RS',
#  'RU',
#  'SA',
#  'SG',
#  'SL',
#  'TH',
#  'TK',
#  'TT',
#  'TW',
#  'UAE',
#  'UK',
#  'UR',
#  'USA',
#  'USAC',
#  'USAE',
#  'USAM',
#  'USAW',
#  'VA',
#  'VE',
#  'ZA',
#  'ZM'}

# %%
tudf['broad_location'] = tudf['location'].apply(lambda this_location: locs[this_location] if this_location in locs.keys() else 'undefined')

# %%
# count the number of tweets covered by this dictionary
tudf['broad_location'].value_counts().head(20)
# Out:
# undefined    293109
# USAE          15601
# UK            10712
# JPN            7718
# ES             7507
# USAC           6573
# USA            5562
# USAW           4859
# IN             4297
# ASTL           3281
# CAE            2457
# AR             2066
# GENDER         1638
# USAM           1580
# IE             1334
# CLEVER         1305
# TK             1304
# CA              947
# MX              869
# PH              861
# Name: broad_location, dtype: int64

# %%
defined_loc_num = len(tudf[tudf['broad_location'] != 'undefined']) 
tudf_size = len(tudf)
print(f'{"{0:.1f}%".format(100*defined_loc_num/tudf_size)} == {defined_loc_num}/{tudf_size}.')
# Out:
# 24.2% == 93348/386457.

# %% [markdown]
# A bit less than 1/4 of the tweets have associated users who gave their location in one of these top categories. One out of four giving a general location is still valuable. By far, and unsurprisingly, the USA and UK are in the top. Wordle is an English language game. But Japan follows, with many Pokemon Worlders, as well as Spain, which appears to having its own popular Wordle variant in Spanish. India, Australia, Canada, Argentina, Ireland, Turkey, Mexico, and the Phillipines are all in the top 20.
#
# English and Japanese users like to write a few "clever" common locations, such as "in bed", "at home." All of the Japanese ones are assigned a location of Japan, as it's a good bet someone writing in Japanese is from Japan. English is more widespread, so it is harder to assign a single location to these clever ones.
#
# It is common in a few languages to write general locations like "Earth", or "the galaxy." These are funneled into "Earth" in the dictionary, but will be ultimately given undefined status along with "clever"s for assigning a location.
#
# Some people put pronouns in their location spot. These were assigned "GENDER" location. These as well will be given an "undefined" broad location. They could be valuable demographic information.

# %%
#send clevers to undefined
tudf[tudf['broad_location'] == 'CLEVER'] = 'undefined'

#send earths to undefined
tudf[tudf['broad_location'] == 'Earth'] = 'undefined'

#send genders to undefined
tudf[tudf['broad_location'] == 'GENDER'] = 'undefined'

# %%
loc_vcs = tudf['broad_location'].value_counts()

# %%
loc_vcs.index
# Out:
# Index(['undefined', 'USAE', 'UK', 'JPN', 'ES', 'USAC', 'USA', 'USAW', 'IN',
#        'ASTL', 'CAE', 'AR', 'USAM', 'IE', 'TK', 'CA', 'MX', 'PH', 'NZ', 'CL',
#        'SA', 'EUR', 'CAW', 'MY', 'CAM', 'CO', 'ID', 'DE', 'TH', 'FR', 'KOR',
#        'SG', 'PK', 'PE', 'KE', 'UR', 'EG', 'TT', 'NG', 'JAM', 'TW', 'CAC',
#        'BR', 'VE', 'CAT', 'HK', 'PA', 'UAE', 'CR', 'PARA', 'GUAT', 'EC', 'AT',
#        'SL', 'HI', 'IL', 'ELSL', 'BO', 'VA', 'BA', 'LEBN', 'MLDV', 'KZ', 'HO',
#        'NEP', 'AZR', 'BAHR', 'ZA', 'GHAN', 'RU', 'RS', 'ZM', 'AK', 'PT', 'PR',
#        'GH', ''],
#       dtype='object')

# %%
loc_vcs.values
# Out:
# array([296667,  15601,  10712,   7718,   7507,   6573,   5562,   4859,
#          4297,   3281,   2457,   2066,   1580,   1334,   1304,    947,
#           869,    861,    795,    793,    789,    765,    649,    559,
#           520,    519,    496,    453,    410,    367,    344,    314,
#           246,    243,    241,    230,    221,    206,    185,    184,
#           168,    160,    160,    158,    154,    151,    143,    141,
#           134,    101,     96,     95,     90,     84,     82,     62,
#            57,     54,     43,     42,     40,     40,     38,     35,
#            34,     34,     34,     33,     32,     29,     29,     28,
#            28,     27,     24,     24,     23], dtype=int64)

# %%
#look at remaining top broad locations
tudf['broad_location'].value_counts().head(50)
# Out:
# undefined    296667
# USAE          15601
# UK            10712
# JPN            7718
# ES             7507
# USAC           6573
# USA            5562
# USAW           4859
# IN             4297
# ASTL           3281
# CAE            2457
# AR             2066
# USAM           1580
# IE             1334
# TK             1304
# CA              947
# MX              869
# PH              861
# NZ              795
# CL              793
# SA              789
# EUR             765
# CAW             649
# MY              559
# CAM             520
# CO              519
# ID              496
# DE              453
# TH              410
# FR              367
# KOR             344
# SG              314
# PK              246
# PE              243
# KE              241
# UR              230
# EG              221
# TT              206
# NG              185
# JAM             184
# TW              168
# CAC             160
# BR              160
# VE              158
# CAT             154
# HK              151
# PA              143
# UAE             141
# CR              134
# PARA            101
# Name: broad_location, dtype: int64

# %%
#linear plot of broad locations
plt.figure(figsize = (12,6))
plt.barh(width = loc_vcs.values[1:20], y = loc_vcs.index[1:20])
# Out:
# <BarContainer object of 19 artists>

# %%
#log plot of broad locations
plt.figure(figsize = (12,6))
plt.barh(width = loc_vcs.values[1:26], y = loc_vcs.index[1:26], log = True)
# Out:
# <BarContainer object of 25 artists>

# %% [markdown]
# In the preprocessing stage, these will be turned into booleans for the model to grab onto.

# %% [markdown]
# # User `entities`
#
# I've called them `entities_user` in the merged df.

# %%
tudf.columns
# Out:
# Index(['conversation_id', 'reply_settings', 'lang', 'possibly_sensitive',
#        'source', 'text', 'context_annotations', 'author_id', 'created_at',
#        'referenced_tweets', 'in_reply_to_user_id', 'attachments', 'geo',
#        'withheld_tweet', 'name', 'public_metrics_user', 'url', 'description',
#        'profile_image_url', 'location', 'protected', 'username', 'verified',
#        'entities_user', 'pinned_tweet_id', 'withheld_user',
#        'entities_tweeturls', 'entities_tweetmentions',
#        'entities_tweethashtags', 'entities_tweetannotations',
#        'entities_tweetcashtags', 'public_metrics_tweetretweet_count',
#        'public_metrics_tweetreply_count', 'public_metrics_tweetlike_count',
#        'public_metrics_tweetquote_count', 'game', 'win', 'is_poke',
#        'user_has_description', 'wordle_tweet_number', 'ones',
#        'time_since_last_tweet', 'wordle_tweet_rate',
#        'time_since_last_tweet_rolling_60', 'time_since_last_tweet_rolling_600',
#        'tweet_rate_60', 'tweet_rate_600', 'broad_location'],
#       dtype='object')

# %%
#the .replace("'", '"')
# must be done to replace single quotes with double quotes. otherwise it's not JSON.
json.loads(tudf['entities_user'].iloc[1].replace("'", '"'))
# Out:
# {'url': {'urls': [{'start': 0,
#     'end': 23,
#     'url': 'https://t.co/OqVqYWdqMx',
#     'expanded_url': 'http://www.carlygarza.com/links',
#     'display_url': 'carlygarza.com/links'}]},
#  'description': {'mentions': [{'start': 89,
#     'end': 105,
#     'username': 'brickatbluestar'},
#    {'start': 108, 'end': 119, 'username': 'carlygarza'},
#    {'start': 122, 'end': 138, 'username': 'shopcakeforever'}]}}

# %% [markdown]
# ### verified

# %%
tudf[tudf['verified'] == True]
# Out:
#                          conversation_id reply_settings lang  \
# 1520128996435976193  1520128996435976193       everyone   en
# 1520131320323604480  1520120660642525184       everyone   en
# 1520131823170428930  1520131823170428930       everyone   en
# 1520132947210211330  1520132947210211330       everyone   en
# 1520136221569085440  1520136221569085440       everyone   en
# ...                                  ...            ...  ...
# 1522333017250811904  1522333017250811904       everyone   en
# 1522333020425887744  1522233543010643969       everyone   en
# 1522333776185077761  1522333776185077761       everyone   en
# 1522335034811854855  1522335034811854855       everyone   en
# 1522335060665552900  1522335060665552900       everyone   tr
#
#                     possibly_sensitive               source  \
# 1520128996435976193              False   Twitter for iPhone
# 1520131320323604480              False            TweetDeck
# 1520131823170428930              False   Twitter for iPhone
# 1520132947210211330              False   Twitter for iPhone
# 1520136221569085440              False  Twitter for Android
# ...                                ...                  ...
# 1522333017250811904              False   Twitter for iPhone
# 1522333020425887744              False  Twitter for Android
# 1522333776185077761              False   Twitter for iPhone
# 1522335034811854855              False   Twitter for iPhone
# 1522335060665552900              False      Twitter Web App
#
#                                                                   text  \
# 1520128996435976193  Wordle 314 5/6\n\n⬛🟨⬛⬛⬛\n⬛⬛🟩⬛🟩\n⬛⬛🟩🟨🟩\n⬛🟩🟩⬛🟩\n...
# 1520131320323604480  @cgboan I always appreciate some good Trevor B...
# 1520131823170428930  Wordle (ES)  #113 3/6\n\n⬜⬜⬜⬜🟩\n⬜🟨🟩⬜🟩\n🟩🟩🟩🟩🟩\n...
# 1520132947210211330  Wordle 314 6/6\n\n🟨⬛⬛⬛⬛\n⬛⬛🟩⬛🟨\n🟨⬛🟩⬛⬛\n⬛⬛🟩⬛⬛\n...
# 1520136221569085440  Wordle 315 6/6\n\n⬛🟩⬛⬛⬛\n⬛⬛⬛⬛⬛\n⬛🟩🟩⬛⬛\n⬛🟩🟩⬛⬛\n...
# ...                                                                ...
# 1522333017250811904  Wordle 320 5/6\n\n⬜⬜⬜🟩⬜\n⬜⬜🟨🟨⬜\n🟨🟩⬜🟩🟩\n⬜🟩🟩🟩🟩\n...
# 1522333020425887744  @rklau Sometimes the best thing that can happe...
# 1522333776185077761      Wordle 321 4/6*\n\n⬜⬜🟨⬜⬜\n🟨🟩⬜⬜⬜\n⬜🟩⬜🟩🟩\n🟩🟩🟩🟩🟩
# 1522335034811854855       Wordle 320 4/6\n\n🟩🟨⬛🟨⬛\n🟩⬛🟨🟩⬛\n🟩🟩⬛🟩🟩\n🟩🟩🟩🟩🟩
# 1522335060665552900  Bu tür kelimeleri (ipucu olmasın diye söylemiy...
#
#                                                    context_annotations  \
# 1520128996435976193  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1520131320323604480  [{'domain': {'id': '3', 'name': 'TV Shows', 'd...
# 1520131823170428930  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1520132947210211330  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1520136221569085440  [{'domain': {'id': '30', 'name': 'Entities [En...
# ...                                                                ...
# 1522333017250811904  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1522333020425887744  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1522333776185077761  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1522335034811854855  [{'domain': {'id': '30', 'name': 'Entities [En...
# 1522335060665552900  [{'domain': {'id': '30', 'name': 'Entities [En...
#
#                      author_id                 created_at  \
# 1520128996435976193   21126964  2022-04-29 19:52:50+00:00
# 1520131320323604480  340420393  2022-04-29 20:02:04+00:00
# 1520131823170428930  470448667  2022-04-29 20:04:03+00:00
# 1520132947210211330    5417332  2022-04-29 20:08:31+00:00
# 1520136221569085440  217124128  2022-04-29 20:21:32+00:00
# ...                        ...                        ...
# 1522333017250811904  595964937  2022-05-05 21:50:49+00:00
# 1522333020425887744    8070502  2022-05-05 21:50:50+00:00
# 1522333776185077761   23008442  2022-05-05 21:53:50+00:00
# 1522335034811854855   22028113  2022-05-05 21:58:50+00:00
# 1522335060665552900   95736749  2022-05-05 21:58:56+00:00
#
#                                                      referenced_tweets  \
# 1520128996435976193                                                 []
# 1520131320323604480  [{'type': 'replied_to', 'id': '152012066064252...
# 1520131823170428930                                                 []
# 1520132947210211330                                                 []
# 1520136221569085440                                                 []
# ...                                                                ...
# 1522333017250811904                                                 []
# 1522333020425887744  [{'type': 'replied_to', 'id': '152223354301064...
# 1522333776185077761                                                 []
# 1522335034811854855                                                 []
# 1522335060665552900                                                 []
#
#                     in_reply_to_user_id attachments  \
# 1520128996435976193                 0.0          {}
# 1520131320323604480        1961379848.0          {}
# 1520131823170428930                 0.0          {}
# 1520132947210211330                 0.0          {}
# 1520136221569085440                 0.0          {}
# ...                                 ...         ...
# 1522333017250811904                 0.0          {}
# 1522333020425887744            901651.0          {}
# 1522333776185077761                 0.0          {}
# 1522335034811854855                 0.0          {}
# 1522335060665552900                 0.0          {}
#
#                                                   geo withheld_tweet  \
# 1520128996435976193                                {}             {}
# 1520131320323604480                                {}             {}
# 1520131823170428930  {'place_id': '8f754c4539126636'}             {}
# 1520132947210211330                                {}             {}
# 1520136221569085440                                {}             {}
# ...                                               ...            ...
# 1522333017250811904                                {}             {}
# 1522333020425887744                                {}             {}
# 1522333776185077761                                {}             {}
# 1522335034811854855                                {}             {}
# 1522335060665552900                                {}             {}
#
#                                      name  \
# 1520128996435976193      Quinton Martinez
# 1520131320323604480         Luke Thompson
# 1520131823170428930          Javier Pagán
# 1520132947210211330   Joshua Hale Fialkov
# 1520136221569085440  Krishna Chandra (KC)
# ...                                   ...
# 1522333017250811904         Heather Kelly
# 1522333020425887744           Dan Shapiro
# 1522333776185077761    Chelsea Spresser 🌈
# 1522335034811854855           Nasha Smith
# 1522335060665552900           Tevfik Uyar
#
#                                                    public_metrics_user  \
# 1520128996435976193  {'followers_count': 5285, 'following_count': 3...
# 1520131320323604480  {'followers_count': 2340, 'following_count': 5...
# 1520131823170428930  {'followers_count': 1798, 'following_count': 1...
# 1520132947210211330  {'followers_count': 11947, 'following_count': ...
# 1520136221569085440  {'followers_count': 1382, 'following_count': 8...
# ...                                                                ...
# 1522333017250811904  {'followers_count': 1200, 'following_count': 2...
# 1522333020425887744  {'followers_count': 11391, 'following_count': ...
# 1522333776185077761  {'followers_count': 1048, 'following_count': 2...
# 1522335034811854855  {'followers_count': 1376, 'following_count': 7...
# 1522335060665552900  {'followers_count': 110625, 'following_count':...
#
#                                          url  \
# 1520128996435976193  https://t.co/N9AVjVzyX0
# 1520131320323604480  https://t.co/Oi6PpcR8Lt
# 1520131823170428930
# 1520132947210211330  https://t.co/ebD71SlF5v
# 1520136221569085440  https://t.co/DxROBp5WW4
# ...                                      ...
# 1522333017250811904  https://t.co/NXQzHF8DoY
# 1522333020425887744  https://t.co/ppsmeG0EAB
# 1522333776185077761
# 1522335034811854855  https://t.co/yLRUDUHs99
# 1522335060665552900  https://t.co/HAjXZt989Q
#
#                                                            description  \
# 1520128996435976193  Husband to Eva, Father of Penelope. Mild-manne...
# 1520131320323604480  @Yakima_Herald outdoors/sports reporter. Socce...
# 1520131823170428930      Having fun and working hard at @TwitterEspana
# 1520132947210211330  Maker of TV, Comics (THE BUNKER, THE LIFE AFTE...
# 1520136221569085440  Editor @Reuters. Bookworm. @Arsenal Addict. Te...
# ...                                                                ...
# 1522333017250811904  Producer, News & Traffic reporter.  I tell peo...
# 1522333020425887744  CEO @Glowforge and https://t.co/7QcGGhEiVD. He...
# 1522333776185077761  Just trying to figure out what to do with the ...
# 1522335034811854855  Freelance writer | @Forbes Contributor | Bylin...
# 1522335060665552900  Bilim(+kurgu) Yazarı & Bilimsel Şüpheci, PhD. ...
#
#                                                      profile_image_url  \
# 1520128996435976193  https://pbs.twimg.com/profile_images/378800000...
# 1520131320323604480  https://pbs.twimg.com/profile_images/122443793...
# 1520131823170428930  https://pbs.twimg.com/profile_images/135962418...
# 1520132947210211330  https://pbs.twimg.com/profile_images/145088114...
# 1520136221569085440  https://pbs.twimg.com/profile_images/144014365...
# ...                                                                ...
# 1522333017250811904  https://pbs.twimg.com/profile_images/116529307...
# 1522333020425887744  https://pbs.twimg.com/profile_images/615723757...
# 1522333776185077761  https://pbs.twimg.com/profile_images/147691116...
# 1522335034811854855  https://pbs.twimg.com/profile_images/121317746...
# 1522335060665552900  https://pbs.twimg.com/profile_images/150889543...
#
#                                    location protected         username  \
# 1520128996435976193      Corpus Christi, TX     False        qmartinez
# 1520131320323604480              Yakima, WA     False      LukeTScribe
# 1520131823170428930                  Madrid     False    JavierPagan76
# 1520132947210211330     North Hollywood, CA     False      JoshFialkov
# 1520136221569085440                   India     False    krishna_eluri
# ...                                     ...       ...              ...
# 1522333017250811904      Salt Lake City, UT     False  KSLHeatherKelly
# 1522333020425887744             Seattle, WA     False       danshapiro
# 1522333776185077761  Gold Coast, Queensland     False    chelseajclark
# 1522335034811854855                             False       nashasmith
# 1522335060665552900            Dyson Sphere     False      tevfik_uyar
#
#                     verified  \
# 1520128996435976193     True
# 1520131320323604480     True
# 1520131823170428930     True
# 1520132947210211330     True
# 1520136221569085440     True
# ...                      ...
# 1522333017250811904     True
# 1522333020425887744     True
# 1522333776185077761     True
# 1522335034811854855     True
# 1522335060665552900     True
#
#                                                          entities_user  \
# 1520128996435976193  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1520131320323604480  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1520131823170428930  {'description': {'mentions': [{'start': 31, 'e...
# 1520132947210211330  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1520136221569085440  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# ...                                                                ...
# 1522333017250811904  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1522333020425887744  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1522333776185077761                                                 {}
# 1522335034811854855  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
# 1522335060665552900  {'url': {'urls': [{'start': 0, 'end': 23, 'url...
#
#                            pinned_tweet_id withheld_user  \
# 1520128996435976193                    0.0            {}
# 1520131320323604480                    0.0            {}
# 1520131823170428930                    0.0            {}
# 1520132947210211330  1490959869930663936.0            {}
# 1520136221569085440                    0.0            {}
# ...                                    ...           ...
# 1522333017250811904  1408056799450652672.0            {}
# 1522333020425887744   731635940804853760.0            {}
# 1522333776185077761                    0.0            {}
# 1522335034811854855  1329485467578937088.0            {}
# 1522335060665552900  1522827127665700864.0            {}
#
#                                                     entities_tweeturls  \
# 1520128996435976193                                                NaN
# 1520131320323604480                                                NaN
# 1520131823170428930  [{'start': 42, 'end': 65, 'url': 'https://t.co...
# 1520132947210211330                                                NaN
# 1520136221569085440                                                NaN
# ...                                                                ...
# 1522333017250811904                                                NaN
# 1522333020425887744                                                NaN
# 1522333776185077761                                                NaN
# 1522335034811854855                                                NaN
# 1522335060665552900  [{'start': 171, 'end': 194, 'url': 'https://t....
#
#                                                 entities_tweetmentions  \
# 1520128996435976193                                                NaN
# 1520131320323604480  [{'start': 0, 'end': 7, 'username': 'cgboan', ...
# 1520131823170428930                                                NaN
# 1520132947210211330                                                NaN
# 1520136221569085440                                                NaN
# ...                                                                ...
# 1522333017250811904                                                NaN
# 1522333020425887744  [{'start': 0, 'end': 6, 'username': 'rklau', '...
# 1522333776185077761                                                NaN
# 1522335034811854855                                                NaN
# 1522335060665552900                                                NaN
#
#                                                 entities_tweethashtags  \
# 1520128996435976193                                                NaN
# 1520131320323604480                                                NaN
# 1520131823170428930                                                NaN
# 1520132947210211330                                                NaN
# 1520136221569085440                                                NaN
# ...                                                                ...
# 1522333017250811904                                                NaN
# 1522333020425887744                                                NaN
# 1522333776185077761                                                NaN
# 1522335034811854855                                                NaN
# 1522335060665552900  [{'start': 99, 'end': 107, 'tag': 'wordle6'}, ...
#
#                                              entities_tweetannotations  \
# 1520128996435976193                                                NaN
# 1520131320323604480  [{'start': 38, 'end': 49, 'probability': 0.990...
# 1520131823170428930                                                NaN
# 1520132947210211330                                                NaN
# 1520136221569085440                                                NaN
# ...                                                                ...
# 1522333017250811904                                                NaN
# 1522333020425887744                                                NaN
# 1522333776185077761                                                NaN
# 1522335034811854855                                                NaN
# 1522335060665552900                                                NaN
#
#                     entities_tweetcashtags public_metrics_tweetretweet_count  \
# 1520128996435976193                    NaN                                 0
# 1520131320323604480                    NaN                                 0
# 1520131823170428930                    NaN                                 0
# 1520132947210211330                    NaN                                 0
# 1520136221569085440                    NaN                                 0
# ...                                    ...                               ...
# 1522333017250811904                    NaN                                 0
# 1522333020425887744                    NaN                                 0
# 1522333776185077761                    NaN                                 0
# 1522335034811854855                    NaN                                 0
# 1522335060665552900                    NaN                                 0
#
#                     public_metrics_tweetreply_count  \
# 1520128996435976193                               0
# 1520131320323604480                               1
# 1520131823170428930                               0
# 1520132947210211330                               0
# 1520136221569085440                               0
# ...                                             ...
# 1522333017250811904                               0
# 1522333020425887744                               0
# 1522333776185077761                               0
# 1522335034811854855                               0
# 1522335060665552900                              12
#
#                     public_metrics_tweetlike_count  \
# 1520128996435976193                              0
# 1520131320323604480                              1
# 1520131823170428930                              1
# 1520132947210211330                              0
# 1520136221569085440                              0
# ...                                            ...
# 1522333017250811904                              0
# 1522333020425887744                              1
# 1522333776185077761                              0
# 1522335034811854855                              0
# 1522335060665552900                              8
#
#                     public_metrics_tweetquote_count game    win is_poke  \
# 1520128996435976193                               0  NaN  False   False
# 1520131320323604480                               0  NaN  False   False
# 1520131823170428930                               0  NaN  False   False
# 1520132947210211330                               0  NaN  False   False
# 1520136221569085440                               0  NaN  False   False
# ...                                             ...  ...    ...     ...
# 1522333017250811904                               0  NaN  False   False
# 1522333020425887744                               0  NaN  False   False
# 1522333776185077761                               0  NaN  False   False
# 1522335034811854855                               0  NaN  False   False
# 1522335060665552900                               0  NaN  False   False
#
#                     user_has_description wordle_tweet_number ones  \
# 1520128996435976193                 True                 107  1.0
# 1520131320323604480                 True                 312  1.0
# 1520131823170428930                 True                 358  1.0
# 1520132947210211330                 True                 453  1.0
# 1520136221569085440                 True                 743  1.0
# ...                                  ...                 ...  ...
# 1522333017250811904                 True              386110  1.0
# 1522333020425887744                 True              386111  1.0
# 1522333776185077761                 True              386226  1.0
# 1522335034811854855                 True              386423  1.0
# 1522335060665552900                 True              386427  1.0
#
#                     time_since_last_tweet wordle_tweet_rate  \
# 1520128996435976193                   1.0               1.0
# 1520131320323604480                   5.0               0.2
# 1520131823170428930                   4.0              0.25
# 1520132947210211330                   0.0               inf
# 1520136221569085440                   1.0               1.0
# ...                                   ...               ...
# 1522333017250811904                   1.0               1.0
# 1522333020425887744                   0.0               inf
# 1522333776185077761                   0.0               inf
# 1522335034811854855                   1.0               1.0
# 1522335060665552900                   2.0               0.5
#
#                     time_since_last_tweet_rolling_60  \
# 1520128996435976193                         3.116667
# 1520131320323604480                         2.566667
# 1520131823170428930                             2.65
# 1520132947210211330                              2.3
# 1520136221569085440                              2.3
# ...                                              ...
# 1522333017250811904                         1.383333
# 1522333020425887744                             1.35
# 1522333776185077761                         1.566667
# 1522335034811854855                         1.383333
# 1522335060665552900                             1.45
#
#                     time_since_last_tweet_rolling_600 tweet_rate_60  \
# 1520128996435976193                               NaN      0.320856
# 1520131320323604480                               NaN       0.38961
# 1520131823170428930                               NaN      0.377358
# 1520132947210211330                               NaN      0.434783
# 1520136221569085440                          2.723333      0.434783
# ...                                               ...           ...
# 1522333017250811904                          1.543333      0.722892
# 1522333020425887744                          1.541667      0.740741
# 1522333776185077761                          1.543333      0.638298
# 1522335034811854855                          1.553333      0.722892
# 1522335060665552900                          1.553333      0.689655
#
#                     tweet_rate_600 broad_location
# 1520128996435976193            NaN      undefined
# 1520131320323604480            NaN      undefined
# 1520131823170428930            NaN             ES
# 1520132947210211330            NaN      undefined
# 1520136221569085440       0.367197             IN
# ...                            ...            ...
# 1522333017250811904       0.647948           USAM
# 1522333020425887744       0.648649           USAW
# 1522333776185077761       0.647948      undefined
# 1522335034811854855       0.643777      undefined
# 1522335060665552900       0.643777      undefined
#
# [2565 rows x 48 columns]

# %% [markdown]
# # Export for preprocessing
#
# choosing columns to build a model with.
#
# reply_settings will lead to overfitting. perhaps also with replies, etc.
# anything that favors a small number of individual tweets or users with high influence will cause overfitting.
#
#
# - lang
# - possibly sensitive
#     seems to have a relationship with location. specific sites.
# - source
#     make top sources
# - text
# - created_at
# - location
# - game
# - win
# - is_poke
# - broad location
# - hashtags
# - has_hashtags

# %%
save_these_cols = [
    'lang',
    'possibly_sensitive',
    'source',
    'text',
    'created_at',
    'location',
    'game',
    'win',
    'is_poke',
    'broad_location',
    'hashtags',
    'has_hashtags'
]

# %%
#export these columns
data_for_preprocessing_path = '../merged_data/data_for_preprocessing.csv'
tudf[save_these_cols].to_csv(data_for_preprocessing_path)
