# %% [markdown]
# Location subsets
# ---
#
# Locations can be quite broad or specific. This dictionary can be used to get the broad location corresponding to a specific one.

# %%
import json

# %%
'USAE'
'USAW'
'USAC'
'CAE'
'CAW'
'USAM'
# Out:
# 'USAM'

# %%
#pull in list of unique locations from EDA notebook.
locs = list(pd.read_csv('unique_locations.csv', index_col='Unnamed: 0')['0'])

# %%
locs
# Out:
# [nan,
#  '0',
#  'United States',
#  'Los Angeles, CA',
#  'London',
#  'London, England',
#  'India',
#  'Chicago, IL',
#  '日本',
#  'Canada',
#  'Madrid',
#  'New York, NY',
#  'she/her',
#  'United Kingdom',
#  'Japan',
#  'Australia',
#  'Atlanta, GA',
#  'California, USA',
#  'UK',
#  'England, United Kingdom',
#  'España',
#  'Washington, DC',
#  'USA',
#  'Toronto, Ontario',
#  'Seattle, WA',
#  'Tokyo',
#  'Buenos Aires, Argentina',
#  'Ireland',
#  'Madrid, Comunidad de Madrid',
#  'Argentina',
#  '東京',
#  'Florida, USA',
#  'Brooklyn, NY',
#  'Houston, TX',
#  '東京都',
#  'Philadelphia, PA',
#  'Toronto',
#  'New York, USA',
#  'Melbourne, Victoria',
#  'Boston, MA',
#  'Texas, USA',
#  'Santiago, Chile',
#  'Mumbai, India',
#  'New York',
#  'Austin, TX',
#  'New Jersey, USA',
#  'Tokyo, Japan',
#  'Earth',
#  'Philippines',
#  'Chicago',
#  'California',
#  'Barcelona',
#  'Mumbai',
#  'NYC',
#  'Bengaluru, India',
#  'Los Angeles',
#  'Spain',
#  'Dallas, TX',
# ...

# %%
locations = {
    'United States':'USA',
 'Los Angeles, CA':'USA',
 'London':'UK',
 'London, England':'UK',
 'India':'IN',
 'Chicago, IL':'USA',
 '日本':'JPN',
 'Canada':'CA',
 'Madrid':'ES',
 'New York, NY':'USA',
 'she/her':'GENDER',
 'United Kingdom':'UK',
 'Japan':'JPN',
 'Australia':'ASTL',
 'Atlanta, GA':'USAE',
 'California, USA':'USAW',
 'UK':'UK',
 'England, United Kingdom':'UK',
 'España':'ES',
 'Washington, DC':'USAE',
 'USA':'USA',
 'Toronto, Ontario':'CAE',
 'Seattle, WA':'USAW',
 'Tokyo':'JPN',
 'Buenos Aires, Argentina':'AR',
 'Ireland':'IE',
 'Madrid, Comunidad de Madrid':'ES',
 'Argentina':'AR',
 '東京':'JPN',
 'Florida, USA':'USAE',
 'Brooklyn, NY':'USAE',
 'Houston, TX':'USAC',
 '東京都':'JPN',
 'Philadelphia, PA':'USAE',
 'Toronto':'CAE',
 'New York, USA':'USAE',
 'Melbourne, Victoria':'ASTL',
 'Boston, MA':'USAE',
 'Texas, USA':'USAC',
 'Santiago, Chile':'CL',
 'Mumbai, India':'IN',
 'New York':'USAE',
 'Austin, TX':'USAC',
 'New Jersey, USA':'USAE',
 'Tokyo, Japan':'JPN',
 'Earth':'Earth',
 'Philippines':'PH',
 'Chicago':'USAC',
 'California':'USAW',
 'Barcelona':'ES',
 'Mumbai':'IN',
 'NYC':'USAE',
 'Bengaluru, India':'IN',
 'Los Angeles':'USAW',
 'Spain':'ES',
 'Dallas, TX':'USAC',
 'Singapore':'SG',
 'Malaysia':'MY',
 'San Diego, CA':'USAE',
 'İstanbul, Türkiye':'TK',
 'Portland, OR':'USAW',
 'Massachusetts, USA':'USAE',
 'Chennai, India':'IN',
 'Scotland':'UK',
 'Bangalore':'IN',
 'Ontario, Canada':'CAE',
 'Pittsburgh, PA':'USAE',
 'Las Vegas, NV':'USAW',
 'Texas':'USAC',
 'Sydney, New South Wales':'ASTL',
 'San Francisco, CA':'USAW',
 'Michigan, USA':'USAE',
 'Nashville, TN':'USAC',
 'Melbourne, Australia':'ASTL',
 '日本 東京':'JPN',
 'Charlotte, NC':'USAE',
 'Ohio, USA':'USAE',
 'Buenos Aires':'AR',
 'Pennsylvania, USA':'USAE',
 'Virginia, USA':'USAE',
 'he/him':'GENDER',
 'Chile':'CL',
 'New Delhi, India':'IN',
 'North Carolina, USA':'USA',
 'New Zealand':'NZ',
 'Dublin':'IE',
 'Melbourne':'ASTL',
 'Scotland, United Kingdom':'UK',
 'Glasgow, Scotland':'UK',
 'England':'UK',
 'Orlando, FL':'USAE',
 'Barcelona, España':'ES',
 'Indonesia':'ID',
 'Sydney, Australia':'ASTL',
 'Ciudad Autónoma de Buenos Aire':'AR',
 'Manchester, England':'UK',
 'Sevilla':'ES',
 'Denver, CO':'USAM',
 'New Jersey':'USAE',
 'Sydney':'ASTL',
 'Manchester':'UK',
 'Maryland, USA':'USA',
 'Baltimore, MD':'USA',
 'South Africa':'SA',
 'Bangkok, Thailand':'TH',
 'Johannesburg, South Africa':'SA',
 'New York City':'USAE',
 'México':'MX',
 '神奈川県':'JPN',
 'Phoenix, AZ':'USAM',
 'Minneapolis, MN':'USAE',
 'Illinois, USA':'USAC',
 'Colorado, USA':'USAM',
 'Vancouver, British Columbia':'CAW',
 'Republic of the Philippines':'PH',
 'Auckland, New Zealand':'NZ',
 'Istanbul':'TK',
 '大阪':'JPN',
 'Toronto, Canada':'CAE',
 'Edinburgh, Scotland':'UK',
 'Glasgow':'UK',
 'Columbus, OH':'USAE',
 'Málaga, España':'ES',
 'Cincinnati, OH':'USA',
 'Hyderabad, India':'IN',
 'Germany':'DE',
 'London, UK':'UK',
 'Bogotá, D.C., Colombia':'CO',
 'Cleveland, OH':'USAE',
 'Mexico':'MX',
 'Dublin, Ireland':'IE',
 'Michigan':'USAE',
 'İstanbul':"TK",
 'Connecticut, USA':'USAE',
 'Valencia':'ES',
 'France':'FR',
 'Ottawa, Ontario':'CAE',
 'Miami, FL':'USAE',
 'Valencia, España':'ES',
 'Chennai':'IN',
 'Sevilla, España':'ES',
 'Ohio':'USAE',
 'Raleigh, NC':'USAE',
 'Jamaica':'JAM',
 'Edmonton, Alberta':'CAM',
 'Arizona, USA':'USAM',
 'Madrid, España':'ES',
 'Minnesota, USA':'USAC',
 'Nairobi, Kenya':'KE',
 'Dublin City, Ireland':'IE',
 'Wisconsin, USA':'USAC',
 'Hong Kong':'HK',
 'San Antonio, TX':'USAC',
 'NJ':'USAE',
 'Florida':'USAE',
 'Edinburgh':'UK',
 'North West, England':'UK',
 'Milwaukee, WI':'USAC',
 'Boston':'USAE',
 'Kansas City, MO':'USAC',
 'Trinidad and Tobago':'TT',
 'Liverpool, England':'UK',
 'Brisbane, Queensland':'ASTL',
 'Thailand':'TH',
 'Louisville, KY':'USAE',
 'Georgia, USA':'USAE',
 'South East, England':'UK',
 'Buffalo, NY':'USAE',
 'Seattle':'USAW',
 '愛知県':'JPN',
 'she/they':'GENDER',
 'Birmingham, England':'UK',
 'Calgary, Alberta':'CAM',
 'Montevideo, Uruguay':'UR',
 'Catalunya':'CAT',
 'Minnesota':'USAC',
 'Cape Town, South Africa':'SA',
 'Indianapolis, IN':'USAE',
 'Leeds, England':'UK',
 'North Carolina':'USAE',
 'Massachusetts':'USAE',
 'Tennessee, USA':'USAE',
 'NY':'USAE',
 'Rochester, NY':'USAE',
 'Monterrey, Nuevo León':'MX',
 'Oregon, USA':'USAW',
 'Washington, USA':'USAW',
 'they/them':'GENDER',
 'Pune, India':'IN',
 'Winnipeg, Manitoba':'CAC',
 'İzmir, Türkiye':'TK',
 'Paris, France':'FR',
 'Indiana, USA':'USAE',
 'Queens, NY':'USAE',
 'Fort Worth, TX':'USAC',
 'Cork, Ireland':'IE',
 'Pennsylvania':'USAE',
 'Indiana':'USAE',
 'Zaragoza, España':'ES',
 'Wales, United Kingdom':'UK',
 'Detroit, MI':'USAE',
 'Tucson, AZ':'USAM',
 'Virginia':'USAE',
 'Dubai, United Arab Emirates':'UAE',
 'Colombia':'CO',
 'Taiwan':'TW',
 'New Delhi':'IN',
 'Cape Town':'SA',
 'Wisconsin':'USAC',
 'Sacramento, CA':'USAW',
 'La Plata, Argentina':'AR',
 'Costa Rica':'CR',
 'Rosario, Argentina':'AR',
 'Adelaide, South Australia':'ASTL',
 'Missouri, USA':'USAC',
 'Richmond, VA':'USAE',
 'South Carolina, USA':'USAE',
 'Vancouver, BC':'CAW',
 'San Francisco':'USAW',
 'Zaragoza':'ES',
 'Europe':'EUR',
 'St Louis, MO':'USAC',
 'Liverpool':'UK',
 'Córdoba, Argentina':'AR',
 'Türkiye':'TK',
 'Omaha, NE':'USAC',
 'tokyo':'JPN',
 'Montréal, Québec':'CAE',
 'istanbul':'TK',
 'Lagos, Nigeria':'NG',
 'Leeds':'UK',
 'Tampa, FL':'USAE',
 'British Columbia, Canada':'CAW',
 'New Orleans, LA':'USAC',
 'Southern California':'USAW',
 'Guatemala':'GUAT',
 'Madrid, Spain':'ES',
 'Durham, NC':'USAE',
 'Bilbao':'ES',
 'Illinois':'USAC',
 'San Jose, CA':'USAW',
 'SoCal':'USAW',
 'Philadelphia':'USAE',
 '大阪府':'JPN',
 'Tokyo-to, Japan':'JPN',
 'Málaga':'ES',
 'Manhattan, NY':'USAE',
 '関西':'JPN',
 'Somewhere':'CLEVER',
 '関東':'JPN',
 '神奈川':'JPN',
 'Hyderabad':'IN',
 'Maryland':'USAE',
 'Cairo, Egypt':'EG',
 'Iowa, USA':'USAC',
 'Atlanta':'USAE',
 'West Midlands, England':'UK',
 'Murcia, España':'ES',
 'Kuala Lumpur':'MY',
 'Halifax, Nova Scotia':'CAE',
 'madrid':'ES',
 'Oakland, CA':'USAW',
 'Alberta, Canada':'CAM',
 'Berlin, Germany':'DE',
 'Memphis, TN':'USAC',
 'Valencia, Spain':'ES',
 '横浜':'JPN',
 'Kentucky, USA':'USAE',
 'Turkey':'TK',
 'Newcastle Upon Tyne, England':'UK',
 'Sri Lanka':'SL',
 '北海道':'JPN',
 'Sheffield':'UK',
 'Wales':'UK',
 'Barcelona, Catalunya':'ES',
 'Malaga, Spain':"ES",
 'Bogotá':'CO',
 'Panama':'PA',
 'Essex':'UK',
 '千葉県':'JPN',
 'Mexico City':'MX',
 'Oregon':'USAW',
 'Manila, Philippines':'PH',
 'South West, England':'UK',
 'Johannesburg':'SA',
 'Georgia':'USAE', #COULD BE THE COUNTRY
 'Brisbane':'ASTL',
 'Comunidad de Madrid, España':'ES',
 'Uruguay':'UR',
 'Planet Earth':'Earth',
 'New England':'USAE',
 'Northern Ireland':'UK',
 'Long Beach, CA':'USAW',
 'Nottingham, England':'UK',
 'Brooklyn':'USAE',
 'Ankara, Türkiye':'TK',
 'Berlin':'DE',
 'New York, New York':'USAE',
 'Perth, Western Australia':'ASTL',
 'Jakarta':'ID',
 'Osaka':'JPN',
 'Pittsburgh':'USAE',
 'Asturias':'ES',
 'Deutschland':'DE',
 'TOKYO':'JPN',
 '千葉':'JPN',
 'Bogotá, Colombia':'CO',
 'Columbia, SC':'USAE',
 'Barcelona, Spain':'ES',
 'Italy':'EUR',
 'Here':'CLEVER',
 'NC':'USAE',
 'Murcia':'ES',
 'Colorado':'USAM',
 'Salamanca, España':'ES',
 'Gurgaon, India':'IN',
 'She/Her':'GENDER',
 'Vancouver':'CAW',
 'Birmingham':'UK',
 'North East, England':'UK',
 'Sheffield, England':'UK',
 'Brisbane, Australia':'ASTL',
 'Toronto, ON':'CAE',
 'Everywhere':'CLEVER',
 'Delhi':'IN',
 'CDMX':'MX', #CIUDAD MEXICO
 'Bristol':'UK',
 'Knoxville, TN':'USAC',
 'Queensland, Australia':'ASTL',
 '横浜市':'JPN',
 'JAPAN':'JPN',
 'Arkansas, USA':'USAC',
 'Lima, Perú':'PE',
 'Pakistan':'PK',
 'Wellington, New Zealand':'NZ',
 'Bronx, NY':'USAE',
 'New Hampshire, USA':'USAE',
 'Granada':'ES',
 '대한민국':'KOR',
 'He/Him':'GENDER',
 'Ottawa':'CAE',
 'Bay Area':'USAW',
 'Granada, Spain':'ES',
 'Washington, D.C.':'USAE',
 'The Netherlands':'EUR',
 'Bristol, England':'UK',
 'PA':'USAE', # OR IS IT PANAMA?
 'Lima, Peru':'PE',
 'Alexandria, VA':'CAW',
 '神奈川県横浜市':'JPN',
 'Bangkok':'TH',
 'Baltimore':'USAE',
 'Edmonton':'CAW',
 'Jacksonville, FL':'USAE',
 'Yokohama':'JPN',
 'Cardiff, Wales':'UK',
 'Caracas':'VE',
 'Baton Rouge, LA':'USAC',
 'Cardiff':'UK',
 'Victoria, Australia':'ASTL',
 'Maine, USA':'USAE',
 'カントー地方':'JPN',
 'Jakarta, Indonesia':'ID',
 'Karachi, Pakistan':'PK',
 'Tallahassee, FL':'USAE',
 'おふとん':'JPN', #FUTON. CLEVER?
 '埼玉':'JPN',
 'Bay Area: CA':'USAW',
 'Valladolid':'MX',
 'Arizona':'USAM',
 'Auckland':'NZ',
 'Birmingham, UK':'UK',
 'Hell':'CLEVER',
 'Trinidad':'TT',
 'Oklahoma City, OK':'USAC',
 'Kansas City':'USAC',
 'Santiago de Chile':'CL',
 'Albuquerque, NM':'USAM',
 'Israel':'IL',
 'Canberra':'ASTL',
 'Valladolid, España':'ES',
 'Kolkata, India':'IN',
 'Salt Lake City, UT':'USAM',
 'Panamá':'PA',
 '家':'JPN', #HOME. CLEVER?
 'She/her':'GENDER',
 'Bangalore, India':'IN',
 'Alexandria, Egypt':'EG',
 'Alabama':'USAC',
 'Almería, España':'ES',
 'Wellington City, New Zealand':'NZ',
 'Long Island, NY':'USAE',
 'Oklahoma, USA':'USAC',
 'Nova Scotia, Canada':'CAE',
 'nowhere':'CLEVER',
 'Yorkshire':'UK',
 'Arlington, VA':'USAE',
 'DMV':'CLEVER',
 'Birmingham, AL':'USAE',
 'Seoul':'KOR',
 'Madison, WI':'USAC',
 'Islamabad, Pakistan':'PK',
 'Venezuela':'VE',
 'Cantabria, España':'ES',
 'Paris':'FR',
 '京都':'JPN',
 'Bengaluru South, India':'IN',
 'Louisiana, USA':'USAC',
 'Tennessee':'USAC',
 'El Salvador':'ELSL',
 'Jersey City, NJ':'USAE',
 'Sevilla, Andalucía':'ES',
 'she/her ':'GENDER',
 'Pacific Northwest':'USAW',
 'Nottingham':'UK',
 'Tulsa, OK':'USAC',
 'Rosario':'AR',
 'Seoul, Republic of Korea':'KOR',
 'Brighton, England':'UK',
 'Alabama, USA':'USAE',
 'Community of Madrid, Spain':'ES',
 'Osaka, Japan':'JPN',
 'Oklahoma':'USAC',
 'Calgary, AB':'CAM',
 'Parts Unknown':'CLEVER',
 'Aotearoa':'NZ',
 'Nigeria':'NG',
 '自宅':'JPN', #MEANS HOME. CLEVER?
 'Austin, Texas': 'USAC',
 'Charleston, SC':'USAE',
 '埼玉県':'JPN',
 'Cleveland, Ohio':'USAE',
 'Berkeley, CA':'USAW',
 'Brasil':'BR',
 'TX':'USAC',
 'Las Vegas':'USAW',
 'Belfast, Northern Ireland':'UK',
 'Salamanca':'ES',
 'Lahore, Pakistan':'PK',
 'Asuncion, Paraguay':'PARA',
 'Anaheim, CA':'USAW',
 'South Carolina':'USAE',
 'Twitter':'CLEVER',
 'Adelaide, Australia':'ASTL',
 'Manila':'PH',
 'Malaga':'ES',
 'York, England':'UK',
 'Granada, España':'ES',
 'Chicagoland':'USAC',
 'japan':'JPN',
 'Ciudad de México':'MX',
 'Grand Rapids, MI':'USAE',
 'any pronouns':'GENDER',
 '地球':'JPN', #EARTH. CLEVER?
 'Utah, USA': 'USAM',
 'St. Louis':'USAC',
 '福岡県':'JPN',
 'chennai':'IN',
 'Toronto, Ontario, Canada':'CAE',
 'Lincoln, NE':'USAC',
 'Somerset':'UK',
 'Coimbatore, India':'IN',
 'Cincinnati':'USAE',
 'Galway, Ireland':'IE',
 'Ecuador':'EC',
 'argentina':'AR',
 'earth':'CLEVER',
 'Vitoria-Gasteiz':'ES',
 'Mendoza, Argentina':'AR',
 'Honolulu, HI':'HI',
 'Montreal':'CAE',
 'PNW':'USAW',
 '🇨🇦':'CA',
 'Medellín, Colombia':'CO',
 'Leicester':'UK',
 'Iowa':'USAC',
 'Aberdeen, Scotland':'UK',
 'Leicester, England':'UK',
 'he/they':'GENDER',
 'Columbus, Ohio':'USAE',
 'Santiago':'ES',
 '神奈川県川崎市':'JPN',
 'London, United Kingdom':'UK',
 'Paraguay':'PARA',
 'Norway':'EUR',
 'Jakarta Capital Region':'ID',
 'Belgium':'EUR',
 'Lexington, KY':'USAE',
 'Manchester, UK':'UK',
 'Kenya':'KE',
 'Murcia, Spain':'ES',
 'Valparaíso, Chile':'CL',
 'Dayton, OH':'USAE',
 'さいたま':'JPN',
 'Bombay':'IN',
 'Sweden':'EUR',
 'St. Louis, MO':'USAC',
 'CA':'CA',
 'Houston':'USAC',
 'Minneapolis':'USAC',
 'Southampton, England':'UK',
 '兵庫県':'JPN',
 'Belfast':'UK',
 'Hertfordshire':'UK',
 'Ankara':'TK',
 'Istanbul, Turkey':'TK',
 '名古屋':'JPN',
 'Nashville':'USAC',
 'Reno, NV':'USAW',
 'Guayaquil, Ecuador':'EC',
 'Alicante, Spain':'ES',
 'Boise, ID':'USAM',
 'ヒスイ地方':'JPN', #A PLACE IN POKEMON. CLEVER
 'Chattanooga, TN':'USAC',
 'Greensboro, NC':'USAE',
 'Des Moines, IA':'USA',
 'New Orleans':'USAC',
 'Orange County, CA':'USAW',
 'Winnipeg':'CAC',
 'Selangor, Malaysia':'MY',
 'Seoul, Korea':'KOR',
 'Adelaide':'ASTL',
 'Kent':'UK',
 'Staten Island, NY':'USAE',
 'Louisiana':'USAC',
 'uk':'UK',
 'Madrid ':'ES',
 'Cambridge, England':'UK',
 'San Diego':'USAW',
 'Mars':'CLEVER',
 'South Florida':'USAE',
 '大阪市':'JPN',
 'Oxford, England':'UK',
 'Hampshire':'UK',
 '札幌':'JPN',
 'Maine':'USAE',
 'Cincinnati, Ohio':'USAE',
 'Hamburg, Germany':'DE',
 'New Hampshire':'USAE',
 'Peru':'PE',
 'London, Ontario':'CAE',
 'Kuala Lumpur, Malaysia':'MY',
 'VA':'VA',
 'Quezon City':'PH',
 'おうち':'JPN', #HOUSE CLEVER
 'St Paul, MN':'USAC',
 'Tatooine':'CLEVER',
 'Dundee, Scotland':'UK',
 'Limerick, Ireland':'IE',
 'Global':'Earth',
 'Quezon City, Philippines':'PH',
 'Hogwarts':'CLEVER',
 '神戸':'JPN',
 'Providence, RI':'USAE',
 'Little Rock, AR':'USAC',
 'A Coruña':'ES',
 'Egypt':'EG',
 '愛知':'JPN',
 'Kuala Lumpur City':'MY',
 'Bahamas':'BA',
 'nyc':'USAE',
 'Calgary':'CAM',
 'here':'CLEVER',
 'Santiago de Compostela':'ES',
 'Delaware, USA':'USAE',
 'Greenville, SC':'USAE',
 '福岡':'JPN',
 'Northern Virginia':'USAE',
 'FL':'USAE',
 'Los Angeles, California':'USAW',
 'Tamil Nadu, India':'IN',
 'Norwich, England':'UK',
 'Indianapolis':'USAC',
 'Kansas, USA':'USAC',
 'Dallas, Texas':'USAC',
 'Stockholm, Sweden':'EUR',
 'Huelva, Spain':'ES',
 'Connecticut':'USAE',
 'Utah':'USAM',
 'everywhere':'CLEVER',
 'Lebanon':"LEBN",
 'Maldives':'MLDV',
 'Andalucía, España':'ES',
 'Asheville, NC':'USAE',
 'Galicia, España':'ES',
 'Seville, Spain':'ES',
 'Kentucky':'USAE',
 'Switzerland':"EUR",
 'Neverland':'CLEVER',
 'Tacoma, WA':'USAW',
 'Nowhere':'CLEVER',
 'Arlington, TX':'USAC',
 'Santa Cruz de Tenerife, Spain':'ES',
 'Huntsville, AL':'USAE',
 'Santa Monica, CA':'USAW',
 'Nairobi':'KE',
 '18':'CLEVER',
 'Pune':'IN',
 'Norman, OK':'USAC',
 'Spokane, WA':'USAW',
 'Guadalajara, Jalisco':'MX',
 'Worldwide':'Earth',
 'Pretoria, South Africa':'SA',
 'Hamilton, Ontario':'CAE',
 'Sao Paulo, Brazil':'BR',
 'Kuwait':'KZ',
 'Ottawa, Ontario, Canada':'CAE',
 'São Paulo':"BR",
 'Surrey':'UK',
 'PH':'PH', #PHILLIPINES
 'Yorkshire and The Humber':'UK',
 'Amsterdam, The Netherlands':'EUR',
 'South Dublin, Ireland':'IE',
 '日本 埼玉':'JPN',
 'Denver':'USAM',
 'Atlanta, Georgia':'USAE',
 'Bengaluru':'IN',
 '대한민국 서울':'KOR',
 'Philly':'USAE',
 'West Sussex':'UK',
 'Sioux Falls, SD':'USAC',
 'Christchurch City, New Zealand':'NZ',
 'los angeles':'USAW',
 'Italia':'EUR',
 'Wakanda':'CLEVER',
 'Mesa, AZ':'USAM',
 'ATL':'USAE', #ATLANTA
 'Bristol, UK':'UK',
 'Chesterfield, England':'UK',
 'La Plata':'AR',
 'San Francisco Bay Area':'USAW',
 'Mississauga, Ontario':'CAE',
 '広島':'JPN',
 'West Midlands':'UK',
 '日本 愛知':'JPN',
 'Rhode Island':'USAE',
 'Durban, South Africa':'SA',
 'Narnia':'CLEVER',
 '日本 大阪':'JPN',
 'Corunna, Galicia':'ES',
 'New South Wales, Australia':'ASTL',
 'Arkansas':'USAE',
 'St Petersburg, FL':'USAE',
 'Home':'CLEVER',
 'Honduras':'HO',
 'Oslo, Norway':'EUR',
 'Alicante, España':'ES',
 'london':'UK',
 'Vermont, USA':'USAE',
 'Mississippi, USA':'USAC',
 'Iowa City, IA':'USAC',
 'Caceres, Spain':'ES',
 'españa':'ES',
 'New Mexico, USA':'USAM',
 'Wichita, KS':'USAC',
 'Houston, Texas':'USAC',
 'Badalona':'ES',
 'El Paso, TX':'USAC',
 'Alicante':'ES',
 'Tokyo,Japan':'JPN',
 'Caracas, Venezuela':'VE',
 'Somewhere over the rainbow':'CLEVER',
 'Gotham City':'CLEVER',
 '北':'JPN', #NORTH. CLEVER? 
 'Azerbaijan':'AZR',
 'Bahrain':'BAHR',
 'Derbyshire':'UK',
 'Nepal':'NEP',
 'Aberdeen':'UK',
 'she/her 21':'GENDER',
 'Ponferrada, Spain':'ES',
 'Badajoz':'ES',
 'Cambridge, MA':'USAE',
 'Calgary, Alberta, Canada':'USAM',
 'Finland':'EUR',
 'Lima':'PE',
 'Jerez de la Frontera, España':'ES',
 'Lincoln, England':'UK',
 'Greece':'EUR',
 'DC':'USAE',
 'Winston-Salem, NC':'USAE',
 'Missouri':'USAC',
 'Barcelona, Cataluña':'ES',
 'Concepción, Chile':'CL',
 'Chandigarh, India':'IN',
 'Murcia, Región de Murcia':'ES',
 'Derby, England':"UK",
 'Hawaii, USA':'HI',
 'CT':'USAE',
 'Principado de Asturias, España':'ES',
 'Riyadh':'ZA', #I'VE BEEN USING SA FOR SOUTH AFRICA. ZA IS ACTUALLY SOUTH AFRICA'S. SWAPPIN.
 'Osaka-fu, Japan':'JPN',
 'Las Palmas de Gran Canaria':'ES',
 'Cymru':'UK',
 'Kanagawa, Japan':'JPN',
 'Kalamazoo, MI':'USAE',
 'Puebla, México':'MX',
 'Córdoba, España':'ES',
 'Accra, Ghana':'GHAN',
 '北海道 札幌市':'JPN',
 '布団の中':'JPN', #BED. CLEVER
 'Columbia, MD':'USAE',
 'Valladolid, Spain':'ES',
 'Kolkata':'IN',
 'Saragossa, Spain':'ES',
 'NorCal':'USAW',
 '試される大地':'JPN', #SOMETHING ABOUT THE EARTH. EARTH?
 'Behind you':'CLEVER',
 'South Jersey':'USAE',
 'Wien':'AT', #AUSTRIA
 'Lugo':'ES',
 'West Virginia, USA':'USAE',
 'Córdoba':'ES',
 'Christchurch, New Zealand':'NZ',
 'そのへん':'JPN', #'THAT STRANGE'? CLEVER?
 'Noida, India':'IN',
 'Bogota':'CO',
 'North Yorkshire':'UK',
 'Kansas':'USAE',
 'Bandung, Indonesia':'ID',
 'Dubai':'UAE',
 'Inverness, Scotland':'UK',
 'Mar del Plata, Argentina':'AR',
 'Yokohama, Japan':'JPN',
 'Wonderland':'CLEVER',
 'LA':'USAW',
 'Elche':'ES',
 'Saitama, Japan':'JPN',
 'A Coruña, España':'ES',
 'Evansville, IN':'USAE',
 'Brazil':'BR',
 'Newfoundland and Labrador':'CAE',
 'Jersey':'USAE',
 'South Australia':'ASTL',
 'Bolivia':'BO',
 'ohio':'USAE',
 'sevilla':'ES',
 'Sarasota, FL':'USAE',
 'Lagos':'NG',
 'Cairo':'EG',
 'Cornwall':'UK',
 'Baltimore, Maryland':'USAE',
 'Kyoto':'JPN',
 'Brighton':'UK',
 'Gijón, España':'ES',
 'Wadawurrung Country':'ASTL', #THE ISLAND
 'Taipei City, Taiwan':'TW',
 'Athens, GA':'USAE',
 'South Korea':'KOR',
 '🌎':'Earth',
 'Green Bay, WI':'USAC',
 'hell':'CLEVER',
 'República Catalana':'CAT',
 'Fort Lauderdale, FL':'USAE',
 'Boulder, CO':'USAM',
 'Taichung, Taiwan':'TW',
 '岐阜':'JPN',
 'Belgrade, Republic of Serbia':'RS', #THAT'S THE ABBREVIATION
 '🌌':'CLEVER',
 '田舎':'JPN', #"RURAL AREA" CLEVER
 'india':'IN',
 'Comunidad Valenciana, España':'ES',
 'Jakarta Selatan, DKI Jakarta':'ID',
 'Bursa, Türkiye':'TK',
 'Washington DC':'USAE',
 'Puerto Rico, USA':'USAE',
 'Ile-de-France, France':'FR',
 'Perú':'PE',
 'Goa, India':'IN',
 'Navi Mumbai, India':'IN',
 'valencia':'ES',
 'Newcastle upon Tyne':'UK',
 'Regina, Saskatchewan':'CAM',
 'somewhere':'CLEVER',
 '虚無':'JPN', #NIHILISM
 'Russia':'RU', 
 'Antarctica':'AT', #POSSIBLY CLEVER, BUT I'M GOING WITH IT
 'Sydney Australia':'ASTL',
 'Vienna, Austria':'AT',
 '日本 ':'JPN',
 'Newcastle':'UK',
 'Worcester, MA':'USAE',
 'Charlottesville, VA':'USAE',
 'South Wales':'UK',
 'Kuala Lumpur Federal Territory':'MY',
 'Antalya, Türkiye':'TK',
 'JPN':'JPN',
 'Yorkshire and The Humber, Engl':'UK',
 'Oviedo':'ES',
 'Vitoria-Gasteiz, Euskadi':'ES', #LOCATION, NOT POLITICAL
 'U.K.':'UK',
 'she/her 19':'GENDER',
 'Lusaka, Zambia':'ZM',
 'Redmond, WA':'USAW',
 'Shropshire':'UK',
 'Badajoz, España':'ES',
 '京都市':'JPN',
 'philippines':'PH',
 'Lincolnshire':'UK',
 'Málaga, Andalucía':'ES',
 'Andalusia, Spain':'ES',
 'Nebraska, USA':'USAC',
 'Mar del Plata':'ES',
 'Fayetteville, AR':'USAC',
 'Anchorage, AK':'AK',
 '九州':'JPN',
 'Vancouver, Canada':'CAW', #CLAW CLAW MEOWTHER~~~~~~
 'Edmonton, AB':'CAM',
 'South Dakota, USA':'USAC',
 'Devon':'UK',
 'Virginia Beach, VA':'USAE',
 'Cleveland':'USAE',
 'Amsterdam':'EUR',
 '都内':'JPN',
 'they/she':'GENDER',
 'Burbank, CA':'USAW',
 'new york':'USAE',
 'Topeka, KS':'USAC',
 'Wirral':'UK',
 'Melbourne, Victoria, Australia':'ASTL',
 'Québec, Canada':'CAE',
 'US':'USA',
 'Bellingham, WA':'USAW',
 'Durham, UK':'UK',
 'とうきょう':'JPN',
 'Portugal':'PT',
 'Salamanca, Spain':'ES',
 '🌍':'Earth',
 'Burnaby, British Columbia':'CAW',
 'Cary, NC':'USAE',
 '127.0.0.1':'CLEVER', #LOCALHOST
 'Fukuoka':'JPN',
 'Silver Spring, MD':'USAE',
 'NZ':'NZ',
 'Milwaukee':'USAC',
 'Gainesville, FL':'USAE',
 'Miami':'USAE',
 'Madrid (España)':'ES',
 'Worthing, England':'UK',
 'Canada ':'CA',
 'Galiza':'ES', #LOCATION
 '犬小屋':'JPN', #CLEVER -- DOG HOUSE
 'Lancashire':'UK',
 'Stillwater, OK':'USAC',
 '.':None,
 'Ontario':'CAE',
 'He/him':'GENDER',
 'Los Angeles ':'USAW',
 'Kingston, Jamaica':'JAM',
 'Albany, NY':'USAE',
 'Kent, UK':'UK',
 'Northern California':'USAW',
 'Montevideo':'UR',
 'Upstate NY':'USAE',
 'East, England':'UK',
 'Silicon Valley':'USAW',
 'Reading, England':'UK',
 'New Brunswick, Canada':'CAE',
 'Milton Keynes':'UK',
 'HTX':'USAC', #HOUSTON TX
 'Cheshire':'UK',
 'San José, Costa Rica':'CR',
 'Tempe, AZ':'USAM',
 'Santa Coloma de Gramenet, Espa':'ES',
 'ちば':'JPN',
 'Chandler, AZ':'USAM',
 'Norwich':'UK',
 'Fife, Scotland':'UK',
 'Recoleta, Chile':'CL',
 'Alpharetta, GA':'USAE',
 '成人済':'JPN', #'ADULT' CLEVER?
 'Decatur, GA':'USAE',
 'Santa Clara, CA':'USAW',
 'America':'USA',
 'Elche, España':'ES',
 'Melbourne Australia':'ASTL',
 'にぽん。いろしま・もなむー':'JPN',
 'Wiltshire':'UK',
 'El mundo':'Earth', #the earth.
 'León, España':'ES',
 'iPhone: 0.000000,0.000000':'CLEVER',
 'SF Bay Area':'USAW',
 'Antalya, Turkey':'TK',
 'Wicklow, Ireland':'IE',
 'Norfolk, VA':'USAE',
 'Toledo, OH':'USAE',
 'México, D.F.':'MX',
 '実家':'JPN', #CLEVER, PARENTS HOUSE
 'East Midlands, England':'UK',
 '東京都新宿区':'JPN', #SHINJUKU
 'Netherlands':'EUR',
 '東京都中央区':'JPN',
 'Oxfordshire':'UK',
 'Riverside, CA':'USAW',
 'North London':'UK',
 'Midwest':'USAC',
 '愛知 名古屋市':'JPN',
 'Kobe':'JPN',
 'Almería, Spain':'ES',
 'Alcorcón, Spain':'ES',
 'Syracuse, NY':'USAE',
 'Tucson, Arizona':'USAM',
 'Quilmes, Argentina':'AR',
 'さいたま市':'JPN',
 'Halifax':'CAE',
 'Chapel Hill, NC':'USAE',
 'indonesia':'ID',
 'canada':'CA',
 'Newcastle Upon Tyne':'UK',
 'St. Catharines, Ontario':'CAE',
 'Montclair, NJ':'USAE',
 '北関東':'JPN',
 '🇵🇭':'PH',
 '修羅の国':'JPN', #CLEVER, 'FIST OF THE NORTH STAR' NINTENDO GAME COUNTRY
 'Durham, England':'UK',
 'Buckinghamshire':'UK',
 'Bodrum, Türkiye':'UK',
 'Calapan | Manila | Pasig':'PH',
 'MD':'USAE',
 'Oakville, Ontario':'CAE',
 'Bath':'UK',
 'Guadalajara':'MX',
 'Charleston, WV':'USAE',
 'Ghana':'GH',
 'chicago':'USAC',
 '東京都江東区':'JPN',
 'Columbia, MO':'USAC',
 'Newark, DE':'USAE',
 'Plano, TX':'USAC',
 'Gran Canaria':'ES',
 '20':'CLEVER', #AGE?
 'Washington State':'USAW',
 'Hampshire, UK':'UK',
 'Scottsdale, AZ':'USAM',
 'Miami, Florida':'USAE',
 'Kent, England':'UK',
 'Peterborough, England':'UK',
 'Ottawa, Canada':'CAE',
 'CABA':'AR',
 '🇺🇸':'USA',
 'Fresno, CA':'USAW',
 'Murfreesboro, TN':'USAC',
 'Lucknow, India':'IN',
 'La Paz - Bolivia':'BO',
 'Northampton':'UK',
 'Las Palmas de Gran Canaria, Es':'ES',
 '狭間の地':'JPN',
 'AZ':'USAM',
 'よこはま':'JPN',
 'El Puerto de Santa María':'ES',
 'KCMO':'USAC',
 'United States of America':'USA',
 'Western Australia, Australia':'ASTL',
 'Huesca':'ES',
 'Bakersfield, CA':'USAW',
 'KWANGYA':'KOR',
 'Ann Arbor, MI':'USAE',
 'Milano':'EUR',
 'Puerto Rico':'PR',
 'Perth, Australia':'ASTL',  #I KNOW, IT'S WESTERN AUSTRALIA
 'Avilés':'ES',
 'Wigan, England':'UK',
 'Hobart, Tasmania':'ASTL',
 'Tampa':'USAE',
 'Auckland, NZ':'NZ',
 'Saskatchewan, Canada':'CA',
 'Princeton, NJ':'USAE',
 'Indy':'USAE',
 'Long Island, New York':'USAE',
 'Portland, ME':'USAE',
 'Colchester, England':'UK',
 'Southampton':'UK',
 'Cádiz, España':'ES',
 'Terrassa':'ES',
 'Copenhagen, Denmark':'EUR',
 'Akron, OH':'USAE',
 'Surprise, AZ':'USAM',
 'Cáceres':'ES',
 'Earth ':'Earth',
 'Nook Inc. 보물쥐도':'KOR',
 'Canberra, Australia':'ASTL',
 'Kawasaki':'JPN',
 'Newfoundland, Canada':'CAE',
 '岐阜県':'JPN',
 'Fukuoka, Japan':'JPN',
 '東京 渋谷区':'JPN',
 'North Wales':'UK',
 'Ahmedabad':"IN",
 'Kingston, Ontario':'CAE',
 'Jaipur, India':'IN',
 'Cyprus':'EUR',
 'Toronto ':'CAE',
 'Tokyo Japan':'JPN',
 'Shanghai':'', #IS THIS THE FIRST CHINA?
 'Delhi, India':'IN',
 'Irvine, CA':'USAW',
 'Milton Keynes, England':'UK',
}
#OK, THAT'S ENOUGH

# %%
#export as json for use elsewhere

filename = 'loc_dict.json'
filepath = './'


with open(filepath+filename, 'w') as file:
    file.write(json.dumps(locations))

# %%
#read from the file to test it out
with open(filepath+filename, 'r') as file:
    test_dict = json.loads(file.read())
    
#test it
test_dict['United Kingdom']
# Out:
# 'UK'
